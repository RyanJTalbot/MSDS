#  0.42628041 0.43042699 0.43087762 0.44845373 0.48052678 0.4930695
#  0.51689002 0.52025565 0.55357745 0.77567315]

# %%
plt.plot(x, y, 'o')

# %%
x = np.arange(100)
y = x**3
plt.plot(y, '1')

# %%
markers = ['o', '*', '.', ',', 'x', 'X', '+', 'P', 's', 'D', 'd', 'p', 'H', 'h', 'v', '^', '<', '>', '1', '2', '3', '4', '|', '_']

for m in markers:
  print(m)
  plt.plot(y, m)
  plt.show()
# Out:
# o
# *
# .
# ,
# x
# X
# +
# P
# s
# D
# d
# p
# H
# h
# v
# ^
# <
# >
# 1
# 2
# 3
# 4
# |
# _

# %%
y = np.array([1, 3, 13])
line = ['-',':','--','-.']
for l in line:
  print(l)
  l = 'o' + l + 'r'
  plt.plot(y, l)
  plt.show()
# Out:
# -
# :
# --
# -.

# %%
color = ['r','g','b','c','m','y','k','w']
for c in color:
  print(c)
  c = 'o:' + c
  plt.plot(y, c)
  plt.show()
# Out:
# r
# g
# b
# c
# m
# y
# k
# w

# %%
plt.plot(y, marker = '^', ms = 30)

# %%
x = np.arange(10)
y1 = x*2
y2 = x**2
plt.plot(y1)
plt.plot(y2)

# %%
plt.plot(x, y1)
plt.plot(x, y2)

# %%
plt.plot(x, y1, label = 'double')
plt.plot(x, y2, label = 'square')
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.grid()
plt.legend(['1st', '2nd'])

# %%
plt.subplot(2, 1, 1)
plt.plot(x, y1, label = 'double')
plt.legend()
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.subplot(2, 1, 2)
plt.plot(x, y2, label = 'square')
plt.legend()
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.grid()

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y1, label = 'double')
plt.legend()
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.subplot(1, 2, 2)
plt.plot(x, y2, label = 'square')
plt.legend()
plt.xlabel("Xs")
plt.ylabel("Ys")
plt.grid()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.plot(x, y, 'o')

# %%
plt.scatter(x, y)

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='hot')

plt.colorbar()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

# %%
plt.scatter(x, y, c = colors, cmap = 'hot', alpha = 0.5, s = sizes)
plt.colorbar()

# %%
plt.bar(x, y)
# Out:
# <BarContainer object of 13 artists>

# %%
plt.hist(x)
# Out:
# (array([2., 1., 2., 2., 3., 0., 2., 0., 0., 1.]),
#  array([ 2. ,  3.5,  5. ,  6.5,  8. ,  9.5, 11. , 12.5, 14. , 15.5, 17. ]),
#  <a list of 10 Patch objects>)

# %%
x = [0.66, 0.25, 0.09]
plt.pie(x, labels = ['2/3', '1/5', 'others'])
plt.legend()

# %%
x = [0.66, 0.25, 0.09]
plt.pie(x, labels = ['2/3', '1/5', 'others'], explode = [0.0, 0.2, 0])
plt.legend()

# %%
x = np.arange(10)
alpha = (x+1)**2/2
delta = (x+2)**2
omicron = (x+3)**2 * 3

plt.plot(x, alpha, label = "Alpha")
plt.plot(x, delta, label = "Delta")
plt.plot(x, omicron, label = "Omicron")
plt.legend()

# %% [markdown]
# # Practice

# %%
file = '/content/sample_data/california_housing_train.csv'
df = pd.read_csv(file)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17000 entries, 0 to 16999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           17000 non-null  float64
#  1   latitude            17000 non-null  float64
#  2   housing_median_age  17000 non-null  float64
#  3   total_rooms         17000 non-null  float64
#  4   total_bedrooms      17000 non-null  float64
#  5   population          17000 non-null  float64
#  6   households          17000 non-null  float64
#  7   median_income       17000 non-null  float64
#  8   median_house_value  17000 non-null  float64
# dtypes: float64(9)
# memory usage: 1.2 MB

# %%
# play with this dataset using the plots we learned so far
