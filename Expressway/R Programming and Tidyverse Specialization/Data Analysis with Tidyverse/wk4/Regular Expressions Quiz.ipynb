# %%
from IPython.display import Image
Image(filename="images/regx1.png")

# %%
Image(filename="images/regx2.png")

# %%
Image(filename="images/regx3.png")

# %%
Image(filename="images/regx4.png")

# %%
Image(filename="images/regx5.png")
