# %% [markdown]
# # About the Final Project
#
# You may drop or withdraw from this course at any time before you have accessed the proctored course exam. Once you have accessed the exam, you will be assigned a course grade according to the announced grading formula; this grade will appear on your university transcript after the eight-week session has concluded. After the two hours of the timed proctored course exam are over, you will not be able to change or re-take the proctored course exam. However, you may continue to make homework assignment submissions until the conclusion of the eight-week session.
#
# # Part One: Cyber Attack Memo
#
# For this assignment,  you will create a one page memo. Please note that his memo must look professional.  The layout and readability of your memo WILL make a difference in responding to scenarios like those listed below.  In your memo, make sure to address the content below with a final product that conveys your message in a clear and concise way that is also aesthetically pleasing to the eye.   Please review the videos in this lesson and the reading items to prepare for your final project.
# Select one (and only one!) of the following scenarios
#
# - <b>Scenario 1: You are a senior leader of the World Health Organization.  You must produce a memo and public service announcement in response to this actual incident.</b>
#
# - Scenario 2: You are a senior leader in the U.S. Department of Health and Human Services (HHS).  You must produce a memo and public service announcement in response to this actual incident.
#
# - Scenario 3: You are a senior leader at a medical research lab.  You must produce a memo and public service announcement in response to this actual incident.
#
# - Scenario 4: You are a senior leader at a large hospital chain.  You must produce a memo and public service announcement in response to this actual incident.
#
# - Scenario 5: You are a senior leader in the Italian Government.  You must produce a memo and public service announcement in response to this actual incident.
#
# This memo addresses the cyber attack and considers the following
#
# - Social/Emotional Impact
#
# - Cultural implications
#
# - Technical awareness and safeguards
#
# - Future proofing
#
# - Policy moving forward to help prevent future instances
#
# - NOTE: Be aware of our current environment in this remote world.  Dealing with this attack must be done with this aspect in mind. How do we get the message out in a clear and concise way?  Which technology tools and modalities do we leverage to disseminate
#
# # Part Two: Cyber Attack Memo
#
# For this assignment you will create a 3 minute PSA using Flipgrid as a response tool.   Your PSA will address the cybersecurity incident.
# The PSA addresses the cyber attack and considers the following
#
# - Social/Emotional Impact
#
# - Cultural implications
#
# - Technical awareness and safeguards
#
# - Future proofing
#
# - Policy moving forward to help prevent future instances
#
# - NOTE: Be aware of our current environment in this remote world.  Dealing with this attack must be done with this aspect in mind. How do we get the message out in a clear and concise way?  Which technology tools and modalities do we leverage to disseminate information?
#
# Record your PSA via the Flipgrid link below
#
#     https://flipgrid.com/e9e48305
#
# Drops, Refunds, and Withdrawals
#
# You may drop this course with a 100% refund within 14 days of your class start date or your enrollment date (whichever is later) as long as long as you have not accessed restricted content (e.g., password quiz, honor code verification, final exam/project, etc.) or received a grade. When a course is dropped under these conditions, it will not appear on your record.  You can withdraw after the 14 days as long as you have not accessed restricted content or received a grade. When a student withdraws under these conditions, they will receive a grade of W on their academic record. Visit the CU Boulder Registrar's Special Programs page to learn more and complete the required forms.

# %% [markdown]
# # Part One:
#
# [Your Name]
# [Your Title]
# [Your Department]
# [Today's Date]
#
# **MEMORANDUM**
#
# **To:** [Recipient's Name]
# **From:** [Your Name]
# **Date:** [Today's Date]
# **Subject:** Addressing the Cyber Attack on the World Health Organization
#
# In light of the recent cyber attack on the World Health Organization (WHO), this memo aims to address various aspects related to the incident and outline steps to prevent future occurrences. It is crucial that we consider not only the technical safeguards but also the social and emotional impact, cultural implications, and future-proofing of our organization.
#
# **1. Social/Emotional Impact:**
# The cyber attack on WHO during a global pandemic is not only reprehensible but also carries significant social and emotional implications. Staff morale may be affected, and the public's trust in our organization might be shaken. It is essential to acknowledge and address these concerns promptly and transparently.
#
# **2. Cultural Implications:**
# Cultural implications are substantial, given the international nature of the WHO. The attack highlights the need for a unified global approach to cybersecurity. Cooperation among nations and international organizations is vital to combat cyber threats effectively.
#
# **3. Technical Awareness and Safeguards:**
# a. In response to the attack, we must review and strengthen our technical safeguards. This includes enhancing our intrusion detection systems, regularly updating security software, and conducting comprehensive staff training on cybersecurity best practices.
# b. Engaging cybersecurity experts and volunteers, as mentioned in the article, could provide an additional layer of defense. Collaborating with organizations that offer assistance to healthcare entities will bolster our security posture.
#
# **4. Future-Proofing:**
# a. The rapidly evolving cyber threat landscape necessitates future-proofing our security measures. This involves staying updated with emerging threats and technologies, adapting to new attack vectors, and implementing proactive measures to mitigate risks.
# b. We must invest in cutting-edge technologies and engage in partnerships with technology companies to ensure a resilient cybersecurity framework.
#
# **5. Policy Moving Forward:**
# We should establish a clear cybersecurity policy moving forward. This policy should encompass:
# a. Reporting procedures for potential cyber threats.
# b. Regular security audits and assessments.
# c. Collaboration with international cybersecurity organizations and law enforcement agencies.
# d. A crisis communication plan to address cyber incidents transparently.
# e. A mechanism to engage volunteers and experts to bolster our defenses.
#
# **6. Communication Strategies:**
# In this remote work environment, our communication strategies must adapt. We should leverage various technology tools and modalities to disseminate information effectively. This may include regular updates via secure communication channels, webinars, and awareness campaigns to ensure that all staff members are well-informed about the cyber threats and preventive measures.
#
# In conclusion, the cyber attack on WHO underscores the urgency of reinforcing our cybersecurity measures and adopting a comprehensive approach to ensure the organization's resilience. By addressing the social and emotional impact, cultural implications, technical safeguards, future-proofing, and effective policies, we can protect the WHO's mission and reputation. Our ability to adapt to the changing cybersecurity landscape will be vital in ensuring a safer and more secure future.
#
# For any further information or discussions, please feel free to reach out.
#
# Sincerely,
#
# [Your Name]
# [Your Contact Information]

# %% [markdown]
# # Part Two:
#
# Title: Analysis of Cybersecurity Incident Impacting the World Health Organization
#
# **Abstract:**
# This report provides a comprehensive analysis of the recent cyber attack on the World Health Organization (WHO). The incident is examined from various angles, including its social and emotional impact, cultural implications, technical awareness and safeguards, future-proofing strategies, and recommended policies to prevent future instances. The report also highlights the challenges posed by the current remote working environment and the technology tools and modalities that can be leveraged for effective dissemination of information.
#
# **1. Introduction:**
# The cyber attack on the World Health Organization (WHO) during the COVID-19 pandemic raises significant concerns about the impact of such incidents on global health organizations. This report delves into the multifaceted aspects of the attack, aiming to provide a holistic understanding of its implications.
#
# **2. Social/Emotional Impact:**
# The attack has had a pronounced social and emotional impact, affecting both WHO staff and the general public. Staff morale has been adversely affected, and trust in the organization has eroded. These repercussions emphasize the importance of addressing the psychological aspects of cybersecurity incidents.
#
# **3. Cultural Implications:**
# The cultural implications of the attack extend to the international stage. The attack underscores the necessity for international collaboration in cybersecurity efforts. A unified global response is essential to counter cyber threats effectively.
#
# **4. Technical Awareness and Safeguards:**
# The technical aspect of the attack necessitates a detailed review of existing safeguards. Measures such as intrusion detection system enhancement, regular security software updates, and comprehensive staff training are essential components of an effective response. Collaboration with cybersecurity experts and volunteers further bolsters technical defenses.
#
# **5. Future-Proofing:**
# The rapidly evolving cyber threat landscape requires a proactive approach to future-proofing. Organizations must adapt to emerging threats, invest in cutting-edge technologies, and implement strategies to mitigate evolving risks. Adapting to new attack vectors is paramount for long-term security.
#
# **6. Policy Moving Forward:**
# Developing a coherent cybersecurity policy moving forward is crucial. Such a policy should include clear procedures for reporting cyber threats, regular security audits, international cooperation, crisis communication planning, and mechanisms for engaging volunteers and experts in cybersecurity defense.
#
# **7. Communication Strategies:**
# In a remote work environment, effective communication strategies are indispensable. Utilizing technology tools and modalities is essential for disseminating information promptly. Secure communication channels, webinars, and awareness campaigns are key components of this approach.
#
# **8. Conclusion:**
# The cyber attack on the WHO serves as a stark reminder of the urgency to strengthen cybersecurity measures for critical organizations. Addressing the social and emotional impact, cultural implications, technical safeguards, future-proofing strategies, and sound policies is vital to protect an organization's mission and reputation.
#
# **9. Recommendations:**
# - Encourage international cooperation in cybersecurity efforts.
# - Invest in advanced technologies and proactive risk mitigation.
# - Develop and implement a comprehensive cybersecurity policy.
# - Leverage technology tools for effective communication in remote work environments.
#
# **10. Future Work:**
# Future research should focus on the long-term implications of cyber attacks on international organizations, including the development of standardized cybersecurity practices and policies.
#
# **References:**
# [Provide a list of relevant sources and citations.]
#
# This report offers a comprehensive understanding of the recent cyber attack on the WHO and its far-reaching implications. By addressing the identified aspects and implementing the recommended measures, organizations can better protect themselves in an increasingly digital and interconnected world.
