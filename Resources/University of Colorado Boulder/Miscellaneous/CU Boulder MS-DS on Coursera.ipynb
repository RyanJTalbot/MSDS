# %%
from IPython.display import Image
Image(filename="images/cu3.png")

# %% [markdown]
# # Courses

# %%
Image(filename="images/cu2.png")

# %%
Image(filename="images/cu1.png")

# %% [markdown]
# ---

# %% [markdown]
# ## Shows 3 courses, despite only 1 course currently available

# %%
Image(filename="images/cu4.png")

# %% [markdown]
# ---

# %%
Image(filename="images/cu5.png")

# %%
Image(filename="images/ibm1.png")

# %%
Image(filename="images/ibm2.png")

# %%
Image(filename="images/ibm3.png")

# %% [markdown]
# ----

# %% [markdown]
# ## Shows only 2 courses - in coursera its 1 course with 4 lessons

# %%
Image(filename="images/cu6.png")

# %% [markdown]
# ---

# %% [markdown]
# ## Shows that last course is elective

# %%
Image(filename="images/cu7.png")
