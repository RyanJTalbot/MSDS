# %%
from IPython.display import Image
Image(filename="images/cp1.png")

# %%
Image(filename="images/cp2.png")

# %%
Image(filename="images/cp3.png")

# %%
Image(filename="images/cp4.png")

# %%
Image(filename="images/cp5.png")
