# %%
from IPython.display import Image
Image(filename="images/fc1.png")

# %%
Image(filename="images/fc2.png")

# %%
Image(filename="images/fc3.png")

# %%
Image(filename="images/fc4.png")

# %%
Image(filename="images/fc5.png")

# %%
Image(filename="images/fc6.png")
