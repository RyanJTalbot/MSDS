# %%
from IPython.display import Image
Image(filename="images/af1.png")

# %%
Image(filename="images/af2.png")

# %%
Image(filename="images/af3.png")

# %%
Image(filename="images/af4.png")

# %%
Image(filename="images/af5.png")

# %%
Image(filename="images/af6.png")

# %%
Image(filename="images/af7.png")
