# %%
# !wget http://128.138.93.164/reviews_Clothing_Shoes_and_Jewelry.json.gz -P /content/drive/MyDrive/MSDS_marketing_text_analytics/master_files/2_topic_modeling
# Out:
# --2022-01-07 18:52:04--  http://128.138.93.164/reviews_Clothing_Shoes_and_Jewelry.json.gz
# Connecting to 128.138.93.164:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 888065454 (847M) [application/octet-stream]
# Saving to: ‘/content/drive/MyDrive/MSDS_marketing_text_analytics/master_files/2_topic_modeling/reviews_Clothing_Shoes_and_Jewelry.json.gz’
#
#             reviews  58%[==========>         ] 492.35M  44.4MB/s    eta 10s    ^C

# %%
# !gzip -d /content/drive/MyDrive/MSDS_marketing_text_analytics/master_files/2_topic_modeling/reviews_Clothing_Shoes_and_Jewelry.json.gz
# Out:
# gzip: /content/drive/MyDrive/MSDS_marketing_text_analytics/master_files/2_topic_modeling/reviews_Clothing_Shoes_and_Jewelry.json already exists; do you wish to overwrite (y or n)? ^C

# %%
import pickle
import json
from time import sleep

##this assigns the filename we're trying to load in to a string variable
working_directory = '/content/drive/MyDrive/MSDS_marketing_text_analytics/master_files/2_topic_modeling'
working_file = '%s/reviews_Clothing_Shoes_and_Jewelry.json' % working_directory
loadedjson = open(working_file, 'r')

# %%
#Step 2 - Parsing the review data
#Let's load the review data into a dictionary. It's the exact same process
#as loading the review data
count = 0
allreviews = {}
for aline in loadedjson:
   count += 1
   if count % 100000 == 0:
       print(count)
   areview = eval(aline)
#    #I'm arbitrarily using the iteration count as the key for the dictionary
#    #but you don't have to do this
   allreviews[count] = areview
   
#how many reviews do we have?
print(len(allreviews))
#
# Out:
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 2500000
# 2600000
# 2700000
# 2800000
# 2900000
# 3000000
# 3100000
# 3200000
# 3300000
# 3400000
# 3500000
# 3600000
# 3700000
# 3800000
# 3900000
# 4000000
# 4100000
# 4200000
# 4300000
# 4400000
# 4500000
# 4600000
# 4700000
# 4800000
# 4900000
# 5000000
# 5100000
# 5200000
# 5300000
# 5400000
# 5500000
# 5600000
# 5700000
# 5748920

# %%
#Now, we need to go through all the reviews and pick out the reviews that
#correspond to the matching ASINs, that is reviews that are tied to Nike ASINs

allnikeasins = []

for data in open('%s/allasins.txt' % working_directory, 'r'):
  asins = data.split(',')
  for anasin in asins:
    allnikeasins.append(anasin)
print(allnikeasins)
# Out:
# ['B0051JYF24', 'B0058LD7Y2', 'B00AEXXHL2', 'B00AQJUK6E', 'B004ZHJGIQ', 'B006ISBN1I', 'B000E8F2YC', 'B00ACOG6BQ', 'B005OAYJAI', 'B0058T9OQ4', 'B00AMU099A', 'B0059S3RZI', 'B007I7CR40', 'B001GUKBD4', 'B004X5U4YU', 'B00CHSCHC2', 'B000E8F292', 'B00AAJ9N54', 'B0058XS0AG', 'B007Q1J7N2', 'B005PQZH7U', 'B0059D3IJ8', 'B00HHJC27Q', 'B004Y91UGG', 'B00ATRDAJW', 'B00HK0EJEQ', 'B00K34M13M', 'B00019FWE4', 'B006U4S8I6', 'B0053HC6T8', 'B001UM8DVU', 'B008P048IW', 'B00AMUG4I0', 'B0007SMKOY', 'B009D4GNUK', 'B008FQI2MO', 'B009YRSY9Y', 'B005O54LCE', 'B006MLNIKK', 'B0059D6246', 'B006H6B6RW', 'B004VLG8UU', 'B00HGSUZWC', 'B0058Z1MTU', 'B008L3EKRC', 'B00BLT5UJ0', 'B007IJ0RN6', 'B009D4YC1W', 'B00J2JODHQ', 'B00CZD82ZA', 'B002N2R3QC', 'B009SMVWR6', 'B009CC9PGC', 'B005OAZPDS', 'B007LO1H6Y', 'B00AOASM4C', 'B00ASPZAES', 'B004V4Z0ZG', 'B00AMU1Z2K', 'B00596CQ0W', 'B008KQS63Y', 'B00AMU0CAG', 'B007WI4YPK', 'B008D3V9TM', 'B00EQE0XSK', 'B0050LCNUY', 'B004HLL69C', 'B00AMU0TM2', 'B00AMUG9A
D60', 'B0010WDTVO', 'B00FENTGEY', 'B00305M1VS', 'B000A8BTPM', 'B003Z2GG30', 'B006K1AM7O', 'B00DTZCHDQ', 'B00F3J3F14', 'B006OP2BI4', 'B00E0ELEC0', 'B00GWTGUPW', 'B000IJOZPE', 'B00AMU27H2', 'B004LBHTIU', 'B002TS90CK', 'B006O3N2B6', 'B00A832XH2', 'B0027T2XAW', 'B00DT7D1V6', 'B0048907W0', 'B005Z3TMGA', 'B008F065A6', 'B008EMDDP0', 'B006ITGCV8', 'B000E8J4OQ', 'B000ARDNNE', 'B004Y8B8LO', 'B00HFTJ1NQ', 'B003JJ72HS', 'B0058XS7KO', 'B00FN8EKVO', 'B00HY17RMW', 'B003ZTDFLY', 'B00EA3O1D0', 'B009D00332', 'B0037A0XEI', 'B007N30O1M', 'B00CG5OWUQ', 'B00596AKDC', 'B00B40COKO', 'B00AMTZYVY', 'B00C40W3DQ', 'B00B51OX06', 'B005GXNBDO', 'B00HQMAG3G', 'B008YZE9S2', 'B005968HU0', 'B0098T374U', 'B0040HQFHQ', 'B00HDZ5KTQ', 'B007MH6MZQ', 'B00IOAK06M', 'B008D45OL0', 'B00C497QMK', 'B00D8QMZTW', 'B004I5GGM4', 'B003V488EM', 'B009CZ72TQ', 'B00CZDT7ZY', 'B00DBKN97C', 'B0060RZAJS', 'B007WMC87C', 'B004IBVYWU', 'B00CJ06T ...

# %%
len(allnikeasins)
# Out:
# 8327

# %%
nikereviews = {}
count = 0
for areview in allreviews:
   count += 1
   if count % 100000 == 0:
       print(count/5748920)      
   #setting current review as a dictionary, so we can easily reference its
   #entries
   thereview = allreviews[areview]
   theasin = thereview['asin']
   reviewerid = thereview['reviewerID']
   if theasin in allnikeasins:
       #im setting the key here as something unique. if we just did by asin
       #we'd only have one review for each asin, with the last review the only
       #one being stored
       thekey = '%s.%s' % (theasin, reviewerid)
       nikereviews[thekey] = thereview


# #that's it! all Nike reviews are stored nikereviews!
# #how many Nike reviews do we have?
# print(len(nikereviews))
        
#let's save our data as a JSON dictionary
json.dump(nikereviews, open('%s/allnikereviews.json' % working_directory, 'w'))
# Out:
# 0.017394571502125616
# 0.03478914300425123
# 0.05218371450637685
# 0.06957828600850247
# 0.08697285751062808
# 0.1043674290127537
# 0.12176200051487931
# 0.13915657201700493
# 0.15655114351913055
# 0.17394571502125616
# 0.19134028652338178
# 0.2087348580255074
# 0.226129429527633
# 0.24352400102975863
# 0.2609185725318843
# 0.27831314403400986
# 0.2957077155361355
# 0.3131022870382611
# 0.33049685854038674
# 0.34789143004251233
# 0.365286001544638
# 0.38268057304676356
# 0.4000751445488892
# 0.4174697160510148
# 0.43486428755314044
# 0.452258859055266
# 0.46965343055739167
# 0.48704800205951726
# 0.5044425735616429
# 0.5218371450637685
# 0.5392317165658941
# 0.5566262880680197
# 0.5740208595701454
# 0.591415431072271
# 0.6088100025743965
# 0.6262045740765222
# 0.6435991455786478
# 0.6609937170807735
# 0.678388288582899
# 0.6957828600850247
# 0.7131774315871503
# 0.730572003089276
# 0.7479665745914015
# 0.7653611460935271
# 0.7827557175956528
# 0.8001502890977784
# 0.8175448605999039
# 0.8349394321020296
# 0.8523340036041552
# 0.8697285751062809
# 0.8871231466084064
# 0.904517718110532
# 0.9219122896126577
# 0.9393068611147833
# 0.9567014326169089
# 0.9740960041190345
# 0.9914905756211602
