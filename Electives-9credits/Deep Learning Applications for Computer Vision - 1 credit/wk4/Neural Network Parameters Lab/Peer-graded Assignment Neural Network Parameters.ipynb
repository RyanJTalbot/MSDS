# %% [markdown]
# Open Ungraded Lab for Module 4
#
# Open the file Build_train_NN_MNIST_part1.ipynb.
#
# Follow the directions for Step 1 and run the code in the corresponding Jupyter Notebook cell:

# %%
from IPython.display import Image
Image(filename="i1.png")

# %%
Image(filename="i2.png")

# %% [markdown]
# After you follow the above steps, answer these questions and write the answers in the text editor:
#
#     What is the size of each image in the data set?
#
#     How many images are in the training data set?
#
#     How many images are in the testing data set?

# %% [markdown]
# Proceed to “Step 3” in the notebook. Follow the instructions to write code that creates a model with two layers:

# %%
Image(filename="i3.png")

# %% [markdown]
# When you are done, run the cell and check for errors.
#
# After you follow the above steps, answer these questions and write the answers in the text editor:
#
#     How many parameters does the network need to learn in the first “Flatten” layer?
#
#     How many parameters does the network need to learn in the second “Dense” layer?

# %% [markdown]
# Proceed to run all the cells up to “Step 4”. Then, follow the directions for “Step 4:

# %%
Image(filename="i4.png")

# %% [markdown]
# After inserting your code, run the cell for “Step 4”. Then, answer the following questions:
#
#     What is the value of the accuracy after 10 epochs?
#
#     What is this accuracy value referring to, the training accuracy or the testing accuracy?

# %% [markdown]
# Proceed to “Step 5” and follow the instructions to complete the code needed to evaluate the model on the testing data:

# %%
Image(filename="i5.png")

# %% [markdown]
# Run the code and answer the following question:
#
# What is the value of the testing accuracy your model achieved?

# %% [markdown]
# In the Ungraded Lab for Module 4:
#
# Open the file Build_train_NN_MNIST_part2.ipynb.
#
# Run each cell in the notebook until “Step 3”. Then follow the instructions for “Step 3” to add another fully connected layer:

# %%
Image(filename="i6.png")

# %% [markdown]
# Run the cell and then answer the following question:
#
# How many total trainable parameters does the new network have?

# %% [markdown]
# Continue to run the cells until the cell for “Step 4”. Here, you want to insert the same code you wrote for “Step 4” in Part 1. Then, run the cell in order to train the model for 10 epochs.
#
# Question: Does the training accuracy improve? Is the new value close to the old one?

# %% [markdown]
# In the Ungraded Lab for Module 4:
#
# Open the file Build_train_NN_MNIST_part3.ipynb.
#
# Run each cell in the notebook until “Step 3”. Then follow the instructions for “Step 3” to add another fully connected layer, this time with the addition of the “relu” activation function:

# %%
Image(filename="i7.png")

# %% [markdown]
# After you write the code and run the cell, please answer the following question:
#
# Does the number of total trainable parameters change?

# %% [markdown]
# Continue to run the cells until the cell for “Step 4”. Here, you want to insert the same code you wrote for “Step 4” in Part 1. Then, run the cell in order to train the model for 10 epochs.
#
# After you are finished running the cell, please answer the following question in the text box:
#
# Does the training accuracy improve?

# %% [markdown]
# Go to the cell for “Step 5”. Here, you want to insert the same code you wrote for “Step 5” in Part 1. Run the cell and answer the following questions:
#
#     What value do you get for “Testing accuracy” after the addition of the activation function?
#
#     What explains the improvement in accuracy of the model in Part 3, as compared to the model in Part 1 and Part 2?
