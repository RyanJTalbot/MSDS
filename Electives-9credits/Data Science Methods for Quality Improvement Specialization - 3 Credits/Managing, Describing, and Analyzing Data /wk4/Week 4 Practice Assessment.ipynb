# %%
from IPython.display import Image
Image(filename="Images/p1.png")

# %%
Image(filename="Images/p2.png")

# %%
Image(filename="Images/p3.png")

# %%
Image(filename="Images/p4.png")

# %%
Image(filename="Images/p5.png")

# %%
Image(filename="Images/p6.png")

# %%
Image(filename="Images/p7.png")

# %%
Image(filename="Images/p8.png")
