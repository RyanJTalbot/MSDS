# %%
from IPython.display import Image
Image(filename="images/pv1.png")

# %%
Image(filename="images/pv2.png")

# %%
Image(filename="images/pv3.png")

# %%
Image(filename="images/pv4.png")

# %%
Image(filename="images/pv5.png")

# %%
Image(filename="images/pv6.png")
