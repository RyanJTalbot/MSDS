# %%
from IPython.display import Image
Image(filename="images/na1.png")

# %%
Image(filename="images/na2.png")

# %%
Image(filename="images/na3.png")

# %%
Image(filename="images/na4.png")

# %%
Image(filename="images/na5.png")

# %%
Image(filename="images/na6.png")

# %%
Image(filename="images/na7.png")

# %%
Image(filename="images/na8.png")

# %%
Image(filename="images/na9.png")
