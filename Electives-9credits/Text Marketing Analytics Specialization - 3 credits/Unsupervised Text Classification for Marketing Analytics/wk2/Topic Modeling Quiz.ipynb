# %%
from IPython.display import Image
Image(filename="images/tm1.png")

# %%
Image(filename="images/tm2.png")

# %%
Image(filename="images/tm3.png")

# %%
Image(filename="images/tm4.png")

# %%
Image(filename="images/tm5.png")
