# %%
from IPython.display import Image
Image(filename="images/q.png")

# %%
Image(filename="images/1and3.png")

# %%
Image(filename="images/numm2.png")

# %%
Image(filename="images/q1.png")

# %%
Image(filename="images/numm4.png")

# %%
Image(filename="images/q2.png")

# %%
Image(filename="images/num5.png")
