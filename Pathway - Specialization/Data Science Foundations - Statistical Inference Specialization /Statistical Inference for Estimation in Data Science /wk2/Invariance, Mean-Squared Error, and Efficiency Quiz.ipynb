# %%
from IPython.display import Image
Image(filename="images/q3.png")

# %% [markdown]
# ## Answer:

# %%
Image(filename="images/NUM1.png")

# %%
Image(filename="images/nummm2.png")

# %%
Image(filename="images/q4.png")

# %% [markdown]
# ## Answer:

# %%
Image(filename="images/NUM3.png")

# %%
Image(filename="images/q5.png")

# %%
Image(filename="images/nummm5.png")
