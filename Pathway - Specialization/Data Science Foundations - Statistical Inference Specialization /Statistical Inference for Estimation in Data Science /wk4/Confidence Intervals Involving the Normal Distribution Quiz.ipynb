# %%
from IPython.display import Image
Image(filename="images/q1.png")

# %%
Image(filename="images/qa1.png")

# %%
Image(filename="images/qaa2.png")

# %%
Image(filename="images/q2.png")

# %%
Image(filename="images/qaa4.png")

# %%
Image(filename="images/q3.png")

# %%
Image(filename="images/qaa5.png")
