# %%
from IPython.display import Image
Image(filename="images/q21.png")

# %% [markdown]
# ## 1. Answer:

# %%
Image(filename="images/1and2.png")

# %%
Image(filename="images/num3.png")

# %% [markdown]
# ## 4. ??

# %% [markdown]
# ## 5. ANSWER: FALSE
