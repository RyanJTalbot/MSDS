# %%
from IPython.display import Image
Image(filename="images/q1.png")

# %%
Image(filename="images/qa12.png")

# %%
Image(filename="images/q2.png")

# %%
Image(filename="images/q3.png")

# %%
Image(filename="images/qa3.png")

# %%
Image(filename="images/q4.png")

# %%
Image(filename="images/q5.png")

# %%
Image(filename="images/q6.png")

# %%
Image(filename="images/q7.png")

# %%
Image(filename="images/qa4.png")

# %%
Image(filename="images/q8.png")

# %%
Image(filename="images/qa5.png")
