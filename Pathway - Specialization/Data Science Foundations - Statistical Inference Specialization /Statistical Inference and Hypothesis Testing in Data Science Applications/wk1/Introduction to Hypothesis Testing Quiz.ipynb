# %%
from IPython.display import Image
Image(filename="images/q1.png")

# %%
Image(filename="images/ia1.png")

# %%
Image(filename="images/q2.png")

# %%
Image(filename="images/ia2.png")

# %%
Image(filename="images/q3.png")

# %%
Image(filename="images/ia4.png")

# %%
Image(filename="images/q4.png")

# %%
Image(filename="images/ia5.png")
