# %%
from IPython.display import Image
Image(filename="images/is1.png")

# %% [markdown]
# ```
# ((n+1)*c1) + (n*(c2+c3+c4)) + c5
#
# ```

# %%
Image(filename="images/is2.png")

# %%
Image(filename="images/is3.png")

# %%
def foo(n):
    sum = 0
    for i in range(n):
        sum = sum + i * i
    return sum
