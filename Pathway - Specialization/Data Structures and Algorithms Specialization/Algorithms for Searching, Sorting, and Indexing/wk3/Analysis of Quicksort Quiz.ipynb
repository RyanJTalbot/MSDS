# %%
from IPython.display import Image
Image(filename="images/aq1.png")

# %%
Image(filename="images/aqa1.png")

# %%
Image(filename="images/aqa2.png")

# %%
Image(filename="images/aq3.png")

# %%
Image(filename="images/aqa3.png")
