# %%
from IPython.display import Image
Image(filename="images/qs12.png")

# %%
Image(filename="images/qsa1.png")

# %%
Image(filename="images/qsa2.png")

# %%
Image(filename="images/qs34.png")

# %%
Image(filename="images/qsa3.png")

# %%
Image(filename="images/qsa4.png")
