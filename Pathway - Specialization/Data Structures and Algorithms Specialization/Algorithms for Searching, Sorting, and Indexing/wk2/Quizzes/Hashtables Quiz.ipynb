# %% [markdown]
# ## 1. Select all true facts about Hashtables which use unordered-list chaining to resolve collisions.

# %%
from IPython.display import Image
Image(filename="../images/htqaa1.png")

# %%
Image(filename="../images/htab2.png")
