# %% [markdown]
# ## 1. Consider a minheap that is presented as a tree below:

# %%
from IPython.display import Image
Image(filename="q1.png")

# %% [markdown]
# Select all the correct facts from the list below.

# %% [markdown]
# - The minheap property is that each element is smaller than or equal to its children (if they exist). The example above satisfies the minheap property.
# - The heap when written as an array will be [-5, 8, 4, 12, 10, 6, 19, 13, 17, 11, 12]
# - The second smallest element of a minheap is always the smaller of the two children of the root node.

# %%
from IPython.display import Image
Image(filename="images/heapqa1.png")

# %% [markdown]
# ## 2. Select all the correct facts about min-heaps from the list below.

# %% [markdown]
# - Every sorted list in ascending order is a minheap.
# - The largest element in a minheap is always a leaf (i.e, it cannot have a child). Assume a heap cannot have repeated elements.
# - Every path from the root of a minheap with nn element to a leaf is of length at most log⁡2(n)log2
# - Suppose we start at the number j=1, and at each step double the number ( j=2×j), until we exceed a limit nn, the process terminates within Θ(log⁡2(n))steps.

# %%
Image(filename="images/heapqa2.png")
