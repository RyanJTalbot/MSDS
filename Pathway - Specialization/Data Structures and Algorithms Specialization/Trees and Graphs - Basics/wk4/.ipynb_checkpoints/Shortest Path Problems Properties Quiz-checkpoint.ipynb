# %%
from IPython.display import Image
Image(filename="images/sa1.png")

# %%
Image(filename="images/saa1.png")

# %%
Image(filename="images/saa2.png")

# %%
Image(filename="images/sa3.png")

# %%
Image(filename="images/saa3.png")
