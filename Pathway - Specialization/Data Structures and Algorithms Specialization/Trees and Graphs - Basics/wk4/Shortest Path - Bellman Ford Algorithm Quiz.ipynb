# %%
from IPython.display import Image
Image(filename="images/sp1.png")

# %%
Image(filename="images/spa1.png")

# %%
Image(filename="images/sp2.png")

# %%
Image(filename="images/spa2.png")

# %%
Image(filename="images/sp3.png")

# %%
Image(filename="images/spa3.png")
