# %%
from IPython.display import Image
Image(filename="images/a1.png")

# %%
Image(filename="images/aa1.png")

# %%
Image(filename="images/a23.png")

# %%
 Image(filename="images/aa2.png")

# %%
Image(filename="images/aa3.png")
