# %%
from IPython.display import Image
Image(filename="images/d1.png")

# %%
Image(filename="images/da1.png")

# %%
Image(filename="images/d2.png")

# %%
Image(filename="images/da2.png")

# %%
Image(filename="images/d3.png")

# %%
Image(filename="images/da3.png")
