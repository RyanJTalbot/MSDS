# %%
from IPython.display import Image
Image(filename="images/bs1.png")

# %%
Image(filename="images/bs11.png")

# %%
Image(filename="images/bs2.png")

# %%
Image(filename="images/bs21.png")

# %%
Image(filename="images/bs3.png")
