# %%
from IPython.display import Image
Image(filename="images/tr1.png")

# %%
Image(filename="images/tra1.png")

# %%
Image(filename="images/tr2.png")

# %%
Image(filename="images/tra2.png")

# %%
Image(filename="images/tr3.png")

# %%
Image(filename="images/tra3.png")
