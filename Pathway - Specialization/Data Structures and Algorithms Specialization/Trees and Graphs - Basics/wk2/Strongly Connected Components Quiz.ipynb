# %%
from IPython.display import Image
Image(filename="images/s12.png")

# %%
Image(filename="images/sa12.png")

# %%
Image(filename="images/s3.png")

# %%
Image(filename="images/sa3.png")

# %%
Image(filename="images/s4.png")

# %%
Image(filename="images/sa4.png")
