# %%
from IPython.display import Image
Image(filename="images/w21.png")

# %%
Image(filename="images/w22.png")

# %%
Image(filename="images/w24.png")

# %%
Image(filename="images/q5.png")

# %%
Image(filename="images/q5-1.png")
