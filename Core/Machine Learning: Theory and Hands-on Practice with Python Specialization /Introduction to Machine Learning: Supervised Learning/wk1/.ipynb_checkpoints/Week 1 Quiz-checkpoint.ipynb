# %%
from IPython.display import Image
Image(filename="images/w1.png")

# %%
Image(filename="images/w2.png")

# %%
Image(filename="images/w2b.png")

# %%
Image(filename="images/w2c.png")

# %%
Image(filename="images/w6.png")

# %%
Image(filename="images/w8.png")

# %%
Image(filename="images/w10.png")

# %%
Image(filename="images/w101.png")
