# %% [markdown]
# In question 5b of your Jupyter notebook, you visualized the correlation matrix as a heat map. Upload a screenshot or copy of your heat map here.

# %%
from IPython.display import Image
Image(filename="images/ans1.png")

# %% [markdown]
# The directions for 5c in your Jupyter notebook are as follows:
#
# Pair plot is a fast way to inspect relationships between features. Use seaborn's .pairplot() function to draw a pair plot of the first 10 columns (including price) and inspect their relationships. Set the diagonal elements to be KDE plot.
#
# Upload a copy or a screenshot of your pair plot.

# %%
Image(filename="images/ans2.png")

# %% [markdown]
# The directions for 6a are:
#
# We will split the data to train and test datasets such that the test dataset is 20% of original data. Use the sklearn.model_selection.train_test_split function to split the data frame to X_train and X_test. X_train is 80% of observation randomly chosen. X_test is the rest 20%.
#
# Both X_train and X_test are pd.DataFrame object and include 'price' in the table. Note that the train_test_split can handle data frame as well as array.
#
# Upload a screenshot of your code for splitting the data frame into training and testing sets.

# %%
Image(filename="images/ans3.png")

# %% [markdown]
# The directions for 6b are:
#
# Use the best_guess_predictor as a single predictor and build a simple linear regression model using the statsmodels.formula.api.ols function (https://www.statsmodels.org/dev/example_formulas.html)
# Train on the X_train portion. Print out the result summary.
#
# Upload a screenshot or copy of the results summary here.

# %%
Image(filename="images/ans4.png")

# %% [markdown]
# The directions for 6c are as follows:
#
# In question 5a, we picked a best guess predictor for price based on the correlation matrix. Now we will consider whether the best_guess_predictor that we used is still the best.
# Print out a list ranking all of the predictors. Then print out a list of the top three predictors in order.
# Hint: Linear regression uses adjusted R squared as fit performance.
#
# You do not need to share your lists here, but please answer the following questions.
# What were your top three predictors? How did you order your list of predictors to select those as the top ones? Is your top predictor for this section the same as the best guess predictor you selected in question 5a?
#
# Type your answer in the rich text field.

# %%
Image(filename="images/ans5.png")
