# %% [markdown]
# 4.5.1
#
# Suppose that $X_1, X_2, \dots, X_{10}$ is a random sample of size 10 from the $N(\mu, 1)$ distribution. Further suppose that we wish to find a test of size $\alpha = 0.05$ of:
#
# $$H_0: \mu \leq 3 \quad \text{versus} \quad H_1: \mu > 3$$
#
# based on the sample mean $\bar{X}$.
#
# **Answer:**
#
# Reject $H_0$ in favor of $H_1$ at the 0.05 level of significance if $\bar{X} > 3.52$.
#
# ---
#
# 4.5.2
#
# Suppose that $X_1, X_2, \dots, X_n$ is a random sample from the $N(\mu, \sigma^2)$ distribution where $\sigma^2$ is known.
#
# Testing the hypotheses:
#
# $$H_0: \mu \geq \mu_0 \quad \text{versus} \quad H_1: \mu < \mu_0$$
#
# for a fixed and known value of $\mu_0$. Use a level of significance $\alpha$.
#
# **Answer:**
#
# Reject $H_0$ if:
#
# $$\bar{X} < \mu_0 + z_{1-\alpha} \frac{\sigma}{\sqrt{n}}$$
#
#
# ---
#
# 4.6.2
#
# Suppose that $X_1, X_2, \dots, X_n$ is a random sample from the exponential distribution with rate $\lambda$. Derive a test of size (level) $\alpha$ for the hypotheses:
#
# $$H_0: \lambda \leq \lambda_0 \quad \text{versus} \quad H_1: \lambda > \lambda_0$$
#
# for some fixed and known $\lambda_0 > 0$, based on the sample mean $\bar{X}$.
#
# **Answer:**
#
# Reject $H_0$ if:
#
# $$\bar{X} < \frac{\chi^2_{1-\alpha, 2n}}{2n \lambda_0}$$
#
#
# ---
#
# 6.2.1
#
# Let $X_1, X_2, \dots, X_n$ be a random sample from the $\text{exp}(\text{RATE} = \theta)$ distribution. Find the best test of size $\alpha$ for:
#
# $$H_0: \theta = \theta_0 \quad \text{versus} \quad H_1: \theta = \theta_1$$
#
# where $\theta_0 < \theta_1$.
#
# **Answer:**
#
# The best test of size $\alpha$ for $H_0: \theta = \theta_0$ versus $H_1: \theta = \theta_1$ is to:
#
# "Reject $H_0$, in favor of $H_1$ if $\sum X_i \leq \frac{\chi^2_{1 - \alpha, 2n}}{2\theta_0}$."
#
#
# ---
#
# 6.2.2
#
# Consider the distribution with pdf:
#
# $$f(x; \theta) = \theta x^{\theta - 1} \, I_{(0, 1)}(x).$$
#
# Based on a random sample of size $n = 1$, find the best test of:
#
# $$H_0: \theta = 1 \quad \text{versus} \quad H_1: \theta = 2$$
#
# with $\alpha = 0.05$.
#
# **Answer:**
#
# "Reject $H_0$, in favor of $H_1$ if $X_1 \geq 0.95$."
#
# ---
#
# 6.3.2
#
# Let $X_1, X_2, \dots, X_n$ be a random sample from the "Weibull distribution" with pdf:
#
# $$f(x; \theta) = \frac{3x^2}{\theta} e^{-x^3/\theta} \, I_{(0, \infty)}(x).$$
#
# Find a UMP test for:
#
# $$H_0: \theta = \theta_0 \quad \text{versus} \quad H_1: \theta > \theta_0.$$
#
# **Answer:**
#
# "Reject $H_0$, in favor of $H_1$, if $\sum_{i=1}^{3} X_i^3 \geq \frac{\theta_0 \chi^2_{\alpha, 2n}}{2}.$"
#
#
# ---
#
# 6.3.4
#
# Let $X_1, X_2, \dots, X_n$ be a random sample from the $N(0, \sigma^2)$ distribution. Find a UMP test of size $\alpha$ for:
#
# $$H_0: \sigma = \sigma_0 \quad \text{versus} \quad H_1: \sigma > \sigma_0.$$
#
# **Answer:**
#
# "Reject $H_0$, in favor of $H_1$, if $\sum_{i=1}^{n} X_i^2 \geq \sigma_0^2 \chi^2_{\alpha, n}$."
#
# ---
#
# 6.4.2
#
# Let $X_1, X_2, \dots, X_n$ be a random sample from the $\text{Unif}(0, \Theta]$ distribution.
#
# Find the GLRT of size $\alpha$ for:
#
# $$H_0: \Theta = \Theta_0 \quad \text{versus} \quad H_1: \Theta \neq \Theta_0.$$
#
# **Answer:**
#
# Reject $H_0$ if:
#
# $$\left(\frac{X_{(n)}}{\Theta_0}\right)^n I_{(0, \Theta_0]}(X_{(n)}) \leq \left(\frac{k_1}{\Theta_0}\right)^n = \left(\frac{\Theta_0 \alpha^{1/n}}{\Theta_0}\right)^n = \alpha$$
#
#
#
# ---
#
# ---

# %% [markdown]
# ### Chapter 4 Exercises
#
# **Question 1.**
# Let $X_1, X_2, \dots, X_{16}$ be a random sample from the $N(\mu, 9)$ distribution. Find a test of size 0.05 for
#
# $$H_0: \mu = 3$$
# $$H_1: \mu \neq 3$$
#
# based on the sample mean $\bar{X}$.
#
#
# **Answer:**
#
# Reject $H_0: \mu = 3$ at the 0.05 significance level if the sample mean $\bar{X}$ falls outside the interval $[1.53, 4.47]$.
#
#   ---
# **Question 2.**
#
# Let $X_1, X_2, \dots, X_n$ be a random sample from the $N(\mu, \sigma^2)$ distribution. Assume that both $\mu$ and $\sigma^2$ are unknown.
#
# a. Derive an exact test of size (level of significance) $\alpha$ for
# $H_0 : \mu = \mu_0$ vs $H_1: \mu \neq \mu_0$
#
# based on the sample mean $\bar{X}$ and sample variance $S^2$.
#
# b. Carry out the test you derived in part (a) in the case that $\mu_0 = 1$ with the following data set:
# $$1.5, 3.2, 0.6, 2.4, -0.1$$
#
# Use $\alpha = 0.05$.
#
#
# **Answer:**
#
# a.
# The test is two-sided because we are testing $H_0: \mu = \mu_0$ against $H_1: \mu \neq \mu_0$. The null hypothesis $H_0$ is rejected if:
# $$|t| > t_{n-1, \alpha/2},$$
#
# where $t_{n-1, \alpha/2}$ is the critical value from the $t$-distribution with $n-1$ degrees of freedom corresponding to the significance level $\alpha$.
#
# b.
# Since $|t| = 0.871 < 2.776$, we fail to reject the null hypothesis.
#
# **Conclusion:**
#
# At the 0.05 significance level, there is not enough evidence to reject the null hypothesis $H_0: \mu = 1$.
#
#
#   ---
# **Question 3.**
#
# Let $X_{(1)}, X_{(2)}, X_{(3)}, X_{(4)}$ be the order statistics of a random sample of size $n = 4$ from the $U(0, \Theta)$ distribution where $\Theta > 0$. Consider the rejection rule: "The hypothesis $H_0 : \Theta = 1$ is rejected in favor of $H_1: \Theta > 1$ if the observed $X_{(4)} \geq c$."
#
# a. Find the constant $c$ so that the level of significance (the "size" of the test) is $\alpha = 0.05$.
#
# b. Determine the power function of the test.
#
#
# **Answer:**
#
# a. The constant $c$ for a test of size $\alpha = 0.05$ is approximately $c \approx 0.9877$.
#
# b. The power function of the test is $\beta(\Theta) = 1 - \frac{0.95}{\Theta^4}$ for $\Theta \geq \sqrt[4]{0.95}$.
#
#
#  ---
# **Question 4.**
#
# Consider a random sample of size $n_1 = 9$ from the $N(\mu_1, \sigma^2_1)$ distribution and an independent random sample of size $n_2 = 12$ from the $N(\mu_2, \sigma^2_2)$ distribution. Suppose that the variances are unknown but, for some reason, you do know that $\sigma^2_1 = 3\sigma^2_2$.
#
# Define a random variable that has a $t$-distribution that can be used to find a $100(1-\alpha)\%$ confidence interval for $\mu_1 - \mu_2$.
#
#
# **Answer:**
#
#
# The random variable that follows a $t$-distribution and can be used to find a $100(1-\alpha)\%$ confidence interval for $\mu_1 - \mu_2$ is:
#
# $$
# t = \frac{\sqrt{3}(\bar{X}_1 - \bar{X}_2)}{S_p},
# $$
#
# where $t$ follows a $t$-distribution with $19$ degrees of freedom.
#
#
#
#
#  ---
# **Question 6.**
#
# Consider the distribution with pdf
#
# $$f(x; \Theta) = 1 - \Theta^2 \left(x - \frac{1}{2}\right), \quad 0 < x < 1, \quad -1 < \Theta < 1.$$
#
# Find a test of size $\alpha$ for $H_0: \Theta = 0$ vs. $H_1: \Theta \neq 0$ based on a sample of size 1.
#
#
#
# **Answer:**
#
# Test: Reject $H_0: \Theta = 0$ in favor of $H_1: \Theta \neq 0$ if the observed value of $x$ is less than $\frac{\alpha}{2}$ or greater than $1 - \frac{\alpha}{2}$.
#
# Size: The size of the test is $\alpha$, as the probability of rejecting $H_0$ under $H_0$ is $\alpha$.
#
#
#  ---
# **Question 7.**
#
# Let $X_1, X_2, \dots, X_n$ be a random sample from the gamma distribution with shape parameter $a$ (usually denoted by $\alpha$, but it would be confusing in this context) and inverse scale parameter $\beta$. Assume $a$ is known. Derive a hypothesis test of size/level $\alpha$ for testing
#
# $$H_0 : \beta \leq \beta_0 \quad \text{vs.} \quad H_1 : \beta > \beta_0$$
#
# based on the sample mean $\bar{X}$.
#
#
#
# **Answer:**
#
#
# Reject $H_0: \beta \leq \beta_0$ in favor of $H_1: \beta > \beta_0$ if:
# $$\frac{\bar{X}}{\beta_0} > c_\alpha,$$
# where $c_\alpha$ is the critical value derived from the gamma distribution with shape parameter $an$ and the given significance level $\alpha$. This test is based on the likelihood ratio and provides a decision rule for testing the hypothesis about the inverse scale parameter $\beta$.
#
#
#  ---
# **Question 8.**
#
# Let $X_1, X_2, \dots, X_n$ be a random sample from the shifted rate 1 exponential distribution with pdf
#
# $$f(x; \Theta ) = e^{-(x-\Theta)}  I_{(\Theta, \infty)}(x)$$
#
# for some parameter $\Theta$.
#
# Derive a test of size $\alpha$ for
#
# $$H_0 : \Theta = \Theta_0 \quad \text{vs.} \quad H_1: \Theta > \Theta_0$$
#
# based on $X_{(1)}$, the minimum value in the sample.
#
#
#
# **Answer:**
#
#
# The test of size $\alpha$ for the hypotheses
# $H_0: \Theta = \Theta_0 \ \text{vs.} \ H_1: \Theta > \Theta_0$
#
# based on $X_{(1)}$, the minimum value in the sample, is to reject $H_0$ if:
# $$X_{(1)} \geq \Theta_0 - \frac{\log(1-\alpha)}{n}.$$
#
# This test ensures that the probability of rejecting $H_0$ when $H_0$ is true is exactly $\alpha$.
#
#
#
#  ---
# **Question 9.**
#
# Let $X_1, X_2, \dots, X_n$ be a random sample of size $n$ from the $N(0, \sigma^2)$ distribution.
#
# a. Derive a test of size/level $\alpha$ for
#
# $$H_0 : \sigma^2 = \sigma^2_0 \quad \text{vs.} \quad H_1 : \sigma^2 > \sigma^2_0.$$
#
# b. Express the power function of your test from the previous problem in terms of the chi-squared distribution.
#
#
#
# **Answer:**
#
# **Part (a):** The test of size $\alpha$ rejects $H_0: \sigma^2 = \sigma_0^2$ if
# $$\frac{n S^2}{\sigma_0^2} > \chi^2_{n, 1-\alpha}.$$
#
# **Part (b):** The power function of the test is
# $$\beta(\sigma_1^2) = P\left(\chi^2_n > \frac{\chi^2_{n, 1-\alpha} \cdot \sigma_0^2}{\sigma_1^2}\right).$$
#
#  ---
# **Question 10.**
#
# Consider a random sample of size $n$ from the $U(0, \Theta)$ distribution. Find a test of size $\alpha$ for
#
# $$H_0 : \Theta \geq \Theta_0 \quad \text{vs.} \quad H_1 : \Theta < \Theta_0$$
#
# based on the sample maximum $X_{(n)}$.
#
# **Answer:**
#
# The test of size $\alpha$ for the hypotheses
# $H_0: \Theta \geq \Theta_0 \ \text{vs.} \ H_1: \Theta < \Theta_0$
#
# based on the sample maximum $X_{(n)}$ is to reject $H_0$ if:
# $$X_{(n)} \leq \Theta_0 \alpha^{1/n}.$$
#
# This critical value ensures that the probability of incorrectly rejecting $H_0$ (i.e., the size of the test) is exactly $\alpha$.

# %% [markdown]
# ---
#
# ### Chapter 6 Exercises
#
# **Question 1.** Let $z_{\alpha/2}$ be the critical value that cuts off area $\alpha / 2$ to the right under the standard normal pdf. Let $X^2_{\alpha,1}$ be the critical value that cuts off area $\alpha$ to the right under the $X^2 (1)$ pdf. Show that $z_{\alpha/2} = \sqrt{X^2_{\alpha, 1}}$.
#
# **Answer:**
#
#  $z_{\alpha/2} = \sqrt{X^2_{\alpha, 1}}$.
#
#
# ---
#
# **Question 2.** Consider a random sample $X_1, X_2, \dots, X_n$ from a discrete distribution with pdf
#
# $$f(x;\Theta) = \left[\left(\frac{\Theta}{\Theta + 1}\right)^2 \bigg/ (\Theta + 1)\right] \cdot I_{\{0,1,2,\dots\}}(x)$$
#
# with $\Theta > 0$.
#
# Consider testing the hypotheses
#
# $$H_0 : \Theta = \Theta_0$$
# $$H_1 : \Theta = \Theta_1$$
#
# for some fixed $\Theta_1 > \Theta_0$.
#
# a. Find the best test of size (level of significance) $\alpha$.
#
#
# b. Is your test from part (a) a UMP (uniformly most powerful) test of size $\alpha$ for $H_0$ against the alternative hypothesis $H_1 : \Theta > \Theta_0$? Explain.
#
#
# **Answer:**
#
# Part (a): The best test of size $\alpha$ is the likelihood ratio test derived from the ratio of the likelihoods under $H_0$ and $H_1$.
#
#
# Part (b): Yes, the test is uniformly most powerful (UMP) for testing $H_0: \Theta = \Theta_0$ against the alternative $H_1: \Theta > \Theta_0$ because of the monotonicity property of the likelihood ratio in this case.
#
# ---
#
# **Question 3.** Consider a random sample $X_1, X_2, \dots, X_n$ from a discrete distribution with pdf
#
#
#
# $$f(x;\Theta) = \left[\left(\frac{\Theta}{\Theta + 1}\right)^2 \bigg/ (\Theta + 1)\right] \cdot I_{\{0,1,2,\dots\}}(x)$$
#
# With $\Theta > 0$. Does a UMP test of size $\alpha$ of $H_0 : \Theta = \Theta_0$ against $H_1 : \Theta > \Theta_0$ exist? If not, explain. If so, find it.
#
# **Answer:**
#
# Given the structure of the likelihood ratio and the nature of the distribution, a UMP test of size $\alpha$ does exist for testing $H_0: \Theta = \Theta_0$ against $H_1: \Theta > \Theta_0$. The likelihood ratio is monotonic with respect to $\Theta$, which ensures that the likelihood ratio test is uniformly most powerful for all $\Theta > \Theta_0$.
#
# ---
#
# **Question 4.** Consider the distribution with pdf
#
# $$F(x; \Theta) = 1 - \Theta^2 \left(x - \frac{1}{2}\right), \quad 0 < x < 1, \quad -1 < \Theta < 1$$
#
# a. Find the best test of size $\alpha$ for
# $H_0: \Theta = 0$ versus $H_1: \Theta \neq 0$
# based on a sample of size 1.
#
# b. Find (if it exists) a UMP (uniformly most powerful) test of size $\alpha$ for
# $H_0 : \Theta = 0$ versus $H_1: \Theta \neq 0$
# based on a sample of size 1.
#
#
# **Answer:**
#
# Part (a): The best test of size $\alpha$ for $H_0: \Theta = 0$ versus $H_1: \Theta \neq 0$ based on a sample of size 1 would involve constructing a likelihood ratio test, but the exact critical region would depend on further distributional information.
#
# Part (b): A UMP test of size $\alpha$ for $H_0: \Theta = 0$ versus $H_1: \Theta \neq 0$ likely does not exist due to the lack of a monotone likelihood ratio across all values of $\Theta$. The test may be optimal for specific values of $\Theta$, but not uniformly most powerful across the entire alternative hypothesis.
#
# ---
#
# **Question 5.**
#
# Let $X_1, X_2, \dots, X_n$ be a random sample of size $n$ from the $N(0, \sigma^2)$ distribution.
#
# * Derive the UMP test of size $\alpha$ for $H_0: \sigma^2 = \sigma^2_0$ vs. $H_1: \sigma^2 > \sigma^2_0$.
#
# * Express the power function of your test from part (a) in terms of the chi-squared distribution.
#
# **Answer:**
#
#
# a. The UMP test of size $\alpha$ rejects $H_0: \sigma^2 = \sigma^2_0$ if
#
# $$\frac{n S^2}{\sigma^2_0} > \chi^2_{n, \alpha}.$$
#
# b. The power function of the test is
#
# $$\beta(\sigma^2_1) = P\left(\chi^2_n > \frac{\sigma^2_0}{\sigma^2_1} \cdot \chi^2_{n, \alpha}\right).$$
#
#
# ---
#
# **Question 6.**
#
# Suppose that we have a random sample of four observations from the distribution with pdf
#
# $$f(x; \Theta) = \frac{1}{2 \Theta^3}  x^2  e^{-x/\Theta}  I_{(0, \infty)}(x)$$
#
# a. Find the best (most powerful) test of size $\alpha$ for $H_0: \Theta = \Theta_0$ vs. $H_1 : \Theta = \Theta_1$, assuming that $\Theta_1 > \Theta_0$. Give your answer in terms of chi-squared critical values.
#
# b. Is your test uniformly most powerful for the alternative hypothesis $H_1: \Theta > \Theta_0$?
#
# **Answer:**
#
# a. In terms of a chi-squared distribution:
#
# $$\frac{2T(x)}{\Theta_0} > \chi^2_{8, 1-\alpha}$$
#
# where $\chi^2_{8, 1-\alpha}$ is the $1-\alpha$ quantile of the chi-squared distribution with 8 degrees of freedom.
#
# **Part (b):** Yes, the test is uniformly most powerful for the alternative hypothesis $H_1: \Theta > \Theta_0$.
#
#
#
#
# ---
#
# **Question 7.**
#
# Suppose that $X_1, X_2, \dots, X_n$ is a random sample from the $N(\mu, 1)$ distribution.
#
# a. Find the UMP test of size $\alpha$ for $H_0: \mu = \mu_0$ against $H_1: \mu > \mu_0$.
#
# b. Explain why there is no UMP test for $H_0: \mu = \mu_0$ against $H_1: \mu \neq \mu_0$.
#
# **Answer:**
#
# a. The uniformly most powerful (UMP) test of size $\alpha$ for $H_0: \mu = \mu_0$ against $H_1: \mu > \mu_0$ is to reject $H_0$ if:
#
#
# $$\bar{X} > \mu_0 + \frac{z_\alpha}{\sqrt{n}}.$$
#
# b. The one-sided nature of the alternative hypothesis in part (a) allows for a UMP test, while the two-sided nature in part (b) precludes the existence of a UMP test.
#
#
# ---
#
# **Question 8.**
#
# Consider a random sample $X_1, \dots, X_n$ from a distribution with pdf
#
# $$f(x; \Theta) = \Theta (1 - x)^{\Theta - 1}, \quad 0 < x < 1, \quad \Theta > 0.$$
#
# Give the form of the GLRT for testing $H_0: \Theta = 1$ against $H_1: \Theta \neq 1$.
#
# **Answer:**
#
# The form of the GLRT for testing $H_0 : \Theta = 1$ against $H_1 : \Theta \neq 1$ is based on the test statistic:
#
#
#
# $$
# \Lambda = \left(-\frac{\log T}{n}\right)^n T^{1 + \log T},
# $$
#
#
#
#
#
# where $T = \prod_{i=1}^{n} (1 - X_i)$. The null hypothesis $H_0$ is rejected if $\Lambda$ is smaller than a critical value that depends on the desired significance level $\alpha$.
#
#
#
# ---
#
#
# **Question 9.**
#
# Suppose that $X_1, X_2, \dots, X_n$ is a random sample from the distribution with pdf
#
# $$f(x; \Theta) = \Theta x^{\Theta - 1} \cdot I_{(0,1)}(x).$$
#
# Derive the GLRT of size $\alpha$ for testing
#
# $H_0 : \Theta = \Theta_0$ vs. $H_1 : \Theta \neq \Theta_0$,
#
# approximating the appropriate critical value based on a large sample size.
#
# **Answer:**
#
# The GLRT for testing $H_0 : \Theta = \Theta_0$ vs. $H_1 : \Theta \neq \Theta_0$ rejects $H_0$ if:
#
# $$
# -2\log \Lambda = -2\left[n \log \left(\frac{\Theta_0 \sum_{i=1}^{n} \log X_i}{-n}\right) - n\right] > \chi^2_{1, \alpha}.
# $$
