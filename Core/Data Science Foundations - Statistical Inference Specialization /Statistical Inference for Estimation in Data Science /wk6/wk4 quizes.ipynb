# %% [markdown]
# # Week 2

# %%
from IPython.display import Image
Image(filename="img/w2q1.png")

# %%
Image(filename="img/w2q2.png")

# %%
Image(filename="img/w2q3.png")

# %%
Image(filename="img/w22q1.png")

# %%
Image(filename="img/w22q2.png")

# %%
Image(filename="img/w22q3.png")

# %%
Image(filename="img/w22q4.png")

# %% [markdown]
# # Week 3

# %%
Image(filename="img/w3q1.png")

# %%
Image(filename="img/w3q2.png")

# %% [markdown]
# # Week 4

# %%
from IPython.display import Image
Image(filename="img/q1.png")

# %% [markdown]
#     Question 1: (2783.27, 2991.93)
#
#     Question 2: (82.758, 83.522)

# %%
Image(filename="img/q2.png")

# %% [markdown]
# Question 3:
#
#     A 90% confidence interval will end up being narrower.
#     A 90% confidence interval for μ will be an interval that is contained in (10.8, 12.4).
#
# Question 4:
#
#     (21.85, 25.55)

# %%
Image(filename="img/q3.png")

# %% [markdown]
# Question 5:
#
#     19

# %%
Image(filename="img/q4.png")

# %% [markdown]
# Question 1:
#
#     (−1.130, 0.130)
#
# Question 2:
#
#     (−1.147, 0.147)

# %%
Image(filename="img/q5.png")

# %% [markdown]
# Question 3:
#
#     (−3.892, −3.088)

# %% [markdown]
# # Week 5

# %%
Image(filename="img/5q1.png")

# %%
Image(filename="img/5q2.png")
