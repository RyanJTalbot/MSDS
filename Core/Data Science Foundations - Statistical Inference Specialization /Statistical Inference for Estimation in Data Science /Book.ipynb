# %% [markdown]
# https://openstax.org/details/books/introductory-statistics

# %% [markdown]
# Additional Reading (optional)
#
# Here is a cool open source statistics textbook that you may find helpful!
