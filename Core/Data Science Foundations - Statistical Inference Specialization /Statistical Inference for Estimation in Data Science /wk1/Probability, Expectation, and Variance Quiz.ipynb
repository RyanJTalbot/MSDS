# %%
from IPython.display import Image
Image(filename="images/one.png")

# %% [markdown]
# ## ANSWER:

# %%
Image(filename="images/Q1.png")

# %%
Image(filename="images/Q2 COPY.png")

# %%
Image(filename="images/three.png")

# %% [markdown]
# ## ANSWER:

# %%
Image(filename="images/Q3.png")

# %%
Image(filename="images/four.png")

# %% [markdown]
# ## ANSWER:

# %%
Image(filename="images/Q4.png")

# %%
Image(filename="images/qaa5.png")
