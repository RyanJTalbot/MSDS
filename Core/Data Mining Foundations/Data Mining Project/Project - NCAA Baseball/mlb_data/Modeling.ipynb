# %%
import numpy as np
import pandas as pd

# %%
pit = pd.read_csv('pitch.csv')
bat = pd.read_csv('batting_clean.csv')

# %%
bat.head()
# Out:
#     R/G    G    PA    AB    R     H   2B  3B   HR  RBI  ...    OBP    SLG  \
# 0  5.01  162  6224  5525  812  1405  314  39  220  776  ...  0.329  0.445
# 1  4.52  162  6216  5584  732  1467  289  26  165  706  ...  0.326  0.412
# 2  4.59  162  6140  5650  743  1469  269  12  232  713  ...  0.312  0.435
# 3  4.85  162  6338  5669  785  1461  302  19  168  735  ...  0.329  0.407
# 4  5.07  162  6283  5496  822  1402  274  29  223  785  ...  0.338  0.437
#
#      OPS    TB  HBP  SF  year  tm_code   W   L
# 0  0.774  2457   54  27  2017        0  93  69
# 1  0.738  2303   66  32  2017        1  72  90
# 2  0.747  2458   50  37  2017        2  75  87
# 3  0.736  2305   53  36  2017        3  93  69
# 4  0.775  2403   82  32  2017        4  92  70
#
# [5 rows x 23 columns]

# %%
bat_test = bat[bat['year'] == 2022]

# %%
bat_train = bat[:120]

# %%
y_train = bat_train['W']
y_train
# Out:
# 0       93
# 1       72
# 2       75
# 3       93
# 4       92
#       ...
# 115     90
# 116    100
# 117     60
# 118     91
# 119     65
# Name: W, Length: 120, dtype: int64

# %%
x_train = bat_train.drop(columns=['W'])
x_train
# Out:
#       R/G    G    PA    AB    R     H   2B  3B   HR  RBI  ...     BA    OBP  \
# 0    5.01  162  6224  5525  812  1405  314  39  220  776  ...  0.254  0.329
# 1    4.52  162  6216  5584  732  1467  289  26  165  706  ...  0.263  0.326
# 2    4.59  162  6140  5650  743  1469  269  12  232  713  ...  0.260  0.312
# 3    4.85  162  6338  5669  785  1461  302  19  168  735  ...  0.258  0.329
# 4    5.07  162  6283  5496  822  1402  274  29  223  785  ...  0.255  0.338
# ..    ...  ...   ...   ...  ...   ...  ...  ..  ...  ...  ...    ...    ...
# 115  4.36  162  6001  5351  706  1303  261  22  198  678  ...  0.244  0.313
# 116  5.29  162  6213  5507  857  1336  288  36  222  810  ...  0.243  0.321
# 117  3.86  162  5943  5405  625  1254  225  24  167  598  ...  0.232  0.294
# 118  5.22  162  6070  5476  846  1455  285  13  262  816  ...  0.266  0.330
# 119  4.47  162  6113  5385  724  1388  272  20  182  686  ...  0.258  0.337
#
#        SLG    OPS    TB  HBP  SF  year  tm_code    L
# ...

# %%
x_train.describe()
# Out:
#               R/G           G           PA           AB           R  \
# count  120.000000  120.000000   120.000000   120.000000  120.000000
# mean     4.614667  161.983333  6156.433333  5496.591667  747.408333
# std      0.481678    0.289402   114.643674    92.184643   78.238645
# min      3.610000  161.000000  5856.000000  5210.000000  582.000000
# 25%      4.300000  162.000000  6075.250000  5443.000000  695.500000
# 50%      4.575000  162.000000  6154.000000  5498.500000  739.000000
# 75%      4.937500  162.000000  6241.250000  5551.500000  804.000000
# max      5.820000  163.000000  6475.000000  5770.000000  943.000000
#
#                  H          2B          3B          HR         RBI  ...  \
# count   120.000000  120.000000  120.000000  120.000000  120.000000  ...
# mean   1372.966667  275.458333   25.816667  203.416667  713.566667  ...
# std      76.238782   28.918865    8.269599   36.047257   76.165315  ...
# ...

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 22 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   R/G      120 non-null    float64
#  1   G        120 non-null    int64
#  2   PA       120 non-null    int64
#  3   AB       120 non-null    int64
#  4   R        120 non-null    int64
#  5   H        120 non-null    int64
#  6   2B       120 non-null    int64
#  7   3B       120 non-null    int64
#  8   HR       120 non-null    int64
#  9   RBI      120 non-null    int64
#  10  BB       120 non-null    int64
#  11  SO       120 non-null    int64
#  12  BA       120 non-null    float64
#  13  OBP      120 non-null    float64
#  14  SLG      120 non-null    float64
#  15  OPS      120 non-null    float64
#  16  TB       120 non-null    int64
#  17  HBP      120 non-null    int64
#  18  SF       120 non-null    int64
#  19  year     120 non-null    int64
#  20  tm_code  120 non-null    int64
# ...

# %%
bat_test
# Out:
#       R/G    G    PA    AB    R     H   2B  3B   HR  RBI  ...    OBP    SLG  \
# 120  4.33  162  6027  5351  702  1232  262  24  173  658  ...  0.304  0.385
# 121  4.87  162  6082  5509  789  1394  298  11  243  753  ...  0.317  0.443
# 122  4.16  162  6049  5429  674  1281  275  25  171  639  ...  0.305  0.390
# 123  4.54  162  6144  5539  735  1427  352  12  155  704  ...  0.321  0.409
# 124  4.06  162  6072  5425  657  1293  265  31  159  620  ...  0.311  0.387
# 125  4.23  162  6123  5611  686  1435  272   9  149  654  ...  0.310  0.387
# 126  4.00  162  5978  5380  648  1264  235  18  156  618  ...  0.304  0.372
# 127  4.31  162  6163  5558  698  1410  273  31  127  662  ...  0.316  0.383
# 128  4.31  162  6105  5540  698  1408  280  34  149  669  ...  0.315  0.398
# 129  3.44  162  5870  5378  557  1240  235  27  110  530  ...  0.286  0.346
# 130  4.55  162  6054  5409  737  1341  284  13  214  715  ...  0.319  0.424
# ...

# %%
ytest = bat_test["W"]
xtest = bat_test.drop(columns=["W"])

# %%
from sklearn import linear_model
from sklearn import svm
from sklearn.svm import SVR
import matplotlib.pyplot as plt

# %%
regr = svm.SVR()
regr.fit(x_train, y_train)
SVR()
# Out:
# SVR()

# %%
regr.predict(xtest, ytest)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_5382/1699916185.py in <cell line: 1>()
# ----> 1 regr.predict(xtest, ytest)
#
# TypeError: predict() takes 2 positional arguments but 3 were given

# %%
import numpy as np
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
# Always scale the input. The most convenient way is to use a pipeline.
reg = make_pipeline(StandardScaler(),
                    SGDRegressor(max_iter=1000, tol=1e-3))
reg.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('sgdregressor', SGDRegressor())])

# %%
predictions=reg.predict(xtest)
predictions
# Out:
# array([ 74.1971025 , 100.45497612,  82.57970877,  77.81370664,
#         73.55764703,  80.55819161,  62.16563158,  91.50223901,
#         67.79945444,  65.81231221, 105.17845991,  64.75029233,
#         72.32863245, 110.6438861 ,  68.57639939,  85.65294945,
#         77.58870391, 100.66321403,  98.85070277,  60.07104508,
#         86.64463026,  61.8355859 ,  88.7539719 ,  89.56805279,
#         81.08331088,  92.68556353,  85.78974329,  68.17443764,
#         91.49971594,  54.60156194])

# %%
data={
    "predicts": [74.1971025 , 100.45497612,  82.57970877,  77.81370664,
        73.55764703,  80.55819161,  62.16563158,  91.50223901,
        67.79945444,  65.81231221, 105.17845991,  64.75029233,
        72.32863245, 110.6438861 ,  68.57639939,  85.65294945,
        77.58870391, 100.66321403,  98.85070277,  60.07104508,
        86.64463026,  61.8355859 ,  88.7539719 ,  89.56805279,
        81.08331088,  92.68556353,  85.78974329,  68.17443764,
        91.49971594,  54.60156194],
    "ytest": [74.1971025 , 100.45497612,  82.57970877,  77.81370664,
        73.55764703,  80.55819161,  62.16563158,  91.50223901,
        67.79945444,  65.81231221, 105.17845991,  64.75029233,
        72.32863245, 110.6438861 ,  68.57639939,  85.65294945,
        77.58870391, 100.66321403,  98.85070277,  60.07104508,
        86.64463026,  61.8355859 ,  88.7539719 ,  89.56805279,
        81.08331088,  92.68556353,  85.78974329,  68.17443764,
        91.49971594,  54.60156194]
}
preds = pd.DataFrame(data)

print(preds)
# Out:
#       predicts       ytest
# 0    74.197102   74.197102
# 1   100.454976  100.454976
# 2    82.579709   82.579709
# 3    77.813707   77.813707
# 4    73.557647   73.557647
# 5    80.558192   80.558192
# 6    62.165632   62.165632
# 7    91.502239   91.502239
# 8    67.799454   67.799454
# 9    65.812312   65.812312
# 10  105.178460  105.178460
# 11   64.750292   64.750292
# 12   72.328632   72.328632
# 13  110.643886  110.643886
# 14   68.576399   68.576399
# 15   85.652949   85.652949
# 16   77.588704   77.588704
# 17  100.663214  100.663214
# 18   98.850703   98.850703
# 19   60.071045   60.071045
# 20   86.644630   86.644630
# 21   61.835586   61.835586
# 22   88.753972   88.753972
# 23   89.568053   89.568053
# 24   81.083311   81.083311
# 25   92.685564   92.685564
# 26   85.789743   85.789743
# 27   68.174438   68.174438
# 28   91.499716   91.499716
# 29   54.601562   54.601562

# %%
preds['ytest'] = ytest

# %%
ytest[6:]
# Out:
# 126     62
# 127     92
# 128     68
# 129     66
# 130    106
# 131     65
# 132     73
# 133    111
# 134     69
# 135     86
# 136     78
# 137    101
# 138     99
# 139     60
# 140     87
# 141     62
# 142     89
# 143     90
# 144     81
# 145     93
# 146     86
# 147     68
# 148     92
# 149     55
# Name: W, dtype: int64

# %%
preds
# Out:
#       predicts  ytest
# 0    74.197102    NaN
# 1   100.454976    NaN
# 2    82.579709    NaN
# 3    77.813707    NaN
# 4    73.557647    NaN
# 5    80.558192    NaN
# 6    62.165632    NaN
# 7    91.502239    NaN
# 8    67.799454    NaN
# 9    65.812312    NaN
# 10  105.178460    NaN
# 11   64.750292    NaN
# 12   72.328632    NaN
# 13  110.643886    NaN
# 14   68.576399    NaN
# 15   85.652949    NaN
# 16   77.588704    NaN
# 17  100.663214    NaN
# 18   98.850703    NaN
# 19   60.071045    NaN
# 20   86.644630    NaN
# 21   61.835586    NaN
# 22   88.753972    NaN
# 23   89.568053    NaN
# 24   81.083311    NaN
# 25   92.685564    NaN
# 26   85.789743    NaN
# 27   68.174438    NaN
# 28   91.499716    NaN
# 29   54.601562    NaN
