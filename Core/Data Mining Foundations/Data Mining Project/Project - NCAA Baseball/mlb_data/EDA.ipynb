# %%
import numpy as np
import pandas as pd

# %%
pit = pd.read_csv('pitch.csv')

# %%
bat = pd.read_csv('batting.csv')

# %%
bat
# Out:
#                        Tm   R/G    G    PA    AB    R     H   2B  3B   HR  \
# 0    Arizona Diamondbacks  5.01  162  6224  5525  812  1405  314  39  220
# 1          Atlanta Braves  4.52  162  6216  5584  732  1467  289  26  165
# 2       Baltimore Orioles  4.59  162  6140  5650  743  1469  269  12  232
# 3          Boston Red Sox  4.85  162  6338  5669  785  1461  302  19  168
# 4            Chicago Cubs  5.07  162  6283  5496  822  1402  274  29  223
# ..                    ...   ...  ...   ...   ...  ...   ...  ...  ..  ...
# 145   St. Louis Cardinals  4.77  162  6165  5496  772  1386  290  21  197
# 146        Tampa Bay Rays  4.11  162  6008  5412  666  1294  296  17  139
# 147         Texas Rangers  4.36  162  6029  5478  707  1308  224  20  198
# 148     Toronto Blue Jays  4.78  162  6158  5555  775  1464  307  12  200
# 149  Washington Nationals  3.72  162  5998  5434  603  1351  252  20  136
#
#      ...   BB    SO     BA    OBP    SLG    OPS    TB  HBP  SF  year
# ...

# %%
bat["tm_code"] = bat["Tm"].astype("category").cat.codes

# %%
bat[bat['Tm'] == "Washington Nationals"]
# Out:
#                        Tm   R/G    G    PA    AB    R     H   2B  3B   HR  \
# 29   Washington Nationals  5.06  162  6214  5553  819  1477  311  31  215
# 59   Washington Nationals  4.76  162  6288  5517  771  1402  284  25  191
# 89   Washington Nationals  5.39  162  6267  5512  873  1460  298  27  231
# 119  Washington Nationals  4.47  162  6113  5385  724  1388  272  20  182
# 149  Washington Nationals  3.72  162  5998  5434  603  1351  252  20  136
#
#      ...    SO     BA    OBP    SLG    OPS    TB  HBP  SF  year  tm_code
# 29   ...  1327  0.266  0.332  0.449  0.782  2495   31  45  2017       30
# 59   ...  1289  0.254  0.335  0.419  0.753  2309   59  40  2018       30
# 89   ...  1308  0.265  0.342  0.454  0.796  2505   81  42  2019       30
# 119  ...  1303  0.258  0.337  0.417  0.754  2246   84  31  2021       30
# 149  ...  1221  0.249  0.310  0.377  0.688  2051   60  37  2022       30
#
# [5 rows x 22 columns]

# %%
pit["tm_code"] = pit["Tm"].astype("category").cat.codes

# %%
pit[pit['Tm'] == "Washington Nationals"]
# Out:
#                        Tm   W    L   ERA    G      IP     H    R   ER   HR  \
# 29   Washington Nationals  97   65  3.88  162  1446.2  1300  672  623  189
# 59   Washington Nationals  82   80  4.04  162  1446.0  1320  682  649  198
# 89   Washington Nationals  93   69  4.27  162  1439.1  1340  724  683  202
# 119  Washington Nationals  65   97  4.80  162  1394.1  1364  820  743  247
# 149  Washington Nationals  55  107  5.00  162  1411.2  1469  855  785  244
#
#      ...  WP    BF   FIP   WHIP   H9  HR9  BB9  SO9  year  tm_code
# 29   ...  44  6068  3.99  1.241  8.1  1.2  3.1  9.1  2017       30
# 59   ...  42  6087  4.15  1.250  8.2  1.2  3.0  8.8  2018       30
# 89   ...  53  6134  4.14  1.290  8.4  1.3  3.2  9.4  2019       30
# 119  ...  43  6073  4.87  1.371  8.8  1.6  3.5  8.7  2021       30
# 149  ...  59  6220  4.98  1.436  9.4  1.6  3.6  7.8  2022       30
#
# [5 rows x 22 columns]

# %%
pit
# Out:
#                        Tm   W    L   ERA    G      IP     H    R   ER   HR  \
# 0    Arizona Diamondbacks  93   69  3.66  162  1441.0  1309  659  586  171
# 1          Atlanta Braves  72   90  4.72  162  1441.1  1463  821  756  192
# 2       Baltimore Orioles  75   87  4.97  162  1441.0  1505  841  795  242
# 3          Boston Red Sox  93   69  3.70  162  1482.1  1384  668  610  195
# 4            Chicago Cubs  92   70  3.95  162  1447.1  1294  695  636  194
# ..                    ...  ..  ...   ...  ...     ...   ...  ...  ...  ...
# 145   St. Louis Cardinals  93   69  3.79  162  1435.2  1335  637  605  146
# 146        Tampa Bay Rays  86   76  3.41  162  1435.2  1260  614  544  172
# 147         Texas Rangers  68   94  4.22  162  1435.0  1345  743  673  169
# 148     Toronto Blue Jays  92   70  3.87  162  1441.1  1356  679  620  180
# 149  Washington Nationals  55  107  5.00  162  1411.2  1469  855  785  244
#
#      ...  WP    BF   FIP   WHIP   H9  HR9  BB9  SO9  year  tm_code
# ...

# %%
pit[pit['year'] == 2022]
# Out:
#                         Tm    W    L   ERA    G      IP     H    R   ER   HR  \
# 120   Arizona Diamondbacks   74   88  4.25  162  1430.0  1345  740  676  191
# 121         Atlanta Braves  101   61  3.46  162  1448.0  1224  609  556  148
# 122      Baltimore Orioles   83   79  3.97  162  1433.1  1406  688  632  171
# 123         Boston Red Sox   78   84  4.53  162  1431.0  1411  787  721  185
# 124           Chicago Cubs   74   88  4.00  162  1443.2  1342  731  642  207
# 125      Chicago White Sox   81   81  3.92  162  1447.2  1330  717  631  166
# 126        Cincinnati Reds   62  100  4.86  162  1423.1  1366  815  768  213
# 127    Cleveland Guardians   92   70  3.46  162  1456.0  1252  634  560  172
# 128       Colorado Rockies   68   94  5.06  162  1425.1  1516  873  802  184
# 129         Detroit Tigers   66   96  4.04  162  1419.2  1336  713  637  167
# 130         Houston Astros  106   56  2.90  162  1445.1  1121  518  465  134
# ...

# %% [markdown]
# #### year 2022 starts on column 120 - will be used as test data

# %%
bat = bat.drop(columns=['Tm'])
bat
# Out:
#       R/G    G    PA    AB    R     H   2B  3B   HR  RBI  ...    SO     BA  \
# 0    5.01  162  6224  5525  812  1405  314  39  220  776  ...  1456  0.254
# 1    4.52  162  6216  5584  732  1467  289  26  165  706  ...  1184  0.263
# 2    4.59  162  6140  5650  743  1469  269  12  232  713  ...  1412  0.260
# 3    4.85  162  6338  5669  785  1461  302  19  168  735  ...  1224  0.258
# 4    5.07  162  6283  5496  822  1402  274  29  223  785  ...  1401  0.255
# ..    ...  ...   ...   ...  ...   ...  ...  ..  ...  ...  ...   ...    ...
# 145  4.77  162  6165  5496  772  1386  290  21  197  739  ...  1226  0.252
# 146  4.11  162  6008  5412  666  1294  296  17  139  634  ...  1395  0.239
# 147  4.36  162  6029  5478  707  1308  224  20  198  670  ...  1446  0.239
# 148  4.78  162  6158  5555  775  1464  307  12  200  756  ...  1242  0.264
# 149  3.72  162  5998  5434  603  1351  252  20  136  579  ...  1221  0.249
#
#        OBP    SLG    OPS    TB  HBP  SF  year  tm_code
# ...

# %%
pit = pit.drop(columns=['Tm'])
pit
# Out:
#       W    L   ERA    G      IP     H    R   ER   HR   BB  ...  WP    BF  \
# 0    93   69  3.66  162  1441.0  1309  659  586  171  516  ...  82  6072
# 1    72   90  4.72  162  1441.1  1463  821  756  192  584  ...  58  6306
# 2    75   87  4.97  162  1441.0  1505  841  795  242  579  ...  53  6293
# 3    93   69  3.70  162  1482.1  1384  668  610  195  465  ...  43  6217
# 4    92   70  3.95  162  1447.1  1294  695  636  194  554  ...  73  6108
# ..   ..  ...   ...  ...     ...   ...  ...  ...  ...  ...  ...  ..   ...
# 145  93   69  3.79  162  1435.2  1335  637  605  146  489  ...  43  6014
# 146  86   76  3.41  162  1435.2  1260  614  544  172  384  ...  54  5930
# 147  68   94  4.22  162  1435.0  1345  743  673  169  581  ...  66  6167
# 148  92   70  3.87  162  1441.1  1356  679  620  180  424  ...  29  6053
# 149  55  107  5.00  162  1411.2  1469  855  785  244  558  ...  59  6220
#
#       FIP   WHIP   H9  HR9  BB9  SO9  year  tm_code
# ...

# %%
test_bat = bat[120:]

# %%
train_bat = bat[:120]

# %%
test_pit = pit[120:]

# %%
train_pit = pit[:120]

# %%
import matplotlib.pyplot as plt

# %%
bat['W'] = pit['W']
bat
# Out:
#       R/G    G    PA    AB    R     H   2B  3B   HR  RBI  ...     BA    OBP  \
# 0    5.01  162  6224  5525  812  1405  314  39  220  776  ...  0.254  0.329
# 1    4.52  162  6216  5584  732  1467  289  26  165  706  ...  0.263  0.326
# 2    4.59  162  6140  5650  743  1469  269  12  232  713  ...  0.260  0.312
# 3    4.85  162  6338  5669  785  1461  302  19  168  735  ...  0.258  0.329
# 4    5.07  162  6283  5496  822  1402  274  29  223  785  ...  0.255  0.338
# ..    ...  ...   ...   ...  ...   ...  ...  ..  ...  ...  ...    ...    ...
# 145  4.77  162  6165  5496  772  1386  290  21  197  739  ...  0.252  0.325
# 146  4.11  162  6008  5412  666  1294  296  17  139  634  ...  0.239  0.309
# 147  4.36  162  6029  5478  707  1308  224  20  198  670  ...  0.239  0.301
# 148  4.78  162  6158  5555  775  1464  307  12  200  756  ...  0.264  0.329
# 149  3.72  162  5998  5434  603  1351  252  20  136  579  ...  0.249  0.310
#
#        SLG    OPS    TB  HBP  SF  year  tm_code   W
# ...

# %%
bat['L'] = pit['L']

# %% [markdown]
# ## EDA for Batting

# %%
bat.columns
# Out:
# Index(['R/G', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'SO',
#        'BA', 'OBP', 'SLG', 'OPS', 'TB', 'HBP', 'SF', 'year', 'tm_code', 'W',
#        'L'],
#       dtype='object')

# %%
bat.plot.bar(stacked=True);

# %%
import seaborn as sns
# %matplotlib inline

# calculate the correlation matrix on the numeric columns
corr = bat.select_dtypes('number').corr()

# plot the heatmap
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
plt.xlabel("RBI's Game")
plt.ylabel("Wins")
plt.title("MLB")

plt.scatter(bat["RBI"], bat["W"])

# %%
plt.xlabel("HR's Game")
plt.ylabel("Wins")
plt.title("MLB")

plt.scatter(bat["HR"], bat["W"])

# %%
plt.xlabel("SF's Game")
plt.ylabel("Wins")
plt.title("MLB")

plt.scatter(bat["SF"], bat["W"])

# %%
sns.distplot(bat['W']);
# Out:
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(bat['HR']);
# Out:
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(bat['RBI']);
# Out:
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(bat['W']);
# Out:
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(x=bat["W"])
plt.show()

# %%
sns.boxplot(x=bat["HR"])
plt.show()

# %% [markdown]
# ## EDA for Pitching

# %%
pit
# Out:
#       W    L   ERA    G      IP     H    R   ER   HR   BB  ...  WP    BF  \
# 0    93   69  3.66  162  1441.0  1309  659  586  171  516  ...  82  6072
# 1    72   90  4.72  162  1441.1  1463  821  756  192  584  ...  58  6306
# 2    75   87  4.97  162  1441.0  1505  841  795  242  579  ...  53  6293
# 3    93   69  3.70  162  1482.1  1384  668  610  195  465  ...  43  6217
# 4    92   70  3.95  162  1447.1  1294  695  636  194  554  ...  73  6108
# ..   ..  ...   ...  ...     ...   ...  ...  ...  ...  ...  ...  ..   ...
# 145  93   69  3.79  162  1435.2  1335  637  605  146  489  ...  43  6014
# 146  86   76  3.41  162  1435.2  1260  614  544  172  384  ...  54  5930
# 147  68   94  4.22  162  1435.0  1345  743  673  169  581  ...  66  6167
# 148  92   70  3.87  162  1441.1  1356  679  620  180  424  ...  29  6053
# 149  55  107  5.00  162  1411.2  1469  855  785  244  558  ...  59  6220
#
#       FIP   WHIP   H9  HR9  BB9  SO9  year  tm_code
# ...

# %%
pit.plot.bar(stacked=True);

# %%
# calculate the correlation matrix on the numeric columns
corr = pit.select_dtypes('number').corr()

# plot the heatmap
sns.heatmap(corr)
# Out:
# <AxesSubplot:>

# %%
plt.xlabel("SO's")
plt.ylabel("Wins")
plt.title("MLB")

plt.scatter(pit["SO"], pit["W"])

# %%
plt.xlabel("era")
plt.ylabel("Wins")
plt.title("MLB")

plt.scatter(pit["ERA"], pit["W"])

# %%
plt.xlabel("WHIP")
plt.ylabel("Wins")
plt.title("MLB")

plt.scatter(pit["WHIP"], pit["W"])

# %%
sns.distplot(pit['WHIP']);
# Out:
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(pit['ERA']);
# Out:
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(pit['SO']);
# Out:
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(pit['HR']);
# Out:
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(x=pit["HR"])
plt.show()

# %%
sns.boxplot(x=pit["SO"])
plt.show()

# %%
sns.boxplot(x=pit["ERA"])
plt.show()

# %%
sns.boxplot(x=pit["H9"])
plt.show()
