# %%
import pandas as pd 
import numpy as np

# %%
wakep = pd.read_csv('../Data/wake-pitch.csv')

# %%
wakep
# Out:
#       Rk            Name   Age   W   L   W-L%    ERA   G  GS  GF  ...  BK  WP  \
# 0    1.0    Will Andrews  22.0   0   0    NaN   0.00   3   0 NaN  ...   0   0
# 1    2.0     Joe Ariola*  19.0   0   0    NaN   6.75  17   0 NaN  ...   0   2
# 2    3.0     Derek Crum*  22.0   1   0  1.000   3.38  19   0 NaN  ...   0   1
# 3    4.0    Josh Hartle*  20.0  11   2  0.846   2.80  17  16 NaN  ...   1   7
# 4    5.0  Zach Johnston*  19.0   0   0    NaN   6.75   4   0 NaN  ...   0   0
# 5    6.0     Seth Keener  21.0   7   1  0.875   2.23  21   7 NaN  ...   1   4
# 6    7.0    Rhett Lowder  21.0  15   0  1.000   1.92  17  17 NaN  ...   0   2
# 7    8.0    Reed Mascolo  23.0   7   1  0.875   3.96  14  11 NaN  ...   1   4
# 8    9.0  Michael Massey  20.0   3   0  1.000   2.58  25   1 NaN  ...   1   1
# 9   10.0     Cam Minacci  21.0   0   1  0.000   2.73  27   0 NaN  ...   0   3
# 10  11.0        Will Ray  21.0   1   1  0.500   5.40  18   0 NaN  ...   0   0
# ...

# %%
wakeb = pd.read_csv('../Data/wake-bat.csv')

# %%
wakeb
# Out:
#       Rk            Name   Age   G    PA    AB    R    H   2B  3B  ...    OBP  \
# 0    1.0  Pierce Bennett  22.0  56   263   221   59   79   19   0  ...  0.434
# 1    2.0    Adam Cecere*  22.0  40   172   135   40   39   11   0  ...  0.436
# 2    3.0   Danny Corona*  19.0  44   159   136   28   41    9   0  ...  0.378
# 3    4.0  Lucas Costello  21.0  45   188   155   43   47    9   1  ...  0.410
# 4    5.0       Gio Cueto  19.0  32    98    78   14   15    4   0  ...  0.337
# 5    6.0    Tommy Hawke*  20.0  62   309   254   72   90   19   1  ...  0.466
# 6    7.0   Marek Houston  19.0  61   245   205   38   46    5   1  ...  0.332
# 7    8.0  Justin Johnson  23.0  61   276   223   60   76   15   3  ...  0.442
# 8    9.0       Kyle Joye  24.0  17    46    39   13   11    4   0  ...  0.391
# 9   10.0      Chris Katz  20.0  26    78    63   10   13    4   0  ...  0.346
# 10  11.0     Nick Kurtz*  20.0  53   252   181   75   67   10   0  ...  0.538
# ...

# %%
wakep = wakep.drop(columns=['BK', 'IBB', 'W-L%', 'GF', 'CG', 'Rk', 'Notes'])
wakep
# Out:
#               Name   Age   W   L    ERA   G  GS  SHO  SV     IP  ...   SO  \
# 0     Will Andrews  22.0   0   0   0.00   3   0    0   0    2.2  ...    3
# 1      Joe Ariola*  19.0   0   0   6.75  17   0    0   0   13.1  ...   17
# 2      Derek Crum*  22.0   1   0   3.38  19   0    0   0   16.0  ...   14
# 3     Josh Hartle*  20.0  11   2   2.80  17  16    0   0   96.1  ...  131
# 4   Zach Johnston*  19.0   0   0   6.75   4   0    0   0    2.2  ...    4
# 5      Seth Keener  21.0   7   1   2.23  21   7    0   1   64.2  ...   86
# 6     Rhett Lowder  21.0  15   0   1.92  17  17    0   0  108.0  ...  131
# 7     Reed Mascolo  23.0   7   1   3.96  14  11    0   0   50.0  ...   44
# 8   Michael Massey  20.0   3   0   2.58  25   1    0   1   38.1  ...   71
# 9      Cam Minacci  21.0   0   1   2.73  27   0    0  12   29.2  ...   44
# 10        Will Ray  21.0   1   1   5.40  18   0    0   0   11.2  ...    9
# 11     Cole Roland  24.0   2   1   2.12  24   0    0   2   29.2  ...   52
# ...

# %%
wakep = wakep.sort_values(by=['BF'], ascending=False)
wakep
# Out:
#               Name   Age   W   L    ERA   G  GS  SHO  SV     IP  ...   SO  \
# 16      16 Players  21.1  52  10   2.84  62  62   10  19  545.2  ...  738
# 6     Rhett Lowder  21.0  15   0   1.92  17  17    0   0  108.0  ...  131
# 3     Josh Hartle*  20.0  11   2   2.80  17  16    0   0   96.1  ...  131
# 13  Sean Sullivan*  20.0   5   3   2.64  15  10    0   3   64.2  ...  108
# 5      Seth Keener  21.0   7   1   2.23  21   7    0   1   64.2  ...   86
# 7     Reed Mascolo  23.0   7   1   3.96  14  11    0   0   50.0  ...   44
# 8   Michael Massey  20.0   3   0   2.58  25   1    0   1   38.1  ...   71
# 9      Cam Minacci  21.0   0   1   2.73  27   0    0  12   29.2  ...   44
# 11     Cole Roland  24.0   2   1   2.12  24   0    0   2   29.2  ...   52
# 2      Derek Crum*  22.0   1   0   3.38  19   0    0   0   16.0  ...   14
# 1      Joe Ariola*  19.0   0   0   6.75  17   0    0   0   13.1  ...   17
# 10        Will Ray  21.0   1   1   5.40  18   0    0   0   11.2  ...    9
# ...

# %%
wakep = wakep[1:]

# %%
wakeb
# Out:
#       Rk            Name   Age   G    PA    AB    R    H   2B  3B  ...    OBP  \
# 0    1.0  Pierce Bennett  22.0  56   263   221   59   79   19   0  ...  0.434
# 1    2.0    Adam Cecere*  22.0  40   172   135   40   39   11   0  ...  0.436
# 2    3.0   Danny Corona*  19.0  44   159   136   28   41    9   0  ...  0.378
# 3    4.0  Lucas Costello  21.0  45   188   155   43   47    9   1  ...  0.410
# 4    5.0       Gio Cueto  19.0  32    98    78   14   15    4   0  ...  0.337
# 5    6.0    Tommy Hawke*  20.0  62   309   254   72   90   19   1  ...  0.466
# 6    7.0   Marek Houston  19.0  61   245   205   38   46    5   1  ...  0.332
# 7    8.0  Justin Johnson  23.0  61   276   223   60   76   15   3  ...  0.442
# 8    9.0       Kyle Joye  24.0  17    46    39   13   11    4   0  ...  0.391
# 9   10.0      Chris Katz  20.0  26    78    63   10   13    4   0  ...  0.346
# 10  11.0     Nick Kurtz*  20.0  53   252   181   75   67   10   0  ...  0.538
# ...

# %%
wakeb = wakeb.drop(columns=['IBB', 'Notes', 'Rk', 'SH', 'CS', 'SB', 'GDP'])
wakeb
# Out:
#               Name   Age   G    PA    AB    R    H   2B  3B   HR  RBI   BB  \
# 0   Pierce Bennett  22.0  56   263   221   59   79   19   0    7   65   26
# 1     Adam Cecere*  22.0  40   172   135   40   39   11   0   10   37   30
# 2    Danny Corona*  19.0  44   159   136   28   41    9   0   13   43   15
# 3   Lucas Costello  21.0  45   188   155   43   47    9   1    4   24   17
# 4        Gio Cueto  19.0  32    98    78   14   15    4   0    2    8   11
# 5     Tommy Hawke*  20.0  62   309   254   72   90   19   1    7   33   50
# 6    Marek Houston  19.0  61   245   205   38   46    5   1    4   29   32
# 7   Justin Johnson  23.0  61   276   223   60   76   15   3   16   76   32
# 8        Kyle Joye  24.0  17    46    39   13   11    4   0    2   10    5
# 9       Chris Katz  20.0  26    78    63   10   13    4   0    3   16   13
# 10     Nick Kurtz*  20.0  53   252   181   75   67   10   0   24   69   59
# ...

# %%
wakeb = wakeb.sort_values(by=['PA'], ascending=False)
wakeb
# Out:
#               Name   Age   G    PA    AB    R    H   2B  3B   HR  RBI   BB  \
# 16      16 Players  20.8  62  2682  2142  583  662  128   7  129  534  404
# 5     Tommy Hawke*  20.0  62   309   254   72   90   19   1    7   33   50
# 14    Brock Wilken  21.0  62   302   224   88   80   15   1   30   80   65
# 7   Justin Johnson  23.0  61   276   223   60   76   15   3   16   76   32
# 0   Pierce Bennett  22.0  56   263   221   59   79   19   0    7   65   26
# 10     Nick Kurtz*  20.0  53   252   181   75   67   10   0   24   69   59
# 6    Marek Houston  19.0  61   245   205   38   46    5   1    4   29   32
# 3   Lucas Costello  21.0  45   188   155   43   47    9   1    4   24   17
# 1     Adam Cecere*  22.0  40   172   135   40   39   11   0   10   37   30
# 11     Bennett Lee  21.0  42   170   130   29   40    3   0    7   33   29
# 2    Danny Corona*  19.0  44   159   136   28   41    9   0   13   43   15
# ...

# %%
wakeb = wakeb[1:]

# %%
wakeb
# Out:
#               Name   Age   G   PA   AB   R   H  2B  3B  HR  RBI  BB  SO  \
# 5     Tommy Hawke*  20.0  62  309  254  72  90  19   1   7   33  50  48
# 14    Brock Wilken  21.0  62  302  224  88  80  15   1  30   80  65  51
# 7   Justin Johnson  23.0  61  276  223  60  76  15   3  16   76  32  42
# 0   Pierce Bennett  22.0  56  263  221  59  79  19   0   7   65  26  21
# 10     Nick Kurtz*  20.0  53  252  181  75  67  10   0  24   69  59  45
# 6    Marek Houston  19.0  61  245  205  38  46   5   1   4   29  32  38
# 3   Lucas Costello  21.0  45  188  155  43  47   9   1   4   24  17  28
# 1     Adam Cecere*  22.0  40  172  135  40  39  11   0  10   37  30  49
# 11     Bennett Lee  21.0  42  170  130  29  40   3   0   7   33  29  28
# 2    Danny Corona*  19.0  44  159  136  28  41   9   0  13   43  15  45
# 4        Gio Cueto  19.0  32   98   78  14  15   4   0   2    8  11  15
# 13  Jake Reinisch*  21.0  27   91   73   8  13   1   0   0    9  15  22
# ...
