# %%
import pandas as pd
import numpy as np

# %%
flop = pd.read_csv('../Data/florida-pitch.csv')
flob = pd.read_csv('../Data/florida-bat.csv')

# %%
flop = flop.drop(columns=['BK', 'IBB', 'W-L%', 'GF', 'CG', 'Rk', 'Notes'])
flop.head()
# Out:
#                 Name Age  W  L    ERA   G  GS  SHO  SV    IP  ...  SO  HBP  \
# 0      Philip Abner*  21  3  0   3.16  25   0    0   3  31.1  ...  51    3
# 1      Chris Arroyo*  18  1  0   5.06   7   0    0   0   5.1  ...   6    0
# 2    Jac Caglianone*  20  7  3   3.78  16  16    0   0  69.0  ...  81    9
# 3   Nick Ficarrotta?  --  0  0   5.45  20   0    0   1  34.2  ...  41    6
# 4  Carsten Finnvold*  21  0  0  36.00   1   0    0   0   1.0  ...   1    0
#
#    WP   BF   WHIP    H9  HR9   BB9   SO9  SO/W
# 0   5  141  1.436   7.5  0.6   5.5  14.6  2.68
# 1   1   25  1.688   3.4  0.0  11.8  10.1  0.86
# 2   7  311  1.377   6.0  0.8   6.4  10.6  1.65
# 3   4  163  1.558  11.2  1.0   2.9  10.6  3.73
# 4   0    7  4.000  27.0  9.0   9.0   9.0  1.00
#
# [5 rows x 25 columns]

# %%
flop = flop.sort_values(by=['BF'], ascending=False)
flop.head()
# Out:
#                Name   Age   W   L   ERA   G  GS  SHO  SV     IP  ...   SO  \
# 16       16 Players  20.3  50  15  4.52  65  65    8  21  557.0  ...  668
# 12   Brandon Sproat    22   8   3  4.69  17  17    1   0   96.0  ...  120
# 15  Hurston Waldrep    21   9   3  4.15  17  17    0   0   93.1  ...  142
# 2   Jac Caglianone*    20   7   3  3.78  16  16    0   0   69.0  ...   81
# 11      Ryan Slater    21  10   1  3.51  24   3    0   3   56.1  ...   47
#
#     HBP  WP    BF   WHIP   H9  HR9  BB9   SO9  SO/W
# 16   68  47  2489  1.368  8.0  1.1  4.3  10.8  2.50
# 12   14   7   415  1.208  7.1  1.3  3.8  11.3  3.00
# 15    7  10   403  1.307  7.1  1.2  4.6  13.7  2.96
# 2     9   7   311  1.377  6.0  0.8  6.4  10.6  1.65
# 11    5   2   237  1.172  7.8  1.1  2.7   7.5  2.76
#
# [5 rows x 25 columns]

# %%
flop = flop[1:]
flop.head()
# Out:
#                Name Age   W  L   ERA   G  GS  SHO  SV    IP  ...   SO  HBP  \
# 12   Brandon Sproat  22   8  3  4.69  17  17    1   0  96.0  ...  120   14
# 15  Hurston Waldrep  21   9  3  4.15  17  17    0   0  93.1  ...  142    7
# 2   Jac Caglianone*  20   7  3  3.78  16  16    0   0  69.0  ...   81    9
# 11      Ryan Slater  21  10  1  3.51  24   3    0   3  56.1  ...   47    5
# 8     Brandon Neely  19   0  2  3.66  30   0    0  13  46.2  ...   64    4
#
#     WP   BF   WHIP   H9  HR9  BB9   SO9  SO/W
# 12   7  415  1.208  7.1  1.3  3.8  11.3  3.00
# 15  10  403  1.307  7.1  1.2  4.6  13.7  2.96
# 2    7  311  1.377  6.0  0.8  6.4  10.6  1.65
# 11   2  237  1.172  7.8  1.1  2.7   7.5  2.76
# 8    0  202  1.243  7.9  1.0  3.3  12.3  3.76
#
# [5 rows x 25 columns]

# %%
flob = flob.drop(columns=['IBB', 'Notes', 'Rk', 'SH', 'CS', 'SB', 'GDP'])
flob.head()
# Out:
#               Name Age   G   PA   AB   R   H  2B  3B  HR  RBI  BB  SO     BA  \
# 0  Jac Caglianone*  20  65  291  256  70  86  13   2  31   84  16  50  0.336
# 1         Ty Evans  20  43  158  143  23  31   7   2   4   34   9  38  0.217
# 2     Deric Fabian  20  20   42   36   9  10   0   0   2    8   5  10  0.278
# 3    Colby Halter*  21  53  192  153  27  38   8   4   3   28  24  26  0.248
# 4      Luke Heyman  19  49  190  168  28  55   6   2  11   36  16  48  0.327
#
#      OBP    SLG    OPS   TB  HBP  SF
# 0  0.402  0.766  1.168  196   15   4
# 1  0.285  0.378  0.662   54    5   1
# 2  0.381  0.444  0.825   16    1   0
# 3  0.360  0.412  0.772   63    5   4
# 4  0.379  0.583  0.962   98    1   5

# %%
flob = flob.sort_values(by=['PA'], ascending=False)
flob.head()
# Out:
#                Name   Age   G    PA    AB    R    H   2B  3B   HR  RBI   BB  \
# 16       16 Players  20.9  65  2564  2142  521  628  116  19  129  484  297
# 0   Jac Caglianone*    20  65   291   256   70   86   13   2   31   84   16
# 10      Josh Rivera    22  64   283   229   66   83    9   1   17   68   44
# 5     Cade Kurland?    --  62   282   237   68   71   16   0   16   46   24
# 6    Wyatt Langford    21  58   273   212   76   79   24   3   18   48   51
#
#      SO     BA    OBP    SLG    OPS    TB  HBP  SF
# 16  501  0.293  0.394  0.546  0.940  1169   81  31
# 0    50  0.336  0.402  0.766  1.168   196   15   4
# 10   26  0.362  0.465  0.633  1.098   145    4   5
# 5    58  0.300  0.408  0.570  0.977   135   20   1
# 6    41  0.373  0.498  0.769  1.267   163    6   4

# %%
flob = flob[1:]
flob.head()
# Out:
#                Name Age   G   PA   AB   R   H  2B  3B  HR  RBI  BB  SO     BA  \
# 0   Jac Caglianone*  20  65  291  256  70  86  13   2  31   84  16  50  0.336
# 10      Josh Rivera  22  64  283  229  66  83   9   1  17   68  44  26  0.362
# 5     Cade Kurland?  --  62  282  237  68  71  16   0  16   46  24  58  0.300
# 6    Wyatt Langford  21  58  273  212  76  79  24   3  18   48  51  41  0.373
# 9    B.T. Riopelle*  23  63  267  216  52  54  10   2  16   65  37  74  0.250
#
#       OBP    SLG    OPS   TB  HBP  SF
# 0   0.402  0.766  1.168  196   15   4
# 10  0.465  0.633  1.098  145    4   5
# 5   0.408  0.570  0.977  135   20   1
# 6   0.498  0.769  1.267  163    6   4
# 9   0.377  0.537  0.914  116    9   3

# %%
flb = flob[:10]
flb
# Out:
#                   Name Age   G   PA   AB   R   H  2B  3B  HR  RBI  BB  SO  \
# 0      Jac Caglianone*  20  65  291  256  70  86  13   2  31   84  16  50
# 10         Josh Rivera  22  64  283  229  66  83   9   1  17   68  44  26
# 5        Cade Kurland?  --  62  282  237  68  71  16   0  16   46  24  58
# 6       Wyatt Langford  21  58  273  212  76  79  24   3  18   48  51  41
# 9       B.T. Riopelle*  23  63  267  216  52  54  10   2  16   65  37  74
# 11  Michael Robertson*  20  62  226  185  40  43   4   1   1   19  32  47
# 3        Colby Halter*  21  53  192  153  27  38   8   4   3   28  24  26
# 4          Luke Heyman  19  49  190  168  28  55   6   2  11   36  16  48
# 13       Tyler Shelnut  21  47  178  151  27  43  12   0   7   27  21  38
# 1             Ty Evans  20  43  158  143  23  31   7   2   4   34   9  38
#
#        BA    OBP    SLG    OPS   TB  HBP  SF
# 0   0.336  0.402  0.766  1.168  196   15   4
# 10  0.362  0.465  0.633  1.098  145    4   5
# ...

# %%
flb = flb.drop(columns=['Name', 'Age'])
flb
# Out:
#      G   PA   AB   R   H  2B  3B  HR  RBI  BB  SO     BA    OBP    SLG    OPS  \
# 0   65  291  256  70  86  13   2  31   84  16  50  0.336  0.402  0.766  1.168
# 10  64  283  229  66  83   9   1  17   68  44  26  0.362  0.465  0.633  1.098
# 5   62  282  237  68  71  16   0  16   46  24  58  0.300  0.408  0.570  0.977
# 6   58  273  212  76  79  24   3  18   48  51  41  0.373  0.498  0.769  1.267
# 9   63  267  216  52  54  10   2  16   65  37  74  0.250  0.377  0.537  0.914
# 11  62  226  185  40  43   4   1   1   19  32  47  0.232  0.359  0.281  0.640
# 3   53  192  153  27  38   8   4   3   28  24  26  0.248  0.360  0.412  0.772
# 4   49  190  168  28  55   6   2  11   36  16  48  0.327  0.379  0.583  0.962
# 13  47  178  151  27  43  12   0   7   27  21  38  0.285  0.382  0.503  0.885
# 1   43  158  143  23  31   7   2   4   34   9  38  0.217  0.285  0.378  0.662
#
#      TB  HBP  SF
# 0   196   15   4
# 10  145    4   5
# 5   135   20   1
# 6   163    6   4
# 9   116    9   3
# ...

# %%
df2 = flb.mean(axis=0)
df2
# Out:
# G       56.6000
# PA     234.0000
# AB     195.0000
# R       47.7000
# H       58.3000
# 2B      10.9000
# 3B       1.7000
# HR      12.4000
# RBI     45.5000
# BB      27.4000
# SO      44.6000
# BA       0.2930
# OBP      0.3915
# SLG      0.5432
# OPS      0.9345
# TB     109.8000
# HBP      7.4000
# SF       3.0000
# dtype: float64

# %%
s = df2.sort_index()
flbat_mean = s.to_frame().T
flbat_mean
# Out:
#      2B   3B     AB     BA    BB     G     H  HBP    HR     OBP     OPS  \
# 0  10.9  1.7  195.0  0.293  27.4  56.6  58.3  7.4  12.4  0.3915  0.9345
#
#       PA     R   RBI   SF     SLG    SO     TB
# 0  234.0  47.7  45.5  3.0  0.5432  44.6  109.8

# %%
# flbat_mean.to_csv('fl-bat-mean.csv', index=False)

# %%
flop
# Out:
#                  Name Age   W  L    ERA   G  GS  SHO  SV    IP  ...   SO  HBP  \
# 12     Brandon Sproat  22   8  3   4.69  17  17    1   0  96.0  ...  120   14
# 15    Hurston Waldrep  21   9  3   4.15  17  17    0   0  93.1  ...  142    7
# 2     Jac Caglianone*  20   7  3   3.78  16  16    0   0  69.0  ...   81    9
# 11        Ryan Slater  21  10  1   3.51  24   3    0   3  56.1  ...   47    5
# 8       Brandon Neely  19   0  2   3.66  30   0    0  13  46.2  ...   64    4
# 5        Cade Fisher*  19   6  0   3.02  22   2    0   1  41.2  ...   41    7
# 3    Nick Ficarrotta?  --   0  0   5.45  20   0    0   1  34.2  ...   41    6
# 0       Philip Abner*  21   3  0   3.16  25   0    0   3  31.1  ...   51    3
# 13        Yoel Tejeda  19   2  0   5.56   8   6    0   0  22.2  ...   11    2
# 9       Tyler Nesbitt  21   1  0   2.95  10   3    0   0  21.1  ...   17    5
# 10      Blake Purnell  21   1  0   7.85  15   0    0   0  18.1  ...   18    6
# ...

# %%
flip = flop[:3]
flip
# Out:
#                Name Age  W  L   ERA   G  GS  SHO  SV    IP  ...   SO  HBP  WP  \
# 12   Brandon Sproat  22  8  3  4.69  17  17    1   0  96.0  ...  120   14   7
# 15  Hurston Waldrep  21  9  3  4.15  17  17    0   0  93.1  ...  142    7  10
# 2   Jac Caglianone*  20  7  3  3.78  16  16    0   0  69.0  ...   81    9   7
#
#      BF   WHIP   H9  HR9  BB9   SO9  SO/W
# 12  415  1.208  7.1  1.3  3.8  11.3  3.00
# 15  403  1.307  7.1  1.2  4.6  13.7  2.96
# 2   311  1.377  6.0  0.8  6.4  10.6  1.65
#
# [3 rows x 25 columns]

# %%
flp = flop.sort_values(by=['G'], ascending=False)
flpg = flp[:3]
flpg
# Out:
#              Name Age   W  L   ERA   G  GS  SHO  SV    IP  ...  SO  HBP  WP  \
# 8   Brandon Neely  19   0  2  3.66  30   0    0  13  46.2  ...  64    4   0
# 0   Philip Abner*  21   3  0  3.16  25   0    0   3  31.1  ...  51    3   5
# 11    Ryan Slater  21  10  1  3.51  24   3    0   3  56.1  ...  47    5   2
#
#      BF   WHIP   H9  HR9  BB9   SO9  SO/W
# 8   202  1.243  7.9  1.0  3.3  12.3  3.76
# 0   141  1.436  7.5  0.6  5.5  14.6  2.68
# 11  237  1.172  7.8  1.1  2.7   7.5  2.76
#
# [3 rows x 25 columns]

# %%
frames = [flpg, flip]

result = pd.concat(frames)
result
# Out:
#                Name Age   W  L   ERA   G  GS  SHO  SV    IP  ...   SO  HBP  \
# 8     Brandon Neely  19   0  2  3.66  30   0    0  13  46.2  ...   64    4
# 0     Philip Abner*  21   3  0  3.16  25   0    0   3  31.1  ...   51    3
# 11      Ryan Slater  21  10  1  3.51  24   3    0   3  56.1  ...   47    5
# 12   Brandon Sproat  22   8  3  4.69  17  17    1   0  96.0  ...  120   14
# 15  Hurston Waldrep  21   9  3  4.15  17  17    0   0  93.1  ...  142    7
# 2   Jac Caglianone*  20   7  3  3.78  16  16    0   0  69.0  ...   81    9
#
#     WP   BF   WHIP   H9  HR9  BB9   SO9  SO/W
# 8    0  202  1.243  7.9  1.0  3.3  12.3  3.76
# 0    5  141  1.436  7.5  0.6  5.5  14.6  2.68
# 11   2  237  1.172  7.8  1.1  2.7   7.5  2.76
# 12   7  415  1.208  7.1  1.3  3.8  11.3  3.00
# 15  10  403  1.307  7.1  1.2  4.6  13.7  2.96
# 2    7  311  1.377  6.0  0.8  6.4  10.6  1.65
#
# [6 rows x 25 columns]

# %%
result = result.drop_duplicates()
result
# Out:
#                Name Age   W  L   ERA   G  GS  SHO  SV    IP  ...   SO  HBP  \
# 8     Brandon Neely  19   0  2  3.66  30   0    0  13  46.2  ...   64    4
# 0     Philip Abner*  21   3  0  3.16  25   0    0   3  31.1  ...   51    3
# 11      Ryan Slater  21  10  1  3.51  24   3    0   3  56.1  ...   47    5
# 12   Brandon Sproat  22   8  3  4.69  17  17    1   0  96.0  ...  120   14
# 15  Hurston Waldrep  21   9  3  4.15  17  17    0   0  93.1  ...  142    7
# 2   Jac Caglianone*  20   7  3  3.78  16  16    0   0  69.0  ...   81    9
#
#     WP   BF   WHIP   H9  HR9  BB9   SO9  SO/W
# 8    0  202  1.243  7.9  1.0  3.3  12.3  3.76
# 0    5  141  1.436  7.5  0.6  5.5  14.6  2.68
# 11   2  237  1.172  7.8  1.1  2.7   7.5  2.76
# 12   7  415  1.208  7.1  1.3  3.8  11.3  3.00
# 15  10  403  1.307  7.1  1.2  4.6  13.7  2.96
# 2    7  311  1.377  6.0  0.8  6.4  10.6  1.65
#
# [6 rows x 25 columns]

# %%
result = result.drop(columns=['Name'])
result
# Out:
#    Age   W  L   ERA   G  GS  SHO  SV    IP   H  ...   SO  HBP  WP   BF   WHIP  \
# 8   19   0  2  3.66  30   0    0  13  46.2  41  ...   64    4   0  202  1.243
# 0   21   3  0  3.16  25   0    0   3  31.1  26  ...   51    3   5  141  1.436
# 11  21  10  1  3.51  24   3    0   3  56.1  49  ...   47    5   2  237  1.172
# 12  22   8  3  4.69  17  17    1   0  96.0  76  ...  120   14   7  415  1.208
# 15  21   9  3  4.15  17  17    0   0  93.1  74  ...  142    7  10  403  1.307
# 2   20   7  3  3.78  16  16    0   0  69.0  46  ...   81    9   7  311  1.377
#
#      H9  HR9  BB9   SO9  SO/W
# 8   7.9  1.0  3.3  12.3  3.76
# 0   7.5  0.6  5.5  14.6  2.68
# 11  7.8  1.1  2.7   7.5  2.76
# 12  7.1  1.3  3.8  11.3  3.00
# 15  7.1  1.2  4.6  13.7  2.96
# 2   6.0  0.8  6.4  10.6  1.65
#
# [6 rows x 24 columns]

# %%
result.columns
# Out:
# Index(['Age', 'W', 'L', 'ERA', 'G', 'GS', 'SHO', 'SV', 'IP', 'H', 'R', 'ER',
#        'HR', 'BB', 'SO', 'HBP', 'WP', 'BF', 'WHIP', 'H9', 'HR9', 'BB9', 'SO9',
#        'SO/W'],
#       dtype='object')

# %%
df2 = result[['W', 'L', 'ERA', 'G', 'GS', 'SHO', 'SV', 'IP', 'H', 'R', 'ER', 'HR',
       'BB', 'SO', 'HBP', 'WP', 'BF', 'WHIP', 'H9', 'HR9', 'BB9', 'SO9',
       'SO/W']].mean()

# %%
p = df2.sort_index()
flpit_mean = p.to_frame().T
flpit_mean
# Out:
#           BB       BB9          BF    ER    ERA     G        GS     H  \
# 0  31.666667  4.383333  284.833333  29.0  3.825  21.5  8.833333  52.0
#
#          H9  HBP  ...    L     R       SHO         SO      SO/W        SO9  \
# 0  7.233333  7.0  ...  2.0  32.0  0.166667  84.166667  2.801667  11.666667
#
#          SV         W    WHIP        WP
# 0  3.166667  6.166667  1.2905  5.166667
#
# [1 rows x 23 columns]

# %%
# flpit_mean.to_csv('fl-pitch-mean.csv', index=False)
