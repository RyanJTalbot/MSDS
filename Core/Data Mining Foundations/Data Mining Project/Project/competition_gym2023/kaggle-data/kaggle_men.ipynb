# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
raw_data = pd.read_csv('athlete_events.csv')
noc = pd.read_csv('noc_regions.csv')

# %%
raw_data
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# 1                China  CHN  2012 Summer  2012  Summer          London
# 2              Denmark  DEN  1920 Summer  1920  Summer       Antwerpen
# 3       Denmark/Sweden  DEN  1900 Summer  1900  Summer           Paris
# 4          Netherlands  NED  1988 Winter  1988  Winter         Calgary
# ...                ...  ...          ...   ...     ...             ...
# 271111        Poland-1  POL  1976 Winter  1976  Winter       Innsbruck
# 271112          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271113          Poland  POL  2014 Winter  2014  Winter           Sochi
# 271114          Poland  POL  1998 Winter  1998  Winter          Nagano
# 271115          Poland  POL  2002 Winter  2002  Winter  Salt Lake City
#
#                 Sport                                     Event Medal
# 0          Basketball               Basketball Men's Basketball   NaN
# 1                Judo              Judo Men's Extra-Lightweight   NaN
# 2            Football                   Football Men's Football   NaN
# 3          Tug-Of-War               Tug-Of-War Men's Tug-Of-War  Gold
# 4       Speed Skating          Speed Skating Women's 500 metres   NaN
# ...               ...                                       ...   ...
# 271111           Luge                Luge Mixed (Men)'s Doubles   NaN
# 271112    Ski Jumping  Ski Jumping Men's Large Hill, Individual   NaN
# 271113    Ski Jumping        Ski Jumping Men's Large Hill, Team   NaN
# 271114      Bobsleigh                      Bobsleigh Men's Four   NaN
# 271115      Bobsleigh                      Bobsleigh Men's Four   NaN
#
# [271116 rows x 15 columns]

# %%
df = raw_data.loc[raw_data['Sport']=='Gymnastics']

# %%
df[df["Sex"]=="M"]
# Out:
#             ID                         Name Sex   Age  Height  Weight  \
# 41          17      Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 42          17      Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 43          17      Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 44          17      Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# 45          17      Paavo Johannes Aaltonen   M  28.0   175.0    64.0
# ...        ...                          ...  ..   ...     ...     ...
# 270670  135363                 Angelo Zucca   M  20.0   167.0    63.0
# 270914  135481  Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
# 270915  135481  Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
# 270916  135481  Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
# 270917  135481  Jules Alexis "Louis" Zutter   M  30.0     NaN     NaN
#
#                Team  NOC        Games  Year  Season      City       Sport  \
# 41          Finland  FIN  1948 Summer  1948  Summer    London  Gymnastics
# 42          Finland  FIN  1948 Summer  1948  Summer    London  Gymnastics
# 43          Finland  FIN  1948 Summer  1948  Summer    London  Gymnastics
# 44          Finland  FIN  1948 Summer  1948  Summer    London  Gymnastics
# 45          Finland  FIN  1948 Summer  1948  Summer    London  Gymnastics
# ...             ...  ...          ...   ...     ...       ...         ...
# 270670        Italy  ITA  1976 Summer  1976  Summer  Montreal  Gymnastics
# 270914  Switzerland  SUI  1896 Summer  1896  Summer    Athina  Gymnastics
# 270915  Switzerland  SUI  1896 Summer  1896  Summer    Athina  Gymnastics
# 270916  Switzerland  SUI  1896 Summer  1896  Summer    Athina  Gymnastics
# 270917  Switzerland  SUI  1896 Summer  1896  Summer    Athina  Gymnastics
#
#                                          Event   Medal
# 41      Gymnastics Men's Individual All-Around  Bronze
# 42            Gymnastics Men's Team All-Around    Gold
# 43             Gymnastics Men's Floor Exercise     NaN
# 44                Gymnastics Men's Horse Vault    Gold
# 45              Gymnastics Men's Parallel Bars     NaN
# ...                                        ...     ...
# 270670        Gymnastics Men's Pommelled Horse     NaN
# 270914            Gymnastics Men's Horse Vault  Silver
# 270915          Gymnastics Men's Parallel Bars  Silver
# 270916         Gymnastics Men's Horizontal Bar     NaN
# 270917        Gymnastics Men's Pommelled Horse    Gold
#
# [17578 rows x 15 columns]

# %%
menz = ["M"]
mens = df.loc[df['Sex'].isin(menz)]

# %%
mens['Year'].unique()
# Out:
# array([1948, 1952, 1920, 2016, 1900, 1960, 2000, 2012, 1936, 1906, 1912,
#        1968, 1908, 1964, 1988, 1956, 1992, 2008, 1996, 2004, 1984, 1932,
#        1904, 1896, 1972, 1976, 1980, 1928, 1924])

# %%
mens['Event'].unique()
# Out:
# array(["Gymnastics Men's Individual All-Around",
#        "Gymnastics Men's Team All-Around",
#        "Gymnastics Men's Floor Exercise", "Gymnastics Men's Horse Vault",
#        "Gymnastics Men's Parallel Bars",
#        "Gymnastics Men's Horizontal Bar", "Gymnastics Men's Rings",
#        "Gymnastics Men's Pommelled Horse",
#        "Gymnastics Men's Team All-Around, Free System",
#        "Gymnastics Men's Team All-Around, Swedish System",
#        "Gymnastics Men's Individual All-Around, 5 Events",
#        "Gymnastics Men's Rope Climbing", "Gymnastics Men's Club Swinging",
#        "Gymnastics Men's Individual All-Around, Field Sports",
#        "Gymnastics Men's Individual All-Around, Apparatus Work",
#        "Gymnastics Men's Parallel Bars, Teams",
#        "Gymnastics Men's Horizontal Bar, Teams",
#        "Gymnastics Men's Side Horse",
#        "Gymnastics Men's Individual All-Around, 4 Events",
#        "Gymnastics Men's Tumbling"], dtype=object)

# %%
mens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17578 entries, 41 to 270917
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      17578 non-null  int64
#  1   Name    17578 non-null  object
#  2   Sex     17578 non-null  object
#  3   Age     16484 non-null  float64
#  4   Height  11022 non-null  float64
#  5   Weight  10758 non-null  float64
#  6   Team    17578 non-null  object
#  7   NOC     17578 non-null  object
#  8   Games   17578 non-null  object
#  9   Year    17578 non-null  int64
#  10  Season  17578 non-null  object
#  11  City    17578 non-null  object
#  12  Sport   17578 non-null  object
#  13  Event   17578 non-null  object
#  14  Medal   1555 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 2.1+ MB

# %% [markdown]
# ## data saved to man before remove medals

# %%
man = mens

# %%
mens = mens.dropna(subset=["Medal"])

# %%
mens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1555 entries, 41 to 270917
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      1555 non-null   int64
#  1   Name    1555 non-null   object
#  2   Sex     1555 non-null   object
#  3   Age     1492 non-null   float64
#  4   Height  699 non-null    float64
#  5   Weight  656 non-null    float64
#  6   Team    1555 non-null   object
#  7   NOC     1555 non-null   object
#  8   Games   1555 non-null   object
#  9   Year    1555 non-null   int64
#  10  Season  1555 non-null   object
#  11  City    1555 non-null   object
#  12  Sport   1555 non-null   object
#  13  Event   1555 non-null   object
#  14  Medal   1555 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 194.4+ KB

# %%
mens['Medal'].unique()
# Out:
# array(['Bronze', 'Gold', 'Silver'], dtype=object)

# %%
g = sns.catplot(data=mens, kind='count', x='Team', order = mens['Team'].value_counts().index, height=4, aspect=3).set_xticklabels(rotation=90)
g.fig.suptitle("Total number of Olympic medals in Mens's Artistic Gymnastics: 1900-2016")
a = mens['Team'].value_counts().to_frame()
a.iloc[0:10]
# Out:
#                Team
# Japan           160
# Soviet Union    141
# Norway          121
# Denmark         111
# Finland          99
# Sweden           88
# Italy            88
# United States    83
# Switzerland      83
# China            74

# %%
sns.set_palette('Reds')
usa = mens.loc[mens['Team']=='United States',]
usa.reset_index(drop=True, inplace=True)

# %%
u = sns.catplot(data=usa, kind='count', x='Year', height=4, aspect=3).set_xticklabels(rotation=90)
u.fig.suptitle('Distribution of Medals')
# Out:
# Text(0.5, 0.98, 'Distribution of Medals')

# %%
sns.set_palette('Blues')
teams = mens.loc[mens['Event']=='Team',]
teams.reset_index(drop=True, inplace=True)

# %%
t = sns.catplot(data=teams, kind='count', x='Team', height=4, aspect=3,
                order=teams['Team'].value_counts().index).set_xticklabels(rotation=90)
t.fig.suptitle('Distribution of Team Medals')
teams['Team'].value_counts().to_frame()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_60127/164894148.py in <cell line: 1>()
# ----> 1 t = sns.catplot(data=teams, kind='count', x='Team', height=4, aspect=3,
#       2                 order=teams['Team'].value_counts().index).set_xticklabels(rotation=90)
#       3 t.fig.suptitle('Distribution of Team Medals')
#       4 teams['Team'].value_counts().to_frame()
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/seaborn/categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3814     # so we need to define ``palette`` to get default behavior for the
#    3815     # categorical functions
# -> 3816     p.establish_colors(color, palette, 1)
#    3817     if kind != "point" or hue is not None:
#    3818         palette = p.colors
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/seaborn/categorical.py in establish_colors(self, color, palette, saturation)
#     317         # Determine the gray color to use for the lines framing the plot
#     318         light_vals = [colorsys.rgb_to_hls(*c)[1] for c in rgb_colors]
# --> 319         lum = min(light_vals) * .6
#     320         gray = mpl.colors.rgb2hex((lum, lum, lum))
#     321
#
# ValueError: min() arg is an empty sequence

# %%
g = sns.catplot(data=mens, kind='count', x='Age', height=4, aspect=3).set_xticklabels(rotation=90)
g.fig.suptitle('WAG Olympic Gymnasts: Age of Gymnast')
# Out:
# Text(0.5, 0.98, 'WAG Olympic Gymnasts: Age of Gymnast')

# %%
mens['Age'].value_counts().to_frame()
# Out:
#       Age
# 24.0  166
# 23.0  156
# 22.0  138
# 25.0  125
# 26.0  109
# 20.0  104
# 21.0  103
# 27.0  101
# 28.0   83
# 29.0   83
# 19.0   78
# 31.0   47
# 30.0   43
# 32.0   28
# 18.0   27
# 33.0   27
# 34.0   22
# 17.0   13
# 35.0   11
# 37.0   10
# 40.0    6
# 36.0    4
# 38.0    3
# 45.0    2
# 15.0    1
# 10.0    1
# 44.0    1

# %% [markdown]
# # Modern Era

# %%
modern = mens.loc[mens['Year'].isin([2008, 2012, 2016])]

# %%
modern['Year'].unique()
# Out:
# array([2012, 2016, 2008])

# %%
mens.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1555 entries, 41 to 270917
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      1555 non-null   int64
#  1   Name    1555 non-null   object
#  2   Sex     1555 non-null   object
#  3   Age     1492 non-null   float64
#  4   Height  699 non-null    float64
#  5   Weight  656 non-null    float64
#  6   Team    1555 non-null   object
#  7   NOC     1555 non-null   object
#  8   Games   1555 non-null   object
#  9   Year    1555 non-null   int64
#  10  Season  1555 non-null   object
#  11  City    1555 non-null   object
#  12  Sport   1555 non-null   object
#  13  Event   1555 non-null   object
#  14  Medal   1555 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 194.4+ KB

# %%
g = sns.catplot(data=modern, kind='count', x='NOC', order = modern['NOC'].value_counts().index).set_xticklabels(rotation=90)
g.fig.suptitle("Medal count by Country: Open-ended scoring")
modern['NOC'].value_counts().to_frame()
# Out:
#      NOC
# CHN   27
# JPN   21
# GBR   13
# RUS   12
# USA   11
# GER    5
# UKR    4
# BRA    4
# FRA    3
# KOR    2
# UZB    1
# ESP    1
# ITA    1
# POL    1
# GRE    1
# HUN    1
# PRK    1
# CRO    1
# NED    1

# %%
g = sns.catplot(data=modern, kind='count', x='Age', height=4, aspect=3).set_xticklabels(rotation=90)
modern['Age'].value_counts().to_frame()
# Out:
#       Age
# 24.0   20
# 23.0   18
# 27.0   15
# 19.0   14
# 22.0   12
# 20.0    7
# 28.0    6
# 25.0    5
# 26.0    5
# 21.0    3
# 31.0    2
# 30.0    2
# 29.0    1
# 18.0    1

# %%
grouped_modern = modern.groupby('NOC')
grouped_modern['Event'].value_counts().to_frame()
# Out:
#                                             Event
# NOC Event
# BRA Gymnastics Men's Floor Exercise             2
#     Gymnastics Men's Rings                      2
# CHN Gymnastics Men's Team All-Around           16
#     Gymnastics Men's Rings                      3
#     Gymnastics Men's Floor Exercise             2
#     Gymnastics Men's Horizontal Bar             2
#     Gymnastics Men's Parallel Bars              2
#     Gymnastics Men's Individual All-Around      1
#     Gymnastics Men's Pommelled Horse            1
# CRO Gymnastics Men's Pommelled Horse            1
# ESP Gymnastics Men's Floor Exercise             1
# FRA Gymnastics Men's Horse Vault                1
#     Gymnastics Men's Individual All-Around      1
#     Gymnastics Men's Parallel Bars              1
# GBR Gymnastics Men's Pommelled Horse            5
#     Gymnastics Men's Team All-Around            5
#     Gymnastics Men's Floor Exercise             1
#     Gymnastics Men's Horizontal Bar             1
#     Gymnastics Men's Individual All-Around      1
# GER Gymnastics Men's Horizontal Bar             3
#     Gymnastics Men's Individual All-Around      1
#     Gymnastics Men's Parallel Bars              1
# GRE Gymnastics Men's Rings                      1
# HUN Gymnastics Men's Pommelled Horse            1
# ITA Gymnastics Men's Rings                      1
# JPN Gymnastics Men's Team All-Around           16
#     Gymnastics Men's Individual All-Around      3
#     Gymnastics Men's Floor Exercise             1
#     Gymnastics Men's Horse Vault                1
# KOR Gymnastics Men's Horse Vault                1
#     Gymnastics Men's Parallel Bars              1
# NED Gymnastics Men's Horizontal Bar             1
# POL Gymnastics Men's Horse Vault                1
# PRK Gymnastics Men's Horse Vault                1
# RUS Gymnastics Men's Team All-Around            5
#     Gymnastics Men's Horse Vault                3
#     Gymnastics Men's Floor Exercise             2
#     Gymnastics Men's Parallel Bars              1
#     Gymnastics Men's Rings                      1
# UKR Gymnastics Men's Horse Vault                1
#     Gymnastics Men's Individual All-Around      1
#     Gymnastics Men's Parallel Bars              1
#     Gymnastics Men's Rings                      1
# USA Gymnastics Men's Team All-Around            6
#     Gymnastics Men's Horizontal Bar             2
#     Gymnastics Men's Individual All-Around      1
#     Gymnastics Men's Parallel Bars              1
#     Gymnastics Men's Pommelled Horse            1
# UZB Gymnastics Men's Parallel Bars              1

# %%
usa = modern[modern['NOC'] == 'USA']

# %%
usa['Year']
# Out:
# 9793      2008
# 21224     2008
# 88196     2008
# 98885     2008
# 98888     2008
# 137845    2012
# 137853    2016
# 137854    2016
# 167240    2016
# 226820    2008
# 235871    2008
# Name: Year, dtype: int64

# %%
usa['Name'].unique()
# Out:
# array(['Alexander Vladimirovich "Sasha" Artemev', 'Stephen Raj Bhavsar',
#        'Joseph "Joey" Hagerty', 'Jonathan Alan Horton',
#        'Danell Johan Leyva Gonzalez', 'Alexander Michael "Alex" Naddour',
#        'Justin Edward Spring', 'Kai-Wen "Kevin" Tan'], dtype=object)

# %%
usa
# Out:
#             ID                                     Name Sex   Age  Height  \
# 9793      5363  Alexander Vladimirovich "Sasha" Artemev   M  22.0   168.0
# 21224    11207                      Stephen Raj Bhavsar   M  27.0   169.0
# 88196    44726                    Joseph "Joey" Hagerty   M  26.0   163.0
# 98885    50052                     Jonathan Alan Horton   M  22.0   155.0
# 98888    50052                     Jonathan Alan Horton   M  22.0   155.0
# 137845   69285              Danell Johan Leyva Gonzalez   M  20.0   170.0
# 137853   69285              Danell Johan Leyva Gonzalez   M  24.0   170.0
# 137854   69285              Danell Johan Leyva Gonzalez   M  24.0   170.0
# 167240   84014         Alexander Michael "Alex" Naddour   M  25.0   170.0
# 226820  113975                     Justin Edward Spring   M  24.0   170.0
# 235871  118270                      Kai-Wen "Kevin" Tan   M  26.0   163.0
#
#         Weight           Team  NOC        Games  Year  Season            City  \
# 9793       NaN  United States  USA  2008 Summer  2008  Summer         Beijing
# 21224     54.0  United States  USA  2008 Summer  2008  Summer         Beijing
# 88196     61.0  United States  USA  2008 Summer  2008  Summer         Beijing
# 98885     59.0  United States  USA  2008 Summer  2008  Summer         Beijing
# 98888     59.0  United States  USA  2008 Summer  2008  Summer         Beijing
# 137845    68.0  United States  USA  2012 Summer  2012  Summer          London
# 137853    68.0  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 137854    68.0  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 167240    70.0  United States  USA  2016 Summer  2016  Summer  Rio de Janeiro
# 226820    64.0  United States  USA  2008 Summer  2008  Summer         Beijing
# 235871    64.0  United States  USA  2008 Summer  2008  Summer         Beijing
#
#              Sport                                   Event   Medal
# 9793    Gymnastics        Gymnastics Men's Team All-Around  Bronze
# 21224   Gymnastics        Gymnastics Men's Team All-Around  Bronze
# 88196   Gymnastics        Gymnastics Men's Team All-Around  Bronze
# 98885   Gymnastics        Gymnastics Men's Team All-Around  Bronze
# 98888   Gymnastics         Gymnastics Men's Horizontal Bar  Silver
# 137845  Gymnastics  Gymnastics Men's Individual All-Around  Bronze
# 137853  Gymnastics          Gymnastics Men's Parallel Bars  Silver
# 137854  Gymnastics         Gymnastics Men's Horizontal Bar  Silver
# 167240  Gymnastics        Gymnastics Men's Pommelled Horse  Bronze
# 226820  Gymnastics        Gymnastics Men's Team All-Around  Bronze
# 235871  Gymnastics        Gymnastics Men's Team All-Around  Bronze

# %%
# Set the style for the visualization
sns.set(style="whitegrid")

# Create a bar plot for Age
plt.figure(figsize=(16, 10))
sns.barplot(x="Name", y="Age", data=usa, hue="Sex")
plt.title('Age Distribution by Name and Sex')
plt.xticks(rotation=45)
plt.show()
