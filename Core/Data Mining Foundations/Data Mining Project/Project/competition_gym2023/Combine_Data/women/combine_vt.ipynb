# %%
import pandas as pd
import numpy as np

# %%
pac16vt = pd.read_csv('../Cleaning/qual_events/clean_pacific_rim2016vt.csv')
bc15vt = pd.read_csv('../Cleaning/qual_events/clean_british_championship2015vt.csv')
jesolo15vt = pd.read_csv('../Cleaning/qual_events/clean_jesolo2015vt.csv')
wc13cott_vt = pd.read_csv('../Cleaning/qual_events/clean_wc13cott_vt.csv')
wc13doha_vt = pd.read_csv('../Cleaning/qual_events/clean_wc14doha_vt.csv')
wc15cott_vt = pd.read_csv('../Cleaning/qual_events/clean_worldcup2015cott_vt.csv')
wc19doha_vt = pd.read_csv('../Cleaning/qual_events/clean_worldcup2019doha_vt.csv')
eu20_vt = pd.read_csv('../Cleaning/qual_events/euro2020vt.csv')
uni19_vt = pd.read_csv('../Cleaning/qual_events/uni2019vt.csv')
wc19melb_vt = pd.read_csv('../Cleaning/qual_events/clean_worldcup2019melbourne_vt.csv')
wc18jeso_vt = pd.read_csv('../Cleaning/qual_events/clean_worldcup2018jesolo_vt.csv')
vt_world_championship_w = pd.read_csv('../Cleaning/World_Championships/vt_world_championship_w.csv')
usopc_vt = pd.read_csv('../Cleaning/USOPC/usopc_women_vt_october.csv')
vt_euro_championship18 = pd.read_csv('../Cleaning/qual_events/clean_european_championship2018vt.csv')
vt_euro_championship21 = pd.read_csv('../Cleaning/qual_events/clean_european_championship2021vt.csv')
pam14am_vt = pd.read_csv('../Cleaning/qual_events/clean_pan_american2014vt.csv')
euro19games_vt = pd.read_csv('../Cleaning/qual_events/clean_european_games2019vt.csv')


clean_universiade2015vt= pd.read_csv('../Cleaning/qual_events/clean_universiade2015vt.csv')
clean_euro15champ_vt= pd.read_csv('../Cleaning/qual_events/clean_euro15champ_vt.csv')

# %%
# wc13cott_vt

# %%
eu20_vt.rename(columns={'Gymnast': 'Name', 'Position': 'Rank', 'Penalty': 'Pen.'}, inplace=True)
uni19_vt['nation'] = uni19_vt['Athlete'].str.extract(r'\((.*?)\)')
uni19_vt['Athlete'] = uni19_vt['Athlete'].str.replace(r'\(.*?\)', '', regex=True)
uni19_vt['year']=2019
eu20_vt['year']=2020
eu20_vt['nation']='eu'
uni19_vt.rename(columns={'Athlete': 'Name', }, inplace=True)
uni19_vt['round']='final'
eu20_vt['round']='final'

# %%
usopc_vt.head(1)
# Out:
#               Name Country Gender        Date  \
# 0  Jana ABDELSALAM     EGY      w  2022-11-06
#
#                                          Competition Round Apparatus   Rank  \
# 0  2022 51st FIG Artistic Gymnastics World Champi...  qual       VT1  110.0
#
#    D_Score  E_Score  Penalty   Score
# 0      4.2    8.433      0.3  12.333

# %%
vt_world_championship_w.head(1)
# Out:
#    Rank               Gymnast  D Score1  E Score1  Pen.1  Score 1  D Score2  \
# 0   1.0  McKayla Maroney(USA)       6.3     9.766    0.1   15.966       6.0
#
#    E Score2  Pen.2  Score 2   Total  year
# 0     9.483    0.0   15.483  15.724  2013

# %%
wc18jeso_vt.head(1)
# Out:
#    Rank    Athlete Nation    D      E   ND   Total   D2     E2  ND2  Total2  \
# 0     1  Liu Jinru    CHN  5.6  8.733  0.0  14.333  5.8  8.433  NaN  14.233
#
#    Average
# 0   14.283

# %%
wc19melb_vt.head(1)
# Out:
#    Rank        Athlete Nation    D      E   ND   Total   D2     E2  ND2  \
# 0     1  Yeo Seo-jeong    KOR  5.8  8.666  0.0  14.466  5.4  8.666  0.0
#
#    Total2  Average
# 0  14.066   14.266

# %%
uni19_vt.head(1)
# Out:
#    Rank              Name  D Score1  E Score1  Pen.1  Score1  D Score2  \
# 0   1.0  Marina Nekrasova       5.4       8.7      0    14.1       5.2
#
#    E Score2  Pen.2  Score2  Total nation  year  round
# 0       8.8    0.1    13.9   14.0    AZE  2019  final

# %%
eu20_vt.head(1)
# Out:
#    Rank           Name  D Score1  E Score1  Pen.1  Score 1  D Score2  \
# 0     1  Zsófia Kóvacs       5.4      8.95    0.0    14.35       4.8
#
#    E Score2  Pen.2  Score 2  Total  year nation  round
# 0      8.95    0.0    13.75  14.05  2020     eu  final

# %%
wc19doha_vt.head(1)
# Out:
#    Rank     Athlete         Nation    D      E   ND   Total   d2   e2  pen2  \
# 0     1  Jade Carey  United States  6.0  9.066  0.0  15.066  5.4  9.3   0.0
#
#    score2  Average
# 0    14.7   14.883

# %%
wc15cott_vt.head(1)
# Out:
#    Rank             Athlete   D1     E1  ND1  Total1   d2     e2  pen2  \
# 0     1  Oksana Chusovitina  5.8  9.125  0.0  14.925  5.5  9.325   0.0
#
#    score1   total  year Nation
# 0  14.825  14.875  2015    UZB

# %%
wc13doha_vt.head(1)
# Out:
#    Rank          Athlete Nation    D      E   ND   Score   d2   e2  nd2  \
# 0     1  Larisa Iordache    ROU  5.8  8.775  0.0  14.575  5.2  8.9  0.0
#
#    score2   Total  year  round
# 0    14.1  14.337  2014  final

# %%
wc13cott_vt.head(1)
# Out:
#    Rank             Athlete Nation    D     E   ND  Total   d2     e2  nd2  \
# 0     1  Oksana Chusovitina    UZB  5.8  9.15  0.0  14.95  5.5  9.325  0.0
#
#    total2  Average
# 0  14.825   14.887

# %%
jesolo15vt.head(1)
# Out:
#    Rank       Athlete Nation    D    E   ND  Total   D2    E2  ND2  Total2  \
# 0     1  Simone Biles    USA  6.3  9.6  0.0   15.9  5.6  9.55  0.0   15.15
#
#    Average  year  round
# 0   15.525  2015  final

# %%
bc15vt.head(1)
# Out:
#    Rank            Athlete    D    E   ND  Total   D2   E2  ND2  Total2  \
# 0     1  Claudia Fragapane  5.8  8.9  0.0   14.7  5.2  8.8  0.0    14.0
#
#    Average  year nation  round
# 0    14.35  2015    GBR  final

# %%
pac16vt.head(1)
# Out:
#    Rank        Athlete Nation    D     E   ND  Total   D2    E2  ND2  Total2  \
# 0     1  Shallon Olsen    CAN  5.8  9.15  0.0  14.95  5.9  8.65  0.0   14.55
#
#    Average  year  round
# 0    14.75  2016  final

# %%
wc13cott_vt['year']=2013
wc13cott_vt['round']='final'

# %%
wc18jeso_vt['year']=2018
wc18jeso_vt['round']='final'

# %%
wc19melb_vt['year']=2019
wc19melb_vt['round']='final'

# %%
vt_world_championship_w['round']='final'

# %%
usopc_vt=usopc_vt.drop(columns=["Gender", 'Competition', 'Apparatus', ])
usopc_vt['year'] = usopc_vt['Date'].str[:4]
usopc_vt=usopc_vt.drop(columns=["Date"])

# %%
usopc_vt
# Out:
#                      Name Country  Round   Rank  D_Score  E_Score  Penalty  \
# 0         Jana ABDELSALAM     EGY   qual  110.0      4.2    8.433      0.3
# 1         Jana ABOELHASAN     EGY   qual  138.0      3.2    8.400      0.0
# 2        Ondine ACHAMPONG     GBR   qual    3.0      5.0    9.466      0.0
# 3        Ondine ACHAMPONG     GBR   qual    1.0      5.0    9.250      0.0
# 4        Ondine ACHAMPONG     GBR   qual    4.0      5.0    8.933      0.0
# ...                   ...     ...    ...    ...      ...      ...      ...
# 1466       Evandra ZLOBEC     CAN   qual   37.0      4.2    7.550      0.3
# 1467       Evandra ZLOBEC     CAN   qual   37.0      0.0    0.000      0.0
# 1468    Christina ZWICKER     CRO   qual  114.0      3.2    8.300      0.0
# 1469  Daria Angelina None     SUI  final    8.0      3.6    8.733      0.0
# 1470  Daria Angelina None     SUI  final    8.0      3.4    8.700      0.0
#
#        Score  year
# 0     12.333  2022
# 1     11.600  2022
# ...

# %%
bc15vt.rename(columns={'nation': 'Nation',}, inplace=True)

# %%
# combined_df = pd.concat([pac16vt, bc15vt, jesolo15vt,], axis=0)

# %%
# vt = combined_df.copy()

# %%
# vt

# %%
wc13doha_vt.head(1)
# Out:
#    Rank          Athlete Nation    D      E   ND   Score   d2   e2  nd2  \
# 0     1  Larisa Iordache    ROU  5.8  8.775  0.0  14.575  5.2  8.9  0.0
#
#    score2   Total  year  round
# 0    14.1  14.337  2014  final

# %%
def rename_columns(dataframe):
    # Define the column name mapping
    column_name_mapping = {
        'Total': 'Average',
        'Score': 'Total',
        'd2': 'D2',
        'e2': 'E2',
        'nd2': 'ND2',
        'score2': 'Total2',
    }

    return dataframe.rename(columns=column_name_mapping, inplace=True)

# %%
rename_columns(wc13doha_vt)

# %%
wc13doha_vt
# Out:
#    Rank              Athlete Nation    D      E   ND   Total   D2     E2  ND2  \
# 0     1      Larisa Iordache    ROU  5.8  8.775  0.0  14.575  5.2  8.900  0.0
# 1     2           Teja Belak    SLO  5.3  8.800  0.0  14.100  5.3  8.800  0.0
# 2     3  Hiu Ying Angel Wong    HKG  5.2  8.675  0.0  13.875  5.0  8.750  0.0
# 3     4    Courtney McGregor    NZL  5.8  8.475 -0.3  13.975  4.8  8.650  0.0
# 4     5     Valerija Grisane    LAT  5.2  8.750 -0.1  13.850  5.0  8.500  0.0
# 5     6       Dorina Böczögö    HUN  5.0  8.950  0.0  13.950  4.4  8.825  0.0
# 6     7       Do Thi Van Anh    VIE  5.0  8.625 -0.3  13.325  5.0  8.425 -0.1
# 7     8       Tjasa Kysselef    SLO  4.6  8.500  0.0  13.100  4.8  8.625  0.0
#
#    Total2  Average  year  round
# 0  14.100   14.337  2014  final
# 1  14.100   14.100  2014  final
# 2  13.750   13.812  2014  final
# 3  13.450   13.712  2014  final
# 4  13.500   13.675  2014  final
# 5  13.225   13.587  2014  final
# 6  13.325   13.325  2014  final
# ...

# %%
# rename_columns(wc13cott_vt)

# %%
rename_columns(wc15cott_vt)

# %%
# rename_columns(wc19doha_vt)

# %%
# rename_columns(wc19melb_vt)

# %%
# rename_columns(wc18jeso_vt )

# %%
# vt.head(1)

# %%
# wc13doha_vt, wc13cott_vt, wc15cott_vt, wc19doha_vt,
#                          wc19melb_vt,wc18jeso_vt
#     vt

# %%
# combined_df = pd.concat([vt, wc13doha_vt,])

# %%
# vt=combined_df.copy()

# %%
wc13cott_vt
# Out:
#    Rank              Athlete Nation    D      E   ND   Total   d2     e2  nd2  \
# 0     1   Oksana Chusovitina    UZB  5.8  9.150  0.0  14.950  5.5  9.325  0.0
# 1     2    Noel van Klaveren    NED  5.3  9.325  0.0  14.625  5.2  8.975  0.0
# 2     3         Maegan Chant    CAN  5.2  9.250  0.0  14.450  5.4  8.750 -0.3
# 3     4  Hiu Ying Angel Wong    HKG  5.2  8.775  0.0  13.975  5.0  8.825  0.0
# 4     4       Makarena Pinto    CHI  5.2  8.600 -0.3  13.500  5.4  8.900  0.0
# 5     6     Chantysha Netteb    NED  5.3  7.900  0.0  13.200  5.2  9.050  0.0
# 6     7          Ofir Netzer    ISR  4.6  8.750  0.0  13.350  5.3  8.825 -0.1
# 7     8         Paula Mejias    PUR  4.3  7.525  0.0  11.825  5.3  8.225 -0.3
#
#    total2  Average  year  round
# 0  14.825   14.887  2013  final
# 1  14.175   14.400  2013  final
# 2  13.850   14.150  2013  final
# 3  13.825   13.900  2013  final
# 4  14.300   13.900  2013  final
# 5  14.250   13.725  2013  final
# 6  14.025   13.687  2013  final
# ...

# %%
wc13cott_vt.rename(columns={'d2': 'D2', 'e2': 'E2',
                            'nd2': 'ND2', 'total2': 'Total2'}, inplace=True)

# %%
# combined_df = pd.concat([vt, wc13cott_vt])

# %%
# vt= combined_df.copy()

# %%
# combined_df.columns

# %%
wc15cott_vt

wc13cott_vt.rename(columns={'D1': 'D', 'E1': 'E',
                            'ND1': 'ND', 'Total1': 'Total',
                           'pen2': 'ND2', 'score1': 'Total2', 'total':'Average'}, inplace=True)

# %%
wc13cott_vt=wc13cott_vt[['Rank', 'Athlete', 'Nation', 'D', 'E', 'ND', 'Total', 'D2', 'E2', 'ND2',
       'Total2', 'Average', 'year', 'round']]

# %%
wc13cott_vt
# Out:
#    Rank              Athlete Nation    D      E   ND   Total   D2     E2  ND2  \
# 0     1   Oksana Chusovitina    UZB  5.8  9.150  0.0  14.950  5.5  9.325  0.0
# 1     2    Noel van Klaveren    NED  5.3  9.325  0.0  14.625  5.2  8.975  0.0
# 2     3         Maegan Chant    CAN  5.2  9.250  0.0  14.450  5.4  8.750 -0.3
# 3     4  Hiu Ying Angel Wong    HKG  5.2  8.775  0.0  13.975  5.0  8.825  0.0
# 4     4       Makarena Pinto    CHI  5.2  8.600 -0.3  13.500  5.4  8.900  0.0
# 5     6     Chantysha Netteb    NED  5.3  7.900  0.0  13.200  5.2  9.050  0.0
# 6     7          Ofir Netzer    ISR  4.6  8.750  0.0  13.350  5.3  8.825 -0.1
# 7     8         Paula Mejias    PUR  4.3  7.525  0.0  11.825  5.3  8.225 -0.3
#
#    Total2  Average  year  round
# 0  14.825   14.887  2013  final
# 1  14.175   14.400  2013  final
# 2  13.850   14.150  2013  final
# 3  13.825   13.900  2013  final
# 4  14.300   13.900  2013  final
# 5  14.250   13.725  2013  final
# 6  14.025   13.687  2013  final
# ...

# %%
# combined_df = pd.concat([vt, wc13cott_vt])

# %%
# vt=combined_df.copy()

# %%
wc19doha_vt
# Out:
#    Rank             Athlete         Nation    D      E   ND   Total   d2  \
# 0     1          Jade Carey  United States  6.0  9.066  0.0  15.066  5.4
# 1     2        Maria Paseka         Russia  6.0  8.533 -0.1  14.433  5.8
# 2     3    Coline Devillard         France  5.8  9.133  0.0  14.933  5.4
# 3     4        Alexa Moreno         Mexico  5.8  8.700 -0.1  14.400  5.6
# 4     5  Oksana Chusovitina     Uzbekistan  5.2  8.666  0.0  13.866  5.2
# 5     6        Emily Thomas  Great Britain  5.0  9.033  0.0  14.033  4.8
# 6     7      Gabriela Janik         Poland  4.8  8.866  0.0  13.666  4.8
# 7     8    Marina Nekrasova     Azerbaijan  4.8  7.533  0.0  12.333  5.4
#
#       e2  pen2  score2  Average
# 0  9.300   0.0  14.700   14.883
# 1  9.300   0.0  15.100   14.766
# 2  8.766   0.0  14.166   14.549
# 3  8.800   0.0  14.400   14.400
# 4  8.766  -0.1  13.866   13.866
# 5  8.866   0.0  13.666   13.849
# 6  8.966   0.0  13.766   13.716
# 7  8.800  -0.1  14.100   13.216

# %%
wc19doha_vt.rename(columns={'d2': 'D2', 'e2': 'E2',
                            'pen2': 'ND2', 'score2': 'Total2'}, inplace=True)

# %%
# combined_df = pd.concat([vt, wc19doha_vt])

# %%
# head=combined_df.copy()

# %%
# combined_df = pd.concat([wc18jeso_vt, wc19melb_vt, wc19melb_vt, wc18jeso_vt])

# %%
# Average, pen2
# add round and year

# %%
# pac16vt 
# bc15vt
# jesolo15vt


# wc13cott_vt 
# wc13doha_vt


# wc15cott_vt 

# wc19doha_vt
#wc19melb_vt 
# wc18jeso_vt 




# eu20_vt 
# uni19_vt 
# 
# 
# vt_world_championship_w 
# usopc_vt

# %%
combined_df = pd.concat([wc18jeso_vt, wc19melb_vt, wc19melb_vt, wc18jeso_vt, wc19doha_vt,
                        wc13cott_vt, wc13doha_vt,pac16vt, bc15vt, jesolo15vt])

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71 entries, 0 to 4
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     71 non-null     int64
#  1   Athlete  71 non-null     object
#  2   Nation   71 non-null     object
#  3   D        71 non-null     float64
#  4   E        71 non-null     float64
#  5   ND       71 non-null     float64
#  6   Total    71 non-null     float64
#  7   D2       71 non-null     float64
#  8   E2       71 non-null     float64
#  9   ND2      59 non-null     float64
#  10  Total2   71 non-null     float64
#  11  Average  71 non-null     float64
#  12  year     63 non-null     float64
#  13  round    63 non-null     object
# dtypes: float64(10), int64(1), object(3)
# memory usage: 8.3+ KB

# %% [markdown]
# to add:
#     wc15cott_vt
#    eu20_vt
#
#
# uni19_vt
# vt_world_championship_w
# usopc_vt

# %%
wc15cott_vt.head(1)
# Out:
#    Rank             Athlete   D1     E1  ND1  Total1   D2     E2  pen2  \
# 0     1  Oksana Chusovitina  5.8  9.125  0.0  14.925  5.5  9.325   0.0
#
#    score1   total  year Nation
# 0  14.825  14.875  2015    UZB

# %%
combined_df.head(1)
# Out:
#    Rank    Athlete Nation    D      E   ND   Total   D2     E2  ND2  Total2  \
# 0     1  Liu Jinru    CHN  5.6  8.733  0.0  14.333  5.8  8.433  NaN  14.233
#
#    Average    year  round
# 0   14.283  2018.0  final

# %%
wc15cott_vt['round']=2015

# %%
wc15cott_vt.rename(columns={'D1': 'D', 'E1': 'E', 'ND1':'ND', 'Total1': 'Total',
                            'pen2': 'ND2', 'score1': 'Total2', 'total':'Average'}, inplace=True)




wc15cott_vt=wc15cott_vt[['Rank', 'Athlete', 'Nation', 'D', 'E', 'ND', 'Total', 'D2', 'E2', 'ND2',
       'Total2', 'Average', 'year', 'round']]

# %%
eu20_vt.head(1)
# Out:
#    Rank           Name  D Score1  E Score1  Pen.1  Score 1  D Score2  \
# 0     1  Zsófia Kóvacs       5.4      8.95    0.0    14.35       4.8
#
#    E Score2  Pen.2  Score 2  Total  year nation  round
# 0      8.95    0.0    13.75  14.05  2020     eu  final

# %%
eu20_vt.rename(columns={ 'Name': 'Athlete', 'D Score1': 'D', 'E Score1': 'E', 'Pen.1':'ND',
                        'D Score2': 'D2', 'E Score2':  'E2',
                        'Pen.2': 'ND2', 'Score 2': 'Total2','Total':'Average', 
                        'nation':'Nation',  'Score 1': 'Total',}, inplace=True)




eu20_vt=eu20_vt[['Rank', 'Athlete', 'Nation', 'D', 'E', 'ND', 'Total', 'D2', 'E2', 'ND2',
       'Total2', 'Average', 'year', 'round']]

# %%
vt=combined_df.copy()

# %%
vt.head()
# Out:
#    Rank              Athlete Nation    D      E   ND   Total   D2     E2  ND2  \
# 0     1            Liu Jinru    CHN  5.6  8.733  0.0  14.333  5.8  8.433  NaN
# 1     2   Angelina Melnikova    RUS  5.4  9.133  0.0  14.533  5.2  8.900 -0.1
# 2     3  Eleonora Afanasyeva    RUS  5.4  9.233  0.0  14.633  4.8  9.000  NaN
# 3     4       Denisa Golgota    ROU  5.4  9.067  0.0  14.467  4.8  8.867  NaN
# 4     5       Grace McCallum    USA  5.4  9.267  0.0  14.667  4.6  8.767  NaN
#
#    Total2  Average    year  round
# 0  14.233   14.283  2018.0  final
# 1  14.000   14.267  2018.0  final
# 2  13.800   14.217  2018.0  final
# 3  13.667   14.067  2018.0  final
# 4  13.367   14.017  2018.0  final

# %%
eu20_vt.head()
# Out:
#    Rank             Athlete Nation    D     E   ND  Total   D2    E2  ND2  \
# 0     1       Zsófia Kóvacs     eu  5.4  8.95  0.0  14.35  4.8  8.95  0.0
# 1     2     Larisa Iordache     eu  5.4  8.80  0.0  14.20  4.8  8.75  0.0
# 2     3    Anastasiia Motak     eu  5.4  8.85  0.0  14.25  4.8  8.65  0.0
# 3     4      Csenge Bácksay     eu  5.0  8.70  0.0  13.70  4.8  8.80  0.0
# 4     5  Ioana Stănciulescu     eu  5.4  8.75  0.0  14.15  4.2  8.80  0.0
#
#    Total2  Average  year  round
# 0   13.75   14.050  2020  final
# 1   13.55   13.875  2020  final
# 2   13.45   13.850  2020  final
# 3   13.60   13.650  2020  final
# 4   13.00   13.575  2020  final

# %%
combined_df = pd.concat([vt,eu20_vt,wc15cott_vt])

# %%
vt=combined_df.copy()

# %%
vt.head(1)
# Out:
#    Rank    Athlete Nation    D      E   ND   Total   D2     E2  ND2  Total2  \
# 0     1  Liu Jinru    CHN  5.6  8.733  0.0  14.333  5.8  8.433  NaN  14.233
#
#    Average    year  round
# 0   14.283  2018.0  final

# %%
usopc_vt.head()
# Out:
#                Name Country Round   Rank  D_Score  E_Score  Penalty   Score  \
# 0   Jana ABDELSALAM     EGY  qual  110.0      4.2    8.433      0.3  12.333
# 1   Jana ABOELHASAN     EGY  qual  138.0      3.2    8.400      0.0  11.600
# 2  Ondine ACHAMPONG     GBR  qual    3.0      5.0    9.466      0.0  14.466
# 3  Ondine ACHAMPONG     GBR  qual    1.0      5.0    9.250      0.0  14.250
# 4  Ondine ACHAMPONG     GBR  qual    4.0      5.0    8.933      0.0  13.933
#
#    year
# 0  2022
# 1  2022
# 2  2022
# 3  2022
# 4  2022

# %%
usopc_vt['D2'] = 0
usopc_vt['E2']=0
usopc_vt['ND2']=0
usopc_vt['Total2']=0
usopc_vt['Total']=0

# %%
usopc_vt.rename(columns={ 'Name': 'Athlete', 'Country': 'Nation', 'D_Score': 'D',
                        'E_Score': 'E','Penalty': 'ND', 'Score':'Average',  
                        'Round':'round'}, inplace=True)




usopc_vt=usopc_vt[['Rank', 'Athlete', 'Nation', 'D', 'E', 'ND', 'Total', 'D2', 'E2', 'ND2',
       'Total2', 'Average', 'year', 'round']]

# %%
combined_df = pd.concat([vt,usopc_vt])

# %%
vt=combined_df.copy()

# %%
vt.head()
# Out:
#    Rank              Athlete Nation    D      E   ND   Total   D2     E2  ND2  \
# 0   1.0            Liu Jinru    CHN  5.6  8.733  0.0  14.333  5.8  8.433  NaN
# 1   2.0   Angelina Melnikova    RUS  5.4  9.133  0.0  14.533  5.2  8.900 -0.1
# 2   3.0  Eleonora Afanasyeva    RUS  5.4  9.233  0.0  14.633  4.8  9.000  NaN
# 3   4.0       Denisa Golgota    ROU  5.4  9.067  0.0  14.467  4.8  8.867  NaN
# 4   5.0       Grace McCallum    USA  5.4  9.267  0.0  14.667  4.6  8.767  NaN
#
#    Total2  Average    year  round
# 0  14.233   14.283  2018.0  final
# 1  14.000   14.267  2018.0  final
# 2  13.800   14.217  2018.0  final
# 3  13.667   14.067  2018.0  final
# 4  13.367   14.017  2018.0  final

# %%
vt_world_championship_w.head()
# Out:
#    Rank                  Gymnast  D Score1  E Score1  Pen.1  Score 1  \
# 0   1.0     McKayla Maroney(USA)       6.3     9.766    0.1   15.966
# 1   2.0        Simone Biles(USA)       6.3     9.633    0.0   15.933
# 2   3.0        Hong Un-Jong(PRK)       6.3     9.266    0.0   15.566
# 3   4.0  Giulia Steingruber(SUI)       6.2     9.300    0.0   15.500
# 4   5.0  Oksana Chusovitina(UZB)       6.2     8.533    0.1   14.633
#
#    D Score2  E Score2  Pen.2  Score 2   Total  year  round
# 0       6.0     9.483    0.0   15.483  15.724  2013  final
# 1       5.6     9.658    0.0   15.258  15.595  2013  final
# 2       6.4     9.000    0.0   15.400  15.483  2013  final
# 3       5.8     9.166    0.0   14.966  15.233  2013  final
# 4       5.5     9.033    0.0   14.533  14.583  2013  final

# %%
# Extract text within parentheses and create a new 'Nation' column
vt_world_championship_w['Nation'] = vt_world_championship_w['Gymnast'].str.extract(r'\(([^)]+)\)')

# Remove text within parentheses in the 'Athlete' column
vt_world_championship_w['Gymnast'] = vt_world_championship_w['Gymnast'].str.replace(r'\s*\([^)]*\)', '')

# %%
vt_world_championship_w['Gymnast'] = vt_world_championship_w['Gymnast'].str.replace(r'\([^)]*\)', '', regex=True)

# %%
vt_world_championship_w.head()
# Out:
#    Rank             Gymnast  D Score1  E Score1  Pen.1  Score 1  D Score2  \
# 0   1.0     McKayla Maroney       6.3     9.766    0.1   15.966       6.0
# 1   2.0        Simone Biles       6.3     9.633    0.0   15.933       5.6
# 2   3.0        Hong Un-Jong       6.3     9.266    0.0   15.566       6.4
# 3   4.0  Giulia Steingruber       6.2     9.300    0.0   15.500       5.8
# 4   5.0  Oksana Chusovitina       6.2     8.533    0.1   14.633       5.5
#
#    E Score2  Pen.2  Score 2   Total  year  round Nation
# 0     9.483    0.0   15.483  15.724  2013  final    USA
# 1     9.658    0.0   15.258  15.595  2013  final    USA
# 2     9.000    0.0   15.400  15.483  2013  final    PRK
# 3     9.166    0.0   14.966  15.233  2013  final    SUI
# 4     9.033    0.0   14.533  14.583  2013  final    UZB

# %%
vt_world_championship_w.rename(columns={ 'Gymnast': 'Athlete', 'D Score1': 'D', 'E Score1': 'E',
                                        'Pen.1':'ND','D Score2': 'D2', 'E Score2': 'E2',
                        'Pen.2': 'ND2', 'Score 2': 'Total2', 'Total':'Average', 
                          'Score 1': 'Total',}, inplace=True)




vt_world_championship_w=vt_world_championship_w[['Rank', 'Athlete', 'Nation', 'D', 'E', 'ND', 'Total', 'D2', 'E2', 'ND2',
       'Total2', 'Average', 'year', 'round']]

# %%
vt_world_championship_w.head()
# Out:
#    Rank             Athlete Nation    D      E   ND   Total   D2     E2  ND2  \
# 0   1.0     McKayla Maroney    USA  6.3  9.766  0.1  15.966  6.0  9.483  0.0
# 1   2.0        Simone Biles    USA  6.3  9.633  0.0  15.933  5.6  9.658  0.0
# 2   3.0        Hong Un-Jong    PRK  6.3  9.266  0.0  15.566  6.4  9.000  0.0
# 3   4.0  Giulia Steingruber    SUI  6.2  9.300  0.0  15.500  5.8  9.166  0.0
# 4   5.0  Oksana Chusovitina    UZB  6.2  8.533  0.1  14.633  5.5  9.033  0.0
#
#    Total2  Average  year  round
# 0  15.483   15.724  2013  final
# 1  15.258   15.595  2013  final
# 2  15.400   15.483  2013  final
# 3  14.966   15.233  2013  final
# 4  14.533   14.583  2013  final

# %%
vt.head()
# Out:
#    Rank              Athlete Nation    D      E   ND   Total   D2     E2  ND2  \
# 0   1.0            Liu Jinru    CHN  5.6  8.733  0.0  14.333  5.8  8.433  NaN
# 1   2.0   Angelina Melnikova    RUS  5.4  9.133  0.0  14.533  5.2  8.900 -0.1
# 2   3.0  Eleonora Afanasyeva    RUS  5.4  9.233  0.0  14.633  4.8  9.000  NaN
# 3   4.0       Denisa Golgota    ROU  5.4  9.067  0.0  14.467  4.8  8.867  NaN
# 4   5.0       Grace McCallum    USA  5.4  9.267  0.0  14.667  4.6  8.767  NaN
#
#    Total2  Average    year  round
# 0  14.233   14.283  2018.0  final
# 1  14.000   14.267  2018.0  final
# 2  13.800   14.217  2018.0  final
# 3  13.667   14.067  2018.0  final
# 4  13.367   14.017  2018.0  final

# %%
combined_df = pd.concat([vt,vt_world_championship_w])

# %%
vt=combined_df.copy()

# %%
vt.duplicated().sum()
# Out:
# 28

# %%
vt = vt.drop_duplicates()

# %%
vt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1578 entries, 0 to 47
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     1575 non-null   float64
#  1   Athlete  1578 non-null   object
#  2   Nation   1532 non-null   object
#  3   D        1578 non-null   float64
#  4   E        1578 non-null   float64
#  5   ND       1578 non-null   float64
#  6   Total    1578 non-null   float64
#  7   D2       1578 non-null   float64
#  8   E2       1578 non-null   float64
#  9   ND2      1572 non-null   float64
#  10  Total2   1578 non-null   float64
#  11  Average  1578 non-null   float64
#  12  year     1570 non-null   object
#  13  round    1570 non-null   object
# dtypes: float64(10), object(4)
# memory usage: 184.9+ KB

# %%
vt['Nation'].fillna('none', inplace=True)
vt['ND2'].fillna(0, inplace=True)
vt['round'].fillna('final', inplace=True)

# %%
vt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1578 entries, 0 to 47
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     1575 non-null   float64
#  1   Athlete  1578 non-null   object
#  2   Nation   1578 non-null   object
#  3   D        1578 non-null   float64
#  4   E        1578 non-null   float64
#  5   ND       1578 non-null   float64
#  6   Total    1578 non-null   float64
#  7   D2       1578 non-null   float64
#  8   E2       1578 non-null   float64
#  9   ND2      1578 non-null   float64
#  10  Total2   1578 non-null   float64
#  11  Average  1578 non-null   float64
#  12  year     1570 non-null   object
#  13  round    1578 non-null   object
# dtypes: float64(10), object(4)
# memory usage: 184.9+ KB

# %%
vt=vt.dropna()

# %%
vt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1567 entries, 0 to 47
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     1567 non-null   float64
#  1   Athlete  1567 non-null   object
#  2   Nation   1567 non-null   object
#  3   D        1567 non-null   float64
#  4   E        1567 non-null   float64
#  5   ND       1567 non-null   float64
#  6   Total    1567 non-null   float64
#  7   D2       1567 non-null   float64
#  8   E2       1567 non-null   float64
#  9   ND2      1567 non-null   float64
#  10  Total2   1567 non-null   float64
#  11  Average  1567 non-null   float64
#  12  year     1567 non-null   object
#  13  round    1567 non-null   object
# dtypes: float64(10), object(4)
# memory usage: 183.6+ KB

# %%
vt.head(1)
# Out:
#    Rank    Athlete Nation    D      E   ND   Total   D2     E2  ND2  Total2  \
# 0   1.0  Liu Jinru    CHN  5.6  8.733  0.0  14.333  5.8  8.433  0.0  14.233
#
#    Average    year  round
# 0   14.283  2018.0  final

# %%
vt_euro_championship18.head(1)
# Out:
#    Rank             Athlete Nation    D      E   ND   Total   D2     E2  ND2  \
# 0     1  Giulia Steingruber    SUI  5.8  9.266  0.0  15.066  5.4  9.183  0.0
#
#    Total2  Average  year  round
# 0  14.583   14.824  2021  final

# %%
vt_euro_championship21.head(1)
# Out:
#    Rank         Athlete Nation    D      E   ND   Total  Average  year  round  \
# 0     1  Boglarka Devai    HUN  6.0  8.733 -0.1  14.633   14.349  2021  final
#
#    D2  E2  ND2  Total2
# 0   0   0    0       0

# %%
vt_euro_championship21=vt_euro_championship21[['Rank', 'Athlete', 'Nation', 'D', 'E', 'ND', 'Total', 'D2', 'E2', 'ND2',
       'Total2', 'Average', 'year', 'round']]

# %%
combined_df = pd.concat([vt,vt_euro_championship18, vt_euro_championship21])

# %%
vt=combined_df.copy()

# %%
vt.duplicated().sum()
# Out:
# 0

# %%
vt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1591 entries, 0 to 15
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     1591 non-null   float64
#  1   Athlete  1591 non-null   object
#  2   Nation   1591 non-null   object
#  3   D        1591 non-null   float64
#  4   E        1591 non-null   float64
#  5   ND       1591 non-null   float64
#  6   Total    1591 non-null   float64
#  7   D2       1591 non-null   float64
#  8   E2       1591 non-null   float64
#  9   ND2      1591 non-null   float64
#  10  Total2   1591 non-null   float64
#  11  Average  1591 non-null   float64
#  12  year     1591 non-null   object
#  13  round    1591 non-null   object
# dtypes: float64(10), object(4)
# memory usage: 186.4+ KB

# %%
# pam14am_vt
# euro19games_vt

# %%
vt.head(1)
# Out:
#    Rank    Athlete Nation    D      E   ND   Total   D2     E2  ND2  Total2  \
# 0   1.0  Liu Jinru    CHN  5.6  8.733  0.0  14.333  5.8  8.433  0.0  14.233
#
#    Average    year  round
# 0   14.283  2018.0  final

# %%
pam14am_vt.rename(columns={ 'D.1': 'D2',
                        'E.1': 'E2','ND.1': 'ND2', 'Total.1':'Total2'}, inplace=True)




pam14am_vt=pam14am_vt[['Rank', 'Athlete', 'Nation', 'D', 'E', 'ND', 'Total', 'D2', 'E2', 'ND2',
       'Total2', 'Average', 'year', 'round']]

# %%
euro19games_vt['D2']=0
euro19games_vt['E2']=0
euro19games_vt['ND2']=0
euro19games_vt['Total2']=0

# %%
euro19games_vt=euro19games_vt[['Rank', 'Athlete', 'Nation', 'D', 'E', 'ND', 'Total', 'D2', 'E2', 'ND2',
       'Total2', 'Average', 'year', 'round']]

# %%
combined_df = pd.concat([vt,euro19games_vt, pam14am_vt])

# %%
vt=combined_df.copy()

# %%
vt.duplicated().sum()
# Out:
# 0

# %%
# clean_universiade2015vt
# clean_euro15champ_vt

# %%
combined_df = pd.concat([vt,clean_universiade2015vt, clean_euro15champ_vt])

# %%
vt=combined_df.copy()

# %%
vt.duplicated().sum()
# Out:
# 0

# %%
vt.head()
# Out:
#    Rank              Athlete Nation    D      E   ND   Total   D2     E2  ND2  \
# 0   1.0            Liu Jinru    CHN  5.6  8.733  0.0  14.333  5.8  8.433  0.0
# 1   2.0   Angelina Melnikova    RUS  5.4  9.133  0.0  14.533  5.2  8.900 -0.1
# 2   3.0  Eleonora Afanasyeva    RUS  5.4  9.233  0.0  14.633  4.8  9.000  0.0
# 3   4.0       Denisa Golgota    ROU  5.4  9.067  0.0  14.467  4.8  8.867  0.0
# 4   5.0       Grace McCallum    USA  5.4  9.267  0.0  14.667  4.6  8.767  0.0
#
#    Total2  Average    year  round
# 0  14.233   14.283  2018.0  final
# 1  14.000   14.267  2018.0  final
# 2  13.800   14.217  2018.0  final
# 3  13.667   14.067  2018.0  final
# 4  13.367   14.017  2018.0  final

# %%
# vt.to_csv('vt_w.csv', index=False)
