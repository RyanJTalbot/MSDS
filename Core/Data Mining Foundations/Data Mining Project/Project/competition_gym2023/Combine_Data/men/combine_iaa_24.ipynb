# %%
import pandas as pd
import numpy as np

# %%
iaa21 = pd.read_csv('../../Cleaning/qual_events/men/iaa2021.csv')
iaa22 = pd.read_csv('../../Cleaning/qual_events/men/iaa2022.csv')
iaa23 = pd.read_csv('../../Cleaning/qual_events/men/iaa2023.csv')

# %%
iaa21.head()
# Out:
#    Rank          Athlete      FX      PH      SR      VT      PB      HB  \
# 0     1  hashimoto daiki  14.733  15.075  13.333  15.066  15.200  14.633
# 1     2     zhang boheng  14.133  14.666  14.866  14.766  15.300  14.166
# 2     3        adem asil  14.066  12.666  14.533  14.966  14.366  13.833
# 3     4         shi cong  13.200  13.466  13.933  14.233  15.200  13.866
# 4     5     illia kovtun  14.333  13.766  12.500  14.066  14.700  14.200
#
#        AA round   Nation  year
# 0  88.040  qual    Japan  2021
# 1  87.897  qual    China  2021
# 2  84.430  qual   Turkey  2021
# 3  83.898  qual    China  2021
# 4  83.565  qual  Ukraine  2021

# %%
iaa22.head()
# Out:
#   Rank           Athlete      FX      PH      SR      VT      PB      HB  \
# 0    1   tanigawa wataru  14.166  13.733    14.0    14.4  14.866  13.566
# 1    2   hashimoto daiki  14.466  11.666    14.0    14.7  14.733    15.1
# 2    3       carlos yulo  15.266  11.766  14.066  14.733    15.3  13.533
# 3    4  joe fraser great    13.9  12.533  13.933  14.266  15.066  14.266
# 4    5      zhang boheng    14.5    14.0  12.033    13.6    14.9  14.733
#
#        AA round       Nation  year
# 0  84.731  qual        Japan  2022
# 1  84.665  qual        Japan  2022
# 2  84.664  qual  Philippines  2022
# 3  83.964  qual      Britain  2022
# 4  83.766  qual        China  2022

# %%
iaa23.head()
# Out:
#   Rank            Athlete      FX      PH      SR      VT      PB      HB  \
# 0    1        chiba kenta    13.9    14.7  13.666  14.333    14.7    14.5
# 1    2        kaya kazuma    14.1  14.066    14.2  14.266    14.8  14.166
# 2    3    hashimoto daiki    14.5  13.266    13.7  14.366    14.6    15.0
# 3    4  jake jarman great  14.366    13.9  13.233    14.0  14.566  13.966
# 4    5   james hall great  13.966  14.033  13.833    13.5  14.466  13.833
#
#        AA round   Nation  year
# 0  85.799  qual    Japan  2023
# 1  85.598  qual    Japan  2023
# 2  85.432  qual    Japan  2023
# 3  84.031  qual  Britain  2023
# 4  83.631  qual  Britain  2023

# %%
combined_df = pd.concat([iaa21, iaa22, iaa23], ignore_index=True)
iaa24=combined_df.copy()

# %%
import re

# Define a function to remove parentheses and their contents
def remove_parentheses(text):
    return re.sub(r'\([^)]*\)', '', text)

# Define the columns to clean
columns_to_clean = ['FX', 'PH', 'SR', 'VT', 'PB', 'HB', 'AA']  # Add other column names if needed

# Ensure that the selected columns are of string data type
iaa24[columns_to_clean] = iaa24[columns_to_clean].astype(str)

# Apply the function to the DataFrame
df_cleaned = iaa24.copy()
df_cleaned[columns_to_clean] = df_cleaned[columns_to_clean].applymap(remove_parentheses)

# Display the cleaned DataFrame
print(df_cleaned)
# Out:
#     Rank          Athlete      FX       PH       SR      VT      PB      HB  \
# 0      1  hashimoto daiki  14.733   15.075   13.333  15.066    15.2  14.633
# 1      2     zhang boheng  14.133   14.666   14.866  14.766    15.3  14.166
# 2      3        adem asil  14.066   12.666   14.533  14.966  14.366  13.833
# 3      4         shi cong    13.2   13.466   13.933  14.233    15.2  13.866
# 4      5     illia kovtun  14.333   13.766     12.5  14.066    14.7    14.2
# ..   ...              ...     ...      ...      ...     ...     ...     ...
# 716   38      ian skirkey       0  14.972         0       0       0       0
# 717   39  ignacio yockers       0  14.942         0       0       0       0
# 718   40     brandon dang       0  14.466         0       0       0       0
# 719   41   vahe petrosyan       0        0        0   13.35       0       0
# 720   42       troy lipis       0        0  12.711        0       0       0
#
#           AA  round   Nation  year
# ...

# %%
iaa24=df_cleaned.copy()

# %%
iaa24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 721 entries, 0 to 720
# Data columns (total 12 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     721 non-null    object
#  1   Athlete  721 non-null    object
#  2   FX       721 non-null    object
#  3   PH       721 non-null    object
#  4   SR       721 non-null    object
#  5   VT       721 non-null    object
#  6   PB       721 non-null    object
#  7   HB       721 non-null    object
#  8   AA       721 non-null    object
#  9   round    721 non-null    object
#  10  Nation   721 non-null    object
#  11  year     721 non-null    int64
# dtypes: int64(1), object(11)
# memory usage: 67.7+ KB

# %%
iaa24.columns
# Out:
# Index(['Rank', 'Athlete', 'FX', 'PH', 'SR', 'VT', 'PB', 'HB', 'AA', 'round',
#        'Nation', 'year'],
#       dtype='object')

# %%
columns_to_convert_to_float = ['FX', 'PH', 'SR', 'VT', 'PB', 'HB', 'AA']
columns_to_convert_to_int = ['Rank']

# Convert columns to float
iaa24[columns_to_convert_to_float] = iaa24[columns_to_convert_to_float].apply(pd.to_numeric, errors='coerce')

# Convert 'Rank' column to int
iaa24['Rank'] = iaa24['Rank'].apply(pd.to_numeric, downcast='integer', errors='coerce')

# %%
iaa24.head()
# Out:
#    Rank          Athlete      FX      PH      SR      VT      PB      HB  \
# 0   1.0  hashimoto daiki  14.733  15.075  13.333  15.066  15.200  14.633
# 1   2.0     zhang boheng  14.133  14.666  14.866  14.766  15.300  14.166
# 2   3.0        adem asil  14.066  12.666  14.533  14.966  14.366  13.833
# 3   4.0         shi cong  13.200  13.466  13.933  14.233  15.200  13.866
# 4   5.0     illia kovtun  14.333  13.766  12.500  14.066  14.700  14.200
#
#        AA round   Nation  year
# 0  88.040  qual    Japan  2021
# 1  87.897  qual    China  2021
# 2  84.430  qual   Turkey  2021
# 3  83.898  qual    China  2021
# 4  83.565  qual  Ukraine  2021

# %%
# iaa24.to_csv('iaa2024.csv', index=False)
