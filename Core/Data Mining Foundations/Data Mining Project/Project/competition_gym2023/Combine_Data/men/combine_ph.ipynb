# %%
import pandas as pd
import numpy as np

# %%
wc19melb = pd.read_csv('../../Cleaning/qual_events/men/wc19bmelb_ph.csv')
wc20baku = pd.read_csv('../../Cleaning/qual_events/men/wc20baku_ph.csv')
world18 = pd.read_csv('../../Cleaning/qual_events/men/world18championship_ph.csv')

# %%
ph = pd.concat([wc19melb, wc20baku, world18])

# %%
ph
# Out:
#      Rank            Athlete Nation    D      E   ND   Total  year  round
# 0       1       lee chih-kai   none  6.5  8.766  0.0  15.266  2019  final
# 1       2           weng hao    CHN  6.5  8.733  0.0  15.233  2019  final
# 2       3  tomomasa hasegawa    JPN  6.5  8.166  0.0  14.666  2019  final
# 3       4   thierry pellerin    CAN  6.1  7.600  0.0  13.700  2019  final
# 4       5      ferhat arican    TUR  5.9  7.233  0.0  13.133  2019  final
# ..    ...                ...    ...  ...    ...  ...     ...   ...    ...
# 205   198   jamorn prommanee    THA  3.2  4.900 -4.0   4.100  2018   qual
# 206   199      daniel aguero    PER  3.4  4.366 -4.0   3.766  2018   qual
# 207   200        isaac nuñez    MEX  3.3  4.366 -4.0   3.666  2018   qual
# 208   201      patricio razo    MEX  2.9  4.566 -4.0   3.466  2018   qual
# 209   202      filip lidbeck    SWE  2.2  4.700 -4.0   2.900  2018   qual
#
# [269 rows x 9 columns]
