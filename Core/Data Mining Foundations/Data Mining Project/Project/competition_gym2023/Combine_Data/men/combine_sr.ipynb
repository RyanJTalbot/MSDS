# %%
import pandas as pd
import numpy as np

# %%
wc19melb = pd.read_csv('../../Cleaning/qual_events/men/wc19bmelb_sr.csv')
wc20baku = pd.read_csv('../../Cleaning/qual_events/men/wc20baku_sr.csv')
world18 = pd.read_csv('../../Cleaning/qual_events/men/world18championship_sr.csv')

# %%
sr = pd.concat([wc19melb, wc20baku, world18])

# %%
sr
# Out:
#      Rank           Athlete Nation    D      E   ND   Total    year  round
# 0       1          liu yang    CHN  6.4  8.766  0.0  15.166  2019.0  final
# 1       2           you hao    CHN  6.4  8.733  0.0  15.133  2019.0  final
# 2       3    arthur zanetti    BRA  6.2  8.766  0.0  14.966  2019.0  final
# 3       4  kazuya takahashi    JPN  6.2  8.400  0.0  14.600  2019.0  final
# 4       5  courtney tulloch   none  6.4  8.200  0.0  14.600  2019.0  final
# ..    ...               ...    ...  ...    ...  ...     ...     ...    ...
# 197   190         filip ude    CRO  2.2  8.383 -4.3   6.283  2018.0   qual
# 198   191    leonardo kusan    CRO  2.5  7.633 -4.0   6.133  2018.0   qual
# 199   192  jamorn prommanee    THA  2.9  7.300 -4.3   5.900  2018.0   qual
# 200   193      lee chih-kai   none  3.6  6.300 -4.0   5.900  2018.0   qual
# 201   194   anton kovacevic    CRO  2.1  7.666 -4.3   5.466  2018.0   qual
#
# [253 rows x 9 columns]
