# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../scraping/women/miscellaneous/individ_qual_2020.csv')

# %%
df
# Out:
#                       Gymnast               vault_score  vault_rank  \
# 0         Rebeca Andrade(BRA)  15.400/14.800Avg: 15.100           3
# 1             Jade Carey(USA)  15.166/15.166Avg: 15.166           2
# 2        MyKayla Skinner(USA)  14.933/14.800Avg: 14.866           4
# 3          Zsófia Kovács(HUN)                      14.5           0
# 4            Lee Yun-seo(KOR)                      13.4           0
# 5     Giulia Steingruber(SUI)  14.833/14.300Avg: 14.566          10
# 6         Georgia Godwin(AUS)                    13.766           0
# 7       Elena Gerasimova(ROC)                    13.466           0
# 8         Filipa Martins(POR)                    13.466           0
# 9        Emily Whitehead(AUS)                        14           0
# 10      Luciana Alvarado(CRC)                    13.433           0
# 11      Barbora Mokošová(SVK)                    13.333           0
# 12       Gabriela Sasnal(POL)  13.600/13.366Avg: 13.483          17
# ...

# %%
# Extract data within parentheses and store it in a new column
df["Country"] = df['Gymnast'].str.extract(r'\((.*?)\)')

# Remove data within parentheses from the original column
df['Gymnast'] = df['Gymnast'].str.replace(r'\(.*?\)', '')

df
# Out:
#                       Gymnast               vault_score  vault_rank  \
# 0         Rebeca Andrade(BRA)  15.400/14.800Avg: 15.100           3
# 1             Jade Carey(USA)  15.166/15.166Avg: 15.166           2
# 2        MyKayla Skinner(USA)  14.933/14.800Avg: 14.866           4
# 3          Zsófia Kovács(HUN)                      14.5           0
# 4            Lee Yun-seo(KOR)                      13.4           0
# 5     Giulia Steingruber(SUI)  14.833/14.300Avg: 14.566          10
# 6         Georgia Godwin(AUS)                    13.766           0
# 7       Elena Gerasimova(ROC)                    13.466           0
# 8         Filipa Martins(POR)                    13.466           0
# 9        Emily Whitehead(AUS)                        14           0
# 10      Luciana Alvarado(CRC)                    13.433           0
# 11      Barbora Mokošová(SVK)                    13.333           0
# 12       Gabriela Sasnal(POL)  13.600/13.366Avg: 13.483          17
# ...

# %%
df['Gymnast'] = df['Gymnast'].apply(lambda x: x.split('(')[0].strip())
df
# Out:
#                  Gymnast               vault_score  vault_rank  uneven_score  \
# 0         Rebeca Andrade  15.400/14.800Avg: 15.100           3        14.200
# 1             Jade Carey  15.166/15.166Avg: 15.166           2        14.133
# 2        MyKayla Skinner  14.933/14.800Avg: 14.866           4        13.666
# 3          Zsófia Kovács                      14.5           0        14.433
# 4            Lee Yun-seo                      13.4           0        14.333
# 5     Giulia Steingruber  14.833/14.300Avg: 14.566          10        12.800
# 6         Georgia Godwin                    13.766           0        13.033
# 7       Elena Gerasimova                    13.466           0        13.233
# 8         Filipa Martins                    13.466           0        14.300
# 9        Emily Whitehead                        14           0        13.066
# 10      Luciana Alvarado                    13.433           0        12.741
# ...

# %%
# Split the 'Vault_Scores' column into 'vault1_score' and 'vault2_score'
df[['vault1_score', 'vault2_score']] = df['vault_score'].str.split('/', expand=True)
df
# Out:
#                  Gymnast               vault_score  vault_rank  uneven_score  \
# 0         Rebeca Andrade  15.400/14.800Avg: 15.100           3        14.200
# 1             Jade Carey  15.166/15.166Avg: 15.166           2        14.133
# 2        MyKayla Skinner  14.933/14.800Avg: 14.866           4        13.666
# 3          Zsófia Kovács                      14.5           0        14.433
# 4            Lee Yun-seo                      13.4           0        14.333
# 5     Giulia Steingruber  14.833/14.300Avg: 14.566          10        12.800
# 6         Georgia Godwin                    13.766           0        13.033
# 7       Elena Gerasimova                    13.466           0        13.233
# 8         Filipa Martins                    13.466           0        14.300
# 9        Emily Whitehead                        14           0        13.066
# 10      Luciana Alvarado                    13.433           0        12.741
# ...

# %%
df[['vault2_score', 'vault_avg_score']] = df['vault2_score'].str.split('Avg:', expand=True)
df
# Out:
#                  Gymnast               vault_score  vault_rank  uneven_score  \
# 0         Rebeca Andrade  15.400/14.800Avg: 15.100           3        14.200
# 1             Jade Carey  15.166/15.166Avg: 15.166           2        14.133
# 2        MyKayla Skinner  14.933/14.800Avg: 14.866           4        13.666
# 3          Zsófia Kovács                      14.5           0        14.433
# 4            Lee Yun-seo                      13.4           0        14.333
# 5     Giulia Steingruber  14.833/14.300Avg: 14.566          10        12.800
# 6         Georgia Godwin                    13.766           0        13.033
# 7       Elena Gerasimova                    13.466           0        13.233
# 8         Filipa Martins                    13.466           0        14.300
# 9        Emily Whitehead                        14           0        13.066
# 10      Luciana Alvarado                    13.433           0        12.741
# ...

# %%
# Remove leading/trailing whitespace
df['vault2_score'] = df['vault2_score'].str.strip()
df['vault_avg_score'] = df['vault_avg_score'].str.strip()
df
# Out:
#                  Gymnast               vault_score  vault_rank  uneven_score  \
# 0         Rebeca Andrade  15.400/14.800Avg: 15.100           3        14.200
# 1             Jade Carey  15.166/15.166Avg: 15.166           2        14.133
# 2        MyKayla Skinner  14.933/14.800Avg: 14.866           4        13.666
# 3          Zsófia Kovács                      14.5           0        14.433
# 4            Lee Yun-seo                      13.4           0        14.333
# 5     Giulia Steingruber  14.833/14.300Avg: 14.566          10        12.800
# 6         Georgia Godwin                    13.766           0        13.033
# 7       Elena Gerasimova                    13.466           0        13.233
# 8         Filipa Martins                    13.466           0        14.300
# 9        Emily Whitehead                        14           0        13.066
# 10      Luciana Alvarado                    13.433           0        12.741
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gymnast          50 non-null     object
#  1   vault_score      50 non-null     object
#  2   vault_rank       50 non-null     int64
#  3   uneven_score     50 non-null     float64
#  4   uneven_rank      50 non-null     object
#  5   bb_score         50 non-null     float64
#  6   bb_rank          50 non-null     object
#  7   floor_score      50 non-null     float64
#  8   floor_rank       50 non-null     object
#  9   total_score      50 non-null     float64
#  10  total_rank       50 non-null     int64
#  11  Country          50 non-null     object
#  12  vault1_score     50 non-null     object
#  13  vault2_score     12 non-null     object
#  14  vault_avg_score  12 non-null     object
# dtypes: float64(4), int64(2), object(9)
# memory usage: 6.0+ KB

# %%
df.fillna(0, inplace=True)
df
# Out:
#                  Gymnast               vault_score  vault_rank  uneven_score  \
# 0         Rebeca Andrade  15.400/14.800Avg: 15.100           3        14.200
# 1             Jade Carey  15.166/15.166Avg: 15.166           2        14.133
# 2        MyKayla Skinner  14.933/14.800Avg: 14.866           4        13.666
# 3          Zsófia Kovács                      14.5           0        14.433
# 4            Lee Yun-seo                      13.4           0        14.333
# 5     Giulia Steingruber  14.833/14.300Avg: 14.566          10        12.800
# 6         Georgia Godwin                    13.766           0        13.033
# 7       Elena Gerasimova                    13.466           0        13.233
# 8         Filipa Martins                    13.466           0        14.300
# 9        Emily Whitehead                        14           0        13.066
# 10      Luciana Alvarado                    13.433           0        12.741
# ...

# %%
df['vault_avg_score'] = df['vault_avg_score'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gymnast          50 non-null     object
#  1   vault_score      50 non-null     object
#  2   vault_rank       50 non-null     int64
#  3   uneven_score     50 non-null     float64
#  4   uneven_rank      50 non-null     object
#  5   bb_score         50 non-null     float64
#  6   bb_rank          50 non-null     object
#  7   floor_score      50 non-null     float64
#  8   floor_rank       50 non-null     object
#  9   total_score      50 non-null     float64
#  10  total_rank       50 non-null     int64
#  11  Country          50 non-null     object
#  12  vault1_score     50 non-null     object
#  13  vault2_score     50 non-null     object
#  14  vault_avg_score  50 non-null     float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 6.0+ KB

# %%
df['vault2_score'] = df['vault2_score'].astype(float)
df['vault1_score'] = df['vault1_score'].astype(float)
df = df.drop(columns=["vault_score"])
df
# Out:
#                  Gymnast  vault_rank  uneven_score uneven_rank  bb_score  \
# 0         Rebeca Andrade           3        14.200          19    13.733
# 1             Jade Carey           2        14.133          20    12.866
# 2        MyKayla Skinner           4        13.666         31T    13.233
# 3          Zsófia Kovács           0        14.433          14    13.133
# 4            Lee Yun-seo           0        14.333          16    12.841
# 5     Giulia Steingruber          10        12.800          53    12.600
# 6         Georgia Godwin           0        13.033          45    12.900
# 7       Elena Gerasimova           0        13.233          40    13.766
# 8         Filipa Martins           0        14.300          17    11.866
# 9        Emily Whitehead           0        13.066         43T    12.666
# 10      Luciana Alvarado           0        12.741          55    12.966
# 11      Barbora Mokošová           0        13.333          38    11.700
# ...

# %%
# Remove letters from the column while keeping numbers
df['uneven_rank'] = df['uneven_rank'].str.replace('[A-Za-z]', '', regex=True)
df['bb_rank'] = df['bb_rank'].str.replace('[A-Za-z]', '', regex=True)
df['floor_rank'] = df['floor_rank'].str.replace('[A-Za-z]', '', regex=True)

# %%
df['uneven_rank'] = df['uneven_rank'].astype(float)
df['bb_rank'] = df['bb_rank'].astype(float)
df['floor_rank'] = df['floor_rank'].astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gymnast          50 non-null     object
#  1   vault_rank       50 non-null     int64
#  2   uneven_score     50 non-null     float64
#  3   uneven_rank      50 non-null     float64
#  4   bb_score         50 non-null     float64
#  5   bb_rank          50 non-null     float64
#  6   floor_score      50 non-null     float64
#  7   floor_rank       50 non-null     float64
#  8   total_score      50 non-null     float64
#  9   total_rank       50 non-null     int64
#  10  Country          50 non-null     object
#  11  vault1_score     50 non-null     float64
#  12  vault2_score     50 non-null     float64
#  13  vault_avg_score  50 non-null     float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 5.6+ KB

# %%
df
# Out:
#                  Gymnast  vault_rank  uneven_score  uneven_rank  bb_score  \
# 0         Rebeca Andrade           3        14.200         19.0    13.733
# 1             Jade Carey           2        14.133         20.0    12.866
# 2        MyKayla Skinner           4        13.666         31.0    13.233
# 3          Zsófia Kovács           0        14.433         14.0    13.133
# 4            Lee Yun-seo           0        14.333         16.0    12.841
# 5     Giulia Steingruber          10        12.800         53.0    12.600
# 6         Georgia Godwin           0        13.033         45.0    12.900
# 7       Elena Gerasimova           0        13.233         40.0    13.766
# 8         Filipa Martins           0        14.300         17.0    11.866
# 9        Emily Whitehead           0        13.066         43.0    12.666
# 10      Luciana Alvarado           0        12.741         55.0    12.966
# 11      Barbora Mokošová           0        13.333         38.0    11.700
# ...

# %%
df.columns
# Out:
# Index(['Gymnast', 'vault_rank', 'uneven_score', 'uneven_rank', 'bb_score',
#        'bb_rank', 'floor_score', 'floor_rank', 'total_score', 'total_rank',
#        'Country', 'vault1_score', 'vault2_score', 'vault_avg_score'],
#       dtype='object')

# %%
new_order = ['Gymnast', 'uneven_score', 'uneven_rank', 'bb_score', 'bb_rank',
       'floor_score', 'floor_rank','vault1_score', 'vault2_score', 
             'vault_avg_score', 'vault_rank', 'total_score', 'total_rank']

df = df[new_order]

df
# Out:
#                  Gymnast  uneven_score  uneven_rank  bb_score  bb_rank  \
# 0         Rebeca Andrade        14.200         19.0    13.733     18.0
# 1             Jade Carey        14.133         20.0    12.866     41.0
# 2        MyKayla Skinner        13.666         31.0    13.233     27.0
# 3          Zsófia Kovács        14.433         14.0    13.133     29.0
# 4            Lee Yun-seo        14.333         16.0    12.841     42.0
# 5     Giulia Steingruber        12.800         53.0    12.600     47.0
# 6         Georgia Godwin        13.033         45.0    12.900     38.0
# 7       Elena Gerasimova        13.233         40.0    13.766     16.0
# 8         Filipa Martins        14.300         17.0    11.866     69.0
# 9        Emily Whitehead        13.066         43.0    12.666     45.0
# 10      Luciana Alvarado        12.741         55.0    12.966     37.0
# 11      Barbora Mokošová        13.333         38.0    11.700     72.0
# ...

# %%
# df.to_csv('w_ind_qual2020.csv', index=False)  # Set index=False to exclude index column
