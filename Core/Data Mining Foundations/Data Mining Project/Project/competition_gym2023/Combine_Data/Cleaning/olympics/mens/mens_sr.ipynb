# %%
import pandas as pd
import numpy as np

# %%
df12 = pd.read_csv('../../../scraping/men/olympics/olympic2012men_final/Gymnastics_ 2012_Olympics_Men\'s_artistic_rings.csv')
df16 = pd.read_csv('../../../scraping/men/olympics/olympic2016men/Gymnastics_ 2016_Olympics_Men\'s_artistic_rings.csv')
df20 = pd.read_csv('../../../scraping/men/olympics/mens202olympics_fianl/Gymnastics_ 2020_Olympics_Men\'s_artistic_rings.csv')

# %%
df12.head(1)
# Out:
#    Rank         Gymnast  Nation  D Score  E Score  Pen.  Total
# 0     1  Arthur Zanetti  Brazil      6.8      9.1   NaN   15.9

# %%
df12.head(1)
# Out:
#    Rank         Gymnast  Nation  D Score  E Score  Pen.  Total
# 0     1  Arthur Zanetti  Brazil      6.8      9.1   NaN   15.9

# %%
df16.head(1)
# Out:
#    Rank                 Gymnast  Nation  D Score  E Score  Pen.  Total
# 0     1  Eleftherios Petrounias  Greece      6.8      9.2   NaN   16.0

# %%
df20.head(1)
# Out:
#    Rank        Gymnast  D Score  E Score  Pen.  Total
# 0     1  Liu Yang(CHN)      6.5      9.0   NaN   15.5

# %%
df20['year'] = 2020
df16['year'] = 2016
df12['year'] = 2012

# %%
df20['Nation'] = df20['Gymnast'].str.extract(r'\((.*?)\)')
df20['Gymnast'] = df20['Gymnast'].str.replace(r'\([^)]*\)', '', regex=True)

# %%
combined_df = pd.concat([df12, df16, df20], axis=0)

combined_df.reset_index(drop=True, inplace=True)

# %%
df= combined_df.copy()

# %%
df = df.fillna(0)

# %%
df
# Out:
#     Rank                   Gymnast       Nation  D Score  E Score  Pen.  \
# 0      1            Arthur Zanetti       Brazil      6.8    9.100   0.0
# 1      2               Chen Yibing        China      6.8    9.000   0.0
# 2      3            Matteo Morandi        Italy      6.8    8.933   0.0
# 3      4        Aleksandr Balandin       Russia      6.7    8.966   0.0
# 4      5            Denis Ablyazin       Russia      6.6    9.033   0.0
# 5      6               Tommy Ramos  Puerto Rico      6.8    8.800   0.0
# 6      7            Yordan Yovchev     Bulgaria      6.6    8.508   0.0
# 7      8         Federico Molinari    Argentina      6.7    8.033   0.0
# 8      1    Eleftherios Petrounias       Greece      6.8    9.200   0.0
# 9      2            Arthur Zanetti       Brazil      6.8    8.966   0.0
# 10     3            Denis Ablyazin       Russia      6.8    8.900   0.0
# 11     4                  Liu Yang        China      6.9    8.700   0.0
# ...

# %%
df['Nation'].value_counts()
# Out:
# Nation
# Russia         3
# China          3
# Brazil         2
# TUR            2
# CHN            2
# Belgium        1
# ROC            1
# FRA            1
# GRE            1
# Ukraine        1
# France         1
# Greece         1
# Argentina      1
# Bulgaria       1
# Puerto Rico    1
# Italy          1
# BRA            1
# Name: count, dtype: int64

# %%
# Use the replace method to change values
df['Nation'] = df['Nation'].replace({'China': 'CHN', 'Japan': 'JPN',
                                    'Russia': 'RUS', 'Romania': 'RUM',
                                    'Germany': 'GER', 'Cuba': 'CUB',
                                    'United States': 'USA', 'Ukraine': 'UKR',
                                    'Greece': 'GRE', 'Mexico': 'MEX',
                                    'France': 'FRA', 'Netherlands': 'NED',
                                    'Brazil': 'BRA', "Great Britain": 'GBR',
                                    'South Korea': 'KOR', 'Hungary': 'HUN',
                                    'Armenia': 'ARM', 'Belgium': 'BEL', 
                                    'Argentina': 'ARG', 'Bulgaria': 'BUL',
                                    'Puerto Rico': 'PUR'})

# %%
df
# Out:
#     Rank                   Gymnast Nation  D Score  E Score  Pen.   Total  \
# 0      1            Arthur Zanetti    BRA      6.8    9.100   0.0  15.900
# 1      2               Chen Yibing    CHN      6.8    9.000   0.0  15.800
# 2      3            Matteo Morandi  Italy      6.8    8.933   0.0  15.733
# 3      4        Aleksandr Balandin    RUS      6.7    8.966   0.0  15.666
# 4      5            Denis Ablyazin    RUS      6.6    9.033   0.0  15.633
# 5      6               Tommy Ramos    PUR      6.8    8.800   0.0  15.600
# 6      7            Yordan Yovchev    BUL      6.6    8.508   0.0  15.108
# 7      8         Federico Molinari    ARG      6.7    8.033   0.0  14.733
# 8      1    Eleftherios Petrounias    GRE      6.8    9.200   0.0  16.000
# 9      2            Arthur Zanetti    BRA      6.8    8.966   0.0  15.766
# 10     3            Denis Ablyazin    RUS      6.8    8.900   0.0  15.700
# 11     4                  Liu Yang    CHN      6.9    8.700   0.0  15.600
# ...

# %%
# df.to_csv('cleaned_mens2012to2020sr', index=False)
