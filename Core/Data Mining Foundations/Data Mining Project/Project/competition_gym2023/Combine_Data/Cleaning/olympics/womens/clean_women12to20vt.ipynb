# %%
import pandas as pd
import numpy as np

# %%
df20 = pd.read_csv('../../../scraping/women/olympics/womens2020olympics/Gymnastics_ 2020_Olympics_women\'s_artistic_vault.csv')
df16 = pd.read_csv('../../../scraping/women/olympics/women2016olympics/Gymnastics_ 2016_Olympics_women\'s_artistic_vault.csv')
df12 = pd.read_csv('../../../scraping/women/olympics/women2012olympics/Gymnastics_ 2012_Olympics_women\'s_artistic_vaoult.csv')

# %%
df12.head(1)
# Out:
#    Rank        Gymnast  Country  vt1D   vt1E  vt1Pen  Vault Score1  vt2D  \
# 0     1  Sandra Izbașa  Romania   6.1  9.283     NaN        15.383   5.8
#
#    vt2E  vt2Pen  Vault Score2   Total
# 0   9.2     NaN          15.0  15.191

# %%
df16.head(1)
# Out:
#    Rank            Gymnast  vt1_D Score  vt1_E Score  vt1_Pen.  Score 1  \
# 0     1  Simone Biles(USA)          6.3          9.6       NaN     15.9
#
#    vt2_D Score  vt2_E Score  vt2_Pen.  Score 2   Total
# 0          6.4        9.633       NaN   16.033  15.966

# %%
df20.head(1)
# Out:
#    Position              Gymnast  vt1_D Score  vt1_E Score  vt1_Penalty  \
# 0         1  Rebeca Andrade(BRA)          6.0        9.266          0.1
#
#    Score 1  vt2_D Score  vt2_E Score  vt2_Penalty  Score 2   Total
# 0   15.166          5.8          9.2          NaN     15.0  15.083

# %%
column_mapping = {'vt1D': 'vt1_D Score', 
                  'vt1E': 'vt1_E Score', 'vt1Pen': 'vt1_Pen.', 'Vault Score1': 'Score 1',
                 'vt2D': 'vt2_D Score', 'vt2E': 'vt2_E Score', 'vt2Pen': 'vt2_Pen.',
                 'Vault Score2': 'Score 2'}

# Rename the columns using the rename() method
df12.rename(columns=column_mapping, inplace=True)

# %%
df12.head(1)
# Out:
#    Rank        Gymnast  Country  vt1_D Score  vt1_E Score  vt1_Pen.  Score 1  \
# 0     1  Sandra Izbașa  Romania          6.1        9.283       NaN   15.383
#
#    vt2_D Score  vt2_E Score  vt2_Pen.  Score 2   Total
# 0          5.8          9.2       NaN     15.0  15.191

# %%
column_mapping = {'vt1_Penalty': 'vt1_Pen.', 'vt2_Penalty': 'vt2_Pen.'}

# ename the columns using the rename() method
df20.rename(columns=column_mapping, inplace=True)

# %%
df20.head(1)
# Out:
#    Position              Gymnast  vt1_D Score  vt1_E Score  vt1_Pen.  Score 1  \
# 0         1  Rebeca Andrade(BRA)          6.0        9.266       0.1   15.166
#
#    vt2_D Score  vt2_E Score  vt2_Pen.  Score 2   Total
# 0          5.8          9.2       NaN     15.0  15.083

# %%
df12['year'] = 2012
df16['year'] = 2016
df20['year'] = 2020

# %%
df20['Nation'] = df20['Gymnast'].str.extract(r'\((.*?)\)')
df20['Gymnast'] = df20['Gymnast'].str.replace(r'\([^)]*\)', '', regex=True)

# %%
df16['Nation'] = df16['Gymnast'].str.extract(r'\((.*?)\)')
df16['Gymnast'] = df16['Gymnast'].str.replace(r'\([^)]*\)', '', regex=True)

# %%
df16.head()
# Out:
#    Rank             Gymnast  vt1_D Score  vt1_E Score  vt1_Pen.  Score 1  \
# 0     1        Simone Biles          6.3        9.600       NaN   15.900
# 1     2        Maria Paseka          6.4        8.966       0.0   15.266
# 2     3  Giulia Steingruber          6.2        9.333       NaN   15.533
# 3     4       Dipa Karmakar          6.0        8.866       NaN   14.866
# 4     5            Wang Yan          6.0        8.866       NaN   14.866
#
#    vt2_D Score  vt2_E Score  vt2_Pen.  Score 2   Total  year Nation
# 0          6.4        9.633       NaN   16.033  15.966  2016    USA
# 1          6.3        8.941       NaN   15.241  15.253  2016    RUS
# 2          5.8        9.100       NaN   14.900  15.216  2016    SUI
# 3          7.0        8.266       NaN   15.266  15.066  2016    IND
# 4          6.2        8.933       NaN   15.133  14.999  2016    CHN

# %%
df20.head()
# Out:
#    Position             Gymnast  vt1_D Score  vt1_E Score  vt1_Pen.  Score 1  \
# 0         1      Rebeca Andrade          6.0        9.266       0.1   15.166
# 1         2     MyKayla Skinner          6.0        9.033       NaN   15.033
# 2         3       Yeo Seo-jeong          6.2        9.133       NaN   15.333
# 3         4        Alexa Moreno          5.8        8.966       NaN   14.766
# 4         5  Angelina Melnikova          5.4        9.266       NaN   14.666
#
#    vt2_D Score  vt2_E Score  vt2_Pen.  Score 2   Total  year Nation
# 0          5.8        9.200       NaN   15.000  15.083  2020    BRA
# 1          5.8        9.000       NaN   14.800  14.916  2020    USA
# 2          5.4        8.733       NaN   14.133  14.733  2020    KOR
# 3          5.6        9.066       NaN   14.666  14.716  2020    MEX
# 4          6.0        8.800       0.1   14.700  14.683  2020    ROC

# %%
df12.head()
# Out:
#    Rank             Gymnast        Country  vt1_D Score  vt1_E Score  \
# 0     1       Sandra Izbașa        Romania          6.1        9.283
# 1     2     McKayla Maroney  United States          6.5        9.666
# 2     3        Maria Paseka         Russia          6.5        8.900
# 3     4       Janine Berger        Germany          6.3        8.833
# 4     5  Oksana Chusovitina        Germany          6.3        8.800
#
#    vt1_Pen.  Score 1  vt2_D Score  vt2_E Score  vt2_Pen.  Score 2   Total  \
# 0       NaN   15.383          5.8        9.200       NaN   15.000  15.191
# 1       0.3   15.866          6.1        8.200       NaN   14.300  15.083
# 2       NaN   15.400          5.6        9.100       NaN   14.700   15.05
# 3       NaN   15.133          6.0        8.900       NaN   14.900  15.016
# 4       NaN   15.100          5.5        8.966       NaN   14.466  14.783
#
#    year
# 0  2012
# 1  2012
# 2  2012
# 3  2012
# 4  2012

# %%
column_mapping = {'Country': 'Nation'}

# ename the columns using the rename() method
df12.rename(columns=column_mapping, inplace=True)

# %%
df12.head()
# Out:
#    Rank             Gymnast         Nation  vt1_D Score  vt1_E Score  \
# 0     1       Sandra Izbașa        Romania          6.1        9.283
# 1     2     McKayla Maroney  United States          6.5        9.666
# 2     3        Maria Paseka         Russia          6.5        8.900
# 3     4       Janine Berger        Germany          6.3        8.833
# 4     5  Oksana Chusovitina        Germany          6.3        8.800
#
#    vt1_Pen.  Score 1  vt2_D Score  vt2_E Score  vt2_Pen.  Score 2   Total  \
# 0       NaN   15.383          5.8        9.200       NaN   15.000  15.191
# 1       0.3   15.866          6.1        8.200       NaN   14.300  15.083
# 2       NaN   15.400          5.6        9.100       NaN   14.700   15.05
# 3       NaN   15.133          6.0        8.900       NaN   14.900  15.016
# 4       NaN   15.100          5.5        8.966       NaN   14.466  14.783
#
#    year
# 0  2012
# 1  2012
# 2  2012
# 3  2012
# 4  2012

# %%
df12
# Out:
#    Rank             Gymnast              Nation  vt1_D Score  vt1_E Score  \
# 0     1       Sandra Izbașa             Romania          6.1        9.283
# 1     2     McKayla Maroney       United States          6.5        9.666
# 2     3        Maria Paseka              Russia          6.5        8.900
# 3     4       Janine Berger             Germany          6.3        8.833
# 4     5  Oksana Chusovitina             Germany          6.3        8.800
# 5     6        Yamilet Peña  Dominican Republic          7.1        7.566
# 6     7     Brittany Rogers              Canada          5.8        8.966
# 7     8         Ellie Black              Canada          0.0        0.000
#
#    vt1_Pen.  Score 1  vt2_D Score  vt2_E Score  vt2_Pen.  Score 2   Total  \
# 0       NaN   15.383          5.8        9.200       NaN   15.000  15.191
# 1       0.3   15.866          6.1        8.200       NaN   14.300  15.083
# 2       NaN   15.400          5.6        9.100       NaN   14.700   15.05
# ...

# %%
df16
# Out:
#    Rank             Gymnast  vt1_D Score  vt1_E Score  vt1_Pen.  Score 1  \
# 0     1        Simone Biles          6.3        9.600       NaN   15.900
# 1     2        Maria Paseka          6.4        8.966       0.0   15.266
# 2     3  Giulia Steingruber          6.2        9.333       NaN   15.533
# 3     4       Dipa Karmakar          6.0        8.866       NaN   14.866
# 4     5            Wang Yan          6.0        8.866       NaN   14.866
# 5     6        Hong Un-jong          6.4        9.000       NaN   15.400
# 6     7  Oksana Chusovitina          7.0        7.933       NaN   14.933
# 7     8       Shallon Olsen          6.3        8.666       NaN   14.966
#
#    vt2_D Score  vt2_E Score  vt2_Pen.  Score 2   Total  year Nation
# 0          6.4        9.633       NaN   16.033  15.966  2016    USA
# 1          6.3        8.941       NaN   15.241  15.253  2016    RUS
# 2          5.8        9.100       NaN   14.900  15.216  2016    SUI
# ...

# %%
df20
# Out:
#    Position             Gymnast  vt1_D Score  vt1_E Score  vt1_Pen.  Score 1  \
# 0         1      Rebeca Andrade          6.0        9.266       0.1   15.166
# 1         2     MyKayla Skinner          6.0        9.033       NaN   15.033
# 2         3       Yeo Seo-jeong          6.2        9.133       NaN   15.333
# 3         4        Alexa Moreno          5.8        8.966       NaN   14.766
# 4         5  Angelina Melnikova          5.4        9.266       NaN   14.666
# 5         6     Lilia Akhaimova          5.8        8.866       NaN   14.666
# 6         7       Shallon Olsen          6.0        8.700       NaN   14.700
# 7         8          Jade Carey          3.3        8.633       NaN   11.933
#
#    vt2_D Score  vt2_E Score  vt2_Pen.  Score 2   Total  year Nation
# 0          5.8        9.200       NaN   15.000  15.083  2020    BRA
# 1          5.8        9.000       NaN   14.800  14.916  2020    USA
# 2          5.4        8.733       NaN   14.133  14.733  2020    KOR
# ...

# %%
column_mapping = {'Position': 'Rank'}

# ename the columns using the rename() method
df20.rename(columns=column_mapping, inplace=True)

# %%
# desired order of columns
desired_columns_order = ['Rank', 'Gymnast', 'vt1_D Score', 'vt1_E Score', 'vt1_Pen.', 'Score 1',
       'vt2_D Score', 'vt2_E Score', 'vt2_Pen.', 'Score 2', 'Total', 'year',
       'Nation']

df12 = df12[desired_columns_order]

# %%
df12
# Out:
#    Rank             Gymnast  vt1_D Score  vt1_E Score  vt1_Pen.  Score 1  \
# 0     1       Sandra Izbașa          6.1        9.283       NaN   15.383
# 1     2     McKayla Maroney          6.5        9.666       0.3   15.866
# 2     3        Maria Paseka          6.5        8.900       NaN   15.400
# 3     4       Janine Berger          6.3        8.833       NaN   15.133
# 4     5  Oksana Chusovitina          6.3        8.800       NaN   15.100
# 5     6        Yamilet Peña          7.1        7.566       0.1   14.566
# 6     7     Brittany Rogers          5.8        8.966       NaN   14.766
# 7     8         Ellie Black          0.0        0.000       NaN    0.000
#
#    vt2_D Score  vt2_E Score  vt2_Pen.  Score 2   Total  year  \
# 0          5.8        9.200       NaN   15.000  15.191  2012
# 1          6.1        8.200       NaN   14.300  15.083  2012
# 2          5.6        9.100       NaN   14.700   15.05  2012
# 3          6.0        8.900       NaN   14.900  15.016  2012
# ...

# %%
combined_df = pd.concat([df12, df16, df20], axis=0, ignore_index=True)

# %%
combined_df
# Out:
#     Rank             Gymnast  vt1_D Score  vt1_E Score  vt1_Pen.  Score 1  \
# 0      1       Sandra Izbașa          6.1        9.283       NaN   15.383
# 1      2     McKayla Maroney          6.5        9.666       0.3   15.866
# 2      3        Maria Paseka          6.5        8.900       NaN   15.400
# 3      4       Janine Berger          6.3        8.833       NaN   15.133
# 4      5  Oksana Chusovitina          6.3        8.800       NaN   15.100
# 5      6        Yamilet Peña          7.1        7.566       0.1   14.566
# 6      7     Brittany Rogers          5.8        8.966       NaN   14.766
# 7      8         Ellie Black          0.0        0.000       NaN    0.000
# 8      1        Simone Biles          6.3        9.600       NaN   15.900
# 9      2        Maria Paseka          6.4        8.966       0.0   15.266
# 10     3  Giulia Steingruber          6.2        9.333       NaN   15.533
# 11     4       Dipa Karmakar          6.0        8.866       NaN   14.866
# ...

# %%
df= combined_df.copy()

# %%
df = df.fillna(0)

# %%
df
# Out:
#     Rank             Gymnast  vt1_D Score  vt1_E Score  vt1_Pen.  Score 1  \
# 0      1       Sandra Izbașa          6.1        9.283       0.0   15.383
# 1      2     McKayla Maroney          6.5        9.666       0.3   15.866
# 2      3        Maria Paseka          6.5        8.900       0.0   15.400
# 3      4       Janine Berger          6.3        8.833       0.0   15.133
# 4      5  Oksana Chusovitina          6.3        8.800       0.0   15.100
# 5      6        Yamilet Peña          7.1        7.566       0.1   14.566
# 6      7     Brittany Rogers          5.8        8.966       0.0   14.766
# 7      8         Ellie Black          0.0        0.000       0.0    0.000
# 8      1        Simone Biles          6.3        9.600       0.0   15.900
# 9      2        Maria Paseka          6.4        8.966       0.0   15.266
# 10     3  Giulia Steingruber          6.2        9.333       0.0   15.533
# 11     4       Dipa Karmakar          6.0        8.866       0.0   14.866
# ...

# %%
# df.to_csv('cleaned_womens2012to2020vt', index=False)
