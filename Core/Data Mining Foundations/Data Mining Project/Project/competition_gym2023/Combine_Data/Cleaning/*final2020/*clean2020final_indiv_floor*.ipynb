# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../scraping/women/miscellaneous/scrape2020final_indiv_floor.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_38296/224324877.py in <cell line: 1>()
# ----> 1 df = pd.read_csv('../../scraping/women/miscellaneous/scrape2020final_indiv_floor.csv')
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     910     kwds.update(kwds_defaults)
#     911
# --> 912     return _read(filepath_or_buffer, kwds)
#     913
#     914
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     575
#     576     # Create the parser.
# --> 577     parser = TextFileReader(filepath_or_buffer, **kwds)
#     578
#     579     if chunksize or iterator:
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1405
#    1406         self.handles: IOHandles | None = None
# -> 1407         self._engine = self._make_engine(f, self.engine)
#    1408
#    1409     def close(self) -> None:
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1659                 if "b" not in mode:
#    1660                     mode += "b"
# -> 1661             self.handles = get_handle(
#    1662                 f,
#    1663                 mode,
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     857         if ioargs.encoding and "b" not in ioargs.mode:
#     858             # Encoding
# --> 859             handle = open(
#     860                 handle,
#     861                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../scraping/women/miscellaneous/scrape2020final_indiv_floor.csv'

# %%
df
# Out:
#    Rank                  Gymnast  D Score  E Score  Pen.   Total
# 0     1          Jade Carey(USA)      6.3    8.066   NaN  14.366
# 1     2     Vanessa Ferrari(ITA)      5.9    8.300   NaN  14.200
# 2     3        Mai Murakami(JPN)      5.9    8.266   NaN  14.166
# 3     3  Angelina Melnikova(ROC)      5.9    8.266   NaN  14.166
# 4     5      Rebeca Andrade(BRA)      5.9    8.233   0.1  14.033
# 5     6    Jessica Gadirova(GBR)      5.6    8.400   NaN  14.000
# 6     7   Jennifer Gadirova(GBR)      5.1    8.133   NaN  13.233
# 7     8  Viktoria Listunova(ROC)      5.2    7.300   0.1  12.400

# %%
# Extract data within parentheses and store it in a new column
df["Country"] = df['Gymnast'].str.extract(r'\((.*?)\)')

df['Gymnast'] = df['Gymnast'].apply(lambda x: x.split('(')[0].strip())
df.head()
# Out:
#    Rank             Gymnast  D Score  E Score  Pen.   Total Country
# 0     1          Jade Carey      6.3    8.066   NaN  14.366     USA
# 1     2     Vanessa Ferrari      5.9    8.300   NaN  14.200     ITA
# 2     3        Mai Murakami      5.9    8.266   NaN  14.166     JPN
# 3     3  Angelina Melnikova      5.9    8.266   NaN  14.166     ROC
# 4     5      Rebeca Andrade      5.9    8.233   0.1  14.033     BRA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     8 non-null      int64
#  1   Gymnast  8 non-null      object
#  2   D Score  8 non-null      float64
#  3   E Score  8 non-null      float64
#  4   Pen.     2 non-null      float64
#  5   Total    8 non-null      float64
#  6   Country  8 non-null      object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 576.0+ bytes

# %%
df['Pen.'].fillna(0, inplace=True)

# %%
df
# Out:
#    Rank             Gymnast  D Score  E Score  Pen.   Total Country
# 0     1          Jade Carey      6.3    8.066   0.0  14.366     USA
# 1     2     Vanessa Ferrari      5.9    8.300   0.0  14.200     ITA
# 2     3        Mai Murakami      5.9    8.266   0.0  14.166     JPN
# 3     3  Angelina Melnikova      5.9    8.266   0.0  14.166     ROC
# 4     5      Rebeca Andrade      5.9    8.233   0.1  14.033     BRA
# 5     6    Jessica Gadirova      5.6    8.400   0.0  14.000     GBR
# 6     7   Jennifer Gadirova      5.1    8.133   0.0  13.233     GBR
# 7     8  Viktoria Listunova      5.2    7.300   0.1  12.400     ROC

# %%
# df.to_csv('clean2020final_indiv_floor.csv', index=False)  # Set index=False to exclude index column
