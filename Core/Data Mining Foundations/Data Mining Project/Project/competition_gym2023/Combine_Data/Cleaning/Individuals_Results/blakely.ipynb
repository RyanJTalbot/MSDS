# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
df = pd.read_csv('../../scraping/women/gymnasts_results/blakely/blakely21.csv')

# %%
df
# Out:
#         Date               Competition Unnamed: 2     VT     UB     BB     FX  \
# 0    Jun 3-6        U.S. Championships         AA  14.55  13.60  14.25  13.30
# 1    Jun 3-6        U.S. Championships         QF  14.70  12.95  12.75  13.45
# 2  May 21-22              U.S. Classic         AA  14.00  14.05  12.65  13.30
# 3     24-Apr          American Classic         AA  13.85  14.10  14.30  13.10
# 4     13-Mar  March National Team Camp         AA  14.35   0.00  14.60  11.95
# 5  Feb 26-28                Winter Cup         AA   0.00   0.00  14.50  12.65
#
#       AA
# 0  55.70
# 1  53.85
# 2  54.00
# 3  55.35
# 4   0.00
# 5   0.00

# %%
df["Year"] = 2021

# %%
df["Name"] = "Skye Blakely"

# %%
df
# Out:
#         Date               Competition Unnamed: 2     VT     UB     BB     FX  \
# 0    Jun 3-6        U.S. Championships         AA  14.55  13.60  14.25  13.30
# 1    Jun 3-6        U.S. Championships         QF  14.70  12.95  12.75  13.45
# 2  May 21-22              U.S. Classic         AA  14.00  14.05  12.65  13.30
# 3     24-Apr          American Classic         AA  13.85  14.10  14.30  13.10
# 4     13-Mar  March National Team Camp         AA  14.35   0.00  14.60  11.95
# 5  Feb 26-28                Winter Cup         AA   0.00   0.00  14.50  12.65
#
#       AA  Year          Name
# 0  55.70  2021  Skye Blakely
# 1  53.85  2021  Skye Blakely
# 2  54.00  2021  Skye Blakely
# 3  55.35  2021  Skye Blakely
# 4   0.00  2021  Skye Blakely
# 5   0.00  2021  Skye Blakely

# %%
df2 = pd.read_csv('../../scraping/women/gymnasts_results/blakely/blakely22.csv')

# %%
df2
# Out:
#             Date                 Competition Unnamed: 2      VT      UB  \
# 0   Oct 29-Nov 6         World Championships         EF   0.000   0.000
# 1   Oct 29-Nov 6         World Championships         TF   0.000   0.000
# 2   Oct 29-Nov 6         World Championships         QF   0.000  12.566
# 3      Oct 21-22          U.S. Worlds Trials         EF   0.000  14.200
# 4      Oct 21-22          U.S. Worlds Trials         AA  14.200  13.450
# 5      Aug 18-21          U.S. Championships         AA  14.300  13.900
# 6      Aug 18-21          U.S. Championships         QF  14.100  13.850
# 7      Jul 14-17  Pan American Championships         TF  13.867  13.900
# 8      Jul 14-17  Pan American Championships         AA  13.433  13.933
# 9        Jul 4-5         U.S. Pan Ams Trials         EF   0.000  12.266
# 10       Jul 4-5         U.S. Pan Ams Trials         AA  14.000  13.400
# 11     Mar 18-20    DTB Pokal Team Challenge         AA  14.266  12.000
# ...

# %%
df2["Year"] = 2022

# %%
df2["Name"] = "Skye Blakely"

# %%
df3 = pd.read_csv('../../scraping/women/gymnasts_results/blakely/blakely23.csv')

# %%
df3
# Out:
#         Date              Competition Unnamed: 2     VT     UB     BB    FX  \
# 0  Aug 24-27       U.S. Championships         AA  14.25  14.40  14.20  12.2
# 1  Aug 24-27       U.S. Championships         QF  14.35  14.40  14.05  12.9
# 2    Aug 4-6             U.S. Classic         AA  14.10  14.35  14.30   0.0
# 3   Jul 9-12  July National Team Camp         AA  14.25  14.35  14.05   0.0
# 4  Feb 23-26               Winter Cup         AA   0.00  13.15  13.40   0.0
# 5  Feb 17-19             WOGA Classic         AA   0.00  14.70  13.45   0.0
#
#       AA
# 0  55.05
# 1  55.70
# 2   0.00
# 3   0.00
# 4   0.00
# 5   0.00

# %%
df3["Year"] = 2023

# %%
df3["Name"] = "Skye Blakely"

# %%
result = pd.concat([df, df2, df3], ignore_index=True)

# %%
df = result.copy()

# %%
df.rename(columns={'Unnamed: 2': 'Round'}, inplace=True)

# %%
df
# Out:
#             Date                 Competition Round      VT      UB      BB  \
# 0        Jun 3-6          U.S. Championships    AA  14.550  13.600  14.250
# 1        Jun 3-6          U.S. Championships    QF  14.700  12.950  12.750
# 2      May 21-22                U.S. Classic    AA  14.000  14.050  12.650
# 3         24-Apr            American Classic    AA  13.850  14.100  14.300
# 4         13-Mar    March National Team Camp    AA  14.350   0.000  14.600
# 5      Feb 26-28                  Winter Cup    AA   0.000   0.000  14.500
# 6   Oct 29-Nov 6         World Championships    EF   0.000   0.000  13.300
# 7   Oct 29-Nov 6         World Championships    TF   0.000   0.000  13.266
# 8   Oct 29-Nov 6         World Championships    QF   0.000  12.566  13.733
# 9      Oct 21-22          U.S. Worlds Trials    EF   0.000  14.200  14.550
# 10     Oct 21-22          U.S. Worlds Trials    AA  14.200  13.450  13.550
# ...

# %%
from dateutil import parser

# %%
# Function to parse date entries
def parse_date(entry):
    try:
        return parser.parse(entry).strftime("%b %d")
    except ValueError:
        return entry

# Apply parse_date function to "Date" column
df["Date"] = df["Date"].apply(parse_date)

# %%
def extract_month_day(entry):
    parts = entry.split('-')
    return parts[0]

# Apply extract_month_day function to "Date" column
df["Date"] = df["Date"].apply(extract_month_day)

# %%
df["Date"] = pd.to_datetime(df["Date"] + " " + df["Year"].astype(str), format="%b %d %Y")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         26 non-null     datetime64[ns]
#  1   Competition  26 non-null     object
#  2   Round        26 non-null     object
#  3   VT           26 non-null     float64
#  4   UB           26 non-null     float64
#  5   BB           26 non-null     float64
#  6   FX           26 non-null     float64
#  7   AA           26 non-null     float64
#  8   Year         26 non-null     int64
#  9   Name         26 non-null     object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(3)
# memory usage: 2.2+ KB

# %%
df.head()
# Out:
#         Date               Competition Round     VT     UB     BB     FX  \
# 0 2021-06-03        U.S. Championships    AA  14.55  13.60  14.25  13.30
# 1 2021-06-03        U.S. Championships    QF  14.70  12.95  12.75  13.45
# 2 2021-05-21              U.S. Classic    AA  14.00  14.05  12.65  13.30
# 3 2021-04-24          American Classic    AA  13.85  14.10  14.30  13.10
# 4 2021-03-13  March National Team Camp    AA  14.35   0.00  14.60  11.95
#
#       AA  Year          Name
# 0  55.70  2021  Skye Blakely
# 1  53.85  2021  Skye Blakely
# 2  54.00  2021  Skye Blakely
# 3  55.35  2021  Skye Blakely
# 4   0.00  2021  Skye Blakely

# %%
df = df.drop(columns=["Year"])

# %%
df.columns
# Out:
# Index(['Date', 'Competition', 'Round', 'VT', 'UB', 'BB', 'FX', 'AA', 'Name'], dtype='object')

# %%
# desired column order
desired_order = ['Name', 'Date', 'Competition', 'Round', 'VT', 'UB', 'BB', 'FX', 'AA',
       ]

# Create a new DataFrame with columns in the desired order
df_reordered = df[desired_order]

# %%
df_reordered
# Out:
#             Name       Date                 Competition Round      VT      UB  \
# 0   Skye Blakely 2021-06-03          U.S. Championships    AA  14.550  13.600
# 1   Skye Blakely 2021-06-03          U.S. Championships    QF  14.700  12.950
# 2   Skye Blakely 2021-05-21                U.S. Classic    AA  14.000  14.050
# 3   Skye Blakely 2021-04-24            American Classic    AA  13.850  14.100
# 4   Skye Blakely 2021-03-13    March National Team Camp    AA  14.350   0.000
# 5   Skye Blakely 2021-02-26                  Winter Cup    AA   0.000   0.000
# 6   Skye Blakely 2022-10-29         World Championships    EF   0.000   0.000
# 7   Skye Blakely 2022-10-29         World Championships    TF   0.000   0.000
# 8   Skye Blakely 2022-10-29         World Championships    QF   0.000  12.566
# 9   Skye Blakely 2022-10-21          U.S. Worlds Trials    EF   0.000  14.200
# 10  Skye Blakely 2022-10-21          U.S. Worlds Trials    AA  14.200  13.450
# ...

# %%
# df_reordered.to_csv('blakely.csv', index=False)
