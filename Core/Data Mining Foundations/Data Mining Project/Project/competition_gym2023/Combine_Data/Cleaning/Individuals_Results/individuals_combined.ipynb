# %%
import pandas as pd
import numpy as np

# %%
biles = pd.read_csv('biles.csv')

# %%
biles["Name"] = "Simone Biles"

# %%
carey = pd.read_csv('carey.csv')

# %%
blakely = pd.read_csv('blakely.csv')

# %%
chiles = pd.read_csv('chiles.csv')

# %%
dicello = pd.read_csv('dicello.csv')

# %%
jones = pd.read_csv('jones.csv')

# %%
jong= pd.read_csv('jong.csv')

# %%
lee = pd.read_csv('lee.csv')

# %%
matthews = pd.read_csv('matthews.csv')

# %%
miller = pd.read_csv('miller.csv')

# %%
roberson = pd.read_csv('roberson.csv')

# %%
sullivan = pd.read_csv('sullivan.csv')

# %%
suman = pd.read_csv('suman.csv')

# %%
wong = pd.read_csv('wong.csv')

# %%
lincoln = pd.read_csv('lincoln.csv')

# %%
lincoln = lincoln.rename(columns={'year': 'Date'})

# %%
combined_df = pd.concat([biles, carey, blakely, chiles,
                        dicello, jones, jong, lee, 
                        matthews, miller, roberson,
                        sullivan, suman, wong, lincoln], ignore_index=True)

# %%
combined_df = combined_df.drop(columns=["Gymnast"])

# %%
df = combined_df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         334 non-null    object
#  1   Competition  334 non-null    object
#  2   Round        334 non-null    object
#  3   VT           334 non-null    object
#  4   UB           334 non-null    float64
#  5   BB           334 non-null    float64
#  6   FX           334 non-null    float64
#  7   AA           334 non-null    float64
#  8   Name         334 non-null    object
# dtypes: float64(4), object(5)
# memory usage: 23.6+ KB

# %%
# Define a function to remove asterisk from a value
def remove_asterisk(value):
    return float(value.rstrip('*')) if isinstance(value, str) else value

# Apply the function to the 'VT' column
df['VT'] = df['VT'].apply(remove_asterisk)

# %%
df["VT"].value_counts()
# Out:
# VT
# 0.000     70
# 14.100    11
# 14.350    11
# 14.300    11
# 14.200    10
#           ..
# 14.833     1
# 12.550     1
# 15.000     1
# 13.784     1
# 14.050     1
# Name: count, Length: 86, dtype: int64

# %%
df['VT'] = pd.to_numeric(df['VT'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 334 entries, 0 to 333
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         334 non-null    object
#  1   Competition  334 non-null    object
#  2   Round        334 non-null    object
#  3   VT           334 non-null    float64
#  4   UB           334 non-null    float64
#  5   BB           334 non-null    float64
#  6   FX           334 non-null    float64
#  7   AA           334 non-null    float64
#  8   Name         334 non-null    object
# dtypes: float64(5), object(4)
# memory usage: 23.6+ KB

# %%
df
# Out:
#            Date                   Competition Round      VT      UB      BB  \
# 0    2021-07-23                 Olympic Games    EF   0.000   0.000  14.000
# 1    2021-07-23                 Olympic Games    TF  13.766   0.000   0.000
# 2    2021-07-23                 Olympic Games    QF  14.966  14.566  14.066
# 3    2021-06-24           U.S. Olympic Trials    AA  15.400  13.833  13.700
# 4    2021-06-24           U.S. Olympic Trials    QF  15.466  14.600  15.133
# ..          ...                           ...   ...     ...     ...     ...
# 329        2023            U.S. Championships    QF  14.100  12.300  13.250
# 330        2023                  U.S. Classic    AA  14.150   0.000  12.950
# 331        2023                    Winter Cup    AA  13.500  12.950  11.000
# 332        2023                  WOGA Classic    AA   0.000  13.300   0.000
# 333        2023  Vegas Cup National Qualifier    AA  13.550  12.350  12.900
#
#          FX      AA            Name
# ...

# %%
 aa = df[df['AA'] > 0]

# %%
 apps = df[df['AA'] == 0]

# %%
aa
# Out:
#            Date                   Competition Round      VT      UB      BB  \
# 2    2021-07-23                 Olympic Games    QF  14.966  14.566  14.066
# 3    2021-06-24           U.S. Olympic Trials    AA  15.400  13.833  13.700
# 4    2021-06-24           U.S. Olympic Trials    QF  15.466  14.600  15.133
# 5    2021-06-03            U.S. Championships    AA  15.550  14.700  14.900
# 6    2021-06-03            U.S. Championships    QF  15.800  14.750  14.350
# ..          ...                           ...   ...     ...     ...     ...
# 327        2023            U.S. Worlds Trials    AA  14.250  12.450  13.800
# 328        2023            U.S. Championships    AA  13.900   9.900  12.950
# 329        2023            U.S. Championships    QF  14.100  12.300  13.250
# 331        2023                    Winter Cup    AA  13.500  12.950  11.000
# 333        2023  Vegas Cup National Qualifier    AA  13.550  12.350  12.900
#
#          FX      AA            Name
# ...

# %%
apps
# Out:
#            Date          Competition Round      VT      UB      BB      FX  \
# 0    2021-07-23        Olympic Games    EF   0.000   0.000  14.000   0.000
# 1    2021-07-23        Olympic Games    TF  13.766   0.000   0.000   0.000
# 12   2021-07-23        Olympic Games    EF  12.416   0.000   0.000  14.366
# 15   2021-06-24  U.S. Olympic Trials    AA   0.000  13.733  13.433   0.000
# 19   2021-05-21         U.S. Classic    AA   0.000  13.800  12.750   0.000
# ..          ...                  ...   ...     ...     ...     ...     ...
# 319  2022-08-18   U.S. Championships    AA   0.000  14.250  13.400   0.000
# 320  2022-08-18   U.S. Championships    QF   0.000  14.200  13.150   0.000
# 326        2023   U.S. Worlds Trials    EF   0.000  12.600  13.100   0.000
# 330        2023         U.S. Classic    AA  14.150   0.000  12.950  14.000
# 332        2023         WOGA Classic    AA   0.000  13.300   0.000   0.000
#
#       AA            Name
# 0    0.0    Simone Biles
# ...

# %%
# df.to_csv('individuals_combined.csv', index=False)
