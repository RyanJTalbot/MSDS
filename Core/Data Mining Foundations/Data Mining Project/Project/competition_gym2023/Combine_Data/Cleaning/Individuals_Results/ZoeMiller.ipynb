# %%
import pandas as pd
import numpy as np
from datetime import datetime
from dateutil import parser

# %%
df = pd.read_csv('../../scraping/women/gymnasts_results/miller/miller21.csv')

# %%
df["Year"] = 2021

# %%
df2 = pd.read_csv('../../scraping/women/gymnasts_results/miller/miller22.csv')

# %%
df2["Year"] = 2022

# %%
df3 = pd.read_csv('../../scraping/women/gymnasts_results/miller/miller23.csv')

# %%
df3["Year"] = 2023

# %%
result = pd.concat([df,df2, df3], ignore_index=True)

# %%
df = result.copy()

# %%
df["Name"] = "Zoe Miller"

# %%
df.rename(columns={'Unnamed: 2': 'Round'}, inplace=True)

# %%
# Function to parse date entries
def parse_date(entry):
    try:
        return parser.parse(entry).strftime("%b %d")
    except ValueError:
        return entry

# Apply the parse_date function to the "Date" column
df["Date"] = df["Date"].apply(parse_date)

# %%
def extract_month_day(entry):
    parts = entry.split('-')
    return parts[0]

# Apply the extract_month_day function to the "Date" column
df["Date"] = df["Date"].apply(extract_month_day)

# Now, the "Date

# %%
df
# Out:
#       Date                 Competition Round      VT      UB      BB      FX  \
# 0   Jun 24         U.S. Olympic Trials    AA  13.700  13.633  13.133  12.866
# 1   Jun 24         U.S. Olympic Trials    QF  13.933  13.766  12.566  12.200
# 2   Jun 03          U.S. Championships    AA  14.200  13.900  13.050  12.300
# 3   Jun 03          U.S. Championships    QF  14.100  14.300  11.750  12.800
# 4   May 21                U.S. Classic    AA  13.500  14.000  11.750  12.000
# 5   Feb 26                  Winter Cup    AA  13.600  14.050  12.150  12.700
# 6   Feb 06                WOGA Classic    AA  13.900  12.450  13.700  13.000
# 7   Jul 14  Pan American Championships    TF   0.000  14.467   0.000   0.000
# 8   Jul 14  Pan American Championships    AA   0.000  14.133   0.000   0.000
# 9   Jul 04         U.S. Pan Ams Trials    EF   0.000  14.633  11.833   0.000
# 10  Jul 04         U.S. Pan Ams Trials    AA  13.300  13.900  11.850  12.350
# 11  Apr 09       City of Jesolo Trophy    EF   0.000  14.450   0.000   0.000
# 12  Apr 09       City of Jesolo Trophy    AA  13.067  14.033  12.133  12.300
# 13  Mar 31    March National Team Camp    AA  13.400  14.250  11.950  12.350
# 14  Feb 24                  Winter Cup    AA  13.650  13.100  10.950  12.650
# 15  Feb 12                WOGA Classic    AA  13.600  13.700  11.950  12.500
# 16  Aug 24          U.S. Championships    AA  13.400  14.400  12.250  12.400
# 17  Aug 24          U.S. Championships    QF  13.150  11.000  13.050  11.800
# 18  Aug 04                U.S. Classic    AA  13.650  14.750  12.450  12.150
# 19  Jul 09     July National Team Camp    AA  13.900  14.550  11.100  12.050
# 20  Apr 30         Pan American Trials    AA  13.600  14.750  12.900  12.700
# 21  Mar 17    DTB Pokal Team Challenge    EF   0.000  14.633   0.000   0.000
# 22  Mar 17    DTB Pokal Team Challenge    AA  13.900  14.850  12.900  10.850
# 23  Feb 23                  Winter Cup    AA  13.650  13.900  12.550  12.400
#
#         AA  Year        Name
# 0   53.332  2021  Zoe Miller
# 1   52.465  2021  Zoe Miller
# 2   53.450  2021  Zoe Miller
# 3   52.950  2021  Zoe Miller
# 4   51.250  2021  Zoe Miller
# 5   52.500  2021  Zoe Miller
# 6   53.050  2021  Zoe Miller
# 7    0.000  2022  Zoe Miller
# 8    0.000  2022  Zoe Miller
# 9    0.000  2022  Zoe Miller
# 10  51.400  2022  Zoe Miller
# 11   0.000  2022  Zoe Miller
# 12  51.533  2022  Zoe Miller
# 13  51.950  2022  Zoe Miller
# 14  50.350  2022  Zoe Miller
# 15  51.750  2022  Zoe Miller
# 16  52.450  2023  Zoe Miller
# 17  49.000  2023  Zoe Miller
# 18  53.000  2023  Zoe Miller
# 19  51.600  2023  Zoe Miller
# 20  53.950  2023  Zoe Miller
# 21   0.000  2023  Zoe Miller
# 22  52.500  2023  Zoe Miller
# 23  52.500  2023  Zoe Miller

# %%
df["Date"] = pd.to_datetime(df["Year"].astype(int).astype(str) + '-' + df["Date"], format="%Y-%b %d")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         24 non-null     datetime64[ns]
#  1   Competition  24 non-null     object
#  2   Round        24 non-null     object
#  3   VT           24 non-null     float64
#  4   UB           24 non-null     float64
#  5   BB           24 non-null     float64
#  6   FX           24 non-null     float64
#  7   AA           24 non-null     float64
#  8   Year         24 non-null     int64
#  9   Name         24 non-null     object
# dtypes: datetime64[ns](1), float64(5), int64(1), object(3)
# memory usage: 2.0+ KB

# %%
# Specify the desired column order
desired_order = ['Name', 'Date', 'Competition', 'Round', 'VT', 'UB', 'BB', 'FX', 'AA',
       ]

# Create a new DataFrame with columns in the desired order
df_reordered = df[desired_order]

# %%
df_reordered
# Out:
#           Name       Date                 Competition Round      VT      UB  \
# 0   Zoe Miller 2021-06-24         U.S. Olympic Trials    AA  13.700  13.633
# 1   Zoe Miller 2021-06-24         U.S. Olympic Trials    QF  13.933  13.766
# 2   Zoe Miller 2021-06-03          U.S. Championships    AA  14.200  13.900
# 3   Zoe Miller 2021-06-03          U.S. Championships    QF  14.100  14.300
# 4   Zoe Miller 2021-05-21                U.S. Classic    AA  13.500  14.000
# 5   Zoe Miller 2021-02-26                  Winter Cup    AA  13.600  14.050
# 6   Zoe Miller 2021-02-06                WOGA Classic    AA  13.900  12.450
# 7   Zoe Miller 2022-07-14  Pan American Championships    TF   0.000  14.467
# 8   Zoe Miller 2022-07-14  Pan American Championships    AA   0.000  14.133
# 9   Zoe Miller 2022-07-04         U.S. Pan Ams Trials    EF   0.000  14.633
# 10  Zoe Miller 2022-07-04         U.S. Pan Ams Trials    AA  13.300  13.900
# 11  Zoe Miller 2022-04-09       City of Jesolo Trophy    EF   0.000  14.450
# 12  Zoe Miller 2022-04-09       City of Jesolo Trophy    AA  13.067  14.033
# 13  Zoe Miller 2022-03-31    March National Team Camp    AA  13.400  14.250
# 14  Zoe Miller 2022-02-24                  Winter Cup    AA  13.650  13.100
# 15  Zoe Miller 2022-02-12                WOGA Classic    AA  13.600  13.700
# 16  Zoe Miller 2023-08-24          U.S. Championships    AA  13.400  14.400
# 17  Zoe Miller 2023-08-24          U.S. Championships    QF  13.150  11.000
# 18  Zoe Miller 2023-08-04                U.S. Classic    AA  13.650  14.750
# 19  Zoe Miller 2023-07-09     July National Team Camp    AA  13.900  14.550
# 20  Zoe Miller 2023-04-30         Pan American Trials    AA  13.600  14.750
# 21  Zoe Miller 2023-03-17    DTB Pokal Team Challenge    EF   0.000  14.633
# 22  Zoe Miller 2023-03-17    DTB Pokal Team Challenge    AA  13.900  14.850
# 23  Zoe Miller 2023-02-23                  Winter Cup    AA  13.650  13.900
#
#         BB      FX      AA
# 0   13.133  12.866  53.332
# 1   12.566  12.200  52.465
# 2   13.050  12.300  53.450
# 3   11.750  12.800  52.950
# 4   11.750  12.000  51.250
# 5   12.150  12.700  52.500
# 6   13.700  13.000  53.050
# 7    0.000   0.000   0.000
# 8    0.000   0.000   0.000
# 9   11.833   0.000   0.000
# 10  11.850  12.350  51.400
# 11   0.000   0.000   0.000
# 12  12.133  12.300  51.533
# 13  11.950  12.350  51.950
# 14  10.950  12.650  50.350
# 15  11.950  12.500  51.750
# 16  12.250  12.400  52.450
# 17  13.050  11.800  49.000
# 18  12.450  12.150  53.000
# 19  11.100  12.050  51.600
# 20  12.900  12.700  53.950
# 21   0.000   0.000   0.000
# 22  12.900  10.850  52.500
# 23  12.550  12.400  52.500

# %%
# df_reordered.to_csv('miller.csv', index=False)
