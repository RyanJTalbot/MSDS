# %%
import pandas as pd
import numpy as np

# %%
bb = pd.read_csv('../../../scraping/women/wc19w/wc19w_bb.csv')

# %%
vt = pd.read_csv('../../../scraping/women/wc19w/wc19w_vt.csv')

# %%
fx = pd.read_csv('../../../scraping/women/wc19w/wc19w_fx.csv')

# %%
ub = pd.read_csv('../../../scraping/women/wc19w/wc19w_ub.csv')

# %%
iaa = pd.read_csv('../../../scraping/women/wc19w/wc19w_iaa.csv')

# %%
fx["year"]=2019
vt["year"]=2019
ub["year"]=2019
bb["year"]=2019
iaa["year"]=2019

# %%
fx = fx.fillna(0)
vt = vt.fillna(0)
ub = ub.fillna(0)
bb = bb.fillna(0)

# %%
bb
# Out:
#    Rank                      Gymnast  D Score  E Score  Pen.   Total  year
# 0     1                 Simone Biles      6.4    8.666   0.0  15.066  2019
# 1     2                 Liu Tingting      6.2    8.233   0.0  14.433  2019
# 2     3                    Li Shijia      6.1    8.300   0.1  14.300  2019
# 3     4                   Kara Eaker      5.9    8.100   0.0  14.000  2019
# 4     5  Mélanie de Jesus dos Santos      5.5    8.466   0.0  13.966  2019
# 5     6               Flávia Saraiva      5.7    7.700   0.0  13.400  2019
# 6     7                   Sarah Voss      5.4    7.866   0.0  13.266  2019
# 7     8                Ana Padurariu      5.6    6.333   0.0  11.933  2019

# %%
bb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     8 non-null      int64
#  1   Gymnast  8 non-null      object
#  2   D Score  8 non-null      float64
#  3   E Score  8 non-null      float64
#  4   Pen.     8 non-null      float64
#  5   Total    8 non-null      float64
#  6   year     8 non-null      int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 576.0+ bytes

# %%
bb = bb.fillna(0)

# %%
bb.head(1)
# Out:
#    Rank       Gymnast  D Score  E Score  Pen.   Total  year
# 0     1  Simone Biles      6.4    8.666   0.0  15.066  2019

# %%
ub
# Out:
#    Rank             Gymnast  D Score  E Score  Pen.   Total  year
# 0     1        Nina Derwael      6.5    8.733   0.0  15.233  2019
# 1     2        Becky Downie      6.5    8.500   0.0  15.000  2019
# 2     3          Sunisa Lee      6.4    8.400   0.0  14.800  2019
# 3     4  Angelina Melnikova      6.3    8.433   0.0  14.733  2019
# 4     5        Simone Biles      6.2    8.500   0.0  14.700  2019
# 5     6   Daria Spiridonova      6.3    8.333   0.0  14.633  2019
# 6     7        Liu Tingting      5.9    8.500   0.0  14.400  2019
# 7     8     Elisabeth Seitz      6.0    7.566   0.0  13.566  2019

# %%
ub = ub.fillna(0)

# %%
ub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     8 non-null      int64
#  1   Gymnast  8 non-null      object
#  2   D Score  8 non-null      float64
#  3   E Score  8 non-null      float64
#  4   Pen.     8 non-null      float64
#  5   Total    8 non-null      float64
#  6   year     8 non-null      int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 576.0+ bytes

# %%
ub.head(1)
# Out:
#    Rank       Gymnast  D Score  E Score  Pen.   Total  year
# 0     1  Nina Derwael      6.5    8.733   0.0  15.233  2019

# %%
fx
# Out:
#    Rank                      Gymnast  D Score  E Score  Pen.   Total  year
# 0     1                 Simone Biles      6.7    8.533   0.1  15.133  2019
# 1     2                   Sunisa Lee      5.7    8.433   0.0  14.133  2019
# 2     3           Angelina Melnikova      5.8    8.266   0.0  14.066  2019
# 3     4               Flávia Saraiva      5.5    8.466   0.0  13.966  2019
# 4     5  Mélanie de Jesus dos Santos      5.5    8.433   0.1  13.833  2019
# 5     6                  Roxana Popa      5.4    8.400   0.0  13.800  2019
# 6     7               Brooklyn Moors      5.3    8.400   0.1  13.600  2019
# 7     8              Lilia Akhaimova      6.0    7.800   0.3  13.500  2019

# %%
fx = fx.fillna(0)

# %%
fx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     8 non-null      int64
#  1   Gymnast  8 non-null      object
#  2   D Score  8 non-null      float64
#  3   E Score  8 non-null      float64
#  4   Pen.     8 non-null      float64
#  5   Total    8 non-null      float64
#  6   year     8 non-null      int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 576.0+ bytes

# %%
fx.head(1)
# Out:
#    Rank       Gymnast  D Score  E Score  Pen.   Total  year
# 0     1  Simone Biles      6.7    8.533   0.1  15.133  2019

# %%
vt
# Out:
#    Position          Gymnast  D Score1  E Score1  Pen.1  Score 1  D Score2  \
# 0         1     Simone Biles       6.0     9.333    0.0   15.333       5.8
# 1         2       Jade Carey       6.0     9.166    0.0   15.166       5.8
# 2         3     Ellie Downie       5.4     9.200    0.0   14.600       6.0
# 3         4    Shallon Olsen       5.4     9.200    0.0   14.600       6.0
# 4         5            Qi Qi       5.4     9.200    0.0   14.600       5.8
# 5         6     Alexa Moreno       5.8     8.766    0.1   14.466       5.6
# 6         7  Lilia Akhaimova       5.8     8.900    0.0   14.700       5.6
# 7         8    Yeo Seo-jeong       6.2     8.033    0.3   13.933       5.4
#
#    E Score2  Pen.2  Score 2   total  year
# 0     9.666    0.0   15.466  15.399  2019
# 1     9.100    0.3   14.600  14.883  2019
# 2     9.033    0.0   15.033  14.816  2019
# 3     8.866    0.0   14.866  14.733  2019
# 4     8.900    0.0   14.700  14.650  2019
# ...

# %%
vt = vt.fillna(0)

# %%
vt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  8 non-null      int64
#  1   Gymnast   8 non-null      object
#  2   D Score1  8 non-null      float64
#  3   E Score1  8 non-null      float64
#  4   Pen.1     8 non-null      float64
#  5   Score 1   8 non-null      float64
#  6   D Score2  8 non-null      float64
#  7   E Score2  8 non-null      float64
#  8   Pen.2     8 non-null      float64
#  9   Score 2   8 non-null      float64
#  10  total     8 non-null      float64
#  11  year      8 non-null      int64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 896.0+ bytes

# %%
vt.head(1)
# Out:
#    Position       Gymnast  D Score1  E Score1  Pen.1  Score 1  D Score2  \
# 0         1  Simone Biles       6.0     9.333    0.0   15.333       5.8
#
#    E Score2  Pen.2  Score 2   total  year
# 0     9.666    0.0   15.466  15.399  2019

# %%
iaa
# Out:
#     Rank                      Gymnast      vt      ub      bb      fx   Total  \
# 0      1                 Simone Biles  15.233  14.733  14.633  14.400  58.999
# 1      2                  Tang Xijing  14.166  14.533  14.600  13.600  56.899
# 2      3           Angelina Melnikova  14.433  13.900  14.000  14.066  56.399
# 3      4                  Ellie Black  14.566  14.133  14.000  13.533  56.232
# 4      5                 Nina Derwael  13.600  15.200  13.733  13.500  56.033
# 5      6              Elisabeth Seitz  14.600  14.866  13.233  13.300  55.999
# 6      7               Flávia Saraiva  14.466  13.300  14.033  13.933  55.732
# 7      8                   Sunisa Lee  14.466  13.133  13.833  14.200  55.632
# 8      9                    Li Shijia  14.433  13.366  14.000  13.300  55.099
# 9     10                   Sarah Voss  14.500  13.666  13.866  12.866  54.898
# 10    11                 Aline Friess  14.966  13.600  13.066  13.166  54.798
# ...

# %%
iaa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     24 non-null     int64
#  1   Gymnast  24 non-null     object
#  2   vt       24 non-null     float64
#  3   ub       24 non-null     float64
#  4   bb       24 non-null     float64
#  5   fx       24 non-null     float64
#  6   Total    24 non-null     object
#  7   year     24 non-null     int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 1.6+ KB

# %%
iaa.loc[iaa['Total'] == 'DNF', 'Total'] = 0

# %%
iaa['Total'] = iaa['Total'].astype(float)

# %%
iaa
# Out:
#     Rank                      Gymnast      vt      ub      bb      fx   Total  \
# 0      1                 Simone Biles  15.233  14.733  14.633  14.400  58.999
# 1      2                  Tang Xijing  14.166  14.533  14.600  13.600  56.899
# 2      3           Angelina Melnikova  14.433  13.900  14.000  14.066  56.399
# 3      4                  Ellie Black  14.566  14.133  14.000  13.533  56.232
# 4      5                 Nina Derwael  13.600  15.200  13.733  13.500  56.033
# 5      6              Elisabeth Seitz  14.600  14.866  13.233  13.300  55.999
# 6      7               Flávia Saraiva  14.466  13.300  14.033  13.933  55.732
# 7      8                   Sunisa Lee  14.466  13.133  13.833  14.200  55.632
# 8      9                    Li Shijia  14.433  13.366  14.000  13.300  55.099
# 9     10                   Sarah Voss  14.500  13.666  13.866  12.866  54.898
# 10    11                 Aline Friess  14.966  13.600  13.066  13.166  54.798
# ...

# %%
# fx.to_csv('wc19fx.csv', index=False)
# vt.to_csv('wc19vt.csv', index=False)
# ub.to_csv('wc19ub.csv', index=False)
# bb.to_csv('wc19bb.csv', index=False)
# iaa.to_csv('wc19iaa.csv', index=False)
