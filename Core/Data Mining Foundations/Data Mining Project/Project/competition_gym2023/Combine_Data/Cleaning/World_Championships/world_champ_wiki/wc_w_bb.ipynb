# %%
import pandas as pd
import numpy as np

# %%
wc11 = pd.read_csv('wc11bb.csv')
wc13 = pd.read_csv('wc13bb.csv')
wc14 = pd.read_csv('wc14bb.csv')
wc15 = pd.read_csv('wc15bb.csv')
wc17 = pd.read_csv('wc17bb.csv')
wc18 = pd.read_csv('wc18bb.csv')
wc19 = pd.read_csv('wc19bb.csv')

# %%
wc11 = wc11.drop(columns=["Qual Rk"])

# %%
wc11.rename(columns={ 'Pen.': 'Penalty'}, inplace=True)

# %%
wc11.head(1)
# Out:
#    Position      Gymnast  D Score  E Score  Penalty   Total  year
# 0         1  Sui Lu(CHN)      6.6    9.266      0.0  15.866  2011

# %%
wc13.head(1)
# Out:
#    Position               Gymnast  D Score  E Score  Penalty  Total  year
# 0         1  Aliya Mustafina(RUS)      6.0      8.9      0.0   14.9  2013

# %%
wc14.head(1)
# Out:
#    Position            Gymnast  D Score  E Score  Penalty  Total  year
# 0         1  Simone Biles(USA)      6.4      8.7      0.0   15.1  2014

# %%
wc15.head(1)
# Out:
#    Position            Gymnast  D Score  E Score  Penalty   Total  year
# 0         1  Simone Biles(USA)      6.4    8.958      0.0  15.358  2015

# %%
wc17.head(1)
# Out:
#    Position          Gymnast  D Score  E Score  Penalty   Total  year
# 0         1  Pauline Schäfer      5.5    8.033      0.0  13.533  2017

# %%
wc18.rename(columns={'Rank': 'Position', 'Pen.': 'Penalty'}, inplace=True)

# %%
wc18.head(1)
# Out:
#    Position       Gymnast  D Score  E Score  Penalty   Total  year
# 0         1  Liu Tingting      6.3    8.233      0.0  14.533  2018

# %%
wc19.rename(columns={'Rank': 'Position', 'Pen.': 'Penalty'}, inplace=True)

# %%
wc19.head(1)
# Out:
#    Position       Gymnast  D Score  E Score  Penalty   Total  year
# 0         1  Simone Biles      6.4    8.666      0.0  15.066  2019

# %%
combined_df = pd.concat([wc11, wc13, wc14, wc15, wc17, wc18, wc19], axis=0)

# %%
df = combined_df.copy()

# %%
df['Gymnast'] = df['Gymnast'].str.replace(r'\(.*\)', '', regex=True)

# %%
df
# Out:
#    Position                      Gymnast  D Score  E Score  Penalty   Total  \
# 0         1                       Sui Lu      6.6    9.266      0.0  15.866
# 1         2                   Yao Jinnan      6.3    8.933      0.0  15.233
# 2         3                Jordyn Wieber      6.2    8.933      0.0  15.133
# 3         4                  Aly Raisman      6.4    8.666      0.0  15.066
# 4         5                 Amelia Racea      5.9    8.633      0.0  14.533
# 5         6                Yulia Inshina      5.7    8.825      0.0  14.525
# 6         7               Cătălina Ponor      5.7    8.541      0.0  14.241
# 7         8              Viktoria Komova      5.9    7.866      0.0  13.766
# 0         1              Aliya Mustafina      6.0    8.900      0.0  14.900
# 1         2                    Kyla Ross      6.0    8.833      0.0  14.833
# 2         3                 Simone Biles      6.1    8.233      0.0  14.333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56 entries, 0 to 7
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  56 non-null     int64
#  1   Gymnast   56 non-null     object
#  2   D Score   56 non-null     float64
#  3   E Score   56 non-null     float64
#  4   Penalty   56 non-null     float64
#  5   Total     56 non-null     float64
#  6   year      56 non-null     int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 3.5+ KB

# %%
# df.to_csv('wc11_19w_bb.csv', index=False)
