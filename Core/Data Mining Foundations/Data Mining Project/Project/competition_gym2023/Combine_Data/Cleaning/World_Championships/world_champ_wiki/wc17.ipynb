# %%
import pandas as pd
import numpy as np

# %%
bb = pd.read_csv('../../../scraping/women/wc17w/wc17w_bb.csv')

# %%
ub = pd.read_csv('../../../scraping/women/wc17w/wc17w_ub.csv')

# %%
fx = pd.read_csv('../../../scraping/women/wc17w/wc17w_fx.csv')

# %%
vt = pd.read_csv('../../../scraping/women/wc17w/wc17w_vt.csv')

# %%
iaa = pd.read_csv('../../../scraping/women/wc17w/wc17w_iaa.csv')

# %%
bb = bb.fillna(0)

# %%
ub = ub.fillna(0)

# %%
vt = vt.fillna(0)

# %%
fx = fx.fillna(0)

# %%
fx["year"]=2017
vt["year"]=2017
ub["year"]=2017
bb["year"]=2017
iaa["year"]=2017

# %%
iaa
# Out:
#     Position                      Gymnast      vt      ub      bb      fx  \
# 0          1                  Morgan Hurd  14.533  14.300  12.666  13.733
# 1          2                  Ellie Black  14.600  14.233  12.866  13.433
# 2          3                Elena Eremina  13.866  14.200  13.133  13.600
# 3          4                 Mai Murakami  14.666  13.800  12.000  14.233
# 4          5  Mélanie de Jesus dos Santos  14.466  14.000  12.433  13.233
# 5          6                Aiko Sugihara  14.033  13.533  12.566  13.833
# 6          7           Giulia Steingruber  14.700  12.933  12.400  13.633
# 7          8                 Nina Derwael  13.533  14.966  11.633  13.366
# 8          9              Elisabeth Seitz  13.700  14.566  12.433  12.766
# 9         10                    Tabea Alt  13.866  13.600  13.300  12.633
# 10        11                 Rune Hermans  13.300  13.900  12.033  13.066
# 11        12                    Lara Mori  13.433  13.466  12.266  13.000
# ...

# %%
bb
# Out:
#    Position          Gymnast  D Score  E Score  Penalty   Total  year
# 0         1  Pauline Schäfer      5.5    8.033      0.0  13.533  2017
# 1         2      Morgan Hurd      5.7    7.800     -0.1  13.400  2017
# 2         3        Tabea Alt      5.7    7.600      0.0  13.300  2017
# 3         4     Mai Murakami      5.4    7.666      0.0  13.066  2017
# 4         5    Elena Eremina      5.4    7.566      0.0  12.966  2017
# 5         6   Asuka Teramoto      5.6    7.366      0.0  12.966  2017
# 6         7     Liu Tingting      5.5    7.366     -0.1  12.766  2017
# 7         8      Ellie Black      5.7    6.700      0.0  12.400  2017

# %%
bb
# Out:
#    Position          Gymnast  D Score  E Score  Penalty   Total  year
# 0         1  Pauline Schäfer      5.5    8.033      0.0  13.533  2017
# 1         2      Morgan Hurd      5.7    7.800     -0.1  13.400  2017
# 2         3        Tabea Alt      5.7    7.600      0.0  13.300  2017
# 3         4     Mai Murakami      5.4    7.666      0.0  13.066  2017
# 4         5    Elena Eremina      5.4    7.566      0.0  12.966  2017
# 5         6   Asuka Teramoto      5.6    7.366      0.0  12.966  2017
# 6         7     Liu Tingting      5.5    7.366     -0.1  12.766  2017
# 7         8      Ellie Black      5.7    6.700      0.0  12.400  2017

# %%
fx
# Out:
#    Position            Gymnast  D Score  E Score  Penalty   Total  year
# 0         1       Mai Murakami      5.9    8.333      0.0  14.233  2017
# 1         2         Jade Carey      5.7    8.500      0.0  14.200  2017
# 2         3  Claudia Fragapane      5.6    8.333      0.0  13.933  2017
# 3         4      Thaís Fidélis      5.5    8.166      0.0  13.666  2017
# 4         5     Brooklyn Moors      5.2    8.450      0.0  13.650  2017
# 5         6          Lara Mori      5.4    7.866      0.0  13.266  2017
# 6         7        Ellie Black      5.3    7.900     -0.3  12.900  2017
# 7         8    Vanessa Ferrari      2.0    8.233     -6.3   3.933  2017

# %%
vt
# Out:
#    Position             Gymnast  D Score1  E Score1  Pen.1  Score 1  D Score2  \
# 0         1        Maria Paseka       6.0     8.700    0.0   14.700       5.8
# 1         2          Jade Carey       5.8     9.000    0.0   14.800       5.6
# 2         3  Giulia Steingruber       5.8     8.933   -0.1   14.633       5.4
# 3         4         Ellie Black       5.4     9.166    0.0   14.566       5.2
# 4         5  Oksana Chusovitina       5.4     9.033    0.0   14.433       5.2
# 5         6            Wang Yan       5.6     8.900    0.0   14.500       5.8
# 6         7       Shallon Olsen       5.8     7.833   -0.1   13.533       6.0
# 7         8        Sae Miyakawa       5.8     8.700    0.0   14.500       5.4
#
#    E Score2  Pen.2  score2   Total  year
# 0     9.200    0.0  15.000  14.850  2017
# 1     9.133    0.0  14.733  14.766  2017
# 2     8.900    0.0  14.300  14.466  2017
# 3     9.066    0.0  14.266  14.416  2017
# 4     9.100    0.0  14.300  14.366  2017
# ...

# %%
# fx.to_csv('wc17fx.csv', index=False)
# vt.to_csv('wc17vt.csv', index=False)
# ub.to_csv('wc17ub.csv', index=False)
# bb.to_csv('wc17bb.csv', index=False)
# iaa.to_csv('wc17iaa.csv', index=False)
