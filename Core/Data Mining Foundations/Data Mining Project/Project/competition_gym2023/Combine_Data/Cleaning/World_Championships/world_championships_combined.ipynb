# %%
import pandas as pd
import numpy as np
import re

# %%
fx18 = pd.read_csv('../../scraping/women/wc_18w/wc18w_fx.csv')
bb18 = pd.read_csv('../../scraping/women/wc_18w/wc18w_bb.csv')
ub18 = pd.read_csv('../../scraping/women/wc_18w/wc18w_ub.csv')
vt18 = pd.read_csv('../../scraping/women/wc_18w/wc18w_vt.csv')

# %%
fx19 = pd.read_csv('../../scraping/women/wc19w/wc19w_fx.csv')
bb19 = pd.read_csv('../../scraping/women/wc19w/wc19w_bb.csv')
ub19 = pd.read_csv('../../scraping/women/wc19w/wc19w_ub.csv')
vt19 = pd.read_csv('../../scraping/women/wc19w/wc19w_vt.csv')

# %%
fx17 = pd.read_csv('../../scraping/women/wc17w/wc17w_fx.csv')
bb17 = pd.read_csv('../../scraping/women/wc17w/wc17w_bb.csv')
ub17 = pd.read_csv('../../scraping/women/wc17w/wc17w_ub.csv')
vt17 = pd.read_csv('../../scraping/women/wc17w/wc17w_vt.csv')

# %%
fx15 = pd.read_csv('../../scraping/women/wc15w/wc15w_fx.csv')
bb15 = pd.read_csv('../../scraping/women/wc15w/wc15w_bb.csv')
ub15 = pd.read_csv('../../scraping/women/wc15w/wc15w_ub.csv')
vt15 = pd.read_csv('../../scraping/women/wc15w/wc15w_vt.csv')

# %%
fx11 = pd.read_csv('../../scraping/women/wc11w/wc11w_fx.csv')
bb11 = pd.read_csv('../../scraping/women/wc11w/wc11w_bb.csv')
ub11 = pd.read_csv('../../scraping/women/wc11w/wc11w_ub.csv')
vt11 = pd.read_csv('../../scraping/women/wc11w/wc11w_vt.csv')

# %%
fx13 = pd.read_csv('../../scraping/women/wc13w/wc13w_fx.csv')
bb13 = pd.read_csv('../../scraping/women/wc13w/wc13w_bb.csv')
ub13 = pd.read_csv('../../scraping/women/wc13w/wc13w_ub.csv')
vt13 = pd.read_csv('../../scraping/women/wc13w/wc13w_vt.csv')

# %%
fx14 = pd.read_csv('../../scraping/women/wc14w/wc14w_fx.csv')
bb14 = pd.read_csv('../../scraping/women/wc14w/wc14w_bb.csv')
ub14 = pd.read_csv('../../scraping/women/wc14w/wc14w_ub.csv')
vt14 = pd.read_csv('../../scraping/women/wc14w/wc14w_vt.csv')

# %% [markdown]
# # fx

# %%
# 18
# 19
# 17
# 15
# 11
# 13
# 14

# %%
ub11['year']=2011
ub13['year']=2013
ub14['year']=2014
ub15['year']=2015
ub17['year']=2017
ub18['year']=2018
ub19['year']=2019

# %%
bb11['year']=2011
bb13['year']=2013
bb14['year']=2014
bb15['year']=2015
bb17['year']=2017
bb18['year']=2018
bb19['year']=2019

# %%
vt11['year']=2011
vt13['year']=2013
vt14['year']=2014
vt15['year']=2015
vt17['year']=2017
vt18['year']=2018
vt19['year']=2019

# %%
fx11['year']=2011

# %%
fx13['year']=2013

# %%
fx14['year']=2014

# %%
fx15['year']=2015

# %%
fx17['year']=2017

# %%
fx18['year']=2018

# %%
fx19['year']=2019

# %%
ub13.rename(columns={'Penalty': 'Pen.'}, inplace=True)
ub14.rename(columns={'Penalty': 'Pen.'}, inplace=True)
ub15.rename(columns={'Penalty': 'Pen.'}, inplace=True)
ub17.rename(columns={'Penalty': 'Pen.'}, inplace=True)
ub19.rename(columns={'Rank': 'Position'}, inplace=True)
ub18.rename(columns={'Rank': 'Position'}, inplace=True)

# %%
bb13.rename(columns={'Penalty': 'Pen.'}, inplace=True)
bb14.rename(columns={'Penalty': 'Pen.'}, inplace=True)
bb15.rename(columns={'Penalty': 'Pen.'}, inplace=True)
bb17.rename(columns={'Penalty': 'Pen.'}, inplace=True)
bb19.rename(columns={'Rank': 'Position'}, inplace=True)
bb18.rename(columns={'Rank': 'Position'}, inplace=True)

# %%
vt13.rename(columns={'Penalty': 'Pen.'}, inplace=True)
vt14.rename(columns={'Penalty': 'Pen.'}, inplace=True)
vt15.rename(columns={'Penalty': 'Pen.'}, inplace=True)
vt17.rename(columns={'Penalty': 'Pen.'}, inplace=True)
vt19.rename(columns={'Rank': 'Position'}, inplace=True)
vt18.rename(columns={'Rank': 'Position'}, inplace=True)

# %%
ub13
# Out:
#    Position               Gymnast  D Score  E Score  Pen.   Total  year
# 0         1     Huang Huidan(CHN)      6.6    8.800   NaN  15.400  2013
# 1         2        Kyla Ross(USA)      6.4    8.866   NaN  15.266  2013
# 2         3  Aliya Mustafina(RUS)      6.5    8.533   NaN  15.033  2013
# 3         4     Simone Biles(USA)      6.1    8.616   NaN  14.716  2013
# 4         5   Sophie Scheder(GER)      6.4    8.283   NaN  14.683  2013
# 5         6       Yao Jinnan(CHN)      6.9    7.733   NaN  14.633  2013
# 6         7     Ruby Harrold(GBR)      6.3    8.033   NaN  14.333  2013
# 7         8     Becky Downie(GBR)      6.4    7.400   NaN  13.800  2013

# %%
fx13.rename(columns={'Penalty': 'Pen.'}, inplace=True)

# %%
fx14.rename(columns={'Penalty': 'Pen.'}, inplace=True)

# %%
fx15.rename(columns={'Penalty': 'Pen.'}, inplace=True)

# %%
fx17.rename(columns={'Penalty': 'Pen.'}, inplace=True)

# %%
fx19.rename(columns={'Rank': 'Position'}, inplace=True)

# %%
fx18.rename(columns={'Rank': 'Position'}, inplace=True)

# %%
combined_ub = pd.concat([ub11, ub13, ub14, ub15,  ub17, ub18, ub19], ignore_index=True)

# %%
combined_df = pd.concat([fx11, fx13, fx14, fx15,  fx17, fx18, fx19], ignore_index=True)

# %%
fx = combined_df.copy()

# %%
fx.head()
# Out:
#    Position                 Gymnast  D Score  E Score  Pen.  Qual Rk   Total  \
# 0         1  Ksenia Afanasyeva(RUS)      6.1    9.033   NaN    -10.0  15.133
# 1         2             Sui Lu(CHN)      6.1    8.966   NaN     -2.0  15.066
# 2         3        Aly Raisman(USA)      6.1    8.900   NaN     -1.0  15.000
# 3         4         Yao Jinnan(CHN)      6.0    8.866   NaN     -4.0  14.866
# 4         5    Lauren Mitchell(AUS)      6.3    8.433   NaN     -9.0  14.733
#
#    year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
fx = fx.drop(columns=['Qual Rk'])

# %%
fx['Pen.'].fillna(0, inplace=True)

# %%
# Define a regular expression pattern to extract the text inside parentheses
pattern = r'\(([^)]+)\)'

# Extract the text inside parentheses and create the "Nation" column
fx['Nation'] = fx['Gymnast'].str.extract(pattern)

# %%
# Remove the parentheses and text inside them from the "Gymnast" column
fx['Gymnast'] = fx['Gymnast'].str.replace(pattern, '', regex=True).str.strip()

# %%
fx.head()
# Out:
#    Position            Gymnast  D Score  E Score  Pen.   Total  year Nation
# 0         1  Ksenia Afanasyeva      6.1    9.033   0.0  15.133  2011    RUS
# 1         2             Sui Lu      6.1    8.966   0.0  15.066  2011    CHN
# 2         3        Aly Raisman      6.1    8.900   0.0  15.000  2011    USA
# 3         4         Yao Jinnan      6.0    8.866   0.0  14.866  2011    CHN
# 4         5    Lauren Mitchell      6.3    8.433   0.0  14.733  2011    AUS

# %%
fx['round']='final'

# %%
fx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  56 non-null     int64
#  1   Gymnast   56 non-null     object
#  2   D Score   56 non-null     float64
#  3   E Score   56 non-null     float64
#  4   Pen.      56 non-null     float64
#  5   Total     56 non-null     float64
#  6   year      56 non-null     int64
#  7   Nation    32 non-null     object
#  8   round     56 non-null     object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 4.1+ KB

# %%
# fx.to_csv('fx_world_championship_w.csv', index=False)

# %%
ub = combined_ub.copy()

# %%
ub=ub.drop(columns=['Qual Rk'])

# %%
ub['Pen.'].fillna(0, inplace=True)

# %%
# Define a regular expression pattern to extract the text inside parentheses
pattern = r'\(([^)]+)\)'

# Extract the text inside parentheses and create the "Nation" column
ub['Nation'] = ub['Gymnast'].str.extract(pattern)

# %%
# Remove the parentheses and text inside them from the "Gymnast" column
ub['Gymnast'] = ub['Gymnast'].str.replace(pattern, '', regex=True).str.strip()

# %%
ub['round']='final'

# %%
ub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  56 non-null     int64
#  1   Gymnast   56 non-null     object
#  2   D Score   56 non-null     float64
#  3   E Score   56 non-null     float64
#  4   Pen.      56 non-null     float64
#  5   Total     56 non-null     float64
#  6   year      56 non-null     int64
#  7   Nation    32 non-null     object
#  8   round     56 non-null     object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 4.1+ KB

# %%
# ub.to_csv('ub_world_championship_w.csv', index=False)

# %%
combined_bb = pd.concat([bb11, bb13, bb14, bb15,  bb17, bb18, bb19], ignore_index=True)

# %%
bb = combined_bb.copy()

# %%
bb=bb.drop(columns=['Qual Rk'])

# %%
bb['Pen.'].fillna(0, inplace=True)

# %%
# Define a regular expression pattern to extract the text inside parentheses
pattern = r'\(([^)]+)\)'

# Extract the text inside parentheses and create the "Nation" column
bb['Nation'] = bb['Gymnast'].str.extract(pattern)

# %%
# Remove the parentheses and text inside them from the "Gymnast" column
bb['Gymnast'] = bb['Gymnast'].str.replace(pattern, '', regex=True).str.strip()

# %%
bb['round']='final'

# %%
bb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Position  56 non-null     int64
#  1   Gymnast   56 non-null     object
#  2   D Score   56 non-null     float64
#  3   E Score   56 non-null     float64
#  4   Pen.      56 non-null     float64
#  5   Total     56 non-null     float64
#  6   year      56 non-null     int64
#  7   Nation    32 non-null     object
#  8   round     56 non-null     object
# dtypes: float64(4), int64(2), object(3)
# memory usage: 4.1+ KB

# %%
# bb.to_csv('bb_world_championship_w.csv', index=False)

# %%
vt11.head(1)
# Out:
#    Position               Gymnast  D Score1  E Score1  Pen.1  Score 1  Rk1  \
# 0         1  McKayla Maroney(USA)       6.5       9.3    NaN     15.8   -1
#
#   D Score2  E Score2  Pen.2  Score 2  Rk2  Total  year
# 0      5.6       9.2    NaN     14.8   -1   15.3  2011

# %%
vt13.head(1)
# Out:
#    Rank               Gymnast  D Score1  E Score1  Pen.1  Score 1  D Score2  \
# 0     1  McKayla Maroney(USA)       6.3     9.766    0.1   15.966       6.0
#
#    E Score2  Pen.2  Score 2   Total  year
# 0     9.483    NaN   15.483  15.724  2013

# %%
vt14.head(1)
# Out:
#    Rank            Gymnast  D Score1  E Score1  Pen.1  Score 1  D Score2  \
# 0     1  Hong Un-jong(PRK)       6.3     9.466    NaN   15.766       6.4
#
#    E Score2  Pen.2  Score 2   Total  year
# 0     9.033    NaN   15.433  15.599  2014

# %%
vt15.head(1)
# Out:
#    Position            Gymnast  D Score1  E Score1  Pen.1  Score 1  D Score2  \
# 0         1  Maria Paseka(RUS)       6.4     9.233    NaN   15.633       6.3
#
#    E Score2  Pen.2  Score 2  Total2  year
# 0       9.4    NaN     15.7  15.666  2015

# %%
vt17.head(1)
# Out:
#    Position       Gymnast  D Score1  E Score1  Pen.1  Score 1  D Score2  \
# 0         1  Maria Paseka       6.0       8.7    NaN     14.7       5.8
#
#    E Score2  Pen.2  score2  Total  year
# 0       9.2    NaN    15.0  14.85  2017

# %%
vt18.head(1)
# Out:
#    Position       Gymnast  D Score1  E Score1  Pen.1  Score 1  D Score2  \
# 0       NaN  Simone Biles       6.0     9.266    NaN   15.266       5.8
#
#    E Score2  Pen.2  Score 2   Total  year
# 0     9.666    NaN   15.466  15.366  2018

# %%
vt19.head(1)
# Out:
#    Position       Gymnast  D Score1  E Score1  Pen.1  Score 1  D Score2  \
# 0         1  Simone Biles       6.0     9.333    NaN   15.333       5.8
#
#    E Score2  Pen.2  Score 2   total  year
# 0     9.666    NaN   15.466  15.399  2019

# %%
vt19.rename(columns={'total': 'Total'}, inplace=True)
vt17.rename(columns={'score2': 'Score 2'}, inplace=True)
vt15.rename(columns={'Total2': 'Total'}, inplace=True)
vt15.rename(columns={'Position': 'Rank'}, inplace=True)
vt17.rename(columns={'Position': 'Rank'}, inplace=True)
vt18.rename(columns={'Position': 'Rank'}, inplace=True)
vt19.rename(columns={'Position': 'Rank'}, inplace=True)

# %%
combined_vt = pd.concat([vt13, vt14, vt15,  vt17, vt18, vt19], ignore_index=True)

# %%
vt = combined_vt.copy()

# %%
vt
# Out:
#     Rank                  Gymnast  D Score1  E Score1  Pen.1  Score 1  \
# 0    1.0     McKayla Maroney(USA)       6.3     9.766    0.1   15.966
# 1    2.0        Simone Biles(USA)       6.3     9.633    NaN   15.933
# 2    3.0        Hong Un-Jong(PRK)       6.3     9.266    NaN   15.566
# 3    4.0  Giulia Steingruber(SUI)       6.2     9.300    NaN   15.500
# 4    5.0  Oksana Chusovitina(UZB)       6.2     8.533    0.1   14.633
# 5    6.0   Phan Thị Hà Thanh(VIE)       6.2     8.866    0.1   14.966
# 6    7.0        Yamilet Peña(DOM)       7.0     7.766    0.3   14.466
# 7    8.0    Chantysha Netteb(NED)       5.8     8.100    NaN   13.900
# 8    1.0        Hong Un-jong(PRK)       6.3     9.466    NaN   15.766
# 9    2.0        Simone Biles(USA)       6.3     9.600    NaN   15.900
# 10   3.0     Mykayla Skinner(USA)       6.4     9.300    NaN   15.700
# 11   4.0    Alla Sosnitskaya(RUS)       6.4     8.866    0.3   14.966
# ...

# %%
# vt=vt.drop(columns=['Qual Rk'])
vt['Pen.1'].fillna(0, inplace=True)
vt['Pen.2'].fillna(0, inplace=True)

# %%
vt
# Out:
#     Rank                  Gymnast  D Score1  E Score1  Pen.1  Score 1  \
# 0    1.0     McKayla Maroney(USA)       6.3     9.766    0.1   15.966
# 1    2.0        Simone Biles(USA)       6.3     9.633    0.0   15.933
# 2    3.0        Hong Un-Jong(PRK)       6.3     9.266    0.0   15.566
# 3    4.0  Giulia Steingruber(SUI)       6.2     9.300    0.0   15.500
# 4    5.0  Oksana Chusovitina(UZB)       6.2     8.533    0.1   14.633
# 5    6.0   Phan Thị Hà Thanh(VIE)       6.2     8.866    0.1   14.966
# 6    7.0        Yamilet Peña(DOM)       7.0     7.766    0.3   14.466
# 7    8.0    Chantysha Netteb(NED)       5.8     8.100    0.0   13.900
# 8    1.0        Hong Un-jong(PRK)       6.3     9.466    0.0   15.766
# 9    2.0        Simone Biles(USA)       6.3     9.600    0.0   15.900
# 10   3.0     Mykayla Skinner(USA)       6.4     9.300    0.0   15.700
# 11   4.0    Alla Sosnitskaya(RUS)       6.4     8.866    0.3   14.966
# ...

# %%
# vt.to_csv('vt_world_championship_w.csv', index=False)
