# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../scraping/women/qual2008/scrape2008qual_team.csv')

# %%
df.tail(50)
# Out:
#                             Team  vault_score  vault_rank  uneven_score  \
# 34            Olivia Vivian(AUS)          NaN      14.925        20.000
# 35                        France       58.825      10.000        58.525
# 36             Marine Petit(FRA)       14.850      31.000        14.325
# 37          Laetitia Dugain(FRA)       14.350      52.000        14.625
# 38            Pauline Morel(FRA)       14.275      55.000        14.800
# 39         Katheleen Lindor(FRA)       14.900      26.000        14.700
# 40  Rose-Eliandre Bellemare(FRA)       14.725      41.000        14.400
# 41           Marine Debauve(FRA)          NaN         NaN        14.625
# 42                        Brazil       59.450       5.000        58.425
# 43             Jade Barbosa(BRA)       15.100      17.000        14.800
# 44        Ana Cláudia Silva(BRA)       14.750      39.000        14.550
# 45           Ethiene Franco(BRA)       14.175      61.000        14.100
# ...

# %%
# Select rows 0 and 5 and create a new DataFrame
new_df = pd.concat([df.iloc[0], df.iloc[7], df.iloc[14], df.iloc[28], df.iloc[35],
                   df.iloc[42], df.iloc[49], df.iloc[56], df.iloc[63],
                   df.iloc[70], df.iloc[77]], axis=1).transpose()

# Drop rows 0 and 5 from the original DataFrame
df = df.drop([0, 7, 14, 28, 35, 42, 49, 56, 63, 70, 77])

df = df.reset_index(drop=True)

# %%
new_df
# Out:
#              Team vault_score vault_rank uneven_score uneven_rank bb_score  \
# 0           China      61.825        2.0        62.65         1.0    63.05
# 7   United States      62.225        1.0       61.125         3.0     63.4
# 14         Russia       60.85        3.0       61.775         2.0     62.0
# 28      Australia       59.45        5.0        59.05         6.0   58.625
# 35         France      58.825       10.0       58.525         8.0   58.975
# 42         Brazil       59.45        5.0       58.425        10.0   56.675
# 49          Japan       58.05       11.0       58.725         7.0     59.9
# 56  Great Britain      59.325        7.0       57.875        11.0    57.45
# 63          Italy      59.075        9.0       57.375        12.0     58.2
# 70        Ukraine        58.0       12.0       60.625         4.0     59.7
# 77        Germany       59.15        8.0        59.15         5.0   55.825
#
#    bb_rank floor_score floor_rank total_score total_rank
# ...

# %%
df
# Out:
#                             Team  vault_score  vault_rank  uneven_score  \
# 0                Yang Yilin(CHN)       15.200      12.000        16.650
# 1              Jiang Yuyuan(CHN)       14.775      38.000        15.550
# 2               Deng Linlin(CHN)       15.225      10.000        14.725
# 3                 Cheng Fei(CHN)       16.150       1.000           NaN
# 4                  He Kexin(CHN)       15.250       9.000        15.725
# ..                           ...          ...         ...           ...
# 68               Katja Abel(GER)       14.250      56.000        14.650
# 69              Daria Bijak(GER)       14.175      62.000        14.650
# 70  Marie-Sophie Hindermann(GER)       14.925      25.000        13.125
# 71           Joeline Möbius(GER)       13.675      76.000           NaN
# 72             Anja Brinker(GER)          NaN      15.125        14.000
#
#     uneven_rank  bb_score  bb_rank  floor_score  floor_rank  total_score  \
# ...

# %%
# Extract data within parentheses and store it in a new column
df["Country"] = df['Team'].str.extract(r'\((.*?)\)')

df['Team'] = df['Team'].apply(lambda x: x.split('(')[0].strip())
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Team          73 non-null     object
#  1   vault_score   59 non-null     float64
#  2   vault_rank    70 non-null     float64
#  3   uneven_score  63 non-null     float64
#  4   uneven_rank   65 non-null     float64
#  5   bb_score      63 non-null     float64
#  6   bb_rank       68 non-null     float64
#  7   floor_score   69 non-null     float64
#  8   floor_rank    68 non-null     float64
#  9   total_score   57 non-null     float64
#  10  total_rank    40 non-null     float64
#  11  Country       72 non-null     object
# dtypes: float64(10), object(2)
# memory usage: 7.0+ KB

# %%
df
# Out:
#                        Team  vault_score  vault_rank  uneven_score  \
# 0                Yang Yilin       15.200      12.000        16.650
# 1              Jiang Yuyuan       14.775      38.000        15.550
# 2               Deng Linlin       15.225      10.000        14.725
# 3                 Cheng Fei       16.150       1.000           NaN
# 4                  He Kexin       15.250       9.000        15.725
# ..                      ...          ...         ...           ...
# 68               Katja Abel       14.250      56.000        14.650
# 69              Daria Bijak       14.175      62.000        14.650
# 70  Marie-Sophie Hindermann       14.925      25.000        13.125
# 71           Joeline Möbius       13.675      76.000           NaN
# 72             Anja Brinker          NaN      15.125        14.000
#
#     uneven_rank  bb_score  bb_rank  floor_score  floor_rank  total_score  \
# 0         1.000    15.500   11.000       15.000      10.000       62.350
# ...

# %%
df.fillna(0, inplace=True)
df
# Out:
#                        Team  vault_score  vault_rank  uneven_score  \
# 0                Yang Yilin       15.200      12.000        16.650
# 1              Jiang Yuyuan       14.775      38.000        15.550
# 2               Deng Linlin       15.225      10.000        14.725
# 3                 Cheng Fei       16.150       1.000         0.000
# 4                  He Kexin       15.250       9.000        15.725
# ..                      ...          ...         ...           ...
# 68               Katja Abel       14.250      56.000        14.650
# 69              Daria Bijak       14.175      62.000        14.650
# 70  Marie-Sophie Hindermann       14.925      25.000        13.125
# 71           Joeline Möbius       13.675      76.000         0.000
# 72             Anja Brinker        0.000      15.125        14.000
#
#     uneven_rank  bb_score  bb_rank  floor_score  floor_rank  total_score  \
# 0         1.000    15.500   11.000       15.000      10.000       62.350
# ...

# %%
df["Name"] = df["Team"]
df=df.drop(columns=["Team"])
df
# Out:
#     vault_score  vault_rank  uneven_score  uneven_rank  bb_score  bb_rank  \
# 0        15.200      12.000        16.650        1.000    15.500   11.000
# 1        14.775      38.000        15.550        9.000    15.250   15.000
# 2        15.225      10.000        14.725       29.000    15.550    9.000
# 3        16.150       1.000         0.000       15.875     5.000   15.750
# 4        15.250       9.000        15.725        6.000     0.000    0.000
# ..          ...         ...           ...          ...       ...      ...
# 68       14.250      56.000        14.650       32.000    14.075   58.000
# 69       14.175      62.000        14.650       31.000    11.150   83.000
# 70       14.925      25.000        13.125       74.000    13.425   74.000
# 71       13.675      76.000         0.000       13.925    64.000   14.275
# 72        0.000      15.125        14.000        0.000     0.000   15.125
#
#     floor_score  floor_rank  total_score  total_rank Country  \
# ...

# %%
df.columns
# Out:
# Index(['vault_score', 'vault_rank', 'uneven_score', 'uneven_rank', 'bb_score',
#        'bb_rank', 'floor_score', 'floor_rank', 'total_score', 'total_rank',
#        'Country', 'Name'],
#       dtype='object')

# %%
new_order = ['Country', 'Name','vault_score', 'vault_rank', 'uneven_score', 'uneven_rank', 'bb_score',
       'bb_rank', 'floor_score', 'floor_rank', 'total_score', 'total_rank']

df = df[new_order]

df
# Out:
#    Country                     Name  vault_score  vault_rank  uneven_score  \
# 0      CHN               Yang Yilin       15.200      12.000        16.650
# 1      CHN             Jiang Yuyuan       14.775      38.000        15.550
# 2      CHN              Deng Linlin       15.225      10.000        14.725
# 3      CHN                Cheng Fei       16.150       1.000         0.000
# 4      CHN                 He Kexin       15.250       9.000        15.725
# ..     ...                      ...          ...         ...           ...
# 68     GER               Katja Abel       14.250      56.000        14.650
# 69     GER              Daria Bijak       14.175      62.000        14.650
# 70     GER  Marie-Sophie Hindermann       14.925      25.000        13.125
# 71     GER           Joeline Möbius       13.675      76.000         0.000
# 72     GER             Anja Brinker        0.000      15.125        14.000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country       73 non-null     object
#  1   Name          73 non-null     object
#  2   vault_score   73 non-null     float64
#  3   vault_rank    73 non-null     float64
#  4   uneven_score  73 non-null     float64
#  5   uneven_rank   73 non-null     float64
#  6   bb_score      73 non-null     float64
#  7   bb_rank       73 non-null     float64
#  8   floor_score   73 non-null     float64
#  9   floor_rank    73 non-null     float64
#  10  total_score   73 non-null     float64
#  11  total_rank    73 non-null     float64
# dtypes: float64(10), object(2)
# memory usage: 7.0+ KB

# %%
df["year"] = 2008
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_52498/1862329029.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["year"] = 2008

# %%
df
# Out:
#    Country                     Name  vault_score  vault_rank  uneven_score  \
# 0      CHN               Yang Yilin       15.200      12.000        16.650
# 1      CHN             Jiang Yuyuan       14.775      38.000        15.550
# 2      CHN              Deng Linlin       15.225      10.000        14.725
# 3      CHN                Cheng Fei       16.150       1.000         0.000
# 4      CHN                 He Kexin       15.250       9.000        15.725
# ..     ...                      ...          ...         ...           ...
# 68     GER               Katja Abel       14.250      56.000        14.650
# 69     GER              Daria Bijak       14.175      62.000        14.650
# 70     GER  Marie-Sophie Hindermann       14.925      25.000        13.125
# 71     GER           Joeline Möbius       13.675      76.000         0.000
# 72     GER             Anja Brinker        0.000      15.125        14.000
#
# ...

# %%
# df.to_csv('clean2008qual_team.csv', index=False)  # Set index=False to exclude index column
