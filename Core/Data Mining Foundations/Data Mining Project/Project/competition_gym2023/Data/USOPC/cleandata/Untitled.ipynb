# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data_2022_2023.csv')

# %%
df.head()
# Out:
#   LastName          FirstName Gender Country            Date  \
# 0      AAS            Fredrik      m     NOR  23-26 Feb 2023
# 1      AAS            Fredrik      m     NOR  23-26 Feb 2023
# 2      AAS  Fredrik Bjornevik      m     NOR    1-5 Aug 2023
# 3      AAS  Fredrik Bjornevik      m     NOR    1-5 Aug 2023
# 4      AAS  Fredrik Bjornevik      m     NOR    1-5 Aug 2023
#
#                         Competition Round          Location Apparatus  Rank  \
# 0            2023 Cottbus World Cup  qual  Cottbus, Germany        HB  39.0
# 1            2023 Cottbus World Cup  qual  Cottbus, Germany        PH  44.0
# 2  2023 FISU World University Games  qual    Chengdu, China        FX  54.0
# 3  2023 FISU World University Games  qual    Chengdu, China        HB  44.0
# 4  2023 FISU World University Games  qual    Chengdu, China        PB  54.0
#
#    D_Score  E_Score  Penalty   Score
# 0      4.6    6.700      NaN  11.300
# 1      4.4    7.800      NaN  12.200
# ...

# %%
w=df[df['Gender']=='w']

# %%
usa=w[w['Country']=='USA']

# %%
usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 661 entries, 768 to 15407
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LastName     661 non-null    object
#  1   FirstName    661 non-null    object
#  2   Gender       661 non-null    object
#  3   Country      661 non-null    object
#  4   Date         661 non-null    object
#  5   Competition  661 non-null    object
#  6   Round        661 non-null    object
#  7   Location     661 non-null    object
#  8   Apparatus    661 non-null    object
#  9   Rank         230 non-null    float64
#  10  D_Score      661 non-null    float64
#  11  E_Score      661 non-null    float64
#  12  Penalty      74 non-null     float64
#  13  Score        661 non-null    float64
# dtypes: float64(5), object(9)
# memory usage: 77.5+ KB

# %%
usa['Penalty'].fillna(0, inplace=True)
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_92113/4123893522.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa['Penalty'].fillna(0, inplace=True)

# %%
usa['LastName'].nunique()
# Out:
# 60

# %%
usa['LastName']=usa['LastName'].str.lower()
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_92113/3095800871.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa['LastName']=usa['LastName'].str.lower()

# %%
usa['FirstName']=usa['FirstName'].str.lower()
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_92113/1650609470.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa['FirstName']=usa['FirstName'].str.lower()

# %%
usa['Name'] = usa['FirstName'] + ' ' + usa['LastName']
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_92113/1490324410.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa['Name'] = usa['FirstName'] + ' ' + usa['LastName']

# %%
usa['Year'] = usa['Date'].str[:-4]
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_92113/3004843198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usa['Year'] = usa['Date'].str[:-4]

# %%
usa = usa.drop(columns=['LastName', 'FirstName', 'Country', 'Gender', 
                        'Competition', 'Location', 'Date'])

# %%
usa
# Out:
#          Round Apparatus  Rank  D_Score  E_Score  Penalty  Score  \
# 768       qual        BB   NaN      5.7     7.90      0.0  13.60
# 769      final        BB   NaN      5.7     8.25      0.0  13.95
# 770       qual        FX   NaN      4.5     7.55      0.1  11.95
# 771      final        FX   NaN      4.5     6.85      0.0  11.35
# 772       qual        UB   NaN      4.5     7.85      0.0  12.35
# ...        ...       ...   ...      ...      ...      ...    ...
# 15403    final        VT   NaN      4.2     9.20      0.0  13.40
# 15404  AAfinal        BB  11.0      5.1     7.00      0.0  12.10
# 15405  AAfinal        FX  13.0      4.9     7.65      0.0  12.55
# 15406  AAfinal        UB  14.0      5.4     7.45      0.0  12.85
# 15407  AAfinal        VT   NaN      4.2     8.70      0.0  12.90
#
#                Name        Year
# 768    ciena alipio  19-20 Aug
# 769    ciena alipio  19-20 Aug
# 770    ciena alipio  19-20 Aug
# 771    ciena alipio  19-20 Aug
# ...

# %%
usa['Apparatus'].value_counts()
# Out:
# Apparatus
# UB     165
# BB     163
# FX     158
# VT     152
# VT2     12
# VT1     11
# Name: count, dtype: int64

# %%
bb = usa[usa['Apparatus'] == 'BB']
ub = usa[usa['Apparatus'] == 'UB']
fx = usa[usa['Apparatus'] == 'FX']

# %%
fx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, 770 to 15405
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Round      158 non-null    object
#  1   Apparatus  158 non-null    object
#  2   Rank       67 non-null     float64
#  3   D_Score    158 non-null    float64
#  4   E_Score    158 non-null    float64
#  5   Penalty    158 non-null    float64
#  6   Score      158 non-null    float64
#  7   Name       158 non-null    object
#  8   Year       158 non-null    object
# dtypes: float64(5), object(4)
# memory usage: 12.3+ KB

# %%
bb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 163 entries, 768 to 15404
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Round      163 non-null    object
#  1   Apparatus  163 non-null    object
#  2   Rank       69 non-null     float64
#  3   D_Score    163 non-null    float64
#  4   E_Score    163 non-null    float64
#  5   Penalty    163 non-null    float64
#  6   Score      163 non-null    float64
#  7   Name       163 non-null    object
#  8   Year       163 non-null    object
# dtypes: float64(5), object(4)
# memory usage: 12.7+ KB

# %%
ub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 165 entries, 772 to 15406
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Round      165 non-null    object
#  1   Apparatus  165 non-null    object
#  2   Rank       69 non-null     float64
#  3   D_Score    165 non-null    float64
#  4   E_Score    165 non-null    float64
#  5   Penalty    165 non-null    float64
#  6   Score      165 non-null    float64
#  7   Name       165 non-null    object
#  8   Year       165 non-null    object
# dtypes: float64(5), object(4)
# memory usage: 12.9+ KB

# %%
fx
# Out:
#          Round Apparatus  Rank  D_Score  E_Score  Penalty  Score  \
# 770       qual        FX   NaN      4.5     7.55      0.1  11.95
# 771      final        FX   NaN      4.5     6.85      0.0  11.35
# 777    AAfinal        FX  19.0      5.0     6.85      0.0  11.85
# 1276      qual        FX  11.0      5.7     7.90      0.0  13.60
# 1622   AAfinal        FX  13.0      5.4     7.20      0.0  12.60
# ...        ...       ...   ...      ...      ...      ...    ...
# 15383  AAfinal        FX   6.0      5.0     8.00      0.0  13.00
# 15391  AAfinal        FX   6.0      5.2     7.95      0.0  13.15
# 15398     qual        FX   NaN      4.9     7.80      0.0  12.70
# 15399    final        FX   NaN      4.9     8.00      0.0  12.90
# 15405  AAfinal        FX  13.0      4.9     7.65      0.0  12.55
#
#                 Name                  Year
# 770     ciena alipio            19-20 Aug
# 771     ciena alipio            19-20 Aug
# 777     ciena alipio            25-27 Feb
# ...
