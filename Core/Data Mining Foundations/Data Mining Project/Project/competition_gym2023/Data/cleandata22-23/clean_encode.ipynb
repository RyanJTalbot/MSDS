# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data_2022_2023.csv')

# %%
df1 = pd.read_csv('women22_23.csv')

# %%
dft['Name']=dft['Name'].str.lower()

# %%
usa=dft[dft['Country']=='USA']

# %%
# usa
# Out:
#               Name Gender Country        Date              Competition  \
# 193   ciena alipio      w     USA  2022-08-20  2022 U.S. Championships
# 194   ciena alipio      w     USA  2022-08-20  2022 U.S. Championships
# 195   ciena alipio      w     USA  2022-08-20  2022 U.S. Championships
# 196   ciena alipio      w     USA  2022-08-20  2022 U.S. Championships
# 197   ciena alipio      w     USA  2022-08-20  2022 U.S. Championships
# ...            ...    ...     ...         ...                      ...
# 5289   alicia zhou      w     USA  2023-08-27  2023 U.S. Championships
# 5290   alicia zhou      w     USA  2023-02-26          2023 Winter Cup
# 5291   alicia zhou      w     USA  2023-02-26          2023 Winter Cup
# 5292   alicia zhou      w     USA  2023-02-26          2023 Winter Cup
# 5293   alicia zhou      w     USA  2023-02-26          2023 Winter Cup
#
#         Round              Location Apparatus  Rank  D_Score  E_Score  \
# 193      qual             Tampa, FL        BB   0.0      5.7     7.90
# 194     final             Tampa, FL        BB   0.0      5.7     8.25
# 195      qual             Tampa, FL        FX   0.0      4.5     7.55
# 196     final             Tampa, FL        FX   0.0      4.5     6.85
# 197      qual             Tampa, FL        UB   0.0      4.5     7.85
# ...       ...                   ...       ...   ...      ...      ...
# 5289    final          San Jose, CA        VT   0.0      4.2     9.20
# 5290  AAfinal  Louisville, Kentucky        BB  11.0      5.1     7.00
# 5291  AAfinal  Louisville, Kentucky        FX  13.0      4.9     7.65
# 5292  AAfinal  Louisville, Kentucky        UB  14.0      5.4     7.45
# 5293  AAfinal  Louisville, Kentucky        VT   0.0      4.2     8.70
#
#       Penalty  Score  Total_Score
# 193       0.0  13.60        13.60
# 194       0.0  13.95        13.95
# 195       0.1  11.95        11.95
# 196       0.0  11.35        11.35
# 197       0.0  12.35        12.35
# ...       ...    ...          ...
# 5289      0.0  13.40        13.40
# 5290      0.0  12.10        12.10
# 5291      0.0  12.55        12.55
# 5292      0.0  12.85        12.85
# 5293      0.0  12.90        12.90
#
# [661 rows x 14 columns]

# %%
# usa.to_csv("usa22_23.csv", index=False)

# %%
df
# Out:
#                  Name Gender Country        Date  \
# 0     jana abdelsalam      w     EGY  2022-11-06
# 1     jana abdelsalam      w     EGY  2022-11-06
# 2     jana abdelsalam      w     EGY  2022-11-06
# 3     jana abdelsalam      w     EGY  2022-11-06
# 4     jana abdelsalam      w     EGY  2023-03-12
# ...               ...    ...     ...         ...
# 5304        kate none      w     AUS  2022-11-06
# 5305        kate none      w     AUS  2022-08-02
# 5306        kate none      w     AUS  2022-08-02
# 5307        kate none      w     AUS  2022-08-02
# 5308        kate none      w     AUS  2022-08-02
#
#                                             Competition  Round  \
# 0     2022 51st FIG Artistic Gymnastics World Champi...   qual
# 1     2022 51st FIG Artistic Gymnastics World Champi...   qual
# 2     2022 51st FIG Artistic Gymnastics World Champi...   qual
# 3     2022 51st FIG Artistic Gymnastics World Champi...   qual
# 4                          FIG Apparatus World Cup 2023   qual
# ...                                                 ...    ...
# 5304  2022 51st FIG Artistic Gymnastics World Champi...   qual
# 5305                 BIRMINGHAM 2022 Commonwealth Games  final
# 5306                 BIRMINGHAM 2022 Commonwealth Games   qual
# 5307                 BIRMINGHAM 2022 Commonwealth Games  final
# 5308                 BIRMINGHAM 2022 Commonwealth Games   qual
#
#                  Location Apparatus   Rank  D_Score  E_Score  Penalty   Score  \
# 0      Liverpool, England        BB  100.0      4.8    6.200      0.0  11.000
# 1      Liverpool, England        FX  109.0      4.4    7.466      0.1  11.766
# 2      Liverpool, England        UB   52.0      4.8    8.000      0.0  12.800
# 3      Liverpool, England       VT1  110.0      4.2    8.433      0.3  12.333
# 4        Baku, Azerbaijan        BB   22.0      4.8    6.733      0.0  11.533
# ...                   ...       ...    ...      ...      ...      ...     ...
# 5304   Liverpool, England        UB   17.0      5.6    8.466      0.0  14.066
# 5305  Birmingham, England        BB    1.0      5.1    8.366      0.0  13.466
# 5306  Birmingham, England        BB    5.0      5.0    7.950      0.0  12.950
# 5307  Birmingham, England        UB    7.0      5.3    7.233      0.0  12.533
# 5308  Birmingham, England        UB    5.0      5.6    7.900      0.0  13.500
#
#       Total_Score
# 0          11.000
# 1          11.766
# 2          12.800
# 3          12.333
# 4          11.533
# ...           ...
# 5304       14.066
# 5305       13.466
# 5306       12.950
# 5307       12.533
# 5308       13.500
#
# [5309 rows x 14 columns]

# %%
df.head()
# Out:
#   LastName          FirstName Gender Country            Date  \
# 0      AAS            Fredrik      m     NOR  23-26 Feb 2023
# 1      AAS            Fredrik      m     NOR  23-26 Feb 2023
# 2      AAS  Fredrik Bjornevik      m     NOR    1-5 Aug 2023
# 3      AAS  Fredrik Bjornevik      m     NOR    1-5 Aug 2023
# 4      AAS  Fredrik Bjornevik      m     NOR    1-5 Aug 2023
#
#                         Competition Round          Location Apparatus  Rank  \
# 0      FIG Apparatus World Cup 2023  qual  Cottbus, Germany        HB  39.0
# 1      FIG Apparatus World Cup 2023  qual  Cottbus, Germany        PH  44.0
# 2  2023 FISU World University Games  qual    Chengdu, China        FX  54.0
# 3  2023 FISU World University Games  qual    Chengdu, China        HB  44.0
# 4  2023 FISU World University Games  qual    Chengdu, China        PB  54.0
#
#    D_Score  E_Score  Penalty   Score
# 0      4.6    6.700      NaN  11.300
# 1      4.4    7.800      NaN  12.200
# 2      4.0    8.566      NaN  12.566
# 3      4.6    8.166      NaN  12.766
# 4      4.4    8.066      NaN  12.466

# %%
df = pd.read_csv('women22_23.csv')

# %%
df.head()
# Out:
#               Name Gender Country        Date  \
# 0  Jana ABDELSALAM      w     EGY  2022-11-06
# 1  Jana ABDELSALAM      w     EGY  2022-11-06
# 2  Jana ABDELSALAM      w     EGY  2022-11-06
# 3  Jana ABDELSALAM      w     EGY  2022-11-06
# 4  Jana ABDELSALAM      w     EGY  2023-03-12
#
#                                          Competition Round  \
# 0  2022 51st FIG Artistic Gymnastics World Champi...  qual
# 1  2022 51st FIG Artistic Gymnastics World Champi...  qual
# 2  2022 51st FIG Artistic Gymnastics World Champi...  qual
# 3  2022 51st FIG Artistic Gymnastics World Champi...  qual
# 4                       FIG Apparatus World Cup 2023  qual
#
#              Location Apparatus   Rank  D_Score  E_Score  Penalty   Score  \
# 0  Liverpool, England        BB  100.0      4.8    6.200      0.0  11.000
# 1  Liverpool, England        FX  109.0      4.4    7.466      0.1  11.766
# 2  Liverpool, England        UB   52.0      4.8    8.000      0.0  12.800
# 3  Liverpool, England       VT1  110.0      4.2    8.433      0.3  12.333
# 4    Baku, Azerbaijan        BB   22.0      4.8    6.733      0.0  11.533
#
#    Total_Score
# 0       11.000
# 1       11.766
# 2       12.800
# 3       12.333
# 4       11.533

# %%
df = df.drop(columns=['Gender', 'Competition', 'Location', 'Total_Score'])

# %%
# Assuming you have a DataFrame 'df' with a 'date' column
df['year'] = df['Date'].str[:4]

# The 'year' column now contains the first four digits from the 'date' column

# %%
df = df.drop(columns=['Date'])

# %%
bb = df[df['Apparatus'] == 'BB']
fx = df[df['Apparatus'] == 'FX']
ub = df[df['Apparatus'] == 'UB']

# %%
bb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1307 entries, 0 to 5306
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       1307 non-null   object
#  1   Country    1292 non-null   object
#  2   Round      1307 non-null   object
#  3   Apparatus  1307 non-null   object
#  4   Rank       1307 non-null   float64
#  5   D_Score    1307 non-null   float64
#  6   E_Score    1307 non-null   float64
#  7   Penalty    1307 non-null   float64
#  8   Score      1307 non-null   float64
#  9   year       1289 non-null   object
# dtypes: float64(5), object(5)
# memory usage: 112.3+ KB

# %%
bb['Country'].fillna('none', inplace=True)
bb['year'].fillna(2023, inplace=True)
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_55569/2101912360.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb['Country'].fillna('none', inplace=True)
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_55569/2101912360.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb['year'].fillna(2023, inplace=True)

# %%
fx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1224 entries, 1 to 5295
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       1224 non-null   object
#  1   Country    1208 non-null   object
#  2   Round      1224 non-null   object
#  3   Apparatus  1224 non-null   object
#  4   Rank       1224 non-null   float64
#  5   D_Score    1224 non-null   float64
#  6   E_Score    1224 non-null   float64
#  7   Penalty    1224 non-null   float64
#  8   Score      1224 non-null   float64
#  9   year       1207 non-null   object
# dtypes: float64(5), object(5)
# memory usage: 105.2+ KB

# %%
fx['Country'].fillna('none', inplace=True)
fx['year'].fillna(2023, inplace=True)
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_55569/775039158.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fx['Country'].fillna('none', inplace=True)
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_55569/775039158.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fx['year'].fillna(2023, inplace=True)

# %%
ub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1237 entries, 2 to 5308
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       1237 non-null   object
#  1   Country    1223 non-null   object
#  2   Round      1237 non-null   object
#  3   Apparatus  1237 non-null   object
#  4   Rank       1237 non-null   float64
#  5   D_Score    1237 non-null   float64
#  6   E_Score    1237 non-null   float64
#  7   Penalty    1237 non-null   float64
#  8   Score      1237 non-null   float64
#  9   year       1219 non-null   object
# dtypes: float64(5), object(5)
# memory usage: 106.3+ KB

# %%
ub['Country'].fillna('none', inplace=True)
ub['year'].fillna(2023, inplace=True)
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_55569/3164996516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ub['Country'].fillna('none', inplace=True)
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_55569/3164996516.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ub['year'].fillna(2023, inplace=True)

# %%
ub
# Out:
#                          Name Country  Round Apparatus  Rank  D_Score  \
# 2             Jana ABDELSALAM     EGY   qual        UB  52.0      4.8
# 10            Jana ABDELSALAM     EGY   qual        UB  29.0      4.5
# 11            Jana ABDELSALAM     EGY   qual        UB  21.0      3.8
# 13           Ayesha ABDULLAHI     GBR   qual        UB  45.0      3.5
# 16    Kumudi Imanya ABEYRATNE     SRI   qual        UB  39.0      1.2
# ...                       ...     ...    ...       ...   ...      ...
# 5298        Christina Zwicker     CRO   qual        UB  19.0      4.5
# 5300        Christina Zwicker     CRO   qual        UB  15.0      3.2
# 5304                Kate None     AUS   qual        UB  17.0      5.6
# 5307                Kate None     AUS  final        UB   7.0      5.3
# 5308                Kate None     AUS   qual        UB   5.0      5.6
#
#       E_Score  Penalty   Score  year
# 2       8.000      0.0  12.800  2022
# 10      6.266      0.0  10.766  2023
# 11      5.533      0.0   9.333  2023
# 13      6.700      0.0  10.200  2022
# 16      4.300      0.0   5.500  2022
# ...       ...      ...     ...   ...
# 5298    6.633      0.0  11.133  2023
# 5300    6.767      0.0   9.967  2023
# 5304    8.466      0.0  14.066  2022
# 5307    7.233      0.0  12.533  2022
# 5308    7.900      0.0  13.500  2022
#
# [1237 rows x 10 columns]

# %%
values_to_remove = ['BB', 'UB', 'FX']

# Remove rows where 'Apparatus' is in values_to_remove
filtered_df = df[~df['Apparatus'].isin(values_to_remove)]

# %%
filtered_df['Apparatus'].value_counts()
# Out:
# Apparatus
# VT1    881
# VT2    451
# VT     209
# Name: count, dtype: int64

# %%
vt = filtered_df.copy()

# %%
vt['Name'] = vt['Name'].str.lower()
ub['Name'] = ub['Name'].str.lower()
bb['Name'] = bb['Name'].str.lower()
fx['Name'] = fx['Name'].str.lower()
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_55569/2023177694.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ub['Name'] = ub['Name'].str.lower()
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_55569/2023177694.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bb['Name'] = bb['Name'].str.lower()
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_55569/2023177694.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fx['Name'] = fx['Name'].str.lower()

# %%
bb
# Out:
#                    Name Country  Round Apparatus   Rank  D_Score  E_Score  \
# 0       jana abdelsalam     EGY   qual        BB  100.0      4.8    6.200
# 4       jana abdelsalam     EGY   qual        BB   22.0      4.8    6.733
# 5       jana abdelsalam     EGY  final        BB    8.0      4.8    6.566
# 6       jana abdelsalam     EGY   qual        BB    9.0      4.7    7.466
# 7       jana abdelsalam     EGY  final        BB    4.0      5.0    8.000
# ...                 ...     ...    ...       ...    ...      ...      ...
# 5297  christina zwicker     CRO   qual        BB    3.0      4.6    8.100
# 5299  christina zwicker     CRO   qual        BB   11.0      4.5    7.333
# 5303          kate none     AUS   qual        BB  110.0      5.1    5.633
# 5305          kate none     AUS  final        BB    1.0      5.1    8.366
# 5306          kate none     AUS   qual        BB    5.0      5.0    7.950
#
#       Penalty   Score  year
# 0         0.0  11.000  2022
# 4         0.0  11.533  2023
# 5         0.0  11.366  2023
# 6         0.0  12.166  2023
# 7         0.0  13.000  2023
# ...       ...     ...   ...
# 5297      0.0  12.700  2023
# 5299      0.0  11.833  2023
# 5303      0.0  10.733  2022
# 5305      0.0  13.466  2022
# 5306      0.0  12.950  2022
#
# [1307 rows x 10 columns]

# %%
bb = bb.drop(columns=['Apparatus'])
ub = ub.drop(columns=['Apparatus'])
fx = fx.drop(columns=['Apparatus'])
vt = vt.drop(columns=['Apparatus'])

# %%
bb.rename(columns={'Country': 'nation', 'D_Score': 'D Score',
                            'E_Score': 'E Score', 'Penalty': 'Pen.',
                           'Score': 'Total', 'Round': 'round'}, inplace=True)

bb=bb[['Rank', 'Name', 'nation', 'D Score', 'E Score', 'Pen.', 
                         'Total','year' , 'round' ]]

# %%
bb=bb[['Rank', 'Name', 'nation', 'D Score', 'E Score', 'Pen.', 
                         'Total','year' , 'round' ]]

# %%
bb.head()
# Out:
#     Rank             Name nation  D Score  E Score  Pen.   Total  year  round
# 0  100.0  jana abdelsalam    EGY      4.8    6.200   0.0  11.000  2022   qual
# 4   22.0  jana abdelsalam    EGY      4.8    6.733   0.0  11.533  2023   qual
# 5    8.0  jana abdelsalam    EGY      4.8    6.566   0.0  11.366  2023  final
# 6    9.0  jana abdelsalam    EGY      4.7    7.466   0.0  12.166  2023   qual
# 7    4.0  jana abdelsalam    EGY      5.0    8.000   0.0  13.000  2023  final

# %%
fx.head(1)
# Out:
#               Name Country Round   Rank  D_Score  E_Score  Penalty   Score  \
# 1  jana abdelsalam     EGY  qual  109.0      4.4    7.466      0.1  11.766
#
#    year
# 1  2022

# %%
fx.rename(columns={'Country': 'nation', 'D_Score': 'D Score',
                            'E_Score': 'E Score', 'Penalty': 'Pen.',
                           'Score': 'Total', 'Round': 'round'}, inplace=True)

fx=fx[['Rank', 'Name', 'nation', 'D Score', 'E Score', 'Pen.', 
                         'Total','year' , 'round' ]]

# %%
fx.head()
# Out:
#      Rank                     Name nation  D Score  E Score  Pen.   Total  \
# 1   109.0          jana abdelsalam    EGY      4.4    7.466   0.1  11.766
# 9    22.0          jana abdelsalam    EGY      4.5    7.366   0.0  11.866
# 15   39.0  kumudi imanya abeyratne    SRI      2.9    4.450   0.0   7.350
# 18   74.0          jana aboelhasan    EGY      4.4    7.866   0.0  12.266
# 22   16.0         ondine achampong    GBR      5.3    8.033   0.0  13.333
#
#     year round
# 1   2022  qual
# 9   2023  qual
# 15  2022  qual
# 18  2022  qual
# 22  2022  qual

# %%
ub.rename(columns={'Country': 'nation', 'D_Score': 'D Score',
                            'E_Score': 'E Score', 'Penalty': 'Pen.',
                           'Score': 'Total', 'Round': 'round'}, inplace=True)

ub=ub[['Rank', 'Name', 'nation', 'D Score', 'E Score', 'Pen.', 
                         'Total','year' , 'round' ]]

# %%
bb_encode = bb.copy()
ub_encode = ub.copy()
fx_encode = fx.copy()

# %%
bb['round'] = bb['round'].str.lower()
ub['round'] = ub['round'].str.lower()
fx['round'] = fx['round'].str.lower()

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and 'Name' is the column you want to encode
le = LabelEncoder()

# Fit and transform the 'Name' column to create integer labels
bb['Name_encoded'] = le.fit_transform(bb['Name'])

# Store the mapping between integers and original objects
label_mapping = dict(zip(le.transform(bb['Name']), bb['Name']))

# %%
bbnames = bb[['Name', 'Name_encoded']]

# %%
bb=bb.drop(columns=["Name"])
bb.rename(columns={'Name_encoded': 'Name'}, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and 'Name' is the column you want to encode
le = LabelEncoder()

# Fit and transform the 'Name' column to create integer labels
bb['nation_encoded'] = le.fit_transform(bb['nation'])

# Store the mapping between integers and original objects
label_mapping_nation = dict(zip(le.transform(bb['nation']), bb['nation']))

# To revert the integers back to objects, use the label_mapping
# reverted_names = df['Name_encoded'].map(label_mapping)

# %%
bb=bb.drop(columns=["nation"])
bb.rename(columns={'nation_encoded': 'nation'}, inplace=True)

# %%
bb_encoded = pd.get_dummies(bb, columns=['round'], prefix='round')

# %%
bb_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1307 entries, 0 to 5306
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             1307 non-null   float64
#  1   D Score          1307 non-null   float64
#  2   E Score          1307 non-null   float64
#  3   Pen.             1307 non-null   float64
#  4   Total            1307 non-null   float64
#  5   year             1307 non-null   object
#  6   Name             1307 non-null   int64
#  7   nation           1307 non-null   int64
#  8   round_aafinal    1307 non-null   bool
#  9   round_final      1307 non-null   bool
#  10  round_qual       1307 non-null   bool
#  11  round_teamfinal  1307 non-null   bool
# dtypes: bool(4), float64(5), int64(2), object(1)
# memory usage: 97.0+ KB

# %%
bb_encoded['year'] = pd.to_numeric(bb_encoded['year'], errors='coerce').fillna(0).astype(int)

# %%
bb_encoded
# Out:
#        Rank  D Score  E Score  Pen.   Total  year  Name  nation  \
# 0     100.0      4.8    6.200   0.0  11.000  2022   227      22
# 4      22.0      4.8    6.733   0.0  11.533  2023   227      22
# 5       8.0      4.8    6.566   0.0  11.366  2023   227      22
# 6       9.0      4.7    7.466   0.0  12.166  2023   227      22
# 7       4.0      5.0    8.000   0.0  13.000  2023   227      22
# ...     ...      ...      ...   ...     ...   ...   ...     ...
# 5297    3.0      4.6    8.100   0.0  12.700  2023   117      15
# 5299   11.0      4.5    7.333   0.0  11.833  2023   117      15
# 5303  110.0      5.1    5.633   0.0  10.733  2022   270       3
# 5305    1.0      5.1    8.366   0.0  13.466  2022   270       3
# 5306    5.0      5.0    7.950   0.0  12.950  2022   270       3
#
#       round_aafinal  round_final  round_qual  round_teamfinal
# 0             False        False        True            False
# 4             False        False        True            False
# 5             False         True       False            False
# 6             False        False        True            False
# 7             False         True       False            False
# ...             ...          ...         ...              ...
# 5297          False        False        True            False
# 5299          False        False        True            False
# 5303          False        False        True            False
# 5305          False         True       False            False
# 5306          False        False        True            False
#
# [1307 rows x 12 columns]

# %%
bb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1307 entries, 0 to 5306
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     1307 non-null   float64
#  1   D Score  1307 non-null   float64
#  2   E Score  1307 non-null   float64
#  3   Pen.     1307 non-null   float64
#  4   Total    1307 non-null   float64
#  5   year     1307 non-null   object
#  6   round    1307 non-null   object
#  7   Name     1307 non-null   int64
#  8   nation   1307 non-null   int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 102.1+ KB

# %%
fx
# Out:
#        Rank                     Name nation  D Score  E Score  Pen.   Total  \
# 1     109.0          jana abdelsalam    EGY      4.4    7.466   0.1  11.766
# 9      22.0          jana abdelsalam    EGY      4.5    7.366   0.0  11.866
# 15     39.0  kumudi imanya abeyratne    SRI      2.9    4.450   0.0   7.350
# 18     74.0          jana aboelhasan    EGY      4.4    7.866   0.0  12.266
# 22     16.0         ondine achampong    GBR      5.3    8.033   0.0  13.333
# ...     ...                      ...    ...      ...      ...   ...     ...
# 5277    6.0               lexi zeiss    USA      5.2    7.950   0.0  13.150
# 5284    0.0              alicia zhou    USA      4.9    7.800   0.0  12.700
# 5285    0.0              alicia zhou    USA      4.9    8.000   0.0  12.900
# 5291   13.0              alicia zhou    USA      4.9    7.650   0.0  12.550
# 5295   20.0     kristina zivadinovic   none      4.3    7.033   0.0  11.333
#
#       year    round
# 1     2022     qual
# 9     2023     qual
# 15    2022     qual
# 18    2022     qual
# 22    2022     qual
# ...    ...      ...
# 5277  2023  aafinal
# 5284  2023     qual
# 5285  2023    final
# 5291  2023  aafinal
# 5295  2023     qual
#
# [1224 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and 'Name' is the column you want to encode
le = LabelEncoder()

# Fit and transform the 'Name' column to create integer labels
fx['Name_encoded'] = le.fit_transform(fx['Name'])

# Store the mapping between integers and original objects

# %%
fxnames = fx[['Name', 'Name_encoded']]

# %%
fxnames
# Out:
#                          Name  Name_encoded
# 1             jana abdelsalam           227
# 9             jana abdelsalam           227
# 15    kumudi imanya abeyratne           286
# 18            jana aboelhasan           228
# 22           ondine achampong           414
# ...                       ...           ...
# 5277               lexi zeiss           305
# 5284              alicia zhou            22
# 5285              alicia zhou            22
# 5291              alicia zhou            22
# 5295     kristina zivadinovic           285
#
# [1224 rows x 2 columns]

# %%
fx[fx['Name_encoded'] == 185]
# Out:
#       Rank            Name nation  D Score  E Score  Pen.  Total  year round  \
# 4050   1.0  flavia saraiva    BRA      5.8      8.4   0.0   14.2  2022  qual
#
#       Name_encoded
# 4050           185

# %%
fx=fx.drop(columns=["Name"])
fx.rename(columns={'Name_encoded': 'Name'}, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and 'Name' is the column you want to encode
le = LabelEncoder()

# Fit and transform the 'Name' column to create integer labels
fx['nation_encoded'] = le.fit_transform(fx['nation'])

# Store the mapping between integers and original objects
label_mapping_nation = dict(zip(le.transform(fx['nation']), fx['nation']))

# To revert the integers back to objects, use the label_mapping
# reverted_names = df['Name_encoded'].map(label_mapping)

# %%
fx=fx.drop(columns=["nation"])
fx.rename(columns={'nation_encoded': 'nation'}, inplace=True)

# %%
fx_encoded = pd.get_dummies(fx, columns=['round'], prefix='round')

# %%
fx_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1224 entries, 1 to 5295
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             1224 non-null   float64
#  1   D Score          1224 non-null   float64
#  2   E Score          1224 non-null   float64
#  3   Pen.             1224 non-null   float64
#  4   Total            1224 non-null   float64
#  5   year             1224 non-null   object
#  6   Name             1224 non-null   int64
#  7   nation           1224 non-null   int64
#  8   round_aafinal    1224 non-null   bool
#  9   round_final      1224 non-null   bool
#  10  round_qual       1224 non-null   bool
#  11  round_teamfinal  1224 non-null   bool
# dtypes: bool(4), float64(5), int64(2), object(1)
# memory usage: 90.8+ KB

# %%
fx_encoded['year'] = pd.to_numeric(fx_encoded['year'], errors='coerce').fillna(0).astype(int)

# %%
fx = fx_encoded.copy()

# %%
fx
# Out:
#        Rank  D Score  E Score  Pen.   Total  year  Name  nation  \
# 1     109.0      4.4    7.466   0.1  11.766  2022   227      22
# 9      22.0      4.5    7.366   0.0  11.866  2023   227      22
# 15     39.0      2.9    4.450   0.0   7.350  2022   286      67
# 18     74.0      4.4    7.866   0.0  12.266  2022   228      22
# 22     16.0      5.3    8.033   0.0  13.333  2022   414      28
# ...     ...      ...      ...   ...     ...   ...   ...     ...
# 5277    6.0      5.2    7.950   0.0  13.150  2023   305      76
# 5284    0.0      4.9    7.800   0.0  12.700  2023    22      76
# 5285    0.0      4.9    8.000   0.0  12.900  2023    22      76
# 5291   13.0      4.9    7.650   0.0  12.550  2023    22      76
# 5295   20.0      4.3    7.033   0.0  11.333  2023   285      81
#
#       round_aafinal  round_final  round_qual  round_teamfinal
# 1             False        False        True            False
# 9             False        False        True            False
# 15            False        False        True            False
# 18            False        False        True            False
# 22            False        False        True            False
# ...             ...          ...         ...              ...
# 5277           True        False       False            False
# 5284          False        False        True            False
# 5285          False         True       False            False
# 5291           True        False       False            False
# 5295          False        False        True            False
#
# [1224 rows x 12 columns]

# %%
# fx.to_csv("encoded_w_olympics_fx.csv", index=False)

# %%
# fxnames.to_csv("encoded_w_olympics_fxnames.csv", index=False)

# %%
bb = bb_encoded.copy()

# %%
# bbnames

# %%
# bb.to_csv("encoded_w_olympics_bb.csv", index=False)

# %%
# bbnames.to_csv("encoded_w_olympics_bbnames.csv", index=False)

# %%
ub
# Out:
#       Rank                     Name nation  D Score  E Score  Pen.   Total  \
# 2     52.0          jana abdelsalam    EGY      4.8    8.000   0.0  12.800
# 10    29.0          jana abdelsalam    EGY      4.5    6.266   0.0  10.766
# 11    21.0          jana abdelsalam    EGY      3.8    5.533   0.0   9.333
# 13    45.0         ayesha abdullahi    GBR      3.5    6.700   0.0  10.200
# 16    39.0  kumudi imanya abeyratne    SRI      1.2    4.300   0.0   5.500
# ...    ...                      ...    ...      ...      ...   ...     ...
# 5298  19.0        christina zwicker    CRO      4.5    6.633   0.0  11.133
# 5300  15.0        christina zwicker    CRO      3.2    6.767   0.0   9.967
# 5304  17.0                kate none    AUS      5.6    8.466   0.0  14.066
# 5307   7.0                kate none    AUS      5.3    7.233   0.0  12.533
# 5308   5.0                kate none    AUS      5.6    7.900   0.0  13.500
#
#       year  round
# 2     2022   qual
# 10    2023   qual
# 11    2023   qual
# 13    2022   qual
# 16    2022   qual
# ...    ...    ...
# 5298  2023   qual
# 5300  2023   qual
# 5304  2022   qual
# 5307  2022  final
# 5308  2022   qual
#
# [1237 rows x 9 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and 'Name' is the column you want to encode
le = LabelEncoder()

# Fit and transform the 'Name' column to create integer labels
ub['Name_encoded'] = le.fit_transform(ub['Name'])

# Store the mapping between integers and original objects

# %%
ubnames = ub[['Name', 'Name_encoded']]

# %%
# ubnames

# %%
ub=ub.drop(columns=["Name"])
ub.rename(columns={'Name_encoded': 'Name'}, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and 'Name' is the column you want to encode
le = LabelEncoder()

# Fit and transform the 'Name' column to create integer labels
ub['nation_encoded'] = le.fit_transform(ub['nation'])

# Store the mapping between integers and original objects
label_mapping_nation = dict(zip(le.transform(ub['nation']), ub['nation']))

# To revert the integers back to objects, use the label_mapping
# reverted_names = df['Name_encoded'].map(label_mapping)

# %%
ub=ub.drop(columns=["nation"])
ub.rename(columns={'nation_encoded': 'nation'}, inplace=True)

# %%
ub_encoded = pd.get_dummies(ub, columns=['round'], prefix='round')

# %%
ub_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1237 entries, 2 to 5308
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             1237 non-null   float64
#  1   D Score          1237 non-null   float64
#  2   E Score          1237 non-null   float64
#  3   Pen.             1237 non-null   float64
#  4   Total            1237 non-null   float64
#  5   year             1237 non-null   object
#  6   Name             1237 non-null   int64
#  7   nation           1237 non-null   int64
#  8   round_aafinal    1237 non-null   bool
#  9   round_final      1237 non-null   bool
#  10  round_qual       1237 non-null   bool
#  11  round_teamfinal  1237 non-null   bool
# dtypes: bool(4), float64(5), int64(2), object(1)
# memory usage: 91.8+ KB

# %%
ub_encoded['year'] = pd.to_numeric(ub_encoded['year'], errors='coerce').fillna(0).astype(int)

# %%
ub = ub_encoded.copy()

# %%
ub
# Out:
#       Rank  D Score  E Score  Pen.   Total  year  Name  nation  round_aafinal  \
# 2     52.0      4.8    8.000   0.0  12.800  2022   216      22          False
# 10    29.0      4.5    6.266   0.0  10.766  2023   216      22          False
# 11    21.0      3.8    5.533   0.0   9.333  2023   216      22          False
# 13    45.0      3.5    6.700   0.0  10.200  2022    71      28          False
# 16    39.0      1.2    4.300   0.0   5.500  2022   276      67          False
# ...    ...      ...      ...   ...     ...   ...   ...     ...            ...
# 5298  19.0      4.5    6.633   0.0  11.133  2023   109      15          False
# 5300  15.0      3.2    6.767   0.0   9.967  2023   109      15          False
# 5304  17.0      5.6    8.466   0.0  14.066  2022   256       3          False
# 5307   7.0      5.3    7.233   0.0  12.533  2022   256       3          False
# 5308   5.0      5.6    7.900   0.0  13.500  2022   256       3          False
#
#       round_final  round_qual  round_teamfinal
# 2           False        True            False
# 10          False        True            False
# 11          False        True            False
# 13          False        True            False
# 16          False        True            False
# ...           ...         ...              ...
# 5298        False        True            False
# 5300        False        True            False
# 5304        False        True            False
# 5307         True       False            False
# 5308        False        True            False
#
# [1237 rows x 12 columns]

# %%
# ub.to_csv("encoded_w_olympics_ub.csv", index=False)  
# ubnames.to_csv("encoded_w_olympics_ubnames.csv", index=False)

# %%
vt.head(1)
# Out:
#               Name Country Round   Rank  D_Score  E_Score  Penalty   Score  \
# 3  jana abdelsalam     EGY  qual  110.0      4.2    8.433      0.3  12.333
#
#    year
# 3  2022

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and 'Name' is the column you want to encode
le = LabelEncoder()

# Fit and transform the 'Name' column to create integer labels
vt['Name_encoded'] = le.fit_transform(vt['Name'])

# Store the mapping between integers and original objects

# %%
vtnames = vt[['Name', 'Name_encoded']]

# %%
vt=vt.drop(columns=["Name"])
vt.rename(columns={'Name_encoded': 'Name'}, inplace=True)

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming df is your DataFrame and 'Name' is the column you want to encode
le = LabelEncoder()

# Fit and transform the 'Name' column to create integer labels
vt['nation_encoded'] = le.fit_transform(vt['Country'])

# Store the mapping between integers and original objects
label_mapping_nation = dict(zip(le.transform(vt['Country']), vt['Country']))

# To revert the integers back to objects, use the label_mapping
# reverted_names = df['Name_encoded'].map(label_mapping)

# %%
vt=vt.drop(columns=["Country"])
vt.rename(columns={'nation_encoded': 'nation'}, inplace=True)

# %%
vt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1541 entries, 3 to 5302
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Round    1541 non-null   object
#  1   Rank     1541 non-null   float64
#  2   D_Score  1541 non-null   float64
#  3   E_Score  1541 non-null   float64
#  4   Penalty  1541 non-null   float64
#  5   Score    1541 non-null   float64
#  6   year     1524 non-null   object
#  7   Name     1541 non-null   int64
#  8   nation   1541 non-null   int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 120.4+ KB

# %%
vt=vt.dropna()

# %%
vt_encoded = pd.get_dummies(vt, columns=['Round'], prefix='Round')

# %%
vt_encoded.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1524 entries, 3 to 5302
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Rank             1524 non-null   float64
#  1   D_Score          1524 non-null   float64
#  2   E_Score          1524 non-null   float64
#  3   Penalty          1524 non-null   float64
#  4   Score            1524 non-null   float64
#  5   year             1524 non-null   object
#  6   Name             1524 non-null   int64
#  7   nation           1524 non-null   int64
#  8   Round_AAfinal    1524 non-null   bool
#  9   Round_TeamFinal  1524 non-null   bool
#  10  Round_final      1524 non-null   bool
#  11  Round_qual       1524 non-null   bool
# dtypes: bool(4), float64(5), int64(2), object(1)
# memory usage: 113.1+ KB

# %%
vt_encoded['year'] = pd.to_numeric(vt_encoded['year'], errors='coerce').fillna(0).astype(int)

# %%
vt = vt_encoded.copy()

# %%
# vt.to_csv("encoded_w_olympics_vt.csv", index=False)  
# vtnames.to_csv("encoded_w_olympics_vtnames.csv", index=False)
