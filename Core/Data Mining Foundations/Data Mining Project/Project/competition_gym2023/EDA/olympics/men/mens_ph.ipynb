# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../../Cleaning/olympics/mens/cleaned_mens2012to2020ph")

# %%
df
# Out:
#     Rank              Gymnast Nation  D Score  E Score  Pen.    Total  year
# 0      1      Krisztián Berki    HUN      6.9    9.166   0.0  16.066*  2012
# 1      2          Louis Smith    GBR      7.0    9.066   0.0  16.066*  2012
# 2      3         Max Whitlock    GBR      6.6    9.000   0.0     15.6  2012
# 3      4      Alberto Busnari  Italy      6.6    8.800   0.0     15.4  2012
# 4      5      Cyril Tommasone    FRA      6.5    8.641   0.0   15.141  2012
# 5      6  Vitaliy Nakonechnyi    UKR      6.3    8.466   0.0   14.766  2012
# 6      7     David Belyavskiy    RUS      6.3    8.433   0.0   14.733  2012
# 7      8          Vid Hidvégi    HUN      6.3    8.000   0.0     14.3  2012
# 8      1         Max Whitlock    GBR      7.2    8.766   0.0   15.966  2016
# 9      2          Louis Smith    GBR      6.9    8.933   0.0   15.833  2016
# 10     3    Alexander Naddour    USA      6.8    8.900   0.0     15.7  2016
# ...

# %%
df['Total'] = df['Total'].str.replace('*', '').astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     24 non-null     int64
#  1   Gymnast  24 non-null     object
#  2   Nation   24 non-null     object
#  3   D Score  24 non-null     float64
#  4   E Score  24 non-null     float64
#  5   Pen.     24 non-null     float64
#  6   Total    24 non-null     float64
#  7   year     24 non-null     int64
# dtypes: float64(4), int64(2), object(2)
# memory usage: 1.6+ KB

# %%
medals = df[df['Rank'].isin([1.0, 2.0, 3.0])]

# %%
df = medals.copy()

# %%
df["Nation"].value_counts()
# Out:
# Nation
# GBR    5
# HUN    1
# USA    1
# TPE    1
# JPN    1
# Name: count, dtype: int64

# %%
# Box plot of 'bb' by 'year'
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='year', y='Total')
plt.title('Box Plot of Total by Year')
plt.xlabel('Year')
plt.ylabel('Total')
plt.show()
