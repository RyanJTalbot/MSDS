# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../../../Cleaning/olympics/womens/cleaned_womens2012to2020ub')
ub = pd.read_csv('../../../kaggle-data/olympics_w_ub.csv')

# %%
df
# Out:
#     Rank                      Gymnast         Nation  D Score  E Score  Pen.  \
# 0      1              Aliya Mustafina         Russia      7.0    9.133   0.0
# 1      2                     He Kexin          China      7.1    8.833   0.0
# 2      3                 Beth Tweddle  Great Britain      7.0    8.916   0.0
# 3      4                   Yao Jinnan          China      6.8    8.966   0.0
# 4      5              Viktoria Komova         Russia      7.0    8.666   0.0
# 5      6              Elisabeth Seitz        Germany      6.7    8.566   0.0
# 6      7                 Kōko Tsurumi          Japan      6.4    8.566   0.0
# 7      8                Gabby Douglas  United States      6.3    8.600   0.0
# 8      1              Aliya Mustafina            RUS      6.8    9.100   0.0
# 9      2               Madison Kocian            USA      6.7    9.133   0.0
# 10     3               Sophie Scheder            GER      6.6    8.966   0.0
# 11     4              Elisabeth Seitz            GER      6.6    8.933   0.0
# 12     5               Shang Chunsong            CHN      6.7    8.733   0.0
# 13     6                Jessica López            VEN      6.7    8.633   0.0
# 14     7                Gabby Douglas            USA      6.5    8.566   0.0
# 15     8            Daria Spiridonova            RUS      6.1    7.866   0.0
# 16     1                 Nina Derwael            BEL      6.7    8.500   0.0
# 17     2          Anastasia Ilyankova            ROC      6.3    8.533   0.0
# 18     3                   Sunisa Lee            USA      6.2    8.300   0.0
# 19     4                     Lu Yufei            CHN      6.0    8.400   0.0
# 20     5              Elisabeth Seitz            GER      6.2    8.200   0.0
# 21     6  Mélanie de Jesus dos Santos            FRA      6.1    7.933   0.0
# 22     7                    Fan Yilin            CHN      6.4    7.500   0.0
# 23     8           Angelina Melnikova            ROC      5.9    7.166   0.0
#
#      Total  year
# 0   16.133  2012
# 1   15.933  2012
# 2   15.916  2012
# 3   15.766  2012
# 4   15.666  2012
# 5   15.266  2012
# 6   14.966  2012
# 7   14.900  2012
# 8   15.900  2016
# 9   15.833  2016
# 10  15.566  2016
# 11  15.533  2016
# 12  15.433  2016
# 13  15.333  2016
# 14  15.066  2016
# 15  13.966  2016
# 16  15.200  2020
# 17  14.833  2020
# 18  14.500  2020
# 19  14.400  2020
# 20  14.400  2020
# 21  14.033  2020
# 22  13.900  2020
# 23  13.066  2020

# %%
# Define a mapping dictionary from full country names to abbreviations
country_mapping = {
    'Romania': 'ROU',
    'United States': 'USA',
    'Russia': 'RUS',
    'Great Britain': 'GBR',
    'Germany': 'GER',
    'Japan': 'JPN',
    'China': 'CHN'
}

# Use the replace function to replace the full country names with abbreviations
df['Nation'] = df['Nation'].replace(country_mapping)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
medals = df[df['Rank'].isin([1.0, 2.0, 3.0])]

# %%
# Box plot of 'bb' by 'year'
plt.figure(figsize=(8, 6))
sns.boxplot(data=medals, x='year', y='Total')
plt.title('Box Plot of Total by Year')
plt.xlabel('Year')
plt.ylabel('Total')
plt.show()

# %%
medals["Total"].min()
# Out:
# 14.5

# %%
medals['Nation'].value_counts()
# Out:
# Nation
# RUS    2
# USA    2
# CHN    1
# GBR    1
# GER    1
# BEL    1
# ROC    1
# Name: count, dtype: int64

# %%
ub=ub.drop(columns=["Sex", "Event", ])

# %%
years_to_filter = [2016, 2012, 2020]

# Create a new DataFrame for the specified years
filtered_df = ub[ub['Year'].isin(years_to_filter)]

# %%
ub = filtered_df.copy()

# %%
ub
# Out:
#                                    Name   Age  Height  Weight  NOC  Year Medal
# 7                Jonna Eva-Maj Adlerteg  17.0   153.0    38.0  SWE  2012  none
# 20                       Tabea Lara Alt  16.0   158.0    50.0  GER  2016  none
# 22    Isabella del Carmen Amado Medrano  19.0   155.0    59.0  PAN  2016  none
# 28          Rebeca Rodrigues de Andrade  17.0   151.0    46.0  BRA  2016  none
# 46                       Moldir Azimbay  16.0   162.0     NaN  KAZ  2012  none
# ...                                 ...   ...     ...     ...  ...   ...   ...
# 1472          Toni-Ann Natasha Williams  20.0   155.0    52.0  JAM  2016  none
# 1481              Hiu Ying "Angel" Wong  25.0   153.0    50.0  HKG  2012  none
# 1482                    Rose-Kaying Woo  16.0   145.0    46.0  CAN  2016  none
# 1493                         Yao Jinnan  17.0   145.0    35.0  CHN  2012  none
# 1500                        Tutya Ylmaz  17.0   150.0    48.0  TUR  2016  none
#
# [158 rows x 7 columns]

# %%
df
# Out:
#     Rank                      Gymnast         Nation  D Score  E Score  Pen.  \
# 0      1              Aliya Mustafina         Russia      7.0    9.133   0.0
# 1      2                     He Kexin          China      7.1    8.833   0.0
# 2      3                 Beth Tweddle  Great Britain      7.0    8.916   0.0
# 3      4                   Yao Jinnan          China      6.8    8.966   0.0
# 4      5              Viktoria Komova         Russia      7.0    8.666   0.0
# 5      6              Elisabeth Seitz        Germany      6.7    8.566   0.0
# 6      7                 Kōko Tsurumi          Japan      6.4    8.566   0.0
# 7      8                Gabby Douglas  United States      6.3    8.600   0.0
# 8      1              Aliya Mustafina            RUS      6.8    9.100   0.0
# 9      2               Madison Kocian            USA      6.7    9.133   0.0
# 10     3               Sophie Scheder            GER      6.6    8.966   0.0
# 11     4              Elisabeth Seitz            GER      6.6    8.933   0.0
# 12     5               Shang Chunsong            CHN      6.7    8.733   0.0
# 13     6                Jessica López            VEN      6.7    8.633   0.0
# 14     7                Gabby Douglas            USA      6.5    8.566   0.0
# 15     8            Daria Spiridonova            RUS      6.1    7.866   0.0
# 16     1                 Nina Derwael            BEL      6.7    8.500   0.0
# 17     2          Anastasia Ilyankova            ROC      6.3    8.533   0.0
# 18     3                   Sunisa Lee            USA      6.2    8.300   0.0
# 19     4                     Lu Yufei            CHN      6.0    8.400   0.0
# 20     5              Elisabeth Seitz            GER      6.2    8.200   0.0
# 21     6  Mélanie de Jesus dos Santos            FRA      6.1    7.933   0.0
# 22     7                    Fan Yilin            CHN      6.4    7.500   0.0
# 23     8           Angelina Melnikova            ROC      5.9    7.166   0.0
#
#      Total  year
# 0   16.133  2012
# 1   15.933  2012
# 2   15.916  2012
# 3   15.766  2012
# 4   15.666  2012
# 5   15.266  2012
# 6   14.966  2012
# 7   14.900  2012
# 8   15.900  2016
# 9   15.833  2016
# 10  15.566  2016
# 11  15.533  2016
# 12  15.433  2016
# 13  15.333  2016
# 14  15.066  2016
# 15  13.966  2016
# 16  15.200  2020
# 17  14.833  2020
# 18  14.500  2020
# 19  14.400  2020
# 20  14.400  2020
# 21  14.033  2020
# 22  13.900  2020
# 23  13.066  2020
