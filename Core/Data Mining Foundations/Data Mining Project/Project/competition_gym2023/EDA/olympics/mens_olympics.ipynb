# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('../../kaggle-data/mens_olympics')
modern = pd.read_csv('../../kaggle-data/modern_mens_olympics')

# %%
df
# Out:
#            ID                         Name  NOC  Year   Age      Height  \
# 0          17      Paavo Johannes Aaltonen  FIN  1948  28.0  175.000000
# 1          17      Paavo Johannes Aaltonen  FIN  1948  28.0  175.000000
# 2          17      Paavo Johannes Aaltonen  FIN  1948  28.0  175.000000
# 3          17      Paavo Johannes Aaltonen  FIN  1948  28.0  175.000000
# 4          17      Paavo Johannes Aaltonen  FIN  1948  28.0  175.000000
# ...       ...                          ...  ...   ...   ...         ...
# 16795  135363                 Angelo Zucca  ITA  1976  20.0  167.000000
# 16796  135481  Jules Alexis "Louis" Zutter  SUI  1896  30.0  167.644438
# 16797  135481  Jules Alexis "Louis" Zutter  SUI  1896  30.0  167.644438
# 16798  135481  Jules Alexis "Louis" Zutter  SUI  1896  30.0  167.644438
# 16799  135481  Jules Alexis "Louis" Zutter  SUI  1896  30.0  167.644438
#
#           Weight                  Event   Medal
# 0      64.000000  Individual All-Around  Bronze
# 1      64.000000        Team All-Around    Gold
# 2      64.000000         Floor Exercise     NaN
# 3      64.000000            Horse Vault    Gold
# 4      64.000000          Parallel Bars     NaN
# ...          ...                    ...     ...
# 16795  63.000000        Pommelled Horse     NaN
# 16796  63.343605            Horse Vault  Silver
# 16797  63.343605          Parallel Bars  Silver
# 16798  63.343605         Horizontal Bar     NaN
# 16799  63.343605        Pommelled Horse    Gold
#
# [16800 rows x 9 columns]

# %%
modern
# Out:
#           ID               Name  NOC  Year   Age  Height  Weight  \
# 0         51  Nstor Abad Sanjun  ESP  2016  23.0   167.0    64.0
# 1         51  Nstor Abad Sanjun  ESP  2016  23.0   167.0    64.0
# 2         51  Nstor Abad Sanjun  ESP  2016  23.0   167.0    64.0
# 3         51  Nstor Abad Sanjun  ESP  2016  23.0   167.0    64.0
# 4         51  Nstor Abad Sanjun  ESP  2016  23.0   167.0    64.0
# ...      ...                ...  ...   ...   ...     ...     ...
# 1500  135269            Zou Kai  CHN  2008  20.0   158.0    55.0
# 1501  135269            Zou Kai  CHN  2012  24.0   158.0    55.0
# 1502  135269            Zou Kai  CHN  2012  24.0   158.0    55.0
# 1503  135269            Zou Kai  CHN  2012  24.0   158.0    55.0
# 1504  135269            Zou Kai  CHN  2012  24.0   158.0    55.0
#
#                       Event   Medal
# 0     Individual All-Around     NaN
# 1            Floor Exercise     NaN
# 2             Parallel Bars     NaN
# 3            Horizontal Bar     NaN
# 4                     Rings     NaN
# ...                     ...     ...
# 1500         Horizontal Bar    Gold
# 1501        Team All-Around    Gold
# 1502         Floor Exercise    Gold
# 1503         Horizontal Bar  Bronze
# 1504        Pommelled Horse     NaN
#
# [1505 rows x 9 columns]

# %%
modern['Medal'].fillna('None', inplace=True)

# %%
df['Medal'].fillna('None', inplace=True)

# %%
medals = df[df["Medal"] != "None"]

# %%
modern_medals = modern[modern["Medal"] != "None"]

# %%
import matplotlib.pyplot as plt

# Group the data by 'Year' and calculate the mean age for each year
age_by_year = df.groupby('Year')['Age'].mean()

# Create a line plot
plt.figure(figsize=(10, 6))
age_by_year.plot(kind='line', marker='o')
plt.title('Average Age Over Time')
plt.xlabel('Year')
plt.ylabel('Average Age')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Group the data by 'Year' and calculate the mean age for each year
age_by_year = medals.groupby('Year')['Age'].mean()

# Create a line plot
plt.figure(figsize=(10, 6))
age_by_year.plot(kind='line', marker='o')
plt.title('Average Age Over Time for Medalist')
plt.xlabel('Year')
plt.ylabel('Average Age')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Group the data by 'Year' and calculate the mean age for each year
age_by_year = df.groupby('Year')['Height'].mean()

# Create a line plot
plt.figure(figsize=(10, 6))
age_by_year.plot(kind='line', marker='o')
plt.title('Average Height Over Time')
plt.xlabel('Year')
plt.ylabel('Average Height')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Group the data by 'Year' and calculate the mean age for each year
age_by_year = medals.groupby('Year')['Height'].mean()

# Create a line plot
plt.figure(figsize=(10, 6))
age_by_year.plot(kind='line', marker='o')
plt.title('Average Height Over Time for Medalist')
plt.xlabel('Year')
plt.ylabel('Average Height')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Group the data by 'Year' and calculate the mean age for each year
age_by_year = modern.groupby('Year')['Age'].mean()

# Create a line plot
plt.figure(figsize=(10, 6))
age_by_year.plot(kind='line', marker='o')
plt.title('Average Age Over Time')
plt.xlabel('Year')
plt.ylabel('Average Age')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Group the data by 'Year' and calculate the mean age for each year
age_by_year = modern_medals.groupby('Year')['Age'].mean()

# Create a line plot
plt.figure(figsize=(10, 6))
age_by_year.plot(kind='line', marker='o')
plt.title('Average Age Over Time for Medalist')
plt.xlabel('Year')
plt.ylabel('Average Age')
plt.grid(True)
plt.show()

# %%
df["Event"].unique()
# Out:
# array(['Individual All-Around', 'Team All-Around', 'Floor Exercise',
#        'Horse Vault', 'Parallel Bars', 'Horizontal Bar', 'Rings',
#        'Pommelled Horse'], dtype=object)

# %%
unique_events = ['Individual All-Around', 'Team All-Around', 'Floor Exercise',
       'Horse Vault', 'Parallel Bars', 'Horizontal Bar', 'Rings',
       'Pommelled Horse']

# Create an empty dictionary to store the DataFrames
event_dataframes = {}

# Iterate through the unique events and create separate DataFrames for each
for event in unique_events:
    event_dataframes[event] = modern_medals[modern_medals['Event'] == event].copy()

# %%
event_dataframes['Rings']
# Out:
#           ID                            Name  NOC  Year   Age  Height  Weight  \
# 15       455     Denis Mikhaylovich Ablyazin  RUS  2016  24.0   161.0    62.0
# 264    20312                     Chen Yibing  CHN  2008  23.0   160.0    58.0
# 268    20312                     Chen Yibing  CHN  2012  27.0   160.0    58.0
# 862    81819                  Matteo Morandi  ITA  2012  30.0   165.0    71.0
# 990    94094          Eleftherios Petrounias  GRE  2016  25.0   164.0    62.0
# 1381  127483  Oleksandr Serhiyovych Vorobiov  UKR  2008  23.0   158.0    55.0
# 1453  132547                        Yang Wei  CHN  2008  28.0   160.0    54.0
# 1478  133931        Arthur Nabarrete Zanetti  BRA  2012  22.0   156.0    61.0
# 1480  133931        Arthur Nabarrete Zanetti  BRA  2016  26.0   156.0    61.0
#
#       Event   Medal
# 15    Rings  Bronze
# 264   Rings    Gold
# 268   Rings  Silver
# 862   Rings  Bronze
# 990   Rings    Gold
# 1381  Rings  Bronze
# 1453  Rings  Silver
# 1478  Rings    Gold
# 1480  Rings  Silver
