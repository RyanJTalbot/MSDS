# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Cleaning/USOPC/usopc_clean_women_olympic.csv')

# %%
df
# Out:
#                      Name Country Gender        Date Round Apparatus  Rank  \
# 0              HADI ABDUL     MAS      w  2021-07-25  qual        BB  76.0
# 1              HADI ABDUL     MAS      w  2021-07-25  qual        FX  64.0
# 2              HADI ABDUL     MAS      w  2021-07-25  qual        UE  74.0
# 3              HADI ABDUL     MAS      w  2021-07-25  qual        VT  72.0
# 4    Farah Ann ABDUL HADI     MAS      w  2021-07-25  qual        BB  76.0
# ..                    ...     ...    ...         ...   ...       ...   ...
# 753              JESUS de     FRA      w  2021-07-25  qual        VT  19.0
# 754               POL van     NED      w  2021-07-25  qual        BB  75.0
# 755               POL van     NED      w  2021-07-25  qual        FX  33.0
# 756               POL van     NED      w  2021-07-25  qual        UE  41.0
# 757               POL van     NED      w  2021-07-25  qual        VT  38.0
#
#      D_Score  E_Score  Penalty   Score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 758 entries, 0 to 757
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       758 non-null    object
#  1   Country    758 non-null    object
#  2   Gender     758 non-null    object
#  3   Date       758 non-null    object
#  4   Round      758 non-null    object
#  5   Apparatus  758 non-null    object
#  6   Rank       758 non-null    float64
#  7   D_Score    758 non-null    float64
#  8   E_Score    758 non-null    float64
#  9   Penalty    758 non-null    float64
#  10  Score      758 non-null    float64
# dtypes: float64(5), object(6)
# memory usage: 65.3+ KB

# %%
usa=df[df["Country"]=="USA"]

# %%
usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64 entries, 51 to 604
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       64 non-null     object
#  1   Country    64 non-null     object
#  2   Gender     64 non-null     object
#  3   Date       64 non-null     object
#  4   Round      64 non-null     object
#  5   Apparatus  64 non-null     object
#  6   Rank       64 non-null     float64
#  7   D_Score    64 non-null     float64
#  8   E_Score    64 non-null     float64
#  9   Penalty    64 non-null     float64
#  10  Score      64 non-null     float64
# dtypes: float64(5), object(6)
# memory usage: 6.0+ KB
