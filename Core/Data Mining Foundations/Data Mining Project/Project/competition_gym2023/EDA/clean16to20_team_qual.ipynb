# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../Cleaning/qual08to20/clean16to20_team_qual.csv')

# %%
df
# Out:
#                  Name Country  uneven_score  uneven_rank  bb_score  bb_rank  \
# 0        Simone Biles     USA        15.000         14.0    15.633      1.0
# 1         Aly Raisman     USA        14.733         22.0    14.833      7.0
# 2       Gabby Douglas     USA        15.766          3.0    14.833      7.0
# 3    Laurie Hernandez     USA         0.000          0.0    15.366      2.0
# 4      Madison Kocian     USA        15.866          1.0     0.000      0.0
# ..                ...     ...           ...          ...       ...      ...
# 103      Sanne Wevers     NED        11.733         69.0    13.866     14.0
# 104   Laura Bechdejú     ESP        12.700         56.0    12.666     45.0
# 105  Marina González     ESP        11.033         81.0    12.366     55.0
# 106      Alba Petisco     ESP        12.866         51.0    11.700     73.0
# 107       Roxana Popa     ESP        14.400         15.0    12.866     40.0
#
# ...
