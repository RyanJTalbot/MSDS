# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("../Cleaning/w_qual2020.csv")

# %%
df
# Out:
#                             Name Country  vault_rank  uneven_score  \
# 0                Lilia Akhaimova     ROC           7        12.900
# 1             Viktoria Listunova     ROC           0        14.766
# 2             Angelina Melnikova     ROC           9        14.933
# 3             Vladislava Urazova     ROC           0        14.866
# 4                   Simone Biles     USA           1        14.566
# 5                  Jordan Chiles     USA           0        12.866
# 6                     Sunisa Lee     USA           0        15.200
# 7                 Grace McCallum     USA           0        14.100
# 8                       Lu Yufei     CHN           0        14.700
# 9                      Ou Yushan     CHN           0        13.500
# 10                   Tang Xijing     CHN           0        14.433
# 11                     Zhang Jin     CHN           0        13.100
# 12                  Marine Boyer     FRA           0        10.400
# ...

# %%
sns.relplot(x="Country", y="total_score", data=df)

# %%
usa = df[df["Country"]=="USA"]

# %%
usa
# Out:
#              Name Country  vault_rank  uneven_score  uneven_rank  bb_score  \
# 4    Simone Biles     USA           1        14.566         10.0    14.066
# 5   Jordan Chiles     USA           0        12.866         52.0    11.566
# 6      Sunisa Lee     USA           0        15.200          2.0    14.200
# 7  Grace McCallum     USA           0        14.100         22.0    13.066
#
#    bb_rank  floor_score  floor_rank  total_score  total_rank  vault1_score  \
# 4      7.0       14.133         2.0       57.731           1        14.966
# 5     78.0       13.566        13.0       52.698          40        14.700
# 6      3.0       13.433        18.0       57.166           3        14.333
# 7     32.0       13.466        16.0       55.165          13        14.533
#
#    vault2_score  vault_avg_score
# 4          15.4           15.183
# 5           0.0            0.000
# 6           0.0            0.000
# 7           0.0            0.000

# %%
sns.relplot(x="Name", y="total_score", data=usa)

# %%
df[df["total_score"] > 56]
# Out:
#                   Name Country  vault_rank  uneven_score  uneven_rank  \
# 1   Viktoria Listunova     ROC           0        14.766          6.0
# 2   Angelina Melnikova     ROC           9        14.933          4.0
# 3   Vladislava Urazova     ROC           0        14.866          5.0
# 4         Simone Biles     USA           1        14.566         10.0
# 6           Sunisa Lee     USA           0        15.200          2.0
# 10         Tang Xijing     CHN           0        14.433         13.0
# 17        Nina Derwael     BEL           0        15.366          1.0
#
#     bb_score  bb_rank  floor_score  floor_rank  total_score  total_rank  \
# 1     13.866     13.0       14.000         6.0       56.932           6
# 2     13.733     17.0       14.000         7.0       57.132           4
# 3     14.000      8.0       13.633        10.0       57.099           5
# 4     14.066      7.0       14.133         2.0       57.731           1
# ...

# %%
df["total_rank"].unique()
# Out:
# array([28,  6,  4,  5,  1, 40,  3, 13, 14,  0,  8, 15, 60, 10, 25, 18, 35,
#         7, 42, 26, 17, 12, 48, 33, 20, 34, 27, 39, 49, 23, 41, 31, 50, 19,
#        45, 24, 22, 46, 58, 36, 47, 32, 53, 63, 57, 21])

# %%
df_sorted = df.sort_values(by='total_rank')
df_sorted
# Out:
#                             Name Country  vault_rank  uneven_score  \
# 26               Vanessa Ferrari     ITA           0         0.000
# 43                  Sanne Wevers     NED           0        11.733
# 9                      Ou Yushan     CHN           0        13.500
# 4                   Simone Biles     USA           1        14.566
# 6                     Sunisa Lee     USA           0        15.200
# 2             Angelina Melnikova     ROC           9        14.933
# 3             Vladislava Urazova     ROC           0        14.866
# 1             Viktoria Listunova     ROC           0        14.766
# 17                  Nina Derwael     BEL           0        15.366
# 10                   Tang Xijing     CHN           0        14.433
# 13  Mélanie de Jesus dos Santos     FRA           0        14.566
# 21              Jessica Gadirova     GBR          13        13.800
# 7                 Grace McCallum     USA           0        14.100
# ...

# %%
df['uneven_score'].max()
# Out:
# 15.366

# %%
df['uneven_score'].nlargest(3)
# Out:
# 17    15.366
# 6     15.200
# 2     14.933
# Name: uneven_score, dtype: float64

# %%
df.loc[df['uneven_score'].idxmax()]
# Out:
# Name               Nina Derwael
# Country                     BEL
# vault_rank                    0
# uneven_score             15.366
# uneven_rank                 1.0
# bb_score                 13.766
# bb_rank                    15.0
# floor_score              13.566
# floor_rank                 12.0
# total_score              56.598
# total_rank                    7
# vault1_score               13.9
# vault2_score                0.0
# vault_avg_score             0.0
# Name: 17, dtype: object

# %%
df['bb_score'].nlargest(3)
# Out:
# 10    14.333
# 6     14.200
# 8     14.100
# Name: bb_score, dtype: float64

# %%
df.loc[df['bb_score'].idxmax()]
# Out:
# Name               Tang Xijing
# Country                    CHN
# vault_rank                   0
# uneven_score            14.433
# uneven_rank               13.0
# bb_score                14.333
# bb_rank                    2.0
# floor_score             13.366
# floor_rank                20.0
# total_score             56.432
# total_rank                   8
# vault1_score              14.3
# vault2_score               0.0
# vault_avg_score            0.0
# Name: 10, dtype: object

# %%
df['floor_score'].nlargest(3)
# Out:
# 26    14.166
# 4     14.133
# 21    14.033
# Name: floor_score, dtype: float64

# %%
df.loc[df['floor_score'].idxmax()]
# Out:
# Name               Vanessa Ferrari
# Country                        ITA
# vault_rank                       0
# uneven_score                   0.0
# uneven_rank                    0.0
# bb_score                      12.5
# bb_rank                       52.0
# floor_score                 14.166
# floor_rank                     1.0
# total_score                    0.0
# total_rank                       0
# vault1_score                  14.2
# vault2_score                   0.0
# vault_avg_score                0.0
# Name: 26, dtype: object

# %%
df['vault1_score'].nlargest(3)
# Out:
# 4     14.966
# 14    14.966
# 38    14.966
# Name: vault1_score, dtype: float64

# %%
df.loc[df['vault1_score'].idxmax()]
# Out:
# Name               Simone Biles
# Country                     USA
# vault_rank                    1
# uneven_score             14.566
# uneven_rank                10.0
# bb_score                 14.066
# bb_rank                     7.0
# floor_score              14.133
# floor_rank                  2.0
# total_score              57.731
# total_rank                    1
# vault1_score             14.966
# vault2_score               15.4
# vault_avg_score          15.183
# Name: 4, dtype: object

# %%
df['vault2_score'].nlargest(3)
# Out:
# 4    15.400
# 2    14.766
# 0    14.633
# Name: vault2_score, dtype: float64

# %%
df.loc[df['vault2_score'].idxmax()]
# Out:
# Name               Simone Biles
# Country                     USA
# vault_rank                    1
# uneven_score             14.566
# uneven_rank                10.0
# bb_score                 14.066
# bb_rank                     7.0
# floor_score              14.133
# floor_rank                  2.0
# total_score              57.731
# total_rank                    1
# vault1_score             14.966
# vault2_score               15.4
# vault_avg_score          15.183
# Name: 4, dtype: object

# %%
df['vault_avg_score'].nlargest(3)
# Out:
# 4     15.183
# 0     14.699
# 38    14.699
# Name: vault_avg_score, dtype: float64

# %%
df.loc[df['vault_avg_score'].idxmax()]
# Out:
# Name               Simone Biles
# Country                     USA
# vault_rank                    1
# uneven_score             14.566
# uneven_rank                10.0
# bb_score                 14.066
# bb_rank                     7.0
# floor_score              14.133
# floor_rank                  2.0
# total_score              57.731
# total_rank                    1
# vault1_score             14.966
# vault2_score               15.4
# vault_avg_score          15.183
# Name: 4, dtype: object

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Name', 'Country', 'vault_rank', 'uneven_score', 'uneven_rank',
#        'bb_score', 'bb_rank', 'floor_score', 'floor_rank', 'total_score',
#        'total_rank', 'vault1_score', 'vault2_score', 'vault_avg_score'],
#       dtype='object')

# %%
scores=df[['uneven_score','bb_score','floor_score',
 'vault1_score', 'vault2_score', 'vault_avg_score']]

# %%
scores.plot()
# Out:
# <AxesSubplot:>
