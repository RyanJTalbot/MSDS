# %%
import pandas as pd
import numpy as np

# %%
df16 = pd.read_csv('../../Cleaning/olympics/mens/clean2016Olympics_Men\'s_artistic_team_all-around_Individuals.csv')
df12 = pd.read_csv('../../Cleaning/olympics/mens/clean2012Olympics_Men\'s_artistic_team_all-around_Individuals.csv')
df20 = pd.read_csv('../../Cleaning/olympics/mens/clean2020Olympics_Men\'s_artistic_team_all-around_Individuals.csv')

# %%
df16.head()
# Out:
#              Team country      fx  fx_rank      ph  ph_rank      sr  sr_rank  \
# 0  Kōhei Uchimura     JPN  15.600      2.0  15.100      5.0  14.800     13.0
# 1     Ryōhei Katō     JPN  15.466      3.0  14.933      8.0   0.000      0.0
# 2   Yūsuke Tanaka     JPN   0.000      0.0   0.000      0.0  14.933      7.0
# 3    Kenzō Shirai     JPN  16.133      1.0   0.000      0.0   0.000      0.0
# 4   Koji Yamamuro     JPN   0.000      0.0  13.900     21.0  14.866      8.0
#
#        vt  vt_rank      pb  pb_rank      hb  hb_rank
# 0  15.566      3.0  15.366     12.0  15.166      4.0
# 1  15.000     17.0  15.500      9.0  15.066      8.0
# 2   0.000      0.0  15.900      2.0  15.166      4.0
# 3  15.633      1.0   0.000      0.0   0.000      0.0
# 4   0.000      0.0   0.000      0.0   0.000      0.0

# %%
df12.head()
# Out:
#               Team country      fx  fx_Rank      ph  ph_Rank      sr  sr_Rank  \
# 0      Chen Yibing     CHN   0.000      0.0  14.733     11.0  15.800      2.0
# 1         Feng Zhe     CHN  14.400     21.0   0.000      0.0  14.533     20.0
# 2      Guo Weiyang     CHN   0.000      0.0  14.600     14.0  14.566     19.0
# 3  Zhang Chenglong     CHN  14.900     14.0  14.500     16.0   0.000      0.0
# 4          Zou Kai     CHN  15.833      1.0   0.000      0.0   0.000      0.0
#
#        vt  vt_Rank     pb  pb_Rank      hb  hb_Rank
# 0   0.000      0.0   0.00      0.0   0.000      0.0
# 1  16.216      4.0  15.95      1.0  15.000     14.0
# 2   0.000      0.0  15.20     13.0   0.000      0.0
# 3  16.200      5.0  15.60      2.0  15.666      6.0
# 4  15.900     12.0   0.00      0.0  16.400      1.0

# %%
df20.head()
# Out:
#                Team country      fx      ph      sr      vt      pb      hb
# 0    Denis Ablyazin     ROC  13.900   0.000  15.033  14.866   0.000   0.000
# 1  David Belyavskiy     ROC   0.000  14.841   0.000   0.000  15.333  14.166
# 2   Artur Dalaloyan     ROC  14.066  13.833  14.666  14.933  14.600  13.933
# 3   Nikita Nagornyy     ROC  14.666  14.466  14.700  14.966  15.166  14.366
# 4   Daiki Hashimoto     JPN  14.600  14.800  13.833  14.833   0.000  15.100

# %%
df20.head()
# Out:
#                Team country      fx      ph      sr      vt      pb      hb
# 0    Denis Ablyazin     ROC  13.900   0.000  15.033  14.866   0.000   0.000
# 1  David Belyavskiy     ROC   0.000  14.841   0.000   0.000  15.333  14.166
# 2   Artur Dalaloyan     ROC  14.066  13.833  14.666  14.933  14.600  13.933
# 3   Nikita Nagornyy     ROC  14.666  14.466  14.700  14.966  15.166  14.366
# 4   Daiki Hashimoto     JPN  14.600  14.800  13.833  14.833   0.000  15.100

# %%
df20['year'] = 2020

# %%
df16['year'] = 2016

# %%
df12['year'] = 2012

# %%
dff =df20.copy()

# %%
dff['fx_rank'] = dff['fx'].rank(ascending=False).astype(int)

# %%
dff['ph_rank'] = dff['ph'].rank(ascending=False).astype(int)

# %%
dff['sr_rank'] = dff['sr'].rank(ascending=False).astype(int)

# %%
dff['vt_rank'] = dff['vt'].rank(ascending=False).astype(int)

# %%
dff['pb_rank'] = dff['pb'].rank(ascending=False).astype(int)

# %%
dff['hb_rank'] = dff['hb'].rank(ascending=False).astype(int)

# %%
dff.head()
# Out:
#                Team country      fx      ph      sr      vt      pb      hb  \
# 0    Denis Ablyazin     ROC  13.900   0.000  15.033  14.866   0.000   0.000
# 1  David Belyavskiy     ROC   0.000  14.841   0.000   0.000  15.333  14.166
# 2   Artur Dalaloyan     ROC  14.066  13.833  14.666  14.933  14.600  13.933
# 3   Nikita Nagornyy     ROC  14.666  14.466  14.700  14.966  15.166  14.366
# 4   Daiki Hashimoto     JPN  14.600  14.800  13.833  14.833   0.000  15.100
#
#    year  fx_rank  ph_rank  sr_rank  vt_rank  pb_rank  hb_rank
# 0  2020       14       28        1        4       28       28
# 1  2020       28        3       28       28        3       12
# 2  2020       10       16        4        3       17       16
# 3  2020        1        8        3        2        5        6
# 4  2020        3        4       14        6       28        1

# %%
dff.columns
# Out:
# Index(['Team', 'country', 'fx', 'ph', 'sr', 'vt', 'pb', 'hb', 'year',
#        'fx_rank', 'ph_rank', 'sr_rank', 'vt_rank', 'pb_rank', 'hb_rank'],
#       dtype='object')

# %%
desired_order =['Team', 'country', 'fx','fx_rank', 'ph', 'ph_rank',
                'sr', 'sr_rank','vt','vt_rank',  'pb', 'pb_rank','hb','hb_rank', 'year']

# Reorder the columns
dff = dff[desired_order]

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Team     32 non-null     object
#  1   country  32 non-null     object
#  2   fx       32 non-null     float64
#  3   fx_rank  32 non-null     int64
#  4   ph       32 non-null     float64
#  5   ph_rank  32 non-null     int64
#  6   sr       32 non-null     float64
#  7   sr_rank  32 non-null     int64
#  8   vt       32 non-null     float64
#  9   vt_rank  32 non-null     int64
#  10  pb       32 non-null     float64
#  11  pb_rank  32 non-null     int64
#  12  hb       32 non-null     float64
#  13  hb_rank  32 non-null     int64
#  14  year     32 non-null     int64
# dtypes: float64(6), int64(7), object(2)
# memory usage: 3.9+ KB

# %%
df20 = dff.copy()

# %%
df12.columns
# Out:
# Index(['Team', 'country', 'fx', 'fx_Rank', 'ph', 'ph_Rank', 'sr', 'sr_Rank',
#        'vt', 'vt_Rank', 'pb', 'pb_Rank', 'hb', 'hb_Rank', 'year'],
#       dtype='object')

# %%
column_mapping = {'fx_Rank': 'fx_rank','ph_Rank': 'ph_rank','sr_Rank': 'sr_rank',
                  'vt_Rank': 'vt_rank', 'pb_Rank': 'pb_rank', 'hb_Rank': 'hb_rank'}

# Rename the columns using the rename() method
df12.rename(columns=column_mapping, inplace=True)

# %%
df12
# Out:
#                    Team country      fx  fx_rank       ph  ph_rank      sr  \
# 0           Chen Yibing     CHN   0.000      0.0  14.7330     11.0  15.800
# 1              Feng Zhe     CHN  14.400     21.0   0.0000      0.0  14.533
# 2           Guo Weiyang     CHN   0.000      0.0  14.6000     14.0  14.566
# 3       Zhang Chenglong     CHN  14.900     14.0  14.5000     16.0   0.000
# 4               Zou Kai     CHN  15.833      1.0   0.0000      0.0   0.000
# 5           Ryōhei Katō     JPN  15.300      8.0  14.7660      9.0   0.000
# 6       Kazuhito Tanaka     JPN  13.733     24.0  13.4330     19.0   0.000
# 7         Yusuke Tanaka     JPN   0.000      0.0   0.0000      0.0  15.200
# 8        Kōhei Uchimura     JPN  15.700      2.0  14.1661     18.0  15.133
# 9         Koji Yamamuro     JPN   0.000      0.0   0.0000      0.0  15.366
# 10           Sam Oldham     GBR   0.000      0.0   0.0000      0.0  14.033
# ...

# %%
combined_df = pd.concat([df12, df16, df20], axis=0)

# Reset the index if needed
combined_df.reset_index(drop=True, inplace=True)

# %%
combined_df
# Out:
#                 Team country      fx  fx_rank      ph  ph_rank      sr  \
# 0        Chen Yibing     CHN   0.000      0.0  14.733     11.0  15.800
# 1           Feng Zhe     CHN  14.400     21.0   0.000      0.0  14.533
# 2        Guo Weiyang     CHN   0.000      0.0  14.600     14.0  14.566
# 3    Zhang Chenglong     CHN  14.900     14.0  14.500     16.0   0.000
# 4            Zou Kai     CHN  15.833      1.0   0.000      0.0   0.000
# ..               ...     ...     ...      ...     ...      ...     ...
# 106  Yevgen Yudenkov     UKR  13.966     13.0  13.533     20.0  13.700
# 107     Lukas Dauser     GER  11.500     23.0  12.100     24.0   0.000
# 108      Nils Dunkel     GER   0.000     28.0  13.700     19.0  13.600
# 109   Philipp Herder     GER  11.866     22.0   0.000     28.0  13.200
# 110     Andreas Toba     GER  11.466     24.0  13.400     21.0  13.533
#
#      sr_rank      vt  vt_rank      pb  pb_rank      hb  hb_rank  year
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Team     111 non-null    object
#  1   country  111 non-null    object
#  2   fx       111 non-null    float64
#  3   fx_rank  111 non-null    float64
#  4   ph       111 non-null    float64
#  5   ph_rank  111 non-null    float64
#  6   sr       111 non-null    float64
#  7   sr_rank  111 non-null    float64
#  8   vt       111 non-null    float64
#  9   vt_rank  111 non-null    float64
#  10  pb       111 non-null    float64
#  11  pb_rank  111 non-null    float64
#  12  hb       111 non-null    float64
#  13  hb_rank  111 non-null    float64
#  14  year     111 non-null    int64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 13.1+ KB

# %%
df = combined_df.copy()

# %%
fx3 = df[df['fx_rank'].isin([1.0, 2.0, 3.0])]

# %%
fx3
# Out:
#                Team country      fx  fx_rank       ph  ph_rank      sr  \
# 4           Zou Kai     CHN  15.833      1.0   0.0000      0.0   0.000
# 8    Kōhei Uchimura     JPN  15.700      2.0  14.1661     18.0  15.133
# 11    Daniel Purvis     GBR  15.533      3.0  14.7330     11.0  14.600
# 40   Kōhei Uchimura     JPN  15.600      2.0  15.1000      5.0  14.800
# 41      Ryōhei Katō     JPN  15.466      3.0  14.9330      8.0   0.000
# 43     Kenzō Shirai     JPN  16.133      1.0   0.0000      0.0   0.000
# 82  Nikita Nagornyy     ROC  14.666      1.0  14.4660      8.0  14.700
# 83  Daiki Hashimoto     JPN  14.600      3.0  14.8000      4.0  13.833
# 85  Takeru Kitazono     JPN  14.600      3.0  14.2000     10.0   0.000
# 89     Xiao Ruoteng     CHN  14.600      3.0  14.1660     12.0  14.366
#
#     sr_rank      vt  vt_rank      pb  pb_rank      hb  hb_rank  year
# 4       0.0  15.900     12.0   0.000      0.0  16.400      1.0  2012
# ...

# %%
ph3 = df[df['ph_rank'].isin([1.0, 2.0, 3.0])]

# %%
ph3
# Out:
#                 Team country      fx  fx_rank      ph  ph_rank      sr  \
# 12       Louis Smith     GBR   0.000      0.0  15.966      1.0   0.000
# 14      Max Whitlock     GBR  15.166     11.0  15.233      3.0   0.000
# 39   Cyril Tommasone     FRA  14.533     20.0  15.466      2.0   0.000
# 45  David Belyavskiy     RUS  14.666     13.0  15.500      3.0   0.000
# 55      Max Whitlock     GBR  15.400      4.0  15.991      1.0  14.500
# 77    Oleg Verniaiev     UKR   0.000      0.0  15.633      2.0   0.000
# 80  David Belyavskiy     ROC   0.000     28.0  14.841      3.0   0.000
# 88           Sun Wei     CHN  14.366      7.0  15.000      1.0  14.233
# 94      Max Whitlock     GBR   0.000     28.0  14.966      2.0   0.000
#
#     sr_rank      vt  vt_rank      pb  pb_rank      hb  hb_rank  year
# 12      0.0   0.000      0.0   0.000      0.0   0.000      0.0  2012
# 14      0.0  15.666     16.0  14.800     19.0   0.000      0.0  2012
# ...

# %%
sr3 = df[df['sr_rank'].isin([1.0, 2.0, 3.0])]

# %%
sr3
# Out:
#                   Team country      fx  fx_rank      ph  ph_rank      sr  \
# 0          Chen Yibing     CHN   0.000      0.0  14.733     11.0  15.800
# 25      Denis Ablyazin     RUS  15.475      4.0   0.000      0.0  15.616
# 26  Aleksandr Balandin     RUS   0.000      0.0   0.000      0.0  15.816
# 47      Denis Ablyazin     RUS  15.100      8.0   0.000      0.0  15.700
# 54            Liu Yang     CHN   0.000      0.0   0.000      0.0  15.833
# 69      Arthur Zanetti     BRA   0.000      0.0   0.000      0.0  15.566
# 79      Denis Ablyazin     ROC  13.900     14.0   0.000     28.0  15.033
# 82     Nikita Nagornyy     ROC  14.666      1.0  14.466      8.0  14.700
# 90        Zou Jingyuan     CHN   0.000     28.0  14.800      4.0  15.000
#
#     sr_rank      vt  vt_rank      pb  pb_rank      hb  hb_rank  year
# 0       2.0   0.000      0.0   0.000      0.0   0.000      0.0  2012
# 25      3.0  16.400      2.0   0.000      0.0   0.000      0.0  2012
# ...

# %%
vt3 = df[df['vt_rank'].isin([1.0, 2.0, 3.0])]

# %%
vt3
# Out:
#                Team country      fx  fx_rank      ph  ph_rank      sr  \
# 13  Kristian Thomas     GBR  15.433      6.0   0.000      0.0  14.433
# 19   Oleg Verniaiev     UKR  14.866     16.0   0.000      0.0   0.000
# 25   Denis Ablyazin     RUS  15.475      4.0   0.000      0.0  15.616
# 40   Kōhei Uchimura     JPN  15.600      2.0  15.100      5.0  14.800
# 43     Kenzō Shirai     JPN  16.133      1.0   0.000      0.0   0.000
# 47   Denis Ablyazin     RUS  15.100      8.0   0.000      0.0  15.700
# 81  Artur Dalaloyan     ROC  14.066     10.0  13.833     16.0  14.666
# 82  Nikita Nagornyy     ROC  14.666      1.0  14.466      8.0  14.700
# 86  Wataru Tanigawa     JPN  14.500      6.0   0.000     28.0  14.500
#
#     sr_rank      vt  vt_rank      pb  pb_rank      hb  hb_rank  year
# 13     22.0  16.550      1.0   0.000      0.0  15.200     10.0  2012
# 19      0.0  16.266      3.0  15.600      2.0  14.466     20.0  2012
# ...

# %%
pb3 = df[df['pb_rank'].isin([1.0, 2.0, 3.0])]

# %%
pb3
# Out:
#                  Team country      fx  fx_rank      ph  ph_rank      sr  \
# 1            Feng Zhe     CHN  14.400     21.0   0.000      0.0  14.533
# 3     Zhang Chenglong     CHN  14.900     14.0  14.500     16.0   0.000
# 19     Oleg Verniaiev     UKR  14.866     16.0   0.000      0.0   0.000
# 42      Yūsuke Tanaka     JPN   0.000      0.0   0.000      0.0  14.933
# 51        Lin Chaopan     CHN  14.833     12.0  14.900      9.0   0.000
# 53            You Hao     CHN   0.000      0.0  14.400     16.0  14.800
# 77     Oleg Verniaiev     UKR   0.000      0.0  15.633      2.0   0.000
# 80   David Belyavskiy     ROC   0.000     28.0  14.841      3.0   0.000
# 90       Zou Jingyuan     CHN   0.000     28.0  14.800      4.0  15.000
# 107      Lukas Dauser     GER  11.500     23.0  12.100     24.0   0.000
#
#      sr_rank      vt  vt_rank      pb  pb_rank      hb  hb_rank  year
# 1       20.0  16.216      4.0  15.950      1.0  15.000     14.0  2012
# ...

# %%
hb3 = df[df['hb_rank'].isin([1.0, 2.0, 3.0])]

# %%
hb3
# Out:
#                 Team country      fx  fx_rank      ph  ph_rank      sr  \
# 4            Zou Kai     CHN  15.833      1.0   0.000      0.0   0.000
# 7      Yusuke Tanaka     JPN   0.000      0.0   0.000      0.0  15.200
# 31  Fabian Hambüchen     GER  15.066     12.0   0.000      0.0  14.858
# 52   Zhang Chenglong     CHN  15.133      6.0   0.000      0.0   0.000
# 56       Nile Wilson     GBR  14.666     13.0   0.000      0.0  15.100
# 73  Fabian Hambüchen     GER  14.666     13.0   0.000      0.0   0.000
# 83   Daiki Hashimoto     JPN  14.600      3.0  14.800      4.0  13.833
# 95      Brody Malone     USA   0.000     28.0  14.000     13.0  14.100
# 96       Sam Mikulak     USA  12.133     21.0  13.733     18.0   0.000
#
#     sr_rank      vt  vt_rank      pb  pb_rank      hb  hb_rank  year
# 4       0.0  15.900     12.0   0.000      0.0  16.400      1.0  2012
# 7       8.0   0.000      0.0  15.500      5.0  16.000      3.0  2012
# ...

# %%
combined_dff = pd.concat([hb3, fx3, ph3, sr3, vt3, pb3], axis=0)

# %%
combined_dff.head()
# Out:
#                 Team country      fx  fx_rank   ph  ph_rank      sr  sr_rank  \
# 4            Zou Kai     CHN  15.833      1.0  0.0      0.0   0.000      0.0
# 7      Yusuke Tanaka     JPN   0.000      0.0  0.0      0.0  15.200      8.0
# 31  Fabian Hambüchen     GER  15.066     12.0  0.0      0.0  14.858     14.0
# 52   Zhang Chenglong     CHN  15.133      6.0  0.0      0.0   0.000      0.0
# 56       Nile Wilson     GBR  14.666     13.0  0.0      0.0  15.100      5.0
#
#         vt  vt_rank      pb  pb_rank      hb  hb_rank  year
# 4   15.900     12.0   0.000      0.0  16.400      1.0  2012
# 7    0.000      0.0  15.500      5.0  16.000      3.0  2012
# 31  15.633     17.0  15.400      9.0  16.166      2.0  2012
# 52  15.400      5.0   0.000      0.0  15.566      3.0  2016
# 56   0.000      0.0  15.133     13.0  15.666      1.0  2016

# %%
combined_dff["country"].value_counts()
# Out:
# country
# CHN    13
# JPN    12
# GBR     7
# ROC     7
# RUS     6
# UKR     4
# GER     3
# USA     2
# FRA     1
# BRA     1
# Name: count, dtype: int64

# %%
combined_dff["Team"].value_counts()
# Out:
# Team
# Denis Ablyazin        5
# Oleg Verniaiev        4
# Kōhei Uchimura        3
# David Belyavskiy      3
# Max Whitlock          3
# Nikita Nagornyy       3
# Zou Kai               2
# Zou Jingyuan          2
# Kenzō Shirai          2
# Daiki Hashimoto       2
# Zhang Chenglong       2
# Fabian Hambüchen      2
# Feng Zhe              1
# Wataru Tanigawa       1
# Yūsuke Tanaka         1
# Lin Chaopan           1
# Artur Dalaloyan       1
# Kristian Thomas       1
# You Hao               1
# Arthur Zanetti        1
# Liu Yang              1
# Aleksandr Balandin    1
# Cyril Tommasone       1
# Chen Yibing           1
# Sun Wei               1
# Yusuke Tanaka         1
# Louis Smith           1
# Xiao Ruoteng          1
# Takeru Kitazono       1
# Ryōhei Katō           1
# Daniel Purvis         1
# Sam Mikulak           1
# Brody Malone          1
# Nile Wilson           1
# Lukas Dauser          1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dff = combined_dff.copy()

# %%
dff.head()
# Out:
#                 Team country      fx  fx_rank   ph  ph_rank      sr  sr_rank  \
# 4            Zou Kai     CHN  15.833      1.0  0.0      0.0   0.000      0.0
# 7      Yusuke Tanaka     JPN   0.000      0.0  0.0      0.0  15.200      8.0
# 31  Fabian Hambüchen     GER  15.066     12.0  0.0      0.0  14.858     14.0
# 52   Zhang Chenglong     CHN  15.133      6.0  0.0      0.0   0.000      0.0
# 56       Nile Wilson     GBR  14.666     13.0  0.0      0.0  15.100      5.0
#
#         vt  vt_rank      pb  pb_rank      hb  hb_rank  year
# 4   15.900     12.0   0.000      0.0  16.400      1.0  2012
# 7    0.000      0.0  15.500      5.0  16.000      3.0  2012
# 31  15.633     17.0  15.400      9.0  16.166      2.0  2012
# 52  15.400      5.0   0.000      0.0  15.566      3.0  2016
# 56   0.000      0.0  15.133     13.0  15.666      1.0  2016

# %%
# Box plot of 'bb' by 'year'
plt.figure(figsize=(8, 6))
sns.boxplot(data=dff, x='year', y='fx')
plt.title('Box Plot of total by Year')
plt.xlabel('Year')
plt.ylabel('fx')
plt.show()

# %%
# Box plot of 'bb' by 'year'
plt.figure(figsize=(8, 6))
sns.boxplot(data=dff, x='year', y='ph')
plt.title('Box Plot of total by Year')
plt.xlabel('Year')
plt.ylabel('ph')
plt.show()
