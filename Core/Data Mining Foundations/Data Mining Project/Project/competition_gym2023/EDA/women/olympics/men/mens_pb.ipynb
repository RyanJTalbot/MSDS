# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../../Cleaning/olympics/mens/cleaned_mens2012to2020PB")

# %%
df
# Out:
#     Rank               Gymnast Nation  D Score  E Score  Pen.   Total  year
# 0      1              Feng Zhe    CHN      7.0    8.966   0.0  15.966  2012
# 1      2         Marcel Nguyen    GER      6.8    9.000   0.0  15.800  2012
# 2      3        Hamilton Sabot    FRA      6.7    8.866   0.0  15.566  2012
# 3      4       Kazuhito Tanaka    JPN      8.8    8.800   0.0  15.500  2012
# 4      5         Daniel Corral    MEX      6.6    8.733   0.0  15.333  2012
# 5      6          Emin Garibov    RUS      6.5    8.800   0.0  15.300  2012
# 6      6  Vasileios Tsolakidis    GRE      6.5    8.800   0.0  15.300  2012
# 7      8         Yusuke Tanaka    JPN      6.4    8.700   0.0  15.100  2012
# 8      9       Zhang Chenglong    CHN      6.3    7.508   0.0  13.808  2012
# 9      1        Oleg Verniaiev    UKR      7.1    8.941   0.0  16.041  2016
# 10     2          Danell Leyva    USA      6.9    9.000   0.0  15.900  2016
# 11     3      David Belyavskiy    RUS      6.9    8.883   0.0  15.783  2016
# 12     4            Deng Shudi    CHN      7.2    8.566   0.0  15.766  2016
# 13     5      Manrique Larduet    CUB      7.1    8.525   0.0  15.625  2016
# 14     6        Andrei Muntean    RUM      6.6    9.000   0.0  15.600  2016
# 15     7           Ryōhei Katō    JPN      6.8    8.433   0.0  15.233  2016
# 16     8               You Hao    CHN      7.4    7.433   0.0  14.833  2016
# 17     1          Zou Jingyuan    CHN      6.9    9.333   0.0  16.233  2020
# 18     2          Lukas Dauser    GER      6.7    9.000   0.0  15.700  2020
# 19     3         Ferhat Arıcan    TUR      7.0    8.633   0.0  15.633  2020
# 20     4               You Hao    CHN      6.9    8.566   0.0  15.466  2020
# 21     5      David Belyavskiy    ROC      6.6    8.600   0.0  15.200  2020
# 22     6           Sam Mikulak    USA      6.4    8.600   0.0  15.000  2020
# 23     7        Petro Pakhniuk    UKR      6.1    8.433   0.0  14.533  2020
# 24     8            Joe Fraser    GBR      6.1    8.400   0.0  14.500  2020

# %%
medals = df[df['Rank'].isin([1.0, 2.0, 3.0])]

# %%
df = medals.copy()

# %%
df["Nation"].value_counts()
# Out:
# Nation
# CHN    2
# GER    2
# FRA    1
# UKR    1
# USA    1
# RUS    1
# TUR    1
# Name: count, dtype: int64

# %%
# Box plot of 'bb' by 'year'
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='year', y='Total')
plt.title('Box Plot of Total by Year')
plt.xlabel('Year')
plt.ylabel('Total')
plt.show()
