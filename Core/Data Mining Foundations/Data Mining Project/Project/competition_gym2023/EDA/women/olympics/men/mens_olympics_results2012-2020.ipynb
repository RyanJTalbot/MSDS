# %%
import pandas as pd
import numpy as np

# %%
df20 = pd.read_csv('../../Cleaning/olympics/mens/clean2020Olympics_Men\'s_artistic_team_all-around.csv')
df16 = pd.read_csv('../../Cleaning/olympics/mens/clean2016Olympics_Men\'s_artistic_team_all-around.csv')
df12 = pd.read_csv('../../Cleaning/olympics/mens/clean2012Olympics_Men\'s_artistic_team_all-around.csv')

# %%
df20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 15 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Rank     8 non-null      float64
#  1   Team     8 non-null      object
#  2   fx       8 non-null      float64
#  3   fx_rank  8 non-null      int64
#  4   ph       8 non-null      float64
#  5   ph_rank  8 non-null      int64
#  6   sr       8 non-null      float64
#  7   sr_rank  8 non-null      int64
#  8   vt       8 non-null      float64
#  9   vt_rank  8 non-null      int64
#  10  pb       8 non-null      float64
#  11  pb_rank  8 non-null      int64
#  12  hb       8 non-null      float64
#  13  hb_rank  8 non-null      int64
#  14  Total    8 non-null      float64
# dtypes: float64(8), int64(6), object(1)
# memory usage: 1.1+ KB

# %%
df20["year"] = 2020

# %%
df20.rename(columns={'Rank': 'total_Rank'}, inplace=True)

# %%
df16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Team        8 non-null      object
#  1   fx          8 non-null      float64
#  2   fx_rank     8 non-null      float64
#  3   ph          8 non-null      float64
#  4   ph_rank     8 non-null      float64
#  5   sr          8 non-null      float64
#  6   sr_rank     8 non-null      float64
#  7   vt          8 non-null      float64
#  8   vt_rank     8 non-null      float64
#  9   pb          8 non-null      float64
#  10  pb_rank     8 non-null      float64
#  11  hb          8 non-null      float64
#  12  hb_rank     8 non-null      float64
#  13  total       8 non-null      float64
#  14  total_rank  8 non-null      float64
# dtypes: float64(14), object(1)
# memory usage: 1.1+ KB

# %%
df16["year"] = 2016

# %%
df16.head()
# Out:
#             Team      fx  fx_rank      ph  ph_rank      sr  sr_rank      vt  \
# 0          Japan  47.199      1.0  43.933      4.0  44.599      3.0  46.199
# 1         Russia  44.766      3.0  45.299      2.0  45.432      1.0  46.033
# 2          China  43.799      4.0  44.258      3.0  45.233      2.0  45.000
# 3  Great Britain  45.099      2.0  45.623      1.0  44.066      6.0  45.399
# 4  United States  43.757      5.0  43.699      5.0  44.465      4.0  45.865
#
#    vt_rank      pb  pb_rank      hb  hb_rank    total  total_rank  year
# 0      1.0  46.766      2.0  45.398      1.0  274.094         1.0  2016
# 1      2.0  46.033      4.0  43.890      6.0  271.453         2.0  2016
# 2      6.0  47.866      1.0  44.966      3.0  271.122         3.0  2016
# 3      4.0  44.566      6.0  44.999      2.0  269.752         4.0  2016
# 4      3.0  46.333      3.0  44.441      5.0  268.560         5.0  2016

# %%
df12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Team        8 non-null      object
#  1   fx          8 non-null      float64
#  2   fx_Rank     8 non-null      float64
#  3   ph          8 non-null      float64
#  4   ph_Rank     8 non-null      float64
#  5   sr          8 non-null      float64
#  6   sr_Rank     8 non-null      float64
#  7   vt          8 non-null      float64
#  8   vt_Rank     8 non-null      float64
#  9   pb          8 non-null      float64
#  10  pb_Rank     8 non-null      float64
#  11  hb          8 non-null      float64
#  12  hb_Rank     8 non-null      float64
#  13  tota;       8 non-null      float64
#  14  total_Rank  8 non-null      float64
# dtypes: float64(14), object(1)
# memory usage: 1.1+ KB

# %%
df12["year"] = 2012

# %%
df16.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Team        8 non-null      object
#  1   fx          8 non-null      float64
#  2   fx_rank     8 non-null      float64
#  3   ph          8 non-null      float64
#  4   ph_rank     8 non-null      float64
#  5   sr          8 non-null      float64
#  6   sr_rank     8 non-null      float64
#  7   vt          8 non-null      float64
#  8   vt_rank     8 non-null      float64
#  9   pb          8 non-null      float64
#  10  pb_rank     8 non-null      float64
#  11  hb          8 non-null      float64
#  12  hb_rank     8 non-null      float64
#  13  total       8 non-null      float64
#  14  total_rank  8 non-null      float64
#  15  year        8 non-null      int64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
df12.rename(columns={'tota;': 'total'}, inplace=True)

# %%
df12.rename(columns={'fx_Rank': 'fx_rank', 'ph_Rank':'ph_rank', 'sr_Rank': 'sr_rank',
                    'vt_Rank': 'vt_rank', 'pb_Rank':'pb_rank', 'hb_Rank':'hb_rank',
                    'total_Rank':'total_rank'}, inplace=True)

# %%
df12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Team        8 non-null      object
#  1   fx          8 non-null      float64
#  2   fx_rank     8 non-null      float64
#  3   ph          8 non-null      float64
#  4   ph_rank     8 non-null      float64
#  5   sr          8 non-null      float64
#  6   sr_rank     8 non-null      float64
#  7   vt          8 non-null      float64
#  8   vt_rank     8 non-null      float64
#  9   pb          8 non-null      float64
#  10  pb_rank     8 non-null      float64
#  11  hb          8 non-null      float64
#  12  hb_rank     8 non-null      float64
#  13  total       8 non-null      float64
#  14  total_rank  8 non-null      float64
#  15  year        8 non-null      int64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 1.1+ KB

# %%
df20.rename(columns={'total_Rank': 'total_rank'}, inplace=True)

# %%
df20.rename(columns={'Total': 'total'}, inplace=True)

# %%
combined_df = pd.concat([df12, df16, df20], axis=0, ignore_index=True)

# %%
combined_df
# Out:
#              Team      fx  fx_rank      ph  ph_rank      sr  sr_rank      vt  \
# 0           China  45.133      5.0  43.833      4.0  44.899      5.0  48.316
# 1           Japan  44.733      6.0  42.365      5.0  45.699      2.0  45.971
# 2   Great Britain  46.132      1.0  45.932      1.0  43.066      8.0  48.182
# 3         Ukraine  44.065      8.0  44.966      3.0  45.699      2.0  48.065
# 4   United States  45.266      3.0  40.633      7.0  45.257      4.0  46.632
# 5          Russia  45.308      2.0  42.299      6.0  46.132      1.0  46.866
# 6         Germany  45.199      4.0  40.466      8.0  44.824      6.0  47.032
# 7          France  44.066      7.0  45.265      2.0  43.432      7.0  44.473
# 8           Japan  47.199      1.0  43.933      4.0  44.599      3.0  46.199
# 9          Russia  44.766      3.0  45.299      2.0  45.432      1.0  46.033
# 10          China  43.799      4.0  44.258      3.0  45.233      2.0  45.000
# ...

# %%
df = combined_df.copy()

# %%
usa = df[df["Team"]== "United States"]

# %%
usa
# Out:
#              Team      fx  fx_rank      ph  ph_rank      sr  sr_rank      vt  \
# 4   United States  45.266      3.0  40.633      7.0  45.257      4.0  46.632
# 12  United States  43.757      5.0  43.699      5.0  44.465      4.0  45.865
# 20  United States  39.965      7.0  42.099      5.0  42.166      4.0  42.899
#
#     vt_rank      pb  pb_rank      hb  hb_rank    total  total_rank  year
# 4       6.0  45.765      3.0  46.399      3.0  269.952         5.0  2012
# 12      3.0  46.333      3.0  44.441      5.0  268.560         5.0  2016
# 20      5.0  44.266      4.0  43.199      2.0  254.594         5.0  2020

# %%
usa["total_rank"].value_counts()
# Out:
# total_rank
# 5.0    3
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Team        24 non-null     object
#  1   fx          24 non-null     float64
#  2   fx_rank     24 non-null     float64
#  3   ph          24 non-null     float64
#  4   ph_rank     24 non-null     float64
#  5   sr          24 non-null     float64
#  6   sr_rank     24 non-null     float64
#  7   vt          24 non-null     float64
#  8   vt_rank     24 non-null     float64
#  9   pb          24 non-null     float64
#  10  pb_rank     24 non-null     float64
#  11  hb          24 non-null     float64
#  12  hb_rank     24 non-null     float64
#  13  total       24 non-null     float64
#  14  total_rank  24 non-null     float64
#  15  year        24 non-null     int64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 3.1+ KB

# %%
medals = df[df['total_rank'].isin([1.0, 2.0, 3.0])]

# %%
medals
# Out:
#              Team      fx  fx_rank      ph  ph_rank      sr  sr_rank      vt  \
# 0           China  45.133      5.0  43.833      4.0  44.899      5.0  48.316
# 1           Japan  44.733      6.0  42.365      5.0  45.699      2.0  45.971
# 2   Great Britain  46.132      1.0  45.932      1.0  43.066      8.0  48.182
# 8           Japan  47.199      1.0  43.933      4.0  44.599      3.0  46.199
# 9          Russia  44.766      3.0  45.299      2.0  45.432      1.0  46.033
# 10          China  43.799      4.0  44.258      3.0  45.233      2.0  45.000
# 16            ROC  42.632      2.0  43.140      4.0  44.399      1.0  44.765
# 17          Japan  43.700      1.0  43.566      3.0  42.433      3.0  44.232
# 18          China  42.132      4.0  43.966      1.0  43.599      2.0  44.332
#
#     vt_rank      pb  pb_rank      hb  hb_rank    total  total_rank  year
# 0       1.0  46.750      1.0  47.066      1.0  275.997         1.0  2012
# ...

# %%
medals["total"].min()
# Out:
# 261.894

# %% [markdown]
# ## Needs at least a 271.122 to medal

# %%
medals["Team"].value_counts()
# Out:
# Team
# China            3
# Japan            3
# Great Britain    1
# Russia           1
# ROC              1
# Name: count, dtype: int64

# %%
df = medals.copy()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Box plot of 'bb' by 'year'
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='year', y='total')
plt.title('Box Plot of total by Year')
plt.xlabel('Year')
plt.ylabel('total')
plt.show()

# %%
# Box plot of 'bb' by 'year'
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='year', y='hb')
plt.title('Box Plot of hb by Year')
plt.xlabel('Year')
plt.ylabel('hb')
plt.show()

# %%
# Box plot of 'bb' by 'year'
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='year', y='vt')
plt.title('Box Plot of vt by Year')
plt.xlabel('Year')
plt.ylabel('vt')
plt.show()

# %%
# Box plot of 'bb' by 'year'
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='year', y='ph')
plt.title('Box Plot of ph by Year')
plt.xlabel('Year')
plt.ylabel('ph')
plt.show()

# %%
# Box plot of 'bb' by 'year'
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='year', y='fx')
plt.title('Box Plot of fx by Year')
plt.xlabel('Year')
plt.ylabel('fx')
plt.show()

# %%
# Box plot of 'bb' by 'year'
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, x='year', y='sr')
plt.title('Box Plot of sr by Year')
plt.xlabel('Year')
plt.ylabel('sr')
plt.show()
