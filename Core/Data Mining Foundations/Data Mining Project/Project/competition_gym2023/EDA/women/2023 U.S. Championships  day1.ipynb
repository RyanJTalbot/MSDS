# %%
import pandas as pd 
import numpy as np
 # We will use the Seaborn library
import seaborn as sns

# Matplotlib forms basis for visualization in Python
import matplotlib.pyplot as plt

# We will use the Seaborn library
import seaborn as sns

sns.set()

# Graphics in SVG format are more sharp and legible
# %config InlineBackend.figure_format = 'svg'

# Increase the default plot size and set the color scheme
plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["image.cmap"] = "viridis"

# %%
df = pd.read_csv('../pdfs/combined.csv')

# %%
df.head()
# Out:
#             Name  VT_Diff  VT_EXEC  VT_ND  VT_Final  VT_Place  UE_Diff  \
# 0   Simone Biles      6.4     9.80   -0.5     15.70       0.0      6.0
# 1  Shilese Jones      5.0     9.35    0.0     14.35       0.0      6.3
# 2   Skye Blakely      5.0     9.35    0.0     14.35       0.0      5.9
# 3    Leanne Wong      5.0     9.25    0.0     14.25       0.0      5.7
# 4  Jordan Chiles      5.0     9.30    0.0     14.30       0.0      5.9
#
#    UE_EXEC  UE_ND  UE_Final  ...  BB_Diff  BB_EXEC  BB_ND  BB_Final  BB_Place  \
# 0     8.35    0.0     14.35  ...      6.4     8.05    0.0     14.45       1.0
# 1     8.60    0.0     14.90  ...      5.8     7.65    0.0     13.45       7.0
# 2     8.50    0.0     14.40  ...      6.1     7.95    0.0     14.05       2.0
# 3     8.30    0.0     14.00  ...      5.8     7.95    0.0     13.75       4.0
# 4     8.30    0.0     14.20  ...      5.2     7.80    0.0     13.00      13.0
#
#    FX_Diff  FX_EXEC  FX_ND  FX_Final  FX_Place
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      29 non-null     object
#  1   VT_Diff   29 non-null     float64
#  2   VT_EXEC   29 non-null     float64
#  3   VT_ND     29 non-null     float64
#  4   VT_Final  29 non-null     float64
#  5   VT_Place  28 non-null     float64
#  6   UE_Diff   29 non-null     float64
#  7   UE_EXEC   29 non-null     float64
#  8   UE_ND     29 non-null     float64
#  9   UE_Final  29 non-null     float64
#  10  UE_Place  28 non-null     float64
#  11  BB_Diff   29 non-null     float64
#  12  BB_EXEC   29 non-null     float64
#  13  BB_ND     29 non-null     float64
#  14  BB_Final  29 non-null     float64
#  15  BB_Place  28 non-null     float64
#  16  FX_Diff   29 non-null     float64
#  17  FX_EXEC   29 non-null     float64
#  18  FX_ND     29 non-null     float64
# ...

# %%
df.columns
# Out:
# Index(['Name', 'VT_Diff', 'VT_EXEC', 'VT_ND', 'VT_Final', 'VT_Place',
#        'UE_Diff', 'UE_EXEC', 'UE_ND', 'UE_Final', 'UE_Place', 'BB_Diff',
#        'BB_EXEC', 'BB_ND', 'BB_Final', 'BB_Place', 'FX_Diff', 'FX_EXEC',
#        'FX_ND', 'FX_Final', 'FX_Place'],
#       dtype='object')

# %%
df['final_score'] = df['VT_Final'] + df['UE_Final'] + df['BB_Final'] + df['FX_Final']

# %%
df.head()
# Out:
#             Name  VT_Diff  VT_EXEC  VT_ND  VT_Final  VT_Place  UE_Diff  \
# 0   Simone Biles      6.4     9.80   -0.5     15.70       0.0      6.0
# 1  Shilese Jones      5.0     9.35    0.0     14.35       0.0      6.3
# 2   Skye Blakely      5.0     9.35    0.0     14.35       0.0      5.9
# 3    Leanne Wong      5.0     9.25    0.0     14.25       0.0      5.7
# 4  Jordan Chiles      5.0     9.30    0.0     14.30       0.0      5.9
#
#    UE_EXEC  UE_ND  UE_Final  ...  BB_EXEC  BB_ND  BB_Final  BB_Place  FX_Diff  \
# 0     8.35    0.0     14.35  ...     8.05    0.0     14.45       1.0      6.8
# 1     8.60    0.0     14.90  ...     7.65    0.0     13.45       7.0      5.9
# 2     8.50    0.0     14.40  ...     7.95    0.0     14.05       2.0      5.6
# 3     8.30    0.0     14.00  ...     7.95    0.0     13.75       4.0      5.6
# 4     8.30    0.0     14.20  ...     7.80    0.0     13.00      13.0      5.6
#
#    FX_EXEC  FX_ND  FX_Final  FX_Place  final_score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         29 non-null     object
#  1   VT_Diff      29 non-null     float64
#  2   VT_EXEC      29 non-null     float64
#  3   VT_ND        29 non-null     float64
#  4   VT_Final     29 non-null     float64
#  5   VT_Place     28 non-null     float64
#  6   UE_Diff      29 non-null     float64
#  7   UE_EXEC      29 non-null     float64
#  8   UE_ND        29 non-null     float64
#  9   UE_Final     29 non-null     float64
#  10  UE_Place     28 non-null     float64
#  11  BB_Diff      29 non-null     float64
#  12  BB_EXEC      29 non-null     float64
#  13  BB_ND        29 non-null     float64
#  14  BB_Final     29 non-null     float64
#  15  BB_Place     28 non-null     float64
#  16  FX_Diff      29 non-null     float64
#  17  FX_EXEC      29 non-null     float64
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Summary statistics
summary_stats = df.describe()
summary_stats
# Out:
#          VT_Diff    VT_EXEC      VT_ND   VT_Final  VT_Place    UE_Diff  \
# count  29.000000  29.000000  29.000000  29.000000      28.0  29.000000
# mean    4.641379   8.691379  -0.027586  13.305172       0.0   5.013793
# std     1.018934   1.694006   0.106558   2.629243       0.0   1.449316
# min     0.000000   0.000000  -0.500000   0.000000       0.0   0.000000
# 25%     4.600000   8.850000   0.000000  13.350000       0.0   5.000000
# 50%     4.600000   9.000000   0.000000  13.750000       0.0   5.300000
# 75%     5.000000   9.150000   0.000000  14.100000       0.0   5.600000
# max     6.400000   9.800000   0.000000  15.700000       0.0   6.300000
#
#          UE_EXEC      UE_ND   UE_Final   UE_Place  ...    BB_EXEC      BB_ND  \
# count  29.000000  29.000000  29.000000  28.000000  ...  29.000000  29.000000
# mean    7.081034  -0.027586  12.067241  14.357143  ...   6.944828  -0.003448
# std     2.073748   0.106558   3.477845   8.143228  ...   2.000730   0.018570
# ...

# %%
# Check for missing values
missing_values = df.isnull().sum()
missing_values
# Out:
# Name           0
# VT_Diff        0
# VT_EXEC        0
# VT_ND          0
# VT_Final       0
# VT_Place       1
# UE_Diff        0
# UE_EXEC        0
# UE_ND          0
# UE_Final       0
# UE_Place       1
# BB_Diff        0
# BB_EXEC        0
# BB_ND          0
# BB_Final       0
# BB_Place       1
# FX_Diff        0
# FX_EXEC        0
# FX_ND          0
# FX_Final       0
# FX_Place       1
# final_score    0
# dtype: int64

# %%
df=df.fillna(0)

# %%
# Pairwise correlation matrix
justnums = df.drop(columns=["Name"])
correlation_matrix = justnums.corr()

correlation_matrix
# Out:
#               VT_Diff   VT_EXEC     VT_ND  VT_Final  VT_Place   UE_Diff  \
# VT_Diff      1.000000  0.893237 -0.245679  0.953089       NaN  0.692237
# VT_EXEC      0.893237  1.000000 -0.101280  0.986353       NaN  0.669852
# VT_ND       -0.245679 -0.101280  1.000000 -0.119936       NaN -0.078388
# VT_Final     0.953089  0.986353 -0.119936  1.000000       NaN  0.696674
# VT_Place          NaN       NaN       NaN       NaN       NaN       NaN
# UE_Diff      0.692237  0.669852 -0.078388  0.696674       NaN  1.000000
# UE_EXEC      0.656185  0.661714 -0.139830  0.674969       NaN  0.946802
# UE_ND       -0.054898 -0.032031 -0.069414 -0.044726       NaN -0.052949
# UE_Final     0.678059  0.672728 -0.118170  0.691419       NaN  0.979659
# UE_Place     0.220243  0.237023  0.166589  0.244817       NaN -0.189276
# BB_Diff      0.691934  0.691118 -0.150434  0.707337       NaN  0.351233
# BB_EXEC      0.610468  0.692565 -0.080265  0.679543       NaN  0.390215
# ...

# %%
# Visualize correlation using a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True)
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
# Histograms of numeric columns
numeric_cols = df.select_dtypes(include=[np.number]).columns
plt.figure(figsize=(16, 10))
df[numeric_cols].hist(bins=20, edgecolor='k', alpha=0.7)
plt.title('Histograms of Numeric Columns')
plt.tight_layout()

# %%
# Box plots for selected columns
selected_cols = ['VT_Final', 'UE_Final', 'BB_Final', 'FX_Final', 'final_score']
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[selected_cols], orient='vertical')
plt.title('Box Plots for Selected Columns')
# Out:
# Text(0.5, 1.0, 'Box Plots for Selected Columns')

# %%
# Scatterplot matrix for selected columns
sns.set(style="ticks")
sns.pairplot(df[selected_cols], height=2)
plt.suptitle('Scatterplot Matrix for Selected Columns', y=1.02)

# Bar chart for categorical data (if applicable)
# Example: df['Category'].value_counts().plot(kind='bar')

# Additional EDA as needed for your specific dataset

# Show plots
plt.show()

# %%
# Extract columns ending with "exec" and "diff"
exec_columns = df.filter(like='_EXEC')
diff_columns = df.filter(like='_Diff')

# Summary statistics for the 'exec' columns
exec_summary_stats = exec_columns.describe()
exec_summary_stats
# Out:
#          VT_EXEC    UE_EXEC    BB_EXEC    FX_EXEC
# count  29.000000  29.000000  29.000000  29.000000
# mean    8.691379   7.081034   6.944828   6.801724
# std     1.694006   2.073748   2.000730   2.391073
# min     0.000000   0.000000   0.000000   0.000000
# 25%     8.850000   7.000000   6.950000   7.300000
# 50%     9.000000   7.700000   7.650000   7.500000
# 75%     9.150000   8.050000   7.800000   7.850000
# max     9.800000   8.600000   8.150000   8.250000

# %%
# Summary statistics for the 'diff' columns
diff_summary_stats = diff_columns.describe()
diff_summary_stats
# Out:
#          VT_Diff    UE_Diff    BB_Diff    FX_Diff
# count  29.000000  29.000000  29.000000  29.000000
# mean    4.641379   5.013793   5.089655   4.868966
# std     1.018934   1.449316   1.466615   1.743786
# min     0.000000   0.000000   0.000000   0.000000
# 25%     4.600000   5.000000   5.000000   5.000000
# 50%     4.600000   5.300000   5.500000   5.400000
# 75%     5.000000   5.600000   5.800000   5.600000
# max     6.400000   6.300000   6.400000   6.800000

# %%
# Visualize the distribution of 'exec' columns using histograms
plt.figure(figsize=(12, 8))
exec_columns.hist(bins=20, edgecolor='k', alpha=0.7)
plt.title('Histograms of Columns Ending with "_EXEC"')
plt.tight_layout()

# %%
# Visualize the distribution of 'diff' columns using histograms
plt.figure(figsize=(12, 8))
diff_columns.hist(bins=20, edgecolor='k', alpha=0.7)
plt.title('Histograms of Columns Ending with "_Diff"')
plt.tight_layout()

# %%
# Pairwise correlation matrix for 'exec' columns
exec_correlation_matrix = exec_columns.corr()
exec_correlation_matrix
# Out:
#           VT_EXEC   UE_EXEC   BB_EXEC   FX_EXEC
# VT_EXEC  1.000000  0.661714  0.692565  0.554214
# UE_EXEC  0.661714  1.000000  0.413650  0.753460
# BB_EXEC  0.692565  0.413650  1.000000  0.752845
# FX_EXEC  0.554214  0.753460  0.752845  1.000000

# %%
# Pairwise correlation matrix for 'diff' columns
diff_correlation_matrix = diff_columns.corr()
diff_correlation_matrix
# Out:
#           VT_Diff   UE_Diff   BB_Diff   FX_Diff
# VT_Diff  1.000000  0.692237  0.691934  0.662853
# UE_Diff  0.692237  1.000000  0.351233  0.725259
# BB_Diff  0.691934  0.351233  1.000000  0.756479
# FX_Diff  0.662853  0.725259  0.756479  1.000000

# %%
# Visualize correlation using heatmaps for 'exec' columns
plt.figure(figsize=(12, 8))
sns.heatmap(exec_correlation_matrix, cmap='coolwarm', annot=True)
plt.title('Correlation Heatmap for Columns Ending with "_EXEC"')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap for Columns Ending with "_EXEC"')

# %%
# Visualize correlation using heatmaps for 'diff' columns
plt.figure(figsize=(12, 8))
sns.heatmap(diff_correlation_matrix, cmap='coolwarm', annot=True)
plt.title('Correlation Heatmap for Columns Ending with "_Diff"')

# Show plots
plt.show()

# %%
# Extract columns ending with "exec" and "diff"
exec_columns = df.filter(like='_EXEC')
diff_columns = df.filter(like='_Diff')

# Filter values greater than 0 in the 'exec' columns
exec_columns = exec_columns[exec_columns > 0].dropna()

# Filter values greater than 0 in the 'diff' columns
diff_columns = diff_columns[diff_columns > 0].dropna()

# Summary statistics for the 'exec' columns
exec_summary_stats = exec_columns.describe()
print(exec_summary_stats)

print('\n')

# Summary statistics for the 'diff' columns
diff_summary_stats = diff_columns.describe()
print(diff_summary_stats)

# Visualize the distribution of 'exec' columns using histograms
plt.figure(figsize=(12, 8))
exec_columns.hist(bins=20, edgecolor='k', alpha=0.7)
plt.title('Histograms of Columns Ending with "_EXEC" (Values > 0)')
plt.tight_layout()

# Visualize the distribution of 'diff' columns using histograms
plt.figure(figsize=(12, 8))
diff_columns.hist(bins=20, edgecolor='k', alpha=0.7)
plt.title('Histograms of Columns Ending with "_Diff" (Values > 0)')
plt.tight_layout()

# Pairwise correlation matrix for 'exec' columns
exec_correlation_matrix = exec_columns.corr()

# Pairwise correlation matrix for 'diff' columns
diff_correlation_matrix = diff_columns.corr()

# Visualize correlation using heatmaps for 'exec' columns
plt.figure(figsize=(12, 8))
sns.heatmap(exec_correlation_matrix, cmap='coolwarm', annot=True)
plt.title('Correlation Heatmap for Columns Ending with "_EXEC" (Values > 0)')

# Visualize correlation using heatmaps for 'diff' columns
plt.figure(figsize=(12, 8))
sns.heatmap(diff_correlation_matrix, cmap='coolwarm', annot=True)
plt.title('Correlation Heatmap for Columns Ending with "_Diff" (Values > 0)')

# Show plots
plt.show()
# Out:
#          VT_EXEC    UE_EXEC    BB_EXEC    FX_EXEC
# count  26.000000  26.000000  26.000000  26.000000
# mean    9.001923   7.598077   7.451923   7.586538
# std     0.287569   0.711685   0.580944   0.459469
# min     8.350000   6.000000   6.200000   6.150000
# 25%     8.862500   7.100000   7.050000   7.400000
# 50%     9.000000   7.775000   7.675000   7.575000
# 75%     9.137500   8.162500   7.837500   7.850000
# max     9.800000   8.600000   8.150000   8.250000
#
#
#          VT_Diff    UE_Diff    BB_Diff    FX_Diff
# count  26.000000  26.000000  26.000000  26.000000
# mean    4.838462   5.365385   5.446154   5.430769
# std     0.502853   0.426091   0.413986   0.482302
# min     4.200000   4.500000   4.800000   4.600000
# 25%     4.600000   5.100000   5.125000   5.100000
# 50%     5.000000   5.350000   5.500000   5.400000
# 75%     5.000000   5.575000   5.775000   5.600000
# max     6.400000   6.300000   6.400000   6.800000

# %% [markdown]
# ## it appears theres a high correlation between th difficult on:
# - floor and vault
# - balance beam and vault
#
# ## And a moderat relation between the vault and all other events

# %%
df
# Out:
#                   Name  VT_Diff  VT_EXEC  VT_ND  VT_Final  VT_Place  UE_Diff  \
# 0         Simone Biles      6.4     9.80   -0.5     15.70       0.0      6.0
# 1        Shilese Jones      5.0     9.35    0.0     14.35       0.0      6.3
# 2         Skye Blakely      5.0     9.35    0.0     14.35       0.0      5.9
# 3          Leanne Wong      5.0     9.25    0.0     14.25       0.0      5.7
# 4        Jordan Chiles      5.0     9.30    0.0     14.30       0.0      5.9
# 5       Kaliya Lincoln      5.0     9.10    0.0     14.10       0.0      5.3
# 6      Amelia Disidore      5.0     8.85    0.0     13.85       0.0      5.1
# 7    Joscelyn Roberson      5.6     9.05    0.0     14.65       0.0      4.7
# 8         Katelyn Jong      5.0     8.85    0.0     13.85       0.0      6.0
# 9       Madray Johnson      4.6     8.95    0.0     13.55       0.0      5.0
# 10  Tiana Sumanasekera      5.0     9.20    0.0     14.20       0.0      5.4
# ...
