# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('clean16to20_team_qual.csv')

# %%
df.head(50)
# Out:
#                    Name Country  uneven_score  uneven_rank  bb_score  bb_rank  \
# 0          Simone Biles     USA        15.000         14.0    15.633      1.0
# 1           Aly Raisman     USA        14.733         22.0    14.833      7.0
# 2         Gabby Douglas     USA        15.766          3.0    14.833      7.0
# 3      Laurie Hernandez     USA         0.000          0.0    15.366      2.0
# 4        Madison Kocian     USA        15.866          1.0     0.000      0.0
# 5              Wang Yan     CHN        13.900         44.0    14.100     26.0
# 6        Shang Chunsong     CHN        15.300          8.0    14.366     17.0
# 7             Fan Yilin     CHN        15.266          9.0    14.866      6.0
# 8            Tan Jiaxin     CHN        14.600         28.0     0.000      0.0
# 9                Mao Yi     CHN         0.000          0.0     0.000      0.0
# 10      Seda Tutkhalyan     RUS        15.133         11.0    14.466     14.0
# ...
