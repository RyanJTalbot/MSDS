# %%
import pandas as pd
import numpy as np
from datetime import datetime
from dateutil import parser

# %%
df = pd.read_csv('../../scraping/gymnasts_results/miller/miller21.csv')

# %%
df["Year"] = 2021

# %%
df2 = pd.read_csv('../../scraping/gymnasts_results/miller/miller22.csv')

# %%
df2["Year"] = 2022

# %%
df3 = pd.read_csv('../../scraping/gymnasts_results/miller/miller23.csv')

# %%
df3["Year"] = 2023

# %%
result = pd.concat([df,df2, df3], ignore_index=True)

# %%
df = result.copy()

# %%
df["Name"] = "Zoe Miller"

# %%
df.rename(columns={'Unnamed: 2': 'Round'}, inplace=True)

# %%
# Function to parse date entries
def parse_date(entry):
    try:
        return parser.parse(entry).strftime("%b %d")
    except ValueError:
        return entry

# Apply the parse_date function to the "Date" column
df["Date"] = df["Date"].apply(parse_date)

# %%
def extract_month_day(entry):
    parts = entry.split('-')
    return parts[0]

# Apply the extract_month_day function to the "Date" column
df["Date"] = df["Date"].apply(extract_month_day)

# Now, the "Date

# %%
df
# Out:
#       Date                      Competition Round       VT     UB      BB  \
# 0   Nov 15  U.S. Junior Pan Am Games Trials    EF      0.0   0.00  13.600
# 1   Nov 15  U.S. Junior Pan Am Games Trials    AA    14.15  11.70  13.650
# 2   Jun 03               U.S. Championships    AA     14.3  12.15  13.550
# 3   Jun 03               U.S. Championships    QF    14.35  10.60  13.250
# 4   May 21                     U.S. Classic    AA     14.1  11.35  12.600
# 5   Feb 26                       Winter Cup    AA    13.55  10.95  13.800
# 6   Feb 11    Brestyan’s National Qualifier    AA     13.2  11.45  13.200
# 7   Jan 21         Biles National Qualifier    AA     12.8  11.10  11.750
# 8   Aug 18               U.S. Championships    AA     13.8  11.20  11.950
# 9   Aug 18               U.S. Championships    QF    13.75  10.90  13.250
# 10  Jul 29                     U.S. Classic    AA     14.0  10.55  12.300
# 11  Jul 04              U.S. Pan Ams Trials    EF      0.0   0.00  12.333
# 12  Jul 04              U.S. Pan Ams Trials    AA    13.35  10.95  10.550
# 13  Mar 31         March National Team Camp    AA     13.4  11.15  12.850
# 14  Feb 24                       Winter Cup    AA     12.9   9.75  13.400
# 15  Aug 24               U.S. Championships    AA    14.55  11.80  13.200
# 16  Aug 24               U.S. Championships    QF    14.65  11.80  13.200
# 17  Aug 04                     U.S. Classic    AA    14.65  11.10  14.300
# 18  Jul 09          July National Team Camp    AA    14.25  12.90  13.000
# 19  May 26       Pan American Championships    TF     13.8   0.00  13.733
# 20  May 26       Pan American Championships    AA   13.733   0.00  13.267
# 21  Apr 27                  Cairo World Cup    EF  13.983*   0.00  13.233
# 22  Apr 27                  Cairo World Cup    QF  14.016*  11.40  12.833
# 23  Mar 17         DTB Pokal Team Challenge    EF  14.083*   0.00   0.000
# 24  Mar 17         DTB Pokal Team Challenge    AA     14.2  13.00  12.500
# 25  Feb 23                       Winter Cup    AA       14  10.85  13.300
#
#         FX     AA  Year        Name
# 0   13.000   0.00  2021  Zoe Miller
# 1   11.900  51.40  2021  Zoe Miller
# 2   13.100  53.10  2021  Zoe Miller
# 3   13.100  51.30  2021  Zoe Miller
# 4   13.250  51.30  2021  Zoe Miller
# 5   12.850  51.15  2021  Zoe Miller
# 6   12.900  50.75  2021  Zoe Miller
# 7   12.750  48.40  2021  Zoe Miller
# 8   12.950  49.90  2022  Zoe Miller
# 9   12.850  50.75  2022  Zoe Miller
# 10  12.700  49.55  2022  Zoe Miller
# 11   0.000   0.00  2022  Zoe Miller
# 12  12.450  47.30  2022  Zoe Miller
# 13  13.200  50.60  2022  Zoe Miller
# 14  12.650  48.70  2022  Zoe Miller
# 15  13.600  53.15  2023  Zoe Miller
# 16  13.300  52.95  2023  Zoe Miller
# 17  14.000  54.05  2023  Zoe Miller
# 18  14.000  54.15  2023  Zoe Miller
# 19  14.067   0.00  2023  Zoe Miller
# 20  14.100   0.00  2023  Zoe Miller
# 21  13.700   0.00  2023  Zoe Miller
# 22  14.066   0.00  2023  Zoe Miller
# 23  13.300   0.00  2023  Zoe Miller
# 24  14.150  53.85  2023  Zoe Miller
# 25  13.550  51.70  2023  Zoe Miller

# %%
df["Date"] = pd.to_datetime(df["Year"].astype(int).astype(str) + '-' + df["Date"], format="%Y-%b %d")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         26 non-null     datetime64[ns]
#  1   Competition  26 non-null     object
#  2   Round        26 non-null     object
#  3   VT           26 non-null     object
#  4   UB           26 non-null     float64
#  5   BB           26 non-null     float64
#  6   FX           26 non-null     float64
#  7   AA           26 non-null     float64
#  8   Year         26 non-null     int64
#  9   Name         26 non-null     object
# dtypes: datetime64[ns](1), float64(4), int64(1), object(4)
# memory usage: 2.2+ KB

# %%
# Specify the desired column order
desired_order = ['Name', 'Date', 'Competition', 'Round', 'VT', 'UB', 'BB', 'FX', 'AA',
       ]

# Create a new DataFrame with columns in the desired order
df_reordered = df[desired_order]

# %%
# df_reordered.to_csv('miller.csv', index=False)
