# %% [markdown]
# Scraped from https://en.wikipedia.org/wiki/2023_Asian_Artistic_Gymnastics_Championships
#
# did not get nationalities, will need to be added

# %%
import pandas as pd
import numpy as np

# %%
fl = pd.read_csv("../Data/asia2023championship_men/floor23mens.csv")

# %%
hb = pd.read_csv("../Data/asia2023championship_men/hb23mens.csv")

# %%
iaa = pd.read_csv("../Data/asia2023championship_men/mens2023iaa.csv")

# %%
pb = pd.read_csv("../Data/asia2023championship_men/pb23mens.csv")

# %%
ph = pd.read_csv("../Data/asia2023championship_men/ph23mens.csv")

# %%
sr = pd.read_csv("../Data/asia2023championship_men/rings23mens.csv")

# %%
vt = pd.read_csv("../Data/asia2023championship_men/vault23mens.csv")

# %%
fl["Pen."] = 0

# %%
fl["Apparatus"] = "FX"

# %%
fl
# Out:
#    Rank          Gymnast  D Score  E Score  Pen.   Total Apparatus
# 0     1      Carlos Yulo      6.3    9.000     0  15.300        FX
# 1     2  Dmitriy Patanin      5.9    8.466     0  14.366        FX
# 2     3         Su Weide      6.3    8.033     0  14.333        FX
# 3     4    Fumiya Sasaki      5.8    8.433     0  14.233        FX
# 4     5     Milad Karimi      6.3    8.100     0  14.100        FX
# 5     6   Shinnosuke Oka      5.9    8.433     0  13.933        FX
# 6     7    Ryu Sung-hyun      5.8    7.633     0  13.433        FX
# 7     8   John Ivan Cruz      5.5    5.933     0  11.433        FX

# %%
hb["Pen."] = 0

# %%
hb["Apparatus"] = "HB"

# %%
hb
# Out:
#    Rank                Gymnast  D Score  E Score  Pen.   Total Apparatus
# 0     1               Tian Hao      6.4    8.133     0  14.533        HB
# 1     2         Shinnosuke Oka      5.5    8.866     0  14.366        HB
# 2     3            Carlos Yulo      5.4    8.633     0  14.033        HB
# 3     4           Lee Chih-kai      5.1    8.233     0  13.333        HB
# 4     5  Rasuljon Abdurakhimov      4.9    8.300     0  13.200        HB
# 5     6        Takeru Kitazono      5.4    7.366     0  12.766        HB
# 6     7               Su Weide      5.3    6.566     0  11.866        HB
# 7     8           Milad Karimi      5.2    6.366     0  11.566        HB

# %%
pb["Pen."] = 0

# %%
pb["Apparatus"] = "PB"

# %%
pb
# Out:
#    Rank           Gymnast  D Score  E Score  Pen.   Total Apparatus
# 0     1       Carlos Yulo      6.3    8.966     0  15.266        PB
# 1     2    Shinnosuke Oka      6.4    8.733     0  15.133        PB
# 2     3        Yin Dehang      6.4    8.700     0  15.100        PB
# 3     4     Ryu Sung-hyun      5.6    8.833     0  14.433        PB
# 4     5        Ryu Jae-ho      5.4    8.433     0  13.833        PB
# 5     6   Takeru Kitazono      5.2    7.600     0  12.800        PB
# 6     7        Lan Xingyu      5.9    6.833     0  12.733        PB
# 7     8  Nguyễn Phước Hải      5.5    7.133     0  12.633        PB

# %%
ph["Pen."] = 0

# %%
ph["Apparatus"] = "PH"

# %%
ph
# Out:
#    Rank              Gymnast  D Score  E Score  Pen.   Total Apparatus
# 0     1     Nariman Kurbanov      6.6    8.733     0  15.333        PH
# 1     2    Ahmad Abu Al-Soud      6.4    8.833     0  15.233        PH
# 2     3        Ryota Tsumura      6.6    8.433     0  15.033        PH
# 3     4           Yin Dehang      6.4    8.066     0  14.466        PH
# 4     5       Shinnosuke Oka      5.8    8.600     0  14.400        PH
# 5     6             Tian Hao      5.8    8.500     0  14.300        PH
# 6     7  Khabibullo Ergashev      5.5    8.300     0  13.800        PH
# 7     8       Abdulla Azimov      6.3    6.600     0  12.900        PH

# %%
sr["Pen."] = 0

# %%
sr["Apparatus"] = "SR"

# %%
sr
# Out:
#    Rank                 Gymnast  D Score  E Score  Pen.   Total Apparatus
# 0     1              Lan Xingyu      6.4    8.800     0  15.200        SR
# 1     2  Nguyễn Văn Khánh Phong      5.9    8.466     0  14.366        SR
# 2     3            Ng Kiu Chung      5.7    8.400     0  14.100        SR
# 3     4             Carlos Yulo      5.7    8.333     0  14.033        SR
# 4     5             Lin Guan-yi      5.8    8.200     0  14.000        SR
# 5     6          Shinnosuke Oka      5.6    8.366     0  13.966        SR
# 6     7             Lee Junghyo      5.3    8.500     0  13.800        SR
# 7     8              Yin Dehang      5.5    7.900     0  13.400        SR

# %%
vt
# Out:
#    Rank                 Gymnast  ct1_D Score  vt_1E Score  vt1_Pen.  Score 1  \
# 0     1             Carlos Yulo          5.6        8.366       NaN   13.966
# 1     2     Abdulaziz Mirvaliev          5.6        9.066       NaN   14.666
# 2     3              Kim Jae-ho          5.2        9.133       NaN   14.333
# 3     4   Tikumporn Surintornta          5.2        8.033       NaN   13.233
# 4     5  Erkhembayar Usukhbayar          4.8        9.166       NaN   13.966
# 5     6    Muhammad Sharul Aimy          5.2        7.833       NaN   12.933
# 6     7                Ng Ka Ki          5.6        7.766       NaN   13.366
# 7     8   Juancho Miguel Besana          5.6        7.933       NaN   13.233
#
#    vt2_D Score  vt2_E Score vt_2Pen.  Score 2   Total
# 0          5.6        9.033      NaN   14.633  14.299
# 1          5.6        8.000     –0.1   13.500  14.083
# 2          5.2        8.000      NaN   13.200  13.766
# 3          5.2        8.900      NaN   14.100  13.667
# ...

# %%
vt["vt1_Pen."] = 0

# %%
vt["Apparatus"] = "VT"

# %%
vt
# Out:
#    Rank                 Gymnast  ct1_D Score  vt_1E Score  vt1_Pen.  Score 1  \
# 0     1             Carlos Yulo          5.6        8.366         0   13.966
# 1     2     Abdulaziz Mirvaliev          5.6        9.066         0   14.666
# 2     3              Kim Jae-ho          5.2        9.133         0   14.333
# 3     4   Tikumporn Surintornta          5.2        8.033         0   13.233
# 4     5  Erkhembayar Usukhbayar          4.8        9.166         0   13.966
# 5     6    Muhammad Sharul Aimy          5.2        7.833         0   12.933
# 6     7                Ng Ka Ki          5.6        7.766         0   13.366
# 7     8   Juancho Miguel Besana          5.6        7.933         0   13.233
#
#    vt2_D Score  vt2_E Score vt_2Pen.  Score 2   Total  Pen. Apparatus
# 0          5.6        9.033      NaN   14.633  14.299     0        VT
# 1          5.6        8.000     –0.1   13.500  14.083     0        VT
# ...

# %%
vt_filled = vt.fillna(0)
vt_filled
# Out:
#    Rank                 Gymnast  ct1_D Score  vt_1E Score  vt1_Pen.  Score 1  \
# 0     1             Carlos Yulo          5.6        8.366         0   13.966
# 1     2     Abdulaziz Mirvaliev          5.6        9.066         0   14.666
# 2     3              Kim Jae-ho          5.2        9.133         0   14.333
# 3     4   Tikumporn Surintornta          5.2        8.033         0   13.233
# 4     5  Erkhembayar Usukhbayar          4.8        9.166         0   13.966
# 5     6    Muhammad Sharul Aimy          5.2        7.833         0   12.933
# 6     7                Ng Ka Ki          5.6        7.766         0   13.366
# 7     8   Juancho Miguel Besana          5.6        7.933         0   13.233
#
#    vt2_D Score  vt2_E Score vt_2Pen.  Score 2   Total  Pen. Apparatus
# 0          5.6        9.033        0   14.633  14.299     0        VT
# 1          5.6        8.000     –0.1   13.500  14.083     0        VT
# ...

# %%
vt = vt_filled.copy()

# %%
vt = vt.drop(columns=["Pen.", "Apparatus"])

# %%
vt
# Out:
#    Rank                 Gymnast  ct1_D Score  vt_1E Score  vt1_Pen.  Score 1  \
# 0     1             Carlos Yulo          5.6        8.366         0   13.966
# 1     2     Abdulaziz Mirvaliev          5.6        9.066         0   14.666
# 2     3              Kim Jae-ho          5.2        9.133         0   14.333
# 3     4   Tikumporn Surintornta          5.2        8.033         0   13.233
# 4     5  Erkhembayar Usukhbayar          4.8        9.166         0   13.966
# 5     6    Muhammad Sharul Aimy          5.2        7.833         0   12.933
# 6     7                Ng Ka Ki          5.6        7.766         0   13.366
# 7     8   Juancho Miguel Besana          5.6        7.933         0   13.233
#
#    vt2_D Score  vt2_E Score vt_2Pen.  Score 2   Total
# 0          5.6        9.033        0   14.633  14.299
# 1          5.6        8.000     –0.1   13.500  14.083
# 2          5.2        8.000        0   13.200  13.766
# 3          5.2        8.900        0   14.100  13.667
# ...

# %%
import pandas as pd

# Create a sample DataFrame
data = {'Column1': [1, 2, 3, 4, 5]}
df = pd.DataFrame(data)

df
# Out:
#    Column1
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5

# %%
# Define the values you want to add to the new column
new_column_values = ['JPN', 'FIL', 'JPN', 'KAZ', 'CHN', 'CHN', 'SK', 'UZB']

# Add the new column to the DataFrame
iaa['COUNTRY'] = new_column_values

# Now, the DataFrame 'df' will have a new column 'NewColumn' with the specified values
iaa
# Out:
#    Rank              Gymnast      FX      PH      SR      VT      PB      HB  \
# 0     1       Shinnosuke Oka  14.100  14.566  13.866  14.333  15.000  14.200
# 1     2          Carlos Yulo  14.966  13.266  14.300  14.866  15.066  13.466
# 2     3      Takeru Kitazono  13.900  14.333  13.433  14.366  14.966  14.433
# 3     4         Milad Karimi  14.466  13.500  13.300  14.700  13.366  14.366
# 4     5             Tian Hao  13.933  14.166  13.200  13.766  13.466  15.100
# 5     6           Yin Dehang  13.433  14.300  13.666  13.900  14.900  13.000
# 6     7        Ryu Sung-hyun  14.000  13.533  13.400  14.833  14.000  13.366
# 7     8  Khabibullo Ergashev  13.100  13.866  12.866  14.133  13.633  13.233
#
#     Total COUNTRY
# 0  86.065     JPN
# 1  85.930     FIL
# 2  85.431     JPN
# 3  83.698     KAZ
# 4  83.631     CHN
# 5  83.199     CHN
# 6  83.132      SK
# 7  80.831     UZB

# %%
# Define the values you want to add to the new column
new_column_values = ['FIL', 'KAZ', 'CHN', 'JPN', 'KAZ', 'JPN','SK', 'FIL']

# Add the new column to the DataFrame
fl['COUNTRY'] = new_column_values

# Now, the DataFrame 'df' will have a new column 'NewColumn' with the specified values

# %%
fl
# Out:
#    Rank          Gymnast  D Score  E Score  Pen.   Total Apparatus COUNTRY
# 0     1      Carlos Yulo      6.3    9.000     0  15.300        FX     FIL
# 1     2  Dmitriy Patanin      5.9    8.466     0  14.366        FX     KAZ
# 2     3         Su Weide      6.3    8.033     0  14.333        FX     CHN
# 3     4    Fumiya Sasaki      5.8    8.433     0  14.233        FX     JPN
# 4     5     Milad Karimi      6.3    8.100     0  14.100        FX     KAZ
# 5     6   Shinnosuke Oka      5.9    8.433     0  13.933        FX     JPN
# 6     7    Ryu Sung-hyun      5.8    7.633     0  13.433        FX      SK
# 7     8   John Ivan Cruz      5.5    5.933     0  11.433        FX     FIL

# %%
# Define the values you want to add to the new column
new_column_values = ['KAZ', 'JOR', 'JPN', 'CHN', 'JPN', 'CHN', 'UZB', 'UZB']

# Add the new column to the DataFrame
ph['COUNTRY'] = new_column_values

# Now, the DataFrame 'df' will have a new column 'NewColumn' with the specified values

# %%
ph
# Out:
#    Rank              Gymnast  D Score  E Score  Pen.   Total Apparatus COUNTRY
# 0     1     Nariman Kurbanov      6.6    8.733     0  15.333        PH     KAZ
# 1     2    Ahmad Abu Al-Soud      6.4    8.833     0  15.233        PH     JOR
# 2     3        Ryota Tsumura      6.6    8.433     0  15.033        PH     JPN
# 3     4           Yin Dehang      6.4    8.066     0  14.466        PH     CHN
# 4     5       Shinnosuke Oka      5.8    8.600     0  14.400        PH     JPN
# 5     6             Tian Hao      5.8    8.500     0  14.300        PH     CHN
# 6     7  Khabibullo Ergashev      5.5    8.300     0  13.800        PH     UZB
# 7     8       Abdulla Azimov      6.3    6.600     0  12.900        PH     UZB

# %%
# Define the values you want to add to the new column
new_column_values = ['CHN', 'VIE', 'HK', 'FIL', 'TPE', 'JPN', 'SK', 'CHN']

# Add the new column to the DataFrame
sr['COUNTRY'] = new_column_values

# Now, the DataFrame 'df' will have a new column 'NewColumn' with the specified values

# %%
sr
# Out:
#    Rank                 Gymnast  D Score  E Score  Pen.   Total Apparatus  \
# 0     1              Lan Xingyu      6.4    8.800     0  15.200        SR
# 1     2  Nguyễn Văn Khánh Phong      5.9    8.466     0  14.366        SR
# 2     3            Ng Kiu Chung      5.7    8.400     0  14.100        SR
# 3     4             Carlos Yulo      5.7    8.333     0  14.033        SR
# 4     5             Lin Guan-yi      5.8    8.200     0  14.000        SR
# 5     6          Shinnosuke Oka      5.6    8.366     0  13.966        SR
# 6     7             Lee Junghyo      5.3    8.500     0  13.800        SR
# 7     8              Yin Dehang      5.5    7.900     0  13.400        SR
#
#   COUNTRY
# 0     CHN
# 1     VIE
# 2      HK
# 3     FIL
# 4     TPE
# 5     JPN
# 6      SK
# 7     CHN

# %%
# Define the values you want to add to the new column
new_column_values = ['FIL', 'UZB', 'SK', 'THA', 'MGL', 'MAS', 'HK','FIL']

# Add the new column to the DataFrame
vt['COUNTRY'] = new_column_values

# Now, the DataFrame 'df' will have a new column 'NewColumn' with the specified values

# %%
vt
# Out:
#    Rank                 Gymnast  ct1_D Score  vt_1E Score  vt1_Pen.  Score 1  \
# 0     1             Carlos Yulo          5.6        8.366         0   13.966
# 1     2     Abdulaziz Mirvaliev          5.6        9.066         0   14.666
# 2     3              Kim Jae-ho          5.2        9.133         0   14.333
# 3     4   Tikumporn Surintornta          5.2        8.033         0   13.233
# 4     5  Erkhembayar Usukhbayar          4.8        9.166         0   13.966
# 5     6    Muhammad Sharul Aimy          5.2        7.833         0   12.933
# 6     7                Ng Ka Ki          5.6        7.766         0   13.366
# 7     8   Juancho Miguel Besana          5.6        7.933         0   13.233
#
#    vt2_D Score  vt2_E Score vt_2Pen.  Score 2   Total COUNTRY
# 0          5.6        9.033        0   14.633  14.299     FIL
# 1          5.6        8.000     –0.1   13.500  14.083     UZB
# 2          5.2        8.000        0   13.200  13.766      SK
# ...

# %%
# Define the values you want to add to the new column
new_column_values = ['FIL', 'JPN', 'CHN', 'SK', 'SK', 'JPN', 'CHN', 'VIE']

# Add the new column to the DataFrame
pb['COUNTRY'] = new_column_values

# Now, the DataFrame 'df' will have a new column 'NewColumn' with the specified values

# %%
pb
# Out:
#    Rank           Gymnast  D Score  E Score  Pen.   Total Apparatus COUNTRY
# 0     1       Carlos Yulo      6.3    8.966     0  15.266        PB     FIL
# 1     2    Shinnosuke Oka      6.4    8.733     0  15.133        PB     JPN
# 2     3        Yin Dehang      6.4    8.700     0  15.100        PB     CHN
# 3     4     Ryu Sung-hyun      5.6    8.833     0  14.433        PB      SK
# 4     5        Ryu Jae-ho      5.4    8.433     0  13.833        PB      SK
# 5     6   Takeru Kitazono      5.2    7.600     0  12.800        PB     JPN
# 6     7        Lan Xingyu      5.9    6.833     0  12.733        PB     CHN
# 7     8  Nguyễn Phước Hải      5.5    7.133     0  12.633        PB     VIE

# %%
# Define the values you want to add to the new column
new_column_values = ['CHN', 'JPN', 'FIL', 'TPE', 'UZB', 'JPN', 'CHN', 'KAZ']

# Add the new column to the DataFrame
hb['COUNTRY'] = new_column_values

# Now, the DataFrame 'df' will have a new column 'NewColumn' with the specified values

# %%
hb
# Out:
#    Rank                Gymnast  D Score  E Score  Pen.   Total Apparatus  \
# 0     1               Tian Hao      6.4    8.133     0  14.533        HB
# 1     2         Shinnosuke Oka      5.5    8.866     0  14.366        HB
# 2     3            Carlos Yulo      5.4    8.633     0  14.033        HB
# 3     4           Lee Chih-kai      5.1    8.233     0  13.333        HB
# 4     5  Rasuljon Abdurakhimov      4.9    8.300     0  13.200        HB
# 5     6        Takeru Kitazono      5.4    7.366     0  12.766        HB
# 6     7               Su Weide      5.3    6.566     0  11.866        HB
# 7     8           Milad Karimi      5.2    6.366     0  11.566        HB
#
#   COUNTRY
# 0     CHN
# 1     JPN
# 2     FIL
# 3     TPE
# 4     UZB
# 5     JPN
# 6     CHN
# 7     KAZ

# %%
combined_df = pd.concat([fl, hb, pb, ph, sr], axis=0, ignore_index=True)

# %%
df = combined_df.copy()

# %%
df["COUNTRY"].value_counts()
# Out:
# COUNTRY
# CHN    9
# JPN    9
# FIL    5
# KAZ    4
# SK     4
# UZB    3
# TPE    2
# VIE    2
# JOR    1
# HK     1
# Name: count, dtype: int64

# %%
df.rename(columns={'COUNTRY': 'Country'}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rank       40 non-null     int64
#  1   Gymnast    40 non-null     object
#  2   D Score    40 non-null     float64
#  3   E Score    40 non-null     float64
#  4   Pen.       40 non-null     int64
#  5   Total      40 non-null     float64
#  6   Apparatus  40 non-null     object
#  7   Country    40 non-null     object
# dtypes: float64(3), int64(2), object(3)
# memory usage: 2.6+ KB

# %%
df.columns
# Out:
# Index(['Rank', 'Gymnast', 'D Score', 'E Score', 'Pen.', 'Total', 'Apparatus',
#        'Country'],
#       dtype='object')

# %%
# Define the desired column order
desired_order = ['Rank', 'Gymnast','Country','Apparatus', 
                 'D Score', 'E Score', 'Pen.', 'Total']

# Reorder the columns in the DataFrame
df = df[desired_order]

# %%
df
# Out:
#     Rank                 Gymnast Country Apparatus  D Score  E Score  Pen.  \
# 0      1             Carlos Yulo     FIL        FX      6.3    9.000     0
# 1      2         Dmitriy Patanin     KAZ        FX      5.9    8.466     0
# 2      3                Su Weide     CHN        FX      6.3    8.033     0
# 3      4           Fumiya Sasaki     JPN        FX      5.8    8.433     0
# 4      5            Milad Karimi     KAZ        FX      6.3    8.100     0
# 5      6          Shinnosuke Oka     JPN        FX      5.9    8.433     0
# 6      7           Ryu Sung-hyun      SK        FX      5.8    7.633     0
# 7      8          John Ivan Cruz     FIL        FX      5.5    5.933     0
# 8      1                Tian Hao     CHN        HB      6.4    8.133     0
# 9      2          Shinnosuke Oka     JPN        HB      5.5    8.866     0
# 10     3             Carlos Yulo     FIL        HB      5.4    8.633     0
# ...

# %%
vt
# Out:
#    Rank                 Gymnast  ct1_D Score  vt_1E Score  vt1_Pen.  Score 1  \
# 0     1             Carlos Yulo          5.6        8.366         0   13.966
# 1     2     Abdulaziz Mirvaliev          5.6        9.066         0   14.666
# 2     3              Kim Jae-ho          5.2        9.133         0   14.333
# 3     4   Tikumporn Surintornta          5.2        8.033         0   13.233
# 4     5  Erkhembayar Usukhbayar          4.8        9.166         0   13.966
# 5     6    Muhammad Sharul Aimy          5.2        7.833         0   12.933
# 6     7                Ng Ka Ki          5.6        7.766         0   13.366
# 7     8   Juancho Miguel Besana          5.6        7.933         0   13.233
#
#    vt2_D Score  vt2_E Score vt_2Pen.  Score 2   Total COUNTRY
# 0          5.6        9.033        0   14.633  14.299     FIL
# 1          5.6        8.000     –0.1   13.500  14.083     UZB
# 2          5.2        8.000        0   13.200  13.766      SK
# ...

# %%
vt.rename(columns={'COUNTRY': 'Country'}, inplace=True)

# %%
vt.rename(columns={'ct1_D Score': 'vt1_D Score'}, inplace=True)

# %%
vt.columns
# Out:
# Index(['Rank', 'Gymnast', 'vt1_D Score', 'vt_1E Score', 'vt1_Pen.', 'Score 1',
#        'vt2_D Score', 'vt2_E Score', 'vt_2Pen.', 'Score 2', 'Total',
#        'Country'],
#       dtype='object')

# %%
# Define the desired column order
desired_order =['Rank', 'Gymnast', 'Country', 'vt1_D Score', 'vt_1E Score', 'vt1_Pen.', 'Score 1',
       'vt2_D Score', 'vt2_E Score', 'vt_2Pen.', 'Score 2', 'Total',
       ]

# Reorder the columns in the DataFrame
vt = vt[desired_order]

# %%
vt
# Out:
#    Rank                 Gymnast Country  vt1_D Score  vt_1E Score  vt1_Pen.  \
# 0     1             Carlos Yulo     FIL          5.6        8.366         0
# 1     2     Abdulaziz Mirvaliev     UZB          5.6        9.066         0
# 2     3              Kim Jae-ho      SK          5.2        9.133         0
# 3     4   Tikumporn Surintornta     THA          5.2        8.033         0
# 4     5  Erkhembayar Usukhbayar     MGL          4.8        9.166         0
# 5     6    Muhammad Sharul Aimy     MAS          5.2        7.833         0
# 6     7                Ng Ka Ki      HK          5.6        7.766         0
# 7     8   Juancho Miguel Besana     FIL          5.6        7.933         0
#
#    Score 1  vt2_D Score  vt2_E Score vt_2Pen.  Score 2   Total
# 0   13.966          5.6        9.033        0   14.633  14.299
# 1   14.666          5.6        8.000     –0.1   13.500  14.083
# 2   14.333          5.2        8.000        0   13.200  13.766
# ...

# %%
iaa
# Out:
#    Rank              Gymnast      FX      PH      SR      VT      PB      HB  \
# 0     1       Shinnosuke Oka  14.100  14.566  13.866  14.333  15.000  14.200
# 1     2          Carlos Yulo  14.966  13.266  14.300  14.866  15.066  13.466
# 2     3      Takeru Kitazono  13.900  14.333  13.433  14.366  14.966  14.433
# 3     4         Milad Karimi  14.466  13.500  13.300  14.700  13.366  14.366
# 4     5             Tian Hao  13.933  14.166  13.200  13.766  13.466  15.100
# 5     6           Yin Dehang  13.433  14.300  13.666  13.900  14.900  13.000
# 6     7        Ryu Sung-hyun  14.000  13.533  13.400  14.833  14.000  13.366
# 7     8  Khabibullo Ergashev  13.100  13.866  12.866  14.133  13.633  13.233
#
#     Total COUNTRY
# 0  86.065     JPN
# 1  85.930     FIL
# 2  85.431     JPN
# 3  83.698     KAZ
# 4  83.631     CHN
# 5  83.199     CHN
# 6  83.132      SK
# 7  80.831     UZB

# %%
iaa.rename(columns={'COUNTRY': 'Country'}, inplace=True)

# %%
iaa.columns
# Out:
# Index(['Rank', 'Gymnast', 'FX', 'PH', 'SR', 'VT', 'PB', 'HB', 'Total',
#        'Country'],
#       dtype='object')

# %%
# Define the desired column order
desired_order =['Rank', 'Gymnast','Country', 'FX', 'PH', 'SR', 'VT', 'PB', 'HB', 'Total'
       ]

# Reorder the columns in the DataFrame
iaa = iaa[desired_order]

# %%
iaa
# Out:
#    Rank              Gymnast Country      FX      PH      SR      VT      PB  \
# 0     1       Shinnosuke Oka     JPN  14.100  14.566  13.866  14.333  15.000
# 1     2          Carlos Yulo     FIL  14.966  13.266  14.300  14.866  15.066
# 2     3      Takeru Kitazono     JPN  13.900  14.333  13.433  14.366  14.966
# 3     4         Milad Karimi     KAZ  14.466  13.500  13.300  14.700  13.366
# 4     5             Tian Hao     CHN  13.933  14.166  13.200  13.766  13.466
# 5     6           Yin Dehang     CHN  13.433  14.300  13.666  13.900  14.900
# 6     7        Ryu Sung-hyun      SK  14.000  13.533  13.400  14.833  14.000
# 7     8  Khabibullo Ergashev     UZB  13.100  13.866  12.866  14.133  13.633
#
#        HB   Total
# 0  14.200  86.065
# 1  13.466  85.930
# 2  14.433  85.431
# 3  14.366  83.698
# 4  15.100  83.631
# 5  13.000  83.199
# 6  13.366  83.132
# 7  13.233  80.831

# %%
# df.to_csv("asia2023mens", index=False)  # Set index=False to exclude the index column

# %%
# vt.to_csv("asia2023vt", index=False)  # Set index=False to exclude the index column

# %%
# iaa.to_csv("asia2023iaa", index=False)  # Set index=False to exclude the index column
