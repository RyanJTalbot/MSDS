# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/cleandata9_15/men22_23.csv')

# %%
df
# Out:
#                        Name Country        Date Gender  \
# 0               Fredrik AAS     NOR  2023-02-26      m
# 1               Fredrik AAS     NOR  2023-02-26      m
# 2     Fredrik Bjornevik AAS     NOR  2023-08-05      m
# 3     Fredrik Bjornevik AAS     NOR  2023-08-05      m
# 4     Fredrik Bjornevik AAS     NOR  2023-08-05      m
# ...                     ...     ...         ...    ...
# 8573            Ahmet Önder     TUR  2023-06-04      m
# 8574            Ahmet Önder     TUR  2023-06-04      m
# 8575            Ahmet Önder     TUR  2023-06-04      m
# 8576            Ahmet Önder     TUR  2023-06-04      m
# 8577            Ahmet Önder     TUR  2023-06-04      m
#
#                            Competition  Round          Location Apparatus  \
# 0         FIG Apparatus World Cup 2023   qual  Cottbus, Germany        HB
# 1         FIG Apparatus World Cup 2023   qual  Cottbus, Germany        PH
# 2     2023 FISU World University Games   qual    Chengdu, China        FX
# 3     2023 FISU World University Games   qual    Chengdu, China        HB
# 4     2023 FISU World University Games   qual    Chengdu, China        PB
# ...                                ...    ...               ...       ...
# 8573       2023 Tel Aviv Challenge Cup  final  Tel Aviv, Israel        FX
# 8574       2023 Tel Aviv Challenge Cup   qual  Tel Aviv, Israel        FX
# 8575       2023 Tel Aviv Challenge Cup   qual  Tel Aviv, Israel        HB
# 8576       2023 Tel Aviv Challenge Cup  final  Tel Aviv, Israel        PB
# 8577       2023 Tel Aviv Challenge Cup   qual  Tel Aviv, Israel        PB
#
#       Rank  D_Score  E_Score  Penalty   Score  Total_Score
# 0     39.0      4.6    6.700      0.0  11.300       11.300
# 1     44.0      4.4    7.800      0.0  12.200       12.200
# 2     54.0      4.0    8.566      0.0  12.566       12.566
# 3     44.0      4.6    8.166      0.0  12.766       12.766
# 4     54.0      4.4    8.066      0.0  12.466       12.466
# ...    ...      ...      ...      ...     ...          ...
# 8573   8.0      4.8    7.050      0.0  11.850       11.850
# 8574   3.0      5.8    7.950      0.1  13.650       13.650
# 8575  10.0      5.0    6.250      0.0  11.250       11.250
# 8576   1.0      6.3    8.050      0.0  14.350       14.350
# 8577   8.0      6.0    7.400      0.0  13.400       13.400
#
# [8578 rows x 14 columns]

# %%
df["Country"].value_counts()
# Out:
# Country
# USA    1463
# GBR     768
# TUR     271
# ESP     260
# ITA     240
#        ...
# QAT       4
# THA       4
# PAK       3
# CCS       3
# IOM       1
# Name: count, Length: 93, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8578 entries, 0 to 8577
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         8578 non-null   object
#  1   Country      8435 non-null   object
#  2   Date         8424 non-null   object
#  3   Gender       8578 non-null   object
#  4   Competition  8578 non-null   object
#  5   Round        8578 non-null   object
#  6   Location     8578 non-null   object
#  7   Apparatus    8578 non-null   object
#  8   Rank         8578 non-null   float64
#  9   D_Score      8578 non-null   float64
#  10  E_Score      8578 non-null   float64
#  11  Penalty      8578 non-null   float64
#  12  Score        8578 non-null   float64
#  13  Total_Score  8578 non-null   float64
# dtypes: float64(6), object(8)
# memory usage: 938.3+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8578 entries, 0 to 8577
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         8578 non-null   object
#  1   Country      8435 non-null   object
#  2   Date         8424 non-null   datetime64[ns]
#  3   Gender       8578 non-null   object
#  4   Competition  8578 non-null   object
#  5   Round        8578 non-null   object
#  6   Location     8578 non-null   object
#  7   Apparatus    8578 non-null   object
#  8   Rank         8578 non-null   float64
#  9   D_Score      8578 non-null   float64
#  10  E_Score      8578 non-null   float64
#  11  Penalty      8578 non-null   float64
#  12  Score        8578 non-null   float64
#  13  Total_Score  8578 non-null   float64
# dtypes: datetime64[ns](1), float64(6), object(7)
# memory usage: 938.3+ KB

# %%
df["Location"].value_counts()
# Out:
# Location
# Liverpool, England           1606
# Antalya, Turkey               981
# Munich, Germany               881
# Chengdu, China                661
# San Jose, CA                  458
# Tampa, FL                     455
# Stuttgart, Germany            426
# Birmingham, England           413
# Cottbus, Germany              392
# San Salvador, El Salvador     355
# Baku, Azerbaijan              343
# Doha, Qatar                   308
# Cairo, Egypt                  271
# Osijek, Croatia.              231
# Frisco, Texas                 217
# Louisville, Kentucky          196
# Varna, Bulgaria               195
# Tel Aviv, Israel              142
# Carrara, Australia             47
# Name: count, dtype: int64

# %%
df["Round"].value_counts()
# Out:
# Round
# qual         6039
# final        1287
# AAfinal      1059
# TeamFinal     144
# AAqual         49
# Name: count, dtype: int64

# %%
df["Competition"].value_counts()
# Out:
# Competition
# FIG Apparatus World Cup 2023                             1314
# 2022 51st FIG Artistic Gymnastics World Championships    1064
# 2023 Senior European Championships                        981
# 2022 Senior European Championships                        881
# 2023 FISU World University Games                          557
# 2023 U.S. Championships                                   458
# 2022 U.S. Championships                                   455
# EnBW DTB Pokal Team Challenge 2023                        426
# BIRMINGHAM 2022 Commonwealth Games                        413
# 2023 Central American and Caribbean Games                 355
# 2022 British Gymnastics Championships                     275
# 2023 British Gymnastics Championships                     267
# 2023 Osijek Challenge Cup                                 231
# 2022 Winter Cup                                           217
# 2023 Winter Cup                                           196
# 2023 Varna World Challenge Cup Results                    195
# 2023 Tel Aviv Challenge Cup                               142
# 2023 FISH World University Games                          104
# Oceania Continental Championships 2023                     47
# Name: count, dtype: int64

# %%
df["Gender"].value_counts()
# Out:
# Gender
# m    8578
# Name: count, dtype: int64

# %%
df = df.drop(columns=["Location", "Round", "Competition", "Gender"])

# %%
df
# Out:
#                        Name Country       Date Apparatus  Rank  D_Score  \
# 0               Fredrik AAS     NOR 2023-02-26        HB  39.0      4.6
# 1               Fredrik AAS     NOR 2023-02-26        PH  44.0      4.4
# 2     Fredrik Bjornevik AAS     NOR 2023-08-05        FX  54.0      4.0
# 3     Fredrik Bjornevik AAS     NOR 2023-08-05        HB  44.0      4.6
# 4     Fredrik Bjornevik AAS     NOR 2023-08-05        PB  54.0      4.4
# ...                     ...     ...        ...       ...   ...      ...
# 8573            Ahmet Önder     TUR 2023-06-04        FX   8.0      4.8
# 8574            Ahmet Önder     TUR 2023-06-04        FX   3.0      5.8
# 8575            Ahmet Önder     TUR 2023-06-04        HB  10.0      5.0
# 8576            Ahmet Önder     TUR 2023-06-04        PB   1.0      6.3
# 8577            Ahmet Önder     TUR 2023-06-04        PB   8.0      6.0
#
#       E_Score  Penalty   Score  Total_Score
# 0       6.700      0.0  11.300       11.300
# 1       7.800      0.0  12.200       12.200
# 2       8.566      0.0  12.566       12.566
# 3       8.166      0.0  12.766       12.766
# 4       8.066      0.0  12.466       12.466
# ...       ...      ...     ...          ...
# 8573    7.050      0.0  11.850       11.850
# 8574    7.950      0.1  13.650       13.650
# 8575    6.250      0.0  11.250       11.250
# 8576    8.050      0.0  14.350       14.350
# 8577    7.400      0.0  13.400       13.400
#
# [8578 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8578 entries, 0 to 8577
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         8578 non-null   object
#  1   Country      8435 non-null   object
#  2   Date         8424 non-null   datetime64[ns]
#  3   Apparatus    8578 non-null   object
#  4   Rank         8578 non-null   float64
#  5   D_Score      8578 non-null   float64
#  6   E_Score      8578 non-null   float64
#  7   Penalty      8578 non-null   float64
#  8   Score        8578 non-null   float64
#  9   Total_Score  8578 non-null   float64
# dtypes: datetime64[ns](1), float64(6), object(3)
# memory usage: 670.3+ KB

# %%
df["Apparatus"].value_counts()
# Out:
# Apparatus
# PH     1438
# FX     1365
# PB     1339
# SR     1332
# HB     1312
# VT1     962
# VT2     516
# VT      279
# hb       35
# Name: count, dtype: int64

# %%
# Replace values in the 'Apparatus' column
replacement_dict = {'VT1': 'VT', 'VT2': 'VT', 'hb': 'HB'}
df['Apparatus'] = df['Apparatus'].replace(replacement_dict)

# %%
df["Apparatus"].value_counts()
# Out:
# Apparatus
# VT    1757
# PH    1438
# FX    1365
# HB    1347
# PB    1339
# SR    1332
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8578 entries, 0 to 8577
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         8578 non-null   object
#  1   Country      8435 non-null   object
#  2   Date         8424 non-null   datetime64[ns]
#  3   Apparatus    8578 non-null   object
#  4   Rank         8578 non-null   float64
#  5   D_Score      8578 non-null   float64
#  6   E_Score      8578 non-null   float64
#  7   Penalty      8578 non-null   float64
#  8   Score        8578 non-null   float64
#  9   Total_Score  8578 non-null   float64
# dtypes: datetime64[ns](1), float64(6), object(3)
# memory usage: 670.3+ KB

# %%
df['Name'] = df['Name'].str.lower()
df['Country'] = df['Country'].str.lower()

# %%
df["Country"].nunique()
# Out:
# 93

# %%
df["Name"].nunique()
# Out:
# 710

# %%
df
# Out:
#                        Name Country       Date Apparatus  Rank  D_Score  \
# 0               fredrik aas     nor 2023-02-26        HB  39.0      4.6
# 1               fredrik aas     nor 2023-02-26        PH  44.0      4.4
# 2     fredrik bjornevik aas     nor 2023-08-05        FX  54.0      4.0
# 3     fredrik bjornevik aas     nor 2023-08-05        HB  44.0      4.6
# 4     fredrik bjornevik aas     nor 2023-08-05        PB  54.0      4.4
# ...                     ...     ...        ...       ...   ...      ...
# 8573            ahmet önder     tur 2023-06-04        FX   8.0      4.8
# 8574            ahmet önder     tur 2023-06-04        FX   3.0      5.8
# 8575            ahmet önder     tur 2023-06-04        HB  10.0      5.0
# 8576            ahmet önder     tur 2023-06-04        PB   1.0      6.3
# 8577            ahmet önder     tur 2023-06-04        PB   8.0      6.0
#
#       E_Score  Penalty   Score  Total_Score
# 0       6.700      0.0  11.300       11.300
# 1       7.800      0.0  12.200       12.200
# 2       8.566      0.0  12.566       12.566
# 3       8.166      0.0  12.766       12.766
# 4       8.066      0.0  12.466       12.466
# ...       ...      ...     ...          ...
# 8573    7.050      0.0  11.850       11.850
# 8574    7.950      0.1  13.650       13.650
# 8575    6.250      0.0  11.250       11.250
# 8576    8.050      0.0  14.350       14.350
# 8577    7.400      0.0  13.400       13.400
#
# [8578 rows x 10 columns]

# %%
df["Name"].value_counts()
# Out:
# Name
# illia kovtun              91
# jake jarman               81
# adem asil                 71
# krisztofer meszaros       60
# asher hong                60
#                           ..
# emily whitehead            1
# tara donnelly              1
# none nourishourakchali     1
# danyella richards          1
# georgia godwin             1
# Name: count, Length: 710, dtype: int64

# %%
long_names = df[df['Name'].str.split().apply(len) > 3]

# %%
long_names["Name"]
# Out:
# 129         ahmad abu al soud
# 130         ahmad abu al soud
# 131         ahmad abu al soud
# 132         ahmad abu al soud
# 133         ahmad abu al soud
#                 ...
# 8190    chun hei vincent wong
# 8191    chun hei vincent wong
# 8537    luqman al hafiz zulfa
# 8538    luqman al hafiz zulfa
# 8539    luqman al hafiz zulfa
# Name: Name, Length: 145, dtype: object

# %%
new_df = df.copy()

# %%
def shorten_name(name):
    name_parts = name.split()
    if len(name_parts) > 2:
        return name_parts[0] + ' ' + name_parts[-1]
    else:
        return name

# Apply the function to the "Name" column
new_df['Name'] = new_df['Name'].apply(shorten_name)

# %%
long_names = new_df[new_df['Name'].str.split().apply(len) > 2]

# %%
long_names["Name"]
# Out:
# Series([], Name: Name, dtype: object)

# %%
new_df["Name"]
# Out:
# 0       fredrik aas
# 1       fredrik aas
# 2       fredrik aas
# 3       fredrik aas
# 4       fredrik aas
#            ...
# 8573    ahmet önder
# 8574    ahmet önder
# 8575    ahmet önder
# 8576    ahmet önder
# 8577    ahmet önder
# Name: Name, Length: 8578, dtype: object

# %%
new_df['Name'].nunique()
# Out:
# 678

# %%
new_df['Name'] = new_df['Name'].replace('fred richard', 'frederick richard')

# %%
new_df['Name'].nunique()
# Out:
# 677

# %%
df = new_df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8578 entries, 0 to 8577
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         8578 non-null   object
#  1   Country      8435 non-null   object
#  2   Date         8424 non-null   datetime64[ns]
#  3   Apparatus    8578 non-null   object
#  4   Rank         8578 non-null   float64
#  5   D_Score      8578 non-null   float64
#  6   E_Score      8578 non-null   float64
#  7   Penalty      8578 non-null   float64
#  8   Score        8578 non-null   float64
#  9   Total_Score  8578 non-null   float64
# dtypes: datetime64[ns](1), float64(6), object(3)
# memory usage: 670.3+ KB

# %%
df['Country'].fillna('unknown', inplace=True)
df['Date'].fillna('2023-01-01', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8578 entries, 0 to 8577
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         8578 non-null   object
#  1   Country      8578 non-null   object
#  2   Date         8578 non-null   datetime64[ns]
#  3   Apparatus    8578 non-null   object
#  4   Rank         8578 non-null   float64
#  5   D_Score      8578 non-null   float64
#  6   E_Score      8578 non-null   float64
#  7   Penalty      8578 non-null   float64
#  8   Score        8578 non-null   float64
#  9   Total_Score  8578 non-null   float64
# dtypes: datetime64[ns](1), float64(6), object(3)
# memory usage: 670.3+ KB

# %%
df.nunique()
# Out:
# Name           677
# Country         94
# Date            21
# Apparatus        6
# Rank           140
# D_Score         54
# E_Score        249
# Penalty         18
# Score          362
# Total_Score    429
# dtype: int64

# %%
df["Apparatus_code"] = df["Apparatus"].astype("category").cat.codes

# %%
df["Country_code"] = df["Country"].astype("category").cat.codes

# %%
df["Name_code"] = df["Name"].astype("category").cat.codes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8578 entries, 0 to 8577
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            8578 non-null   object
#  1   Country         8578 non-null   object
#  2   Date            8578 non-null   datetime64[ns]
#  3   Apparatus       8578 non-null   object
#  4   Rank            8578 non-null   float64
#  5   D_Score         8578 non-null   float64
#  6   E_Score         8578 non-null   float64
#  7   Penalty         8578 non-null   float64
#  8   Score           8578 non-null   float64
#  9   Total_Score     8578 non-null   float64
#  10  Apparatus_code  8578 non-null   int8
#  11  Country_code    8578 non-null   int8
#  12  Name_code       8578 non-null   int16
# dtypes: datetime64[ns](1), float64(6), int16(1), int8(2), object(3)
# memory usage: 703.8+ KB

# %%
final_df = df.copy()

# %%
final_df = df.drop(columns=["Apparatus_code", "Country_code", "Name_code"])

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8578 entries, 0 to 8577
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         8578 non-null   object
#  1   Country      8578 non-null   object
#  2   Date         8578 non-null   datetime64[ns]
#  3   Apparatus    8578 non-null   object
#  4   Rank         8578 non-null   float64
#  5   D_Score      8578 non-null   float64
#  6   E_Score      8578 non-null   float64
#  7   Penalty      8578 non-null   float64
#  8   Score        8578 non-null   float64
#  9   Total_Score  8578 non-null   float64
# dtypes: datetime64[ns](1), float64(6), object(3)
# memory usage: 670.3+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Visualization 1: Histogram of Rank
plt.figure(figsize=(8, 4))
plt.hist(final_df['Rank'], bins=10, edgecolor='k')
plt.xlabel('Rank')
plt.ylabel('Frequency')
plt.title('Histogram of Rank')
plt.show()

# %%
# Visualization 2: Box plot of D_Score
plt.figure(figsize=(8, 4))
sns.boxplot(x='D_Score', data=final_df)
plt.xlabel('D_Score')
plt.title('Box Plot of D_Score')
plt.show()

# %%
# Visualization 3: Scatter plot of E_Score vs. Total_Score
plt.figure(figsize=(8, 6))
sns.scatterplot(x='E_Score', y='Total_Score', data=final_df)
plt.xlabel('E_Score')
plt.ylabel('Total_Score')
plt.title('Scatter Plot of E_Score vs. Total_Score')
plt.show()

# %%
# Visualization 4: Countplot of Country
plt.figure(figsize=(8, 4))
sns.countplot(x='Country', data=final_df)
plt.xlabel('Country')
plt.ylabel('Count')
plt.title('Countplot of Country')
plt.show()

# %%
# # Filter the DataFrame to include only countries with count > 100
# country_counts = final_df['Country'].value_counts()
# countries_to_plot = country_counts[country_counts > 200].index
# final_df = final_df[final_df['Country'].isin(countries_to_plot)]

# # Visualization 4: Countplot of Country for countries with count > 100
# plt.figure(figsize=(8, 4))
# sns.countplot(x='Country', data=final_df)
# plt.xlabel('Country')
# plt.ylabel('Count')
# plt.title('Countplot of Country (Count > 100)')
# plt.show()

# %%
final_df
# Out:
#              Name Country       Date Apparatus  Rank  D_Score  E_Score  \
# 0     fredrik aas     nor 2023-02-26        HB  39.0      4.6    6.700
# 1     fredrik aas     nor 2023-02-26        PH  44.0      4.4    7.800
# 2     fredrik aas     nor 2023-08-05        FX  54.0      4.0    8.566
# 3     fredrik aas     nor 2023-08-05        HB  44.0      4.6    8.166
# 4     fredrik aas     nor 2023-08-05        PB  54.0      4.4    8.066
# ...           ...     ...        ...       ...   ...      ...      ...
# 8573  ahmet önder     tur 2023-06-04        FX   8.0      4.8    7.050
# 8574  ahmet önder     tur 2023-06-04        FX   3.0      5.8    7.950
# 8575  ahmet önder     tur 2023-06-04        HB  10.0      5.0    6.250
# 8576  ahmet önder     tur 2023-06-04        PB   1.0      6.3    8.050
# 8577  ahmet önder     tur 2023-06-04        PB   8.0      6.0    7.400
#
#       Penalty   Score  Total_Score
# 0         0.0  11.300       11.300
# 1         0.0  12.200       12.200
# 2         0.0  12.566       12.566
# 3         0.0  12.766       12.766
# 4         0.0  12.466       12.466
# ...       ...     ...          ...
# 8573      0.0  11.850       11.850
# 8574      0.1  13.650       13.650
# 8575      0.0  11.250       11.250
# 8576      0.0  14.350       14.350
# 8577      0.0  13.400       13.400
#
# [8578 rows x 10 columns]

# %%
final_df["Country"].value_counts()
# Out:
# Country
# usa    1463
# gbr     768
# tur     271
# esp     260
# ita     240
#        ...
# qat       4
# tha       4
# pak       3
# ccs       3
# iom       1
# Name: count, Length: 94, dtype: int64

# %%
df_sorted = final_df.sort_values(by=['Apparatus', 'Score'], ascending=[True, False])

# Create a dictionary to store top 5 performers for each apparatus
top5_by_apparatus_dict = {}

# Iterate over unique apparatus names
apparatus_names = final_df['Apparatus'].unique()
for apparatus in apparatus_names:
    top5_per_apparatus = df_sorted[df_sorted['Apparatus'] == apparatus]

    # Create a set to keep track of names already in the top 5 for this apparatus
    top5_names_set = set()

    top5_for_apparatus = []

    # Iterate through rows in this apparatus's DataFrame
    for _, row in top5_per_apparatus.iterrows():
        if row['Name'] not in top5_names_set and len(top5_for_apparatus) < 10:
            top5_for_apparatus.append(row)
            top5_names_set.add(row['Name'])

    # Convert the list of top 5 for this apparatus to a DataFrame
    top5_for_apparatus_df = pd.DataFrame(top5_for_apparatus)

    # Store the top 5 performers for this apparatus in the dictionary
    top5_by_apparatus_dict[apparatus] = top5_for_apparatus_df

# Display the top 5 performers for each apparatus including additional columns
for apparatus, top5 in top5_by_apparatus_dict.items():
    print(f"Top 5 on {apparatus}:")
    print(top5[['Name', 'Country', 'Score', 'Rank', 'D_Score', 'E_Score', 'Penalty']])
    print("\n")
# Out:
# Top 5 on HB:
#                    Name Country   Score  Rank  D_Score  E_Score  Penalty
# 2918    daiki hashimoto     jpn  15.266   1.0      6.7    8.566      0.0
# 8488       boheng zhang     chn  15.233   2.0      6.4    8.833      0.0
# 7013           cong shi     chn  15.200   3.0      6.2    9.000      0.0
# 7283            wei sun     chn  14.833   2.0      6.4    8.433      0.0
# 3681       milad karimi     kaz  14.800   1.0      6.3    8.500      0.0
# 4875       brody malone     usa  14.800   1.0      6.3    8.500      0.0
# 3804    shohei kawakami     jpn  14.700   5.0      6.2    8.500      0.0
# 6549  frederick richard     usa  14.600   6.0      6.2    8.400      0.0
# 1960        ryosuke doi     jpn  14.550   2.0      6.4    8.150      0.0
# 2352         joe fraser     eng  14.500   1.0      5.8    8.700      0.0
#
#
# Top 5 on PH:
#                     Name Country   Score  Rank  D_Score  E_Score  Penalty
# 4482            chih lee     tpe  15.500   1.0      6.5    9.000      0.0
# 4293    nariman kurbanov     kaz  15.400   1.0      6.6    8.800      0.0
# 1455        mc clenaghan     irl  15.300   1.0      6.4    8.900      0.0
# 5674  stephen nedoroscik     usa  15.233   2.0      6.4    8.833      0.0
# 8149             max obe     gbr  15.100   1.0      6.7    8.400      0.0
# 2920     daiki hashimoto     jpn  15.033   1.0      6.3    8.733      0.0
# 5063      rhys clenaghan     irl  15.033   2.0      6.3    8.733      0.0
# 3880    gagik khachikyan     arm  15.000   3.0      6.3    8.700      0.0
# 7020            yu shiao     tpe  14.930   3.0      6.1    8.833      0.0
# 129           ahmad soud     jor  14.866   2.0      6.3    8.566      0.0
#
#
# Top 5 on FX:
#                      Name Country   Score  Rank  D_Score  E_Score  Penalty
# 8317          carlos yulo     phi  15.266   1.0      6.4    8.866      0.0
# 350             adem asil     tur  15.233   1.0      6.0    9.233      0.0
# 3338          jake jarman     gbr  15.200   2.0      6.0    9.200      0.0
# 1999      artem dolgopyat     isr  14.966   1.0      6.1    8.866      0.0
# 1959          ryosuke doi     jpn  14.900   1.0      6.2    8.700      0.0
# 6487        giarnni moran     gbr  14.900   3.0      5.6    9.300      0.0
# 8130      luke whitehouse     gbr  14.900   1.0      6.5    8.400      0.0
# 8223  donnell whittenburg     usa  14.800   0.0      6.4    8.500      0.1
# 3554            paul juda     usa  14.750   0.0      5.5    9.250      0.0
# 5464         brody malone     usa  14.750   0.0      6.1    8.650      0.0
#
#
# Top 5 on PB:
#                  Name Country   Score  Rank  D_Score  E_Score  Penalty
# 8518     jingyuan zou     chn  16.166   1.0      6.9    9.266      0.0
# 6363  curran phillips     usa  15.550   0.0      6.8    8.750      0.0
# 1706     lukas dauser     ger  15.533   1.0      6.6    8.933      0.0
# 3610      yuya kamoto     jpn  15.433   2.0      6.5    8.933      0.0
# 4147     illia kovtun     ukr  15.433   1.0      6.6    8.833      0.0
# 5580     yul moldauer     usa  15.400   0.0      6.6    8.800      0.0
# 8335      carlos yulo     phi  15.400   1.0      6.5    8.900      0.0
# 8483     boheng zhang     chn  15.400   1.0      6.4    9.000      0.0
# 2327       joe fraser     gbr  15.350   1.0      6.4    8.950      0.0
# 7436        blake sun     usa  15.350   0.0      6.4    8.950      0.0
#
#
# Top 5 on SR:
#                         Name Country   Score  Rank  D_Score  E_Score  Penalty
# 4635                yang liu     chn  15.366   1.0      6.4    8.966      0.0
# 4440              xingyu lan     chn  15.360   1.0      6.4    8.966      0.0
# 8526            jingyuan zou     chn  15.260   2.0      6.3    8.966      0.0
# 6105  eleftherios petrounias     gre  15.133   1.0      6.2    8.933      0.0
# 357                adem asil     tur  15.033   2.0      6.3    8.733      0.0
# 8242     donnell whittenburg     usa  15.000   0.0      6.0    9.000      0.0
# 7036          nikita simonov     aze  14.966   2.0      6.2    8.766      0.0
# 3010           vinzenz hoeck     aut  14.866   3.0      6.2    8.666      0.0
# 7810        courtney tulloch     gbr  14.866   3.0      6.1    8.766      0.0
# 8491            boheng zhang     chn  14.833   4.0      6.0    8.833      0.0
#
#
# Top 5 on VT:
#                  Name Country   Score  Rank  D_Score  E_Score  Penalty
# 3359      jake jarman     gbr  15.550   1.0      6.0    0.000      0.0
# 3044       asher hong     usa  15.450   2.0      6.0    9.450      0.0
# 1765    artur davtyan     arm  15.266   1.0      5.6    9.666      0.0
# 394         adem asil     tur  15.250   3.0      5.6    9.650      0.0
# 8397       khoi young     usa  15.200   0.0      5.6    9.600      0.0
# 5896     mahdi olfati     iri  15.166   6.0      5.6    9.566      0.0
# 2995   harry hepworth     gbr  15.100   1.0      5.6    9.500      0.0
# 6414   igor radivilov     ukr  15.033   2.0      5.6    9.433      0.0
# 8345      carlos yulo     phi  15.033   1.0      5.6    9.433      0.0
# 7516  wataru tanigawa     jpn  15.000   1.0      6.0    9.000      0.0

# %%
final_df["Apparatus"].value_counts()
# Out:
# Apparatus
# VT    1757
# PH    1438
# FX    1365
# HB    1347
# PB    1339
# SR    1332
# Name: count, dtype: int64

# %%
# Create a dictionary to store top 5 performers for each apparatus
top5_by_apparatus_dict = {}

# Iterate over unique apparatus names
apparatus_names = final_df['Apparatus'].unique()
for apparatus in apparatus_names:
    top5_per_apparatus = df_sorted[df_sorted['Apparatus'] == apparatus]

    # Create a set to keep track of names already in the top 5 for this apparatus
    top5_names_set = set()

    top5_for_apparatus = []

    # Iterate through rows in this apparatus's DataFrame
    for _, row in top5_per_apparatus.iterrows():
        if row['Name'] not in top5_names_set and len(top5_for_apparatus) < 10:
            top5_for_apparatus.append(row)
            top5_names_set.add(row['Name'])

    # Convert the list of top 5 for this apparatus to a DataFrame
    top5_for_apparatus_df = pd.DataFrame(top5_for_apparatus)

    # Store the top 5 performers for this apparatus in the dictionary
    top5_by_apparatus_dict[apparatus] = top5_for_apparatus_df

# Accessing the top 5 performers for a specific apparatus (e.g., 'HB'):
top5_for_PB = top5_by_apparatus_dict['PB']

top5_for_VT = top5_by_apparatus_dict['VT']

top5_for_FX = top5_by_apparatus_dict['FX']

top5_for_PH = top5_by_apparatus_dict['PH']

top5_for_HB = top5_by_apparatus_dict['HB']

top5_for_SR = top5_by_apparatus_dict['SR']

# %%
top5_for_PB
# Out:
#                  Name Country       Date Apparatus  Rank  D_Score  E_Score  \
# 8518     jingyuan zou     chn 2022-11-06        PB   1.0      6.9    9.266
# 6363  curran phillips     usa 2023-08-27        PB   0.0      6.8    8.750
# 1706     lukas dauser     ger 2022-08-21        PB   1.0      6.6    8.933
# 3610      yuya kamoto     jpn 2022-11-06        PB   2.0      6.5    8.933
# 4147     illia kovtun     ukr 2023-04-16        PB   1.0      6.6    8.833
# 5580     yul moldauer     usa 2023-08-27        PB   0.0      6.6    8.800
# 8335      carlos yulo     phi 2023-03-12        PB   1.0      6.5    8.900
# 8483     boheng zhang     chn 2023-08-05        PB   1.0      6.4    9.000
# 2327       joe fraser     gbr 2022-03-27        PB   1.0      6.4    8.950
# 7436        blake sun     usa 2022-08-20        PB   0.0      6.4    8.950
#
#       Penalty   Score  Total_Score
# 8518      0.0  16.166       16.166
# 6363      0.0  15.550       15.550
# 1706      0.0  15.533       15.533
# 3610      0.0  15.433       15.433
# 4147      0.0  15.433       15.433
# 5580      0.0  15.400       15.400
# 8335      0.0  15.400       15.400
# 8483      0.0  15.400       15.400
# 2327      0.0  15.350       15.350
# 7436      0.0  15.350       15.350

# %%
usa = final_df[final_df["Country"] == "usa"]

# %%
# Sort the DataFrame by 'Apparatus' and 'Score' in descending order
df_sorted = usa.sort_values(by=['Apparatus', 'Score'], ascending=[True, False])

# %%
# Create a DataFrame to store the top 5 performers for each apparatus
top5_by_apparatus = []

# Iterate over unique apparatus names
apparatus_names = usa['Apparatus'].unique()
for apparatus in apparatus_names:
    top5_per_apparatus = df_sorted[df_sorted['Apparatus'] == apparatus]
    
    # Create a set to keep track of names already in the top 5 for this apparatus
    top5_names_set = set()
    
    top5_for_apparatus = []
    
    # Iterate through rows in this apparatus's DataFrame
    for _, row in top5_per_apparatus.iterrows():
        if row['Name'] not in top5_names_set and len(top5_for_apparatus) < 5:
            top5_for_apparatus.append(row)
            top5_names_set.add(row['Name'])
    
    # Convert the list of top 5 for this apparatus to a DataFrame
    top5_for_apparatus_df = pd.DataFrame(top5_for_apparatus)
    
    
    # Append the top 5 performers for this apparatus to the list
    top5_by_apparatus.append(top5_for_apparatus_df)

# Display the top 5 performers for each apparatus
for apparatus, top5 in zip(apparatus_names, top5_by_apparatus):
    print(f"Top 5 on {apparatus}:")
    print(top5[['Name', 'Country', 'Score']])
    print("\n")
# Out:
# Top 5 on FX:
#                      Name Country  Score
# 8223  donnell whittenburg     usa  14.80
# 3554            paul juda     usa  14.75
# 5464         brody malone     usa  14.75
# 5559         yul moldauer     usa  14.70
# 8387           khoi young     usa  14.65
#
#
# Top 5 on HB:
#                    Name Country   Score
# 4875       brody malone     usa  14.800
# 6549  frederick richard     usa  14.600
# 6154    curran phillips     usa  14.133
# 3556          paul juda     usa  14.100
# 1152          crew bold     usa  14.000
#
#
# Top 5 on PB:
#                  Name Country  Score
# 6363  curran phillips     usa  15.55
# 5580     yul moldauer     usa  15.40
# 7436        blake sun     usa  15.35
# 8196      colt walker     usa  15.35
# 1136     cameron bock     usa  14.95
#
#
# Top 5 on PH:
#                     Name Country   Score
# 5674  stephen nedoroscik     usa  15.233
# 7130         ian skirkey     usa  14.700
# 8384          khoi young     usa  14.700
# 5469        brody malone     usa  14.600
# 3195      patrick hoopes     usa  14.550
#
#
# Top 5 on SR:
#                      Name Country  Score
# 8242  donnell whittenburg     usa  15.00
# 3180           asher hong     usa  14.75
# 2124            alex diab     usa  14.40
# 4798           riley loos     usa  14.35
# 5584         yul moldauer     usa  14.30
#
#
# Top 5 on VT:
#                  Name Country  Score
# 3044       asher hong     usa  15.45
# 8397       khoi young     usa  15.20
# 1215  taylor burkhart     usa  14.90
# 4800       riley loos     usa  14.85
# 3128      dallas hale     usa  14.80

# %%
# Create a dictionary to store top 5 performers for each apparatus
top5_by_apparatus_dict = {}

# Iterate over unique apparatus names
apparatus_names = df['Apparatus'].unique()
for apparatus in apparatus_names:
    top5_per_apparatus = df_sorted[df_sorted['Apparatus'] == apparatus]

    # Create a set to keep track of names already in the top 5 for this apparatus
    top5_names_set = set()

    top5_for_apparatus = []

    # Iterate through rows in this apparatus's DataFrame
    for _, row in top5_per_apparatus.iterrows():
        if row['Name'] not in top5_names_set and len(top5_for_apparatus) < 5:
            top5_for_apparatus.append(row)
            top5_names_set.add(row['Name'])

    # Convert the list of top 5 for this apparatus to a DataFrame
    top5_for_apparatus_df = pd.DataFrame(top5_for_apparatus)

    # Store the top 5 performers for this apparatus in the dictionary
    top5_by_apparatus_dict[apparatus] = top5_for_apparatus_df

# Display the top 5 performers for each apparatus including additional columns
for apparatus, top5 in top5_by_apparatus_dict.items():
    print(f"Top 5 on {apparatus}:")
    print(top5[['Name', 'Country', 'Score', 'Rank', 'D_Score', 'E_Score', 'Penalty']])
    print("\n")
# Out:
# Top 5 on HB:
#                    Name Country   Score  Rank  D_Score  E_Score  Penalty
# 4875       brody malone     usa  14.800   1.0      6.3    8.500      0.0
# 6549  frederick richard     usa  14.600   6.0      6.2    8.400      0.0
# 6154    curran phillips     usa  14.133   2.0      5.5    8.633      0.0
# 3556          paul juda     usa  14.100   0.0      5.4    8.700      0.0
# 1152          crew bold     usa  14.000   0.0      5.7    8.300      0.0
#
#
# Top 5 on PH:
#                     Name Country   Score  Rank  D_Score  E_Score  Penalty
# 5674  stephen nedoroscik     usa  15.233   2.0      6.4    8.833      0.0
# 7130         ian skirkey     usa  14.700   2.0      6.5    8.200      0.0
# 8384          khoi young     usa  14.700   1.0      6.2    8.500      0.0
# 5469        brody malone     usa  14.600   0.0      6.1    8.500      0.0
# 3195      patrick hoopes     usa  14.550   2.0      6.4    8.150      0.0
#
#
# Top 5 on FX:
#                      Name Country  Score  Rank  D_Score  E_Score  Penalty
# 8223  donnell whittenburg     usa  14.80   0.0      6.4     8.50      0.1
# 3554            paul juda     usa  14.75   0.0      5.5     9.25      0.0
# 5464         brody malone     usa  14.75   0.0      6.1     8.65      0.0
# 5559         yul moldauer     usa  14.70   0.0      5.7     9.00      0.0
# 8387           khoi young     usa  14.65   0.0      5.6     9.05      0.0
#
#
# Top 5 on PB:
#                  Name Country  Score  Rank  D_Score  E_Score  Penalty
# 6363  curran phillips     usa  15.55   0.0      6.8     8.75      0.0
# 5580     yul moldauer     usa  15.40   0.0      6.6     8.80      0.0
# 7436        blake sun     usa  15.35   0.0      6.4     8.95      0.0
# 8196      colt walker     usa  15.35   0.0      6.2     9.15      0.0
# 1136     cameron bock     usa  14.95   0.0      5.9     9.05      0.0
#
#
# Top 5 on SR:
#                      Name Country  Score  Rank  D_Score  E_Score  Penalty
# 8242  donnell whittenburg     usa  15.00   0.0      6.0     9.00      0.0
# 3180           asher hong     usa  14.75   0.0      6.1     8.65      0.0
# 2124            alex diab     usa  14.40   0.0      5.9     8.50      0.0
# 4798           riley loos     usa  14.35   0.0      5.7     8.65      0.0
# 5584         yul moldauer     usa  14.30   0.0      5.8     8.50      0.0
#
#
# Top 5 on VT:
#                  Name Country  Score  Rank  D_Score  E_Score  Penalty
# 3044       asher hong     usa  15.45   2.0      6.0     9.45      0.0
# 8397       khoi young     usa  15.20   0.0      5.6     9.60      0.0
# 1215  taylor burkhart     usa  14.90   0.0      5.4     9.50      0.0
# 4800       riley loos     usa  14.85   0.0      5.6     9.25      0.0
# 3128      dallas hale     usa  14.80   0.0      5.2     9.60      0.0

# %%
usa = final_df[final_df["Country"] == "usa"]

# Sort the DataFrame by 'Apparatus' and 'Score' in descending order
df_sorted = usa.sort_values(by=['Apparatus', 'Score'], ascending=[True, False])

# Create a dictionary to store top 5 performers for each apparatus
top5_by_apparatus_dict = {}

# Iterate over unique apparatus names
apparatus_names = final_df['Apparatus'].unique()
for apparatus in apparatus_names:
    top5_per_apparatus = df_sorted[df_sorted['Apparatus'] == apparatus]

    # Create a set to keep track of names already in the top 5 for this apparatus
    top5_names_set = set()

    top5_for_apparatus = []

    # Iterate through rows in this apparatus's DataFrame
    for _, row in top5_per_apparatus.iterrows():
        if row['Name'] not in top5_names_set and len(top5_for_apparatus) < 5:
            top5_for_apparatus.append(row)
            top5_names_set.add(row['Name'])

    # Convert the list of top 5 for this apparatus to a DataFrame
    top5_for_apparatus_df = pd.DataFrame(top5_for_apparatus)

    # Store the top 5 performers for this apparatus in the dictionary
    top5_by_apparatus_dict[apparatus] = top5_for_apparatus_df

# Accessing the top 5 performers for a specific apparatus (e.g., 'HB'):
usa_PB = top5_by_apparatus_dict['PB']

usa_VT = top5_by_apparatus_dict['VT']

usa_FX = top5_by_apparatus_dict['FX']

usa_PH = top5_by_apparatus_dict['PH']

usa_HB = top5_by_apparatus_dict['HB']

usa_SR = top5_by_apparatus_dict['SR']

# %% [markdown]
# china, japan, uk

# %%
jpn = final_df[final_df["Country"] == "jpn"]

# Sort the DataFrame by 'Apparatus' and 'Score' in descending order
df_sorted = jpn.sort_values(by=['Apparatus', 'Score'], ascending=[True, False])


# Create a dictionary to store top 5 performers for each apparatus
top5_by_apparatus_dict = {}

# Iterate over unique apparatus names
apparatus_names = final_df['Apparatus'].unique()
for apparatus in apparatus_names:
    top5_per_apparatus = df_sorted[df_sorted['Apparatus'] == apparatus]

    # Create a set to keep track of names already in the top 5 for this apparatus
    top5_names_set = set()

    top5_for_apparatus = []

    # Iterate through rows in this apparatus's DataFrame
    for _, row in top5_per_apparatus.iterrows():
        if row['Name'] not in top5_names_set and len(top5_for_apparatus) < 5:
            top5_for_apparatus.append(row)
            top5_names_set.add(row['Name'])

    # Convert the list of top 5 for this apparatus to a DataFrame
    top5_for_apparatus_df = pd.DataFrame(top5_for_apparatus)

    # Store the top 5 performers for this apparatus in the dictionary
    top5_by_apparatus_dict[apparatus] = top5_for_apparatus_df

# Display the top 5 performers for each apparatus including additional columns
for apparatus, top5 in top5_by_apparatus_dict.items():
    print(f"Top 5 on {apparatus}:")
    print(top5[['Name', 'Country', 'Score', 'Rank', 'D_Score', 'E_Score', 'Penalty']])
    print("\n")
# Out:
# Top 5 on HB:
#                  Name Country   Score  Rank  D_Score  E_Score  Penalty
# 2918  daiki hashimoto     jpn  15.266   1.0      6.7    8.566      0.0
# 3804  shohei kawakami     jpn  14.700   5.0      6.2    8.500      0.0
# 1960      ryosuke doi     jpn  14.550   2.0      6.4    8.150      0.0
# 3608      yuya kamoto     jpn  14.400   6.0      6.0    8.400      0.0
# 5038   kazuki matsumi     jpn  14.233   1.0      5.9    8.333      0.0
#
#
# Top 5 on PH:
#                  Name Country   Score  Rank  D_Score  E_Score  Penalty
# 2920  daiki hashimoto     jpn  15.033   1.0      6.3    8.733      0.0
# 7277   takaaki sugino     jpn  14.833   4.0      6.4    8.433      0.0
# 3826      kazuma kaya     jpn  14.630   4.0      6.5    8.133      0.0
# 7502  kakeru tanigawa     jpn  14.600   2.0      6.4    8.200      0.0
# 1956      ryosuke doi     jpn  14.466   6.0      6.1    8.366      0.0
#
#
# Top 5 on FX:
#                  Name Country   Score  Rank  D_Score  E_Score  Penalty
# 1959      ryosuke doi     jpn  14.900   1.0      6.2    8.700      0.0
# 5210    kazuki minami     jpn  14.733   1.0      6.2    8.533      0.0
# 2917  daiki hashimoto     jpn  14.700   2.0      6.0    8.700      0.0
# 3821      kazuma kaya     jpn  14.330   1.0      5.7    8.633      0.0
# 7493  kakeru tanigawa     jpn  14.300   9.0      5.8    8.500      0.0
#
#
# Top 5 on PB:
#                  Name Country   Score  Rank  D_Score  E_Score  Penalty
# 3610      yuya kamoto     jpn  15.433   2.0      6.5    8.933      0.0
# 2907  daiki hashimoto     jpn  15.000   4.0      6.1    8.900      0.0
# 5040   kazuki matsumi     jpn  14.966   4.0      6.1    8.866      0.0
# 7494  kakeru tanigawa     jpn  14.933  10.0      6.3    8.633      0.0
# 7270   kaito sugimoto     jpn  14.900   2.0      6.3    8.600      0.0
#
#
# Top 5 on SR:
#                  Name Country   Score  Rank  D_Score  E_Score  Penalty
# 3612      yuya kamoto     jpn  14.500   6.0      6.4    8.100      0.0
# 2921  daiki hashimoto     jpn  14.333  12.0      5.8    8.533      0.0
# 3828      kazuma kaya     jpn  14.133  13.0      5.8    8.333      0.0
# 7273   kaito sugimoto     jpn  14.100  14.0      5.8    8.300      0.0
# 7515  wataru tanigawa     jpn  14.000  12.0      6.0    8.000      0.0
#
#
# Top 5 on VT:
#                  Name Country   Score  Rank  D_Score  E_Score  Penalty
# 7516  wataru tanigawa     jpn  15.000   1.0      6.0    9.000      0.0
# 2913  daiki hashimoto     jpn  14.900   2.0      5.6    9.300      0.0
# 5215    kazuki minami     jpn  14.866   6.0      5.6    9.266      0.0
# 1957      ryosuke doi     jpn  14.566  14.0      5.2    9.366      0.0
# 8307    none yonekura     jpn  14.466  12.0      5.6    8.866      0.0

# %%
jpn = final_df[final_df["Country"] == "jpn"]

# Sort the DataFrame by 'Apparatus' and 'Score' in descending order
df_sorted = jpn.sort_values(by=['Apparatus', 'Score'], ascending=[True, False])


# Create a dictionary to store top 5 performers for each apparatus
top5_by_apparatus_dict = {}

# Iterate over unique apparatus names
apparatus_names = final_df['Apparatus'].unique()
for apparatus in apparatus_names:
    top5_per_apparatus = df_sorted[df_sorted['Apparatus'] == apparatus]

    # Create a set to keep track of names already in the top 5 for this apparatus
    top5_names_set = set()

    top5_for_apparatus = []

    # Iterate through rows in this apparatus's DataFrame
    for _, row in top5_per_apparatus.iterrows():
        if row['Name'] not in top5_names_set and len(top5_for_apparatus) < 5:
            top5_for_apparatus.append(row)
            top5_names_set.add(row['Name'])

    # Convert the list of top 5 for this apparatus to a DataFrame
    top5_for_apparatus_df = pd.DataFrame(top5_for_apparatus)

    # Store the top 5 performers for this apparatus in the dictionary
    top5_by_apparatus_dict[apparatus] = top5_for_apparatus_df

# Accessing the top 5 performers for a specific apparatus (e.g., 'HB'):
jpn_PB = top5_by_apparatus_dict['PB']

jpn_VT = top5_by_apparatus_dict['VT']

jpn_FX = top5_by_apparatus_dict['FX']

jpn_PH = top5_by_apparatus_dict['PH']

jpn_HB = top5_by_apparatus_dict['HB']

jpn_SR = top5_by_apparatus_dict['SR']

# %%
jpn_SR
# Out:
#                  Name Country       Date Apparatus  Rank  D_Score  E_Score  \
# 3612      yuya kamoto     jpn 2022-11-06        SR   6.0      6.4    8.100
# 2921  daiki hashimoto     jpn 2023-08-05        SR  12.0      5.8    8.533
# 3828      kazuma kaya     jpn 2023-08-05        SR  13.0      5.8    8.333
# 7273   kaito sugimoto     jpn 2023-08-05        SR  14.0      5.8    8.300
# 7515  wataru tanigawa     jpn 2022-11-06        SR  12.0      6.0    8.000
#
#       Penalty   Score  Total_Score
# 3612      0.0  14.500       14.500
# 2921      0.0  14.333       14.333
# 3828      0.0  14.133       14.133
# 7273      0.0  14.100       14.100
# 7515      0.0  14.000       14.000

# %%
chn = final_df[final_df["Country"] == "chn"]

# Sort the DataFrame by 'Apparatus' and 'Score' in descending order
df_sorted = chn.sort_values(by=['Apparatus', 'Score'], ascending=[True, False])


# Create a dictionary to store top 5 performers for each apparatus
top5_by_apparatus_dict = {}

# Iterate over unique apparatus names
apparatus_names = final_df['Apparatus'].unique()
for apparatus in apparatus_names:
    top5_per_apparatus = df_sorted[df_sorted['Apparatus'] == apparatus]

    # Create a set to keep track of names already in the top 5 for this apparatus
    top5_names_set = set()

    top5_for_apparatus = []

    # Iterate through rows in this apparatus's DataFrame
    for _, row in top5_per_apparatus.iterrows():
        if row['Name'] not in top5_names_set and len(top5_for_apparatus) < 5:
            top5_for_apparatus.append(row)
            top5_names_set.add(row['Name'])

    # Convert the list of top 5 for this apparatus to a DataFrame
    top5_for_apparatus_df = pd.DataFrame(top5_for_apparatus)

    # Store the top 5 performers for this apparatus in the dictionary
    top5_by_apparatus_dict[apparatus] = top5_for_apparatus_df

# Display the top 5 performers for each apparatus including additional columns
for apparatus, top5 in top5_by_apparatus_dict.items():
    print(f"Top 5 on {apparatus}:")
    print(top5[['Name', 'Country', 'Score', 'Rank', 'D_Score', 'E_Score', 'Penalty']])
    print("\n")
# Out:
# Top 5 on HB:
#               Name Country   Score  Rank  D_Score  E_Score  Penalty
# 8488  boheng zhang     chn  15.233   2.0      6.4    8.833      0.0
# 7013      cong shi     chn  15.200   3.0      6.2    9.000      0.0
# 7283       wei sun     chn  14.833   2.0      6.4    8.433      0.0
# 7260      weide su     chn  13.866   9.0      6.0    7.866      0.0
# 8279  jiaxing yang     chn  13.666  24.0      5.3    8.366      0.0
#
#
# Top 5 on PH:
#               Name Country   Score  Rank  D_Score  E_Score  Penalty
# 8305    dehang yin     chn  14.500   4.0      6.2    8.300      0.0
# 8484  boheng zhang     chn  14.500   1.0      6.0    8.500      0.0
# 8525  jingyuan zou     chn  14.366   4.0      5.3    9.066      0.0
# 7008      cong shi     chn  14.333   2.0      5.7    8.633      0.0
# 4439    xingyu lan     chn  13.866   7.0      5.7    8.166      0.0
#
#
# Top 5 on FX:
#               Name Country   Score  Rank  D_Score  E_Score  Penalty
# 8469  boheng zhang     chn  14.500   5.0      6.1    8.400      0.0
# 7011      cong shi     chn  13.866  11.0      5.4    8.466      0.0
# 1415  zhilong chen     chn  13.466   9.0      6.1    7.366      0.0
# 4435    xingyu lan     chn  13.466  23.0      5.5    7.966      0.0
# 8278  jiaxing yang     chn  13.300  52.0      6.1    7.200      0.0
#
#
# Top 5 on PB:
#               Name Country   Score   Rank  D_Score  E_Score  Penalty
# 8518  jingyuan zou     chn  16.166    1.0      6.9    9.266      0.0
# 8483  boheng zhang     chn  15.400    1.0      6.4    9.000      0.0
# 7007      cong shi     chn  14.700    2.0      6.0    8.700      0.0
# 4437    xingyu lan     chn  14.400    6.0      6.1    8.300      0.0
# 8310       hao you     chn  12.700  106.0      6.4    6.300      0.0
#
#
# Top 5 on SR:
#               Name Country   Score  Rank  D_Score  E_Score  Penalty
# 4635      yang liu     chn  15.366   1.0      6.4    8.966      0.0
# 4440    xingyu lan     chn  15.360   1.0      6.4    8.966      0.0
# 8526  jingyuan zou     chn  15.260   2.0      6.3    8.966      0.0
# 8491  boheng zhang     chn  14.833   4.0      6.0    8.833      0.0
# 8313       hao you     chn  14.633   4.0      6.5    8.133      0.0
#
#
# Top 5 on VT:
#               Name Country   Score  Rank  D_Score  E_Score  Penalty
# 8479  boheng zhang     chn  14.900   2.0      5.6    9.300      0.0
# 7010      cong shi     chn  14.666   3.0      5.6    9.066      0.0
# 7261      weide su     chn  14.600   7.0      5.6    9.100      0.1
# 8281  jiaxing yang     chn  14.466  19.0      5.6    8.966      0.1
# 4442    xingyu lan     chn  14.430  11.0      5.6    8.833      0.0

# %%
chn = final_df[final_df["Country"] == "chn"]

# Sort the DataFrame by 'Apparatus' and 'Score' in descending order
df_sorted = chn.sort_values(by=['Apparatus', 'Score'], ascending=[True, False])


# Create a dictionary to store top 5 performers for each apparatus
top5_by_apparatus_dict = {}

# Iterate over unique apparatus names
apparatus_names = final_df['Apparatus'].unique()
for apparatus in apparatus_names:
    top5_per_apparatus = df_sorted[df_sorted['Apparatus'] == apparatus]

    # Create a set to keep track of names already in the top 5 for this apparatus
    top5_names_set = set()

    top5_for_apparatus = []

    # Iterate through rows in this apparatus's DataFrame
    for _, row in top5_per_apparatus.iterrows():
        if row['Name'] not in top5_names_set and len(top5_for_apparatus) < 5:
            top5_for_apparatus.append(row)
            top5_names_set.add(row['Name'])

    # Convert the list of top 5 for this apparatus to a DataFrame
    top5_for_apparatus_df = pd.DataFrame(top5_for_apparatus)

    # Store the top 5 performers for this apparatus in the dictionary
    top5_by_apparatus_dict[apparatus] = top5_for_apparatus_df

# Accessing the top 5 performers for a specific apparatus (e.g., 'HB'):
chn_PB = top5_by_apparatus_dict['PB']

chn_VT = top5_by_apparatus_dict['VT']

chn_FX = top5_by_apparatus_dict['FX']

chn_PH = top5_by_apparatus_dict['PH']

chn_HB = top5_by_apparatus_dict['HB']

chn_SR = top5_by_apparatus_dict['SR']

# %%
gbr = final_df[final_df["Country"] == "gbr"]

# Sort the DataFrame by 'Apparatus' and 'Score' in descending order
df_sorted = gbr.sort_values(by=['Apparatus', 'Score'], ascending=[True, False])


# Create a dictionary to store top 5 performers for each apparatus
top5_by_apparatus_dict = {}

# Iterate over unique apparatus names
apparatus_names = final_df['Apparatus'].unique()
for apparatus in apparatus_names:
    top5_per_apparatus = df_sorted[df_sorted['Apparatus'] == apparatus]

    # Create a set to keep track of names already in the top 5 for this apparatus
    top5_names_set = set()

    top5_for_apparatus = []

    # Iterate through rows in this apparatus's DataFrame
    for _, row in top5_per_apparatus.iterrows():
        if row['Name'] not in top5_names_set and len(top5_for_apparatus) < 5:
            top5_for_apparatus.append(row)
            top5_names_set.add(row['Name'])

    # Convert the list of top 5 for this apparatus to a DataFrame
    top5_for_apparatus_df = pd.DataFrame(top5_for_apparatus)

    # Store the top 5 performers for this apparatus in the dictionary
    top5_by_apparatus_dict[apparatus] = top5_for_apparatus_df

# Display the top 5 performers for each apparatus including additional columns
for apparatus, top5 in top5_by_apparatus_dict.items():
    print(f"Top 5 on {apparatus}:")
    print(top5[['Name', 'Country', 'Score', 'Rank', 'D_Score', 'E_Score', 'Penalty']])
    print("\n")
# Out:
# Top 5 on HB:
#                   Name Country   Score  Rank  D_Score  E_Score  Penalty
# 2324        joe fraser     gbr  14.400   1.0      5.7    8.700      0.0
# 2848        james hall     gbr  14.066   1.0      5.5    8.566      0.0
# 7676        adam tobin     gbr  13.850   1.0      5.2    8.650      0.0
# 3352       jake jarman     gbr  13.750   2.0      4.8    8.950      0.0
# 3730  pavel karnejenko     gbr  13.600   3.0      4.6    9.000      0.0
#
#
# Top 5 on PH:
#                Name Country   Score  Rank  D_Score  E_Score  Penalty
# 8149        max obe     gbr  15.100   1.0      6.7    8.400      0.0
# 2339     joe fraser     gbr  14.600   1.0      6.1    8.500      0.0
# 4592    jamie lewis     gbr  14.600   2.0      6.5    8.100      0.0
# 5649  joshua nathan     gbr  14.350   3.0      6.1    8.250      0.0
# 2837     james hall     gbr  14.033  13.0      6.2    7.833      0.0
#
#
# Top 5 on FX:
#                   Name Country  Score  Rank  D_Score  E_Score  Penalty
# 3338       jake jarman     gbr   15.2   2.0      6.0      9.2      0.0
# 6487     giarnni moran     gbr   14.9   3.0      5.6      9.3      0.0
# 8130   luke whitehouse     gbr   14.9   1.0      6.5      8.4      0.0
# 2986    harry hepworth     gbr   14.6   1.0      6.3      8.3      0.0
# 7809  courtney tulloch     gbr   14.6   4.0      5.6      9.0      0.0
#
#
# Top 5 on PB:
#                   Name Country   Score  Rank  D_Score  E_Score  Penalty
# 2327        joe fraser     gbr  15.350   1.0      6.4    8.950      0.0
# 6476     giarnni moran     gbr  14.966   8.0      6.4    8.566      0.0
# 3353       jake jarman     gbr  14.700   1.0      5.9    8.800      0.0
# 3722  pavel karnejenko     gbr  14.350   2.0      5.4    8.950      0.0
# 812        brinn bevan     gbr  14.300   3.0      5.7    8.600      0.0
#
#
# Top 5 on SR:
#                   Name Country   Score  Rank  D_Score  E_Score  Penalty
# 7810  courtney tulloch     gbr  14.866   3.0      6.1    8.766      0.0
# 3735  pavel karnejenko     gbr  14.350   2.0      5.6    8.750      0.0
# 2341        joe fraser     gbr  14.266   9.0      5.6    8.666      0.0
# 7682        adam tobin     gbr  14.100   3.0      5.4    8.700      0.0
# 2987    harry hepworth     gbr  13.866  14.0      5.4    8.466      0.0
#
#
# Top 5 on VT:
#                   Name Country   Score  Rank  D_Score  E_Score  Penalty
# 3359       jake jarman     gbr  15.550   1.0      6.0    0.000      0.0
# 2995    harry hepworth     gbr  15.100   1.0      5.6    9.500      0.0
# 6493     giarnni moran     gbr  14.966   3.0      5.6    9.366      0.0
# 7813  courtney tulloch     gbr  14.800   7.0      5.6    9.200      0.0
# 8101        david weir     gbr  14.700   2.0      5.2    9.500      0.0

# %%
gbr = final_df[final_df["Country"] == "gbr"]

# Sort the DataFrame by 'Apparatus' and 'Score' in descending order
df_sorted = gbr.sort_values(by=['Apparatus', 'Score'], ascending=[True, False])


# Create a dictionary to store top 5 performers for each apparatus
top5_by_apparatus_dict = {}

# Iterate over unique apparatus names
apparatus_names = final_df['Apparatus'].unique()
for apparatus in apparatus_names:
    top5_per_apparatus = df_sorted[df_sorted['Apparatus'] == apparatus]

    # Create a set to keep track of names already in the top 5 for this apparatus
    top5_names_set = set()

    top5_for_apparatus = []

    # Iterate through rows in this apparatus's DataFrame
    for _, row in top5_per_apparatus.iterrows():
        if row['Name'] not in top5_names_set and len(top5_for_apparatus) < 5:
            top5_for_apparatus.append(row)
            top5_names_set.add(row['Name'])

    # Convert the list of top 5 for this apparatus to a DataFrame
    top5_for_apparatus_df = pd.DataFrame(top5_for_apparatus)

    # Store the top 5 performers for this apparatus in the dictionary
    top5_by_apparatus_dict[apparatus] = top5_for_apparatus_df

# Accessing the top 5 performers for a specific apparatus (e.g., 'HB'):
gbr_PB = top5_by_apparatus_dict['PB']

gbr_VT = top5_by_apparatus_dict['VT']

gbr_FX = top5_by_apparatus_dict['FX']

gbr_PH = top5_by_apparatus_dict['PH']

gbr_HB = top5_by_apparatus_dict['HB']

gbr_SR = top5_by_apparatus_dict['SR']

# %%
gbr_PB
# Out:
#                   Name Country       Date Apparatus  Rank  D_Score  E_Score  \
# 2327        joe fraser     gbr 2022-03-27        PB   1.0      6.4    8.950
# 6476     giarnni moran     gbr 2022-11-06        PB   8.0      6.4    8.566
# 3353       jake jarman     gbr 2023-03-26        PB   1.0      5.9    8.800
# 3722  pavel karnejenko     gbr 2022-03-27        PB   2.0      5.4    8.950
# 812        brinn bevan     gbr 2022-03-27        PB   3.0      5.7    8.600
#
#       Penalty   Score  Total_Score
# 2327      0.0  15.350       15.350
# 6476      0.0  14.966       14.966
# 3353      0.0  14.700       14.700
# 3722      0.0  14.350       14.350
# 812       0.0  14.300       14.300
