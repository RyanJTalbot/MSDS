# %%
import pandas as pd
import numpy as np

# %%
fx = pd.read_csv('../../../scraping/men/world_cup2020baku/world_cup_baku2020fx_qual.csv')
hb = pd.read_csv('../../../scraping/men/world_cup2020baku/world_cup_baku2020hb_qual.csv')
pb = pd.read_csv('../../../scraping/men/world_cup2020baku/world_cup_baku2020pb_qual.csv')
ph = pd.read_csv('../../../scraping/men/world_cup2020baku/world_cup_baku2020ph_qual.csv')
sr = pd.read_csv('../../../scraping/men/world_cup2020baku/world_cup_baku2020sr_qual.csv')
vt = pd.read_csv('../../../scraping/men/world_cup2020baku/world_cup_baku2020vt.csv')

# %%
country_to_noc = {
    'Afghanistan': 'AFG',
    'Netherlands Antilles': 'AHO',
    'Albania': 'ALB',
    'Algeria': 'ALG',
    'Andorra': 'AND',
    'Angola': 'ANG',
    'Antigua & Barbuda': 'ANT',
    'Argentina': 'ARG',
    'Armenia': 'ARM',
    'Aruba': 'ARU',
    'American Samoa': 'ASA',
    'Australia': 'AUS',
    'Austria': 'AUT',
    'Azerbaijan': 'AZE',
    'Bahamas': 'BAH',
    'Bangladesh': 'BAN',
    'Barbados': 'BAR',
    'Burundi': 'BDI',
    'Belgium': 'BEL',
    'Benin': 'BEN',
    'Bermuda': 'BER',
    'Bhutan': 'BHU',
    'Bosnia-Herzegovina': 'BIH',
    'Belize': 'BIZ',
    'Belarus': 'BLR',
    'Bolivia': 'BOL',
    'Botswana': 'BOT',
    'Brazil': 'BRA',
    'Bahrain': 'BRN',
    'Brunei': 'BRU',
    'Bulgaria': 'BUL',
    'Burkina Faso': 'BUR',
    'Central African Republic': 'CAF',
    'Cambodia': 'CAM',
    'Canada': 'CAN',
    'Cayman Islands': 'CAY',
    'Republic of the Congo': 'CGO',
    'Chad': 'CHA',
    'Chile': 'CHI',
    'China': 'CHN',  # Add China
    'Ivory Coast (Côte d´Ivoire)': 'CIV',
    'Cameroon': 'CMR',
    'Democratic Republic of the Congo': 'COD',
    'Cook Islands': 'COK',
    'Colombia': 'COL',
    'Comoros': 'COM',
    'Cape Verde': 'CPV',
    'Costa Rica': 'CRC',
    'Croatia': 'CRO',
    'Cuba': 'CUB',
    'Cyprus': 'CYP',
    'Czech Republic': 'CZE',
    'Denmark': 'DEN',
    'Djibouti': 'DJI',
    'Dominica': 'DMA',
    'Dominican Republic': 'DOM',
    'Ecuador': 'ECU',
    'Egypt': 'EGY',
    'England': 'ENG',
    'Eritrea': 'ERI',
    'El Salvador': 'ESA',
    'Spain': 'ESP',
    'Estonia': 'EST',
    'Ethiopia': 'ETH',
    'Fiji': 'FIJ',
    'Finland': 'FIN',
    'France': 'FRA',
    'Federal Republic of Germany': 'FRG',
    'Micronesia': 'FSM',
    'Gabon': 'GAB',
    'The Gambia': 'GAM',
    'United Kingdom of Great Britain & Northern Ireland': 'GBR',
    'Guinea-Bissau': 'GBS',
    'German Democratic Republic': 'GDR',
    'Georgia': 'GEO',
    'Equatorial Guinea': 'GEQ',
    'Germany (previous to 1948 and from 1991)': 'GER',
    'Ghana': 'GHA',
    'Greece': 'GRE',
    'Grenada': 'GRN',
    'Guatemala': 'GUA',
    'Guinea': 'GUI',
    'Guam': 'GUM',
    'Guyana': 'GUY',
    'Haiti': 'HAI',
    'Hong Kong': 'HKG',
    'Honduras': 'HON',
    'Hungary': 'HUN',
    'Indonesia': 'INA',
    'India': 'IND',
    'Iran': 'IRI',
    'Ireland': 'IRL',
    'Iraq': 'IRQ',
    'Iceland': 'ISL',
    'Israel': 'ISR',
    'US Virgin Islands': 'ISV',
    'Italy': 'ITA',
    'British Virgin Islands': 'IVB',
    'Jamaica': 'JAM',
    'Jordan': 'JOR',
    'Japan': 'JPN',
    'Kazakhstan': 'KAZ',
    'Kenya': 'KEN',
    'Kyrgyzstan': 'KGZ',
    'Kiribati': 'KIR',
    'South Korea': 'KOR',
    'Saudi Arabia': 'KSA',
    'Kuwait': 'KUW',
    'Laos': 'LAO',
    'Latvia': 'LAT',
    'Libya': 'LBA',
    'Liberia': 'LBR',
    'Saint Lucia': 'LCA',
    'Lesotho': 'LES',
    'Lebanon': 'LIB',
    'Liechtenstein': 'LIE',
    'Lithuania': 'LTU',
    'Luxembourg': 'LUX',
    'Madagascar': 'MAD',
    'Morocco': 'MAR',
    'Malaysia': 'MAS',
    'Malawi': 'MAW',
    'Moldova': 'MDA',
    'Maldives': 'MDV',
    'Mexico': 'MEX',
    'Mongolia': 'MGL',
    'Marshall Islands': 'MHL',
    'Macedonia': 'MKD',
    'Mali': 'MLI',
    'Malta': 'MLT',
    'Montenegro': 'MNE',
    'Moldova': 'MOL',
    'Monaco': 'MON',
    'Mozambique': 'MOZ',
    'Mauritius': 'MAU',
    'Mauritania': 'MTN',
    'Myanmar': 'MYA',
    'Namibia': 'NAM',
    'Nicaragua': 'NCA',
    'Netherlands': 'NED',
    'Nepal': 'NEP',
    'Nigeria': 'NGR',
    'Northern Ireland': 'NI',
    'Niger': 'NIG',
    'Norway': 'NOR',
    'Northern Rhodesia': 'NRD',
    'Nauru': 'NRU',
    'New Zealand': 'NZL',
    'Oman': 'OMA',
    'Pakistan': 'PAK',
    'Panama': 'PAN',
    'Paraguay': 'PAR',
    'Peru': 'PER',
    'Philippines': 'PHI',
    'Palestine': 'PLE',
    'Palau': 'PLW',
    'Papua New Guinea': 'PNG',
    'Poland': 'POL',
    'Portugal': 'POR',
    'North Korea (Korean PDR)': 'PRK',
    'Puerto Rico': 'PUR',
    'Qatar': 'QAT',
    'Romania': 'ROU',
    'South Africa': 'RSA',
    'Russia': 'RUS',
    'Rwanda': 'RWA',
    'Samoa': 'SAM',
    'Saudi Arabia': 'SAU',
    'Serbia and Montenegro': 'SCG',
    'Scotland': 'Sco',
    'Senegal': 'SEN',
    'Seychelles': 'SEY',
    'Singapore': 'SIN',
    'Saint Kitts and Nevis': 'SKN',
    'South Korea': 'SKR',
    'Sierra Leone': 'SLE',
    'Slovenia': 'SLO',
    'San Marino Republic': 'SMR',
    'Solomon Islands': 'SOL',
    'Somalia': 'SOM',
    'Serbia': 'SRB',
    'Southern Rhodesia': 'SRD',
    'Sri Lanka': 'SRI',
    'São Tome and Principe': 'STP',
    'Sudan': 'SUD',
    'Switzerland': 'SUI',
    'Suriname': 'SUR',
    'Slovakia': 'SVK',
    'Sweden': 'SWE',
    'Swaziland': 'SWZ',
    'Syria': 'SYR',
    'Tanzania': 'TAN',
    'Czechoslovakia': 'tch',
    'Tonga': 'TGA',
    'Thailand': 'THA',
    'Tajikistan': 'TJK',
    'Turkmenistan': 'TKM',
    'Timor-Leste': 'TLS',
    'Togo': 'TOG',
    'Taiwan (Chinese Taipei)': 'TPE',
    'Trinidad & Tobago': 'TRI',
    'Tunisia': 'TUN',
    'Turkey': 'TUR',
    'Tuvalu': 'TUV',
    'United Arab Emirates': 'UAE',
    'Uganda': 'UGA',
    'Ukraine': 'UKR',
    'Unified Team': 'unt',
    'Soviet Union': 'urs',
    'Uruguay': 'URU',
    'United States': 'USA',
    'Uzbekistan': 'UZB',
    'Vanuatu': 'VAN',
    'Venezuela': 'VEN',
    'Vietnam': 'VIE',
    'St. Vincent and the Grenadines': 'VIN',
    'Wales': 'Wal',
    'West Indies': 'WI',
    'Yemen': 'YEM',
    'Former Yugoslavia': 'yug',
    'Former Yugoslavia': 'yug',
    'Zaire': 'zai',
    'Zambia': 'ZAM',
    'Zimbabwe': 'ZIM'
}

# %%
fx['Nation'].unique()
# Out:
# array(['Turkey', 'Russia', 'Kazakhstan', 'South Korea', 'Japan',
#        'Great Britain', 'Chile', 'Netherlands', 'Slovenia', 'Vietnam',
#        'Switzerland', 'Belarus', 'Croatia', 'Bulgaria', 'Georgia',
#        'Azerbaijan', 'Spain', 'New Zealand', 'Guatemala', 'Greece',
#        'Philippines', 'Poland', 'Finland', 'Mexico', 'Chinese Taipei'],
#       dtype=object)

# %%
fx['year']=2020
fx['round']='qual'


hb['year']=2020
hb['round']='qual'

pb['year']=2020
pb['round']='qual'

hb['year']=2020
hb['round']='qual'

ph['year']=2020
ph['round']='qual'

vt['year']=2020
vt['round']='qual'

# %%
fx.head()
# Out:
#    Rank                    Athlete       Nation    D      E   ND   Total  \
# 0     1  Abdelrahman Magdy Elgamal       Turkey  6.0  8.733  NaN  14.733
# 1     2            Kirill Prokopev       Russia  6.2  8.533  NaN  14.733
# 2     3               Milad Karimi   Kazakhstan  6.3  8.366  NaN  14.666
# 3     4              Ryu Sung-hyun  South Korea  6.5  8.033 -0.1  14.433
# 4     5              Kazuki Minami        Japan  6.4  7.966  NaN  14.366
#
#    year round
# 0  2020  qual
# 1  2020  qual
# 2  2020  qual
# 3  2020  qual
# 4  2020  qual

# %%
fx['Athlete'] = fx['Athlete'].str.lower()

pb['Athlete'] = pb['Athlete'].str.lower()

ph['Athlete'] = ph['Athlete'].str.lower()

sr['Athlete'] = sr['Athlete'].str.lower()

hb['Athlete'] = hb['Athlete'].str.lower()

vt['Athlete'] = vt['Athlete'].str.lower()

# %%
# country_to_noc = {
#     'Turkey': 'TUR',
#     'Russia': 'RUS',
#     'Kazakhstan': 'KAZ',
#     'South Korea': 'KOR',
#     'Japan': 'JPN',
#     'Great Britain': 'GBR',
#     'Chile': 'CHI',
#     'Netherlands': 'NED',
#     'Slovenia': 'SLO',
#     'Vietnam': 'VIE',
#     'Switzerland': 'SUI',
#     'Belarus': 'BLR',
#     'Croatia': 'CRO',
#     'Bulgaria': 'BUL',
#     'Georgia': 'GEO',
#     'Azerbaijan': 'AZE',
#     'Spain': 'ESP',
#     'New Zealand': 'NZL',
#     'Guatemala': 'GUA',
#     'Greece': 'GRE',
#     'Philippines': 'PHI',
#     'Poland': 'POL',
#     'Finland': 'FIN',
#     'Mexico': 'MEX',
#     'Chinese Taipei': 'TPE'
# }

# Apply the mapping to the "Nations" column and create a new column "NOC"
fx['Nation'] = fx['Nation'].map(country_to_noc)

# %%
fx['ND'].fillna(0, inplace=True)
pb['ND'].fillna(0, inplace=True)
ph['ND'].fillna(0, inplace=True)
sr['ND'].fillna(0, inplace=True)
hb['ND'].fillna(0, inplace=True)

vt['ND'].fillna(0, inplace=True)
vt['ND.1'].fillna(0, inplace=True)

# %%
hb['Nation'] = hb['Nation'].map(country_to_noc)
pb['Nation'] = pb['Nation'].map(country_to_noc)
sr['Nation'] = sr['Nation'].map(country_to_noc)
ph['Nation'] = ph['Nation'].map(country_to_noc)
vt['Nation'] = vt['Nation'].map(country_to_noc)

# %%
# fx.to_csv('wc20baku_fx.csv', index=False)
# pb.to_csv('wc20baku_pb.csv', index=False)
# ph.to_csv('wc20baku_ph.csv', index=False)
# sr.to_csv('wc20baku_sr.csv', index=False)
# hb.to_csv('wc20baku_hb.csv', index=False)
# vt.to_csv('wc20baku_vt.csv', index=False)
