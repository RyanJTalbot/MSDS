# %%
import pandas as pd
import numpy as np

# %%
df = df = pd.read_csv('../../scraping/olympics/women2016olympics/Gymnastics_ 2016_Olympics_women\'s_artistic_team_all_around.csv')

# %%
df
# Out:
#     Rank                      Team         vt         ub         bb  \
# 0    1.0             United States  46.866(1)  46.499(1)  45.533(1)
# 1    NaN         Simone Biles(USA)     15.933       14.8       15.3
# 2    NaN          Aly Raisman(USA)     15.833        NaN         15
# 3    NaN     Laurie Hernandez(USA)       15.1        NaN     15.233
# 4    NaN       Madison Kocian(USA)        NaN     15.933        NaN
# 5    NaN        Gabby Douglas(USA)        NaN     15.766        NaN
# 6    2.0                    Russia  45.733(2)  46.166(2)  42.757(5)
# 7    NaN      Aliya Mustafina(RUS)     15.133     15.933     14.958
# 8    NaN   Angelina Melnikova(RUS)       14.9     15.133     13.033
# 9    NaN      Seda Tutkhalyan(RUS)        NaN        NaN     14.766
# 10   NaN         Maria Paseka(RUS)       15.7        NaN        NaN
# 11   NaN    Daria Spiridonova(RUS)        NaN       15.1        NaN
# 12   3.0                     China  44.332(6)  45.007(4)  44.598(2)
# ...

# %%
new_df = df.iloc[::6]

# Reset index in the new DataFrame
new_df.reset_index(drop=True, inplace=True)

# %%
new_df
# Out:
#    Rank           Team         vt         ub         bb         fx    Total
# 0   1.0  United States  46.866(1)  46.499(1)  45.533(1)  45.999(1)  184.897
# 1   2.0         Russia  45.733(2)  46.166(2)  42.757(5)  42.032(5)  176.688
# 2   3.0          China  44.332(6)  45.007(4)  44.598(2)  42.066(4)  176.003
# 3   4.0          Japan  44.832(4)  44.466(6)  42.599(6)  42.474(3)  174.371
# 4   5.0  Great Britain  44.766(5)  44.866(5)  41.965(8)  42.765(2)  174.362
# 5   6.0        Germany  42.999(8)  45.899(3)  43.100(4)  41.674(7)  173.672
# 6   7.0    Netherlands  43.033(7)  43.666(7)  44.082(3)  41.666(8)  172.447
# 7   8.0         Brazil  44.899(3)  43.457(8)  41.999(7)  41.732(6)  172.087

# %%
dff = new_df.copy()

# %%
# Function to extract the number inside parentheses
def extract_number_from_parentheses(entry):
    import re
    match = re.search(r'\((\d+)\)', entry)
    if match:
        return match.group(1)
    else:
        return ''

# Apply the function to the "vt" column and create a new "vt_rank" column
dff['vt_rank'] = dff['vt'].apply(extract_number_from_parentheses)

# %%
# Function to extract the number inside parentheses
def extract_number_from_parentheses(entry):
    import re
    match = re.search(r'\((\d+)\)', entry)
    if match:
        return match.group(1)
    else:
        return ''

# Apply the function to the "vt" column and create a new "vt_rank" column
dff['ub_rank'] = dff['ub'].apply(extract_number_from_parentheses)

# %%
# Function to extract the number inside parentheses
def extract_number_from_parentheses(entry):
    import re
    match = re.search(r'\((\d+)\)', entry)
    if match:
        return match.group(1)
    else:
        return ''

# Apply the function to the "vt" column and create a new "vt_rank" column
dff['bb_rank'] = dff['bb'].apply(extract_number_from_parentheses)

# %%
# Function to extract the number inside parentheses
def extract_number_from_parentheses(entry):
    import re
    match = re.search(r'\((\d+)\)', entry)
    if match:
        return match.group(1)
    else:
        return ''

# Apply the function to the "vt" column and create a new "vt_rank" column
dff['fx_rank'] = dff['fx'].apply(extract_number_from_parentheses)

# %%
dff
# Out:
#    Rank           Team         vt         ub         bb         fx    Total  \
# 0   1.0  United States  46.866(1)  46.499(1)  45.533(1)  45.999(1)  184.897
# 1   2.0         Russia  45.733(2)  46.166(2)  42.757(5)  42.032(5)  176.688
# 2   3.0          China  44.332(6)  45.007(4)  44.598(2)  42.066(4)  176.003
# 3   4.0          Japan  44.832(4)  44.466(6)  42.599(6)  42.474(3)  174.371
# 4   5.0  Great Britain  44.766(5)  44.866(5)  41.965(8)  42.765(2)  174.362
# 5   6.0        Germany  42.999(8)  45.899(3)  43.100(4)  41.674(7)  173.672
# 6   7.0    Netherlands  43.033(7)  43.666(7)  44.082(3)  41.666(8)  172.447
# 7   8.0         Brazil  44.899(3)  43.457(8)  41.999(7)  41.732(6)  172.087
#
#   vt_rank ub_rank bb_rank fx_rank
# 0       1       1       1       1
# 1       2       2       5       5
# 2       6       4       2       4
# 3       4       6       6       3
# 4       5       5       8       2
# 5       8       3       4       7
# 6       7       7       3       8
# ...

# %%
new_df = dff.copy()

# %%
# Function to remove parentheses and numbers inside parentheses
def remove_parentheses(entry):
    import re
    return re.sub(r'\([^)]*\)', '', entry)

# List of columns to modify
columns_to_modify = ['vt', 'ub', 'bb', 'fx']

# Loop through the columns and apply the function
for col in columns_to_modify:
    new_df[col] = dff[col].apply(remove_parentheses)

# %%
new_df
# Out:
#    Rank           Team      vt      ub      bb      fx    Total vt_rank  \
# 0   1.0  United States  46.866  46.499  45.533  45.999  184.897       1
# 1   2.0         Russia  45.733  46.166  42.757  42.032  176.688       2
# 2   3.0          China  44.332  45.007  44.598  42.066  176.003       6
# 3   4.0          Japan  44.832  44.466  42.599  42.474  174.371       4
# 4   5.0  Great Britain  44.766  44.866  41.965  42.765  174.362       5
# 5   6.0        Germany  42.999  45.899  43.100  41.674  173.672       8
# 6   7.0    Netherlands  43.033  43.666  44.082  41.666  172.447       7
# 7   8.0         Brazil  44.899  43.457  41.999  41.732  172.087       3
#
#   ub_rank bb_rank fx_rank
# 0       1       1       1
# 1       2       5       5
# 2       4       2       4
# 3       6       6       3
# 4       5       8       2
# 5       3       4       7
# 6       7       3       8
# 7       8       7       6

# %%
new_df.columns
# Out:
# Index(['Rank', 'Team', 'vt', 'ub', 'bb', 'fx', 'Total', 'vt_rank', 'ub_rank',
#        'bb_rank', 'fx_rank'],
#       dtype='object')

# %%
# Specify the desired column order
new_column_order = ['Rank', 'Team', 'vt', 'vt_rank','ub','ub_rank', 'bb', 'bb_rank', 
                    'fx','fx_rank', 'Total']

# Use the reindex method to reorder the columns
new_df = new_df.reindex(columns=new_column_order)

# %%
new_df
# Out:
#    Rank           Team      vt vt_rank      ub ub_rank      bb bb_rank  \
# 0   1.0  United States  46.866       1  46.499       1  45.533       1
# 1   2.0         Russia  45.733       2  46.166       2  42.757       5
# 2   3.0          China  44.332       6  45.007       4  44.598       2
# 3   4.0          Japan  44.832       4  44.466       6  42.599       6
# 4   5.0  Great Britain  44.766       5  44.866       5  41.965       8
# 5   6.0        Germany  42.999       8  45.899       3  43.100       4
# 6   7.0    Netherlands  43.033       7  43.666       7  44.082       3
# 7   8.0         Brazil  44.899       3  43.457       8  41.999       7
#
#        fx fx_rank    Total
# 0  45.999       1  184.897
# 1  42.032       5  176.688
# 2  42.066       4  176.003
# 3  42.474       3  174.371
# 4  42.765       2  174.362
# 5  41.674       7  173.672
# 6  41.666       8  172.447
# 7  41.732       6  172.087

# %%
# new_df.to_csv('clean2016Olympics_women\'s_artistic_team_all-around.csv', index=False)

# %%
# Remove rows where "Rank" is not NaN
df = df[df['Rank'].isna()]

# Reset the index if needed
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#     Rank                      Team      vt      ub      bb      fx   Total
# 0    NaN         Simone Biles(USA)  15.933    14.8    15.3    15.8  61.833
# 1    NaN          Aly Raisman(USA)  15.833     NaN      15  15.366  46.199
# 2    NaN     Laurie Hernandez(USA)    15.1     NaN  15.233  14.833  45.166
# 3    NaN       Madison Kocian(USA)     NaN  15.933     NaN     NaN  15.933
# 4    NaN        Gabby Douglas(USA)     NaN  15.766     NaN     NaN  15.766
# 5    NaN      Aliya Mustafina(RUS)  15.133  15.933  14.958      14  60.024
# 6    NaN   Angelina Melnikova(RUS)    14.9  15.133  13.033  14.266  57.332
# 7    NaN      Seda Tutkhalyan(RUS)     NaN     NaN  14.766  13.766  28.532
# 8    NaN         Maria Paseka(RUS)    15.7     NaN     NaN     NaN  15.700
# 9    NaN    Daria Spiridonova(RUS)     NaN    15.1     NaN     NaN  15.100
# 10   NaN       Shang Chunsong(CHN)     NaN  14.333  15.066    14.7  44.099
# ...

# %%
df = df.drop(columns=["Rank"])

# %%
df = df.fillna(0)

# %%
df = df.rename(columns={'Team': 'Name'})

# %%
df
# Out:
#                         Name      vt      ub      bb      fx   Total
# 0          Simone Biles(USA)  15.933    14.8    15.3    15.8  61.833
# 1           Aly Raisman(USA)  15.833       0      15  15.366  46.199
# 2      Laurie Hernandez(USA)    15.1       0  15.233  14.833  45.166
# 3        Madison Kocian(USA)       0  15.933       0       0  15.933
# 4         Gabby Douglas(USA)       0  15.766       0       0  15.766
# 5       Aliya Mustafina(RUS)  15.133  15.933  14.958      14  60.024
# 6    Angelina Melnikova(RUS)    14.9  15.133  13.033  14.266  57.332
# 7       Seda Tutkhalyan(RUS)       0       0  14.766  13.766  28.532
# 8          Maria Paseka(RUS)    15.7       0       0       0  15.700
# 9     Daria Spiridonova(RUS)       0    15.1       0       0  15.100
# 10       Shang Chunsong(CHN)       0  14.333  15.066    14.7  44.099
# 11             Wang Yan(CHN)  14.733       0  14.466  14.733  43.932
# 12            Fan Yilin(CHN)       0  15.733  15.066       0  30.799
# ...

# %%
dfg = df.copy()

# %%
# Function to extract content inside parentheses
def extract_country(name):
    import re
    match = re.search(r'\((.*?)\)', name)
    if match:
        return match.group(1)
    else:
        return ''

# Create a new "Country" column by applying the function
dfg['Country'] = dfg['Name'].apply(extract_country)

# Remove words inside parentheses in the "Name" column
dfg['Name'] = dfg['Name'].str.replace(r'\(.*\)', '')

# %%
dfg['Name'] = dfg['Name'].str.replace(r'\([^)]*\)', '', regex=True)

# %%
dfg
# Out:
#                    Name      vt      ub      bb      fx   Total Country
# 0          Simone Biles  15.933    14.8    15.3    15.8  61.833     USA
# 1           Aly Raisman  15.833       0      15  15.366  46.199     USA
# 2      Laurie Hernandez    15.1       0  15.233  14.833  45.166     USA
# 3        Madison Kocian       0  15.933       0       0  15.933     USA
# 4         Gabby Douglas       0  15.766       0       0  15.766     USA
# 5       Aliya Mustafina  15.133  15.933  14.958      14  60.024     RUS
# 6    Angelina Melnikova    14.9  15.133  13.033  14.266  57.332     RUS
# 7       Seda Tutkhalyan       0       0  14.766  13.766  28.532     RUS
# 8          Maria Paseka    15.7       0       0       0  15.700     RUS
# 9     Daria Spiridonova       0    15.1       0       0  15.100     RUS
# 10       Shang Chunsong       0  14.333  15.066    14.7  44.099     CHN
# 11             Wang Yan  14.733       0  14.466  14.733  43.932     CHN
# ...

# %%
# dfg.to_csv('clean2016Olympics_women\'s_artistic_team_all-around_individual.csv', index=False)
