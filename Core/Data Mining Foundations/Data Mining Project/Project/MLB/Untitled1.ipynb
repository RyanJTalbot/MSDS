# %%
import pandas as pd 
import numpy as np

# %%
teams = pd.read_csv('baseballdatabank-2023.1/Core/Teams.csv')

# %%
teams
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome   W    L  ...   DP  \
# 0       1871  NaN    BS1      BNA   NaN     3   31    NaN  20   10  ...   24
# 1       1871  NaN    CH1      CNA   NaN     2   28    NaN  19    9  ...   16
# 2       1871  NaN    CL1      CFC   NaN     8   29    NaN  10   19  ...   15
# 3       1871  NaN    FW1      KEK   NaN     7   19    NaN   7   12  ...    8
# 4       1871  NaN    NY2      NNA   NaN     5   33    NaN  16   17  ...   14
# ...      ...  ...    ...      ...   ...   ...  ...    ...  ..  ...  ...  ...
# 3010    2022   NL    SLN      STL     C     1  162   81.0  93   69  ...  181
# 3011    2022   AL    TBA      TBD     E     1  162   81.0  86   76  ...  110
# 3012    2022   AL    TEX      TEX     W     4  162   81.0  68   94  ...  143
# 3013    2022   AL    TOR      TOR     E     2  162   81.0  92   70  ...  120
# 3014    2022   NL    WAS      WSN     E     5  162   81.0  55  107  ...  126
#
# ...

# %%
teamz = pd.read_csv('baseballdatabank-2023.1/upstream/Teams.csv')

# %%
teamz
# Out:
#       yearID lgID teamID franchID divID  Rank  Ghome DivWin WCWin LgWin WSWin  \
# 0       1871  NaN    BS1      BNA   NaN     3    NaN    NaN   NaN     N   NaN
# 1       1871  NaN    CH1      CNA   NaN     2    NaN    NaN   NaN     N   NaN
# 2       1871  NaN    CL1      CFC   NaN     8    NaN    NaN   NaN     N   NaN
# 3       1871  NaN    FW1      KEK   NaN     7    NaN    NaN   NaN     N   NaN
# 4       1871  NaN    NY2      NNA   NaN     5    NaN    NaN   NaN     N   NaN
# ...      ...  ...    ...      ...   ...   ...    ...    ...   ...   ...   ...
# 3010    2022   NL    SLN      STL     C     1   81.0      Y     N     N     N
# 3011    2022   AL    TBA      TBD     E     1   81.0      N     Y     N     N
# 3012    2022   AL    TEX      TEX     W     4   81.0      N     N     N     N
# 3013    2022   AL    TOR      TOR     E     2   81.0      N     Y     N     N
# 3014    2022   NL    WAS      WSN     E     5   81.0      N     N     N     N
#
# ...

# %%
series = pd.read_csv('baseballdatabank-2023.1/Core/SeriesPost.csv')

# %%
series
# Out:
#      yearID  round teamIDwinner lgIDwinner teamIDloser lgIDloser  wins  \
# 0      1884     WS          PRO         NL         NY4        AA     3
# 1      1885     WS          CHN         NL         SL4        AA     3
# 2      1886     WS          SL4         AA         CHN        NL     4
# 3      1887     WS          DTN         NL         SL4        AA    10
# 4      1888     WS          NY1         NL         SL4        AA     6
# ..      ...    ...          ...        ...         ...       ...   ...
# 373    2022  NLWC2          PHI         NL         SLN        NL     2
# 374    2022  NLDS1          PHI         NL         ATL        NL     3
# 375    2022  NLDS2          SDN         NL         LAN        NL     3
# 376    2022   NLCS          PHI         NL         SDN        NL     4
# 377    2022     WS          HOU         NL         PHI        NL     4
#
#      losses  ties
# 0         0     0
# 1         3     1
# 2         2     0
# 3         5     0
# ...

# %%
HomeGames = pd.read_csv('baseballdatabank-2023.1/Core/HomeGames.csv')

# %%
HomeGames
# Out:
#       year.key league.key team.key park.key  span.first   span.last  games  \
# 0         1871        NaN      BS1    BOS01  1871-05-16  1871-10-07     16
# 1         1871        NaN      BS1    NYC01  1871-05-27  1871-05-27      1
# 2         1871        NaN      CH1    CHI01  1871-05-08  1871-09-29     16
# 3         1871        NaN      CH1    NYC01  1871-10-30  1871-10-30      1
# 4         1871        NaN      CL1    CIN01  1871-05-13  1871-07-22      2
# ...        ...        ...      ...      ...         ...         ...    ...
# 3195      2022         NL      SLN    STL10  2022-04-07  2022-10-02     81
# 3196      2022         AL      TBA    STP01  2022-04-08  2022-09-25     81
# 3197      2022         AL      TEX    ARL03  2022-04-11  2022-10-05     81
# 3198      2022         AL      TOR    TOR02  2022-04-08  2022-10-02     81
# 3199      2022         NL      WAS    WAS11  2022-04-07  2022-10-02     81
#
#       openings  attendance
# 0           16       32600
# ...
