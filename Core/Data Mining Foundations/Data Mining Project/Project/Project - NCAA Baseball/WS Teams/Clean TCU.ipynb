# %%
import pandas as pd
import numpy as np

# %%
tcup = pd.read_csv('../Data/tcu-pitch.csv')
tcub = pd.read_csv('../Data/tcu-bat.csv')

# %%
tcup = tcup.drop(columns=['BK', 'IBB', 'W-L%', 'GF', 'CG', 'Rk', 'Notes'])
tcup.head()
# Out:
#              Name   Age  W  L    ERA   G  GS  SHO  SV    IP  ...  SO  HBP  WP  \
# 0     Ben Abeldt*  19.0  3  3   3.72  29   1    0   1  48.1  ...  63   10   3
# 1       Cam Brown  21.0  3  2   5.50  15  11    1   0  52.1  ...  59   10   7
# 2     Cohen Feser  20.0  1  0   2.73  19   0    0   1  29.2  ...  26    0   1
# 3  Justin Hackett  19.0  0  0  11.37   6   0    0   0   6.1  ...   9    0   4
# 4   Hunter Hodges  20.0  1  0   3.09  12   0    0   0  11.2  ...  12    0   3
#
#     BF   WHIP    H9  HR9  BB9   SO9  SO/W
# 0  217  1.386   8.2  0.7  4.3  11.7  2.74
# 1  242  1.452   6.7  0.9  6.4  10.1  1.59
# 2  114  1.011   7.3  0.6  1.8   7.9  4.33
# 3   30  2.053  17.1  2.8  1.4  12.8  9.00
# 4   50  1.629   8.5  1.5  6.2   9.3  1.50
#
# [5 rows x 25 columns]

# %%
tcup = tcup.sort_values(by=['BF'], ascending=False)
tcup.head()
# Out:
#                   Name   Age   W   L   ERA   G  GS  SHO  SV     IP  ...   SO  \
# 17          17 Players  20.2  42  22  4.73  64  64    4  12  563.1  ...  543
# 6         Kole Klecker  18.0  10   4  3.84  17  15    0   0   86.2  ...   69
# 13  Sam Stoutenborough  22.0   5   0  4.52  20   9    0   0   65.2  ...   55
# 1            Cam Brown  21.0   3   2  5.50  15  11    1   0   52.1  ...   59
# 0          Ben Abeldt*  19.0   3   3  3.72  29   1    0   1   48.1  ...   63
#
#     HBP  WP    BF   WHIP   H9  HR9  BB9   SO9  SO/W
# 17   62  53  2492  1.385  8.4  1.1  4.1   8.7  2.12
# 6     7   3   360  1.096  7.0  1.7  2.9   7.2  2.46
# 13    4   3   287  1.325  9.7  1.1  2.2   7.5  3.44
# 1    10   7   242  1.452  6.7  0.9  6.4  10.1  1.59
# 0    10   3   217  1.386  8.2  0.7  4.3  11.7  2.74
#
# [5 rows x 25 columns]

# %%
tcup = tcup[1:]
tcup.head()
# Out:
#                   Name   Age   W  L   ERA   G  GS  SHO  SV    IP  ...  SO  \
# 6         Kole Klecker  18.0  10  4  3.84  17  15    0   0  86.2  ...  69
# 13  Sam Stoutenborough  22.0   5  0  4.52  20   9    0   0  65.2  ...  55
# 1            Cam Brown  21.0   3  2  5.50  15  11    1   0  52.1  ...  59
# 0          Ben Abeldt*  19.0   3  3  3.72  29   1    0   1  48.1  ...  63
# 9      Louis Rodriguez  19.0   2  1  4.53  17   5    0   3  47.2  ...  49
#
#     HBP  WP   BF   WHIP   H9  HR9  BB9   SO9  SO/W
# 6     7   3  360  1.096  7.0  1.7  2.9   7.2  2.46
# 13    4   3  287  1.325  9.7  1.1  2.2   7.5  3.44
# 1    10   7  242  1.452  6.7  0.9  6.4  10.1  1.59
# 0    10   3  217  1.386  8.2  0.7  4.3  11.7  2.74
# 9     8   2  210  1.301  9.4  0.8  2.3   9.3  4.08
#
# [5 rows x 25 columns]

# %%
tcub = tcub.drop(columns=['IBB', 'Notes', 'Rk', 'SH', 'CS', 'SB', 'GDP'])
tcub.head()
# Out:
#                Name   Age   G   PA   AB   R   H  2B  3B  HR  RBI  BB  SO  \
# 0      David Bishop  20.0  35  135  117  20  25   5   1   2   17  16  43
# 1  Owen Blackledge*  20.0   5    6    4   0   1   1   0   0    1   1   3
# 2      Karson Bowen  18.0  52  231  200  45  71  14   0   6   46  22  45
# 3      Luke Boyers#  22.0  54  220  169  42  39   6   1   7   27  38  61
# 4      Kurtis Byrne  22.0  46  198  179  33  52   8   0  10   46  14  34
#
#       BA    OBP    SLG    OPS   TB  HBP  SF
# 0  0.214  0.311  0.325  0.636   38    1   1
# 1  0.250  0.333  0.500  0.833    2    0   1
# 2  0.355  0.422  0.515  0.937  103    4   4
# 3  0.231  0.404  0.402  0.806   68   11   0
# 4  0.291  0.349  0.503  0.851   90    3   2

# %%
tcub = tcub.sort_values(by=['PA'], ascending=False)
tcub.head()
# Out:
#                 Name   Age   G    PA    AB    R    H   2B  3B  HR  RBI   BB  \
# 16        16 Players  20.8  64  2640  2191  515  656  134  10  88  477  314
# 12    Tre Richardson  21.0  64   303   257   56   81   16   2   6   59   26
# 15   Brayden Taylor*  21.0  63   301   242   75   76   14   0  23   69   52
# 5       Austin Davis  23.0  64   287   236   48   66   18   0   9   55   31
# 7   Cole Fontenelle#  21.0  61   276   222   63   77   21   2  13   52   39
#
#      SO     BA    OBP    SLG    OPS    TB  HBP  SF
# 16  504  0.299  0.401  0.490  0.891  1074   79  31
# 12   46  0.315  0.393  0.463  0.856   119   10   5
# 15   56  0.314  0.439  0.657  1.096   159    4   3
# 5    46  0.280  0.369  0.470  0.839   111    7   8
# 7    46  0.347  0.464  0.635  1.099   141   12   3

# %%
tcub = tcub[1:]
tcub.head()
# Out:
#                 Name   Age   G   PA   AB   R   H  2B  3B  HR  RBI  BB  SO  \
# 12    Tre Richardson  21.0  64  303  257  56  81  16   2   6   59  26  46
# 15   Brayden Taylor*  21.0  63  301  242  75  76  14   0  23   69  52  56
# 5       Austin Davis  23.0  64  287  236  48  66  18   0   9   55  31  46
# 7   Cole Fontenelle#  21.0  61  276  222  63  77  21   2  13   52  39  46
# 11     Elijah Nunez*  21.0  59  269  221  56  64  16   2   3   35  34  55
#
#        BA    OBP    SLG    OPS   TB  HBP  SF
# 12  0.315  0.393  0.463  0.856  119   10   5
# 15  0.314  0.439  0.657  1.096  159    4   3
# 5   0.280  0.369  0.470  0.839  111    7   8
# 7   0.347  0.464  0.635  1.099  141   12   3
# 11  0.290  0.404  0.421  0.825   93    9   1

# %%
tcub = tcub[:10]
tcub
# Out:
#                 Name   Age   G   PA   AB   R   H  2B  3B  HR  RBI  BB  SO  \
# 12    Tre Richardson  21.0  64  303  257  56  81  16   2   6   59  26  46
# 15   Brayden Taylor*  21.0  63  301  242  75  76  14   0  23   69  52  56
# 5       Austin Davis  23.0  64  287  236  48  66  18   0   9   55  31  46
# 7   Cole Fontenelle#  21.0  61  276  222  63  77  21   2  13   52  39  46
# 11     Elijah Nunez*  21.0  59  269  221  56  64  16   2   3   35  34  55
# 13     Anthony Silva  19.0  57  246  209  51  71  10   0   7   47  23  29
# 2       Karson Bowen  18.0  52  231  200  45  71  14   0   6   46  22  45
# 3       Luke Boyers#  22.0  54  220  169  42  39   6   1   7   27  38  61
# 4       Kurtis Byrne  22.0  46  198  179  33  52   8   0  10   46  14  34
# 0       David Bishop  20.0  35  135  117  20  25   5   1   2   17  16  43
#
#        BA    OBP    SLG    OPS   TB  HBP  SF
# 12  0.315  0.393  0.463  0.856  119   10   5
# 15  0.314  0.439  0.657  1.096  159    4   3
# ...

# %%
tcub = tcub.drop(columns=['Name', 'Age'])
tcub
# Out:
#      G   PA   AB   R   H  2B  3B  HR  RBI  BB  SO     BA    OBP    SLG    OPS  \
# 12  64  303  257  56  81  16   2   6   59  26  46  0.315  0.393  0.463  0.856
# 15  63  301  242  75  76  14   0  23   69  52  56  0.314  0.439  0.657  1.096
# 5   64  287  236  48  66  18   0   9   55  31  46  0.280  0.369  0.470  0.839
# 7   61  276  222  63  77  21   2  13   52  39  46  0.347  0.464  0.635  1.099
# 11  59  269  221  56  64  16   2   3   35  34  55  0.290  0.404  0.421  0.825
# 13  57  246  209  51  71  10   0   7   47  23  29  0.340  0.430  0.488  0.918
# 2   52  231  200  45  71  14   0   6   46  22  45  0.355  0.422  0.515  0.937
# 3   54  220  169  42  39   6   1   7   27  38  61  0.231  0.404  0.402  0.806
# 4   46  198  179  33  52   8   0  10   46  14  34  0.291  0.349  0.503  0.851
# 0   35  135  117  20  25   5   1   2   17  16  43  0.214  0.311  0.325  0.636
#
#      TB  HBP  SF
# 12  119   10   5
# 15  159    4   3
# 5   111    7   8
# 7   141   12   3
# 11   93    9   1
# ...

# %%
df2 = tcub.mean(axis=0)
df2
# Out:
# G       55.5000
# PA     246.6000
# AB     205.2000
# R       48.9000
# H       62.2000
# 2B      12.8000
# 3B       0.8000
# HR       8.6000
# RBI     45.3000
# BB      29.5000
# SO      46.1000
# BA       0.2977
# OBP      0.3985
# SLG      0.4879
# OPS      0.8863
# TB     102.4000
# HBP      7.2000
# SF       2.8000
# dtype: float64

# %%
s = df2.sort_index()
tcubat_mean = s.to_frame().T
tcubat_mean
# Out:
#      2B   3B     AB      BA    BB     G     H  HBP   HR     OBP     OPS  \
# 0  12.8  0.8  205.2  0.2977  29.5  55.5  62.2  7.2  8.6  0.3985  0.8863
#
#       PA     R   RBI   SF     SLG    SO     TB
# 0  246.6  48.9  45.3  2.8  0.4879  46.1  102.4

# %%
# tcubat_mean.to_csv('tcu-bat-mean.csv', index=False)

# %%
tcup
# Out:
#                   Name   Age   W  L    ERA   G  GS  SHO  SV    IP  ...  SO  \
# 6         Kole Klecker  18.0  10  4   3.84  17  15    0   0  86.2  ...  69
# 13  Sam Stoutenborough  22.0   5  0   4.52  20   9    0   0  65.2  ...  55
# 1            Cam Brown  21.0   3  2   5.50  15  11    1   0  52.1  ...  59
# 0          Ben Abeldt*  19.0   3  3   3.72  29   1    0   1  48.1  ...  63
# 9      Louis Rodriguez  19.0   2  1   4.53  17   5    0   3  47.2  ...  49
# 15      Ryan Vanderhei  22.0   4  3   6.75  13   8    0   0  42.2  ...  43
# 11      Braeden Sloan*  19.0   2  3   6.63  11  10    0   0  38.0  ...  28
# 5        Chase Hoover*  19.0   1  1   5.14  13   4    0   0  35.0  ...  34
# 10         Luke Savage  21.0   5  3   2.50  16   1    0   2  36.0  ...  23
# 2          Cohen Feser  20.0   1  0   2.73  19   0    0   1  29.2  ...  26
# 16      Garrett Wright  21.0   2  2   3.24  18   0    0   5  25.0  ...  31
# ...

# %%
tcuip = tcup[:3]
tcuip
# Out:
#                   Name   Age   W  L   ERA   G  GS  SHO  SV    IP  ...  SO  \
# 6         Kole Klecker  18.0  10  4  3.84  17  15    0   0  86.2  ...  69
# 13  Sam Stoutenborough  22.0   5  0  4.52  20   9    0   0  65.2  ...  55
# 1            Cam Brown  21.0   3  2  5.50  15  11    1   0  52.1  ...  59
#
#     HBP  WP   BF   WHIP   H9  HR9  BB9   SO9  SO/W
# 6     7   3  360  1.096  7.0  1.7  2.9   7.2  2.46
# 13    4   3  287  1.325  9.7  1.1  2.2   7.5  3.44
# 1    10   7  242  1.452  6.7  0.9  6.4  10.1  1.59
#
# [3 rows x 25 columns]

# %%
tcup = tcup.sort_values(by=['G'], ascending=False)
tcupg = tcup[:3]
tcupg
# Out:
#                   Name   Age  W  L   ERA   G  GS  SHO  SV    IP  ...  SO  HBP  \
# 0          Ben Abeldt*  19.0  3  3  3.72  29   1    0   1  48.1  ...  63   10
# 13  Sam Stoutenborough  22.0  5  0  4.52  20   9    0   0  65.2  ...  55    4
# 2          Cohen Feser  20.0  1  0  2.73  19   0    0   1  29.2  ...  26    0
#
#     WP   BF   WHIP   H9  HR9  BB9   SO9  SO/W
# 0    3  217  1.386  8.2  0.7  4.3  11.7  2.74
# 13   3  287  1.325  9.7  1.1  2.2   7.5  3.44
# 2    1  114  1.011  7.3  0.6  1.8   7.9  4.33
#
# [3 rows x 25 columns]

# %%
frames = [tcupg, tcuip]

result = pd.concat(frames)
result
# Out:
#                   Name   Age   W  L   ERA   G  GS  SHO  SV    IP  ...  SO  \
# 0          Ben Abeldt*  19.0   3  3  3.72  29   1    0   1  48.1  ...  63
# 13  Sam Stoutenborough  22.0   5  0  4.52  20   9    0   0  65.2  ...  55
# 2          Cohen Feser  20.0   1  0  2.73  19   0    0   1  29.2  ...  26
# 6         Kole Klecker  18.0  10  4  3.84  17  15    0   0  86.2  ...  69
# 13  Sam Stoutenborough  22.0   5  0  4.52  20   9    0   0  65.2  ...  55
# 1            Cam Brown  21.0   3  2  5.50  15  11    1   0  52.1  ...  59
#
#     HBP  WP   BF   WHIP   H9  HR9  BB9   SO9  SO/W
# 0    10   3  217  1.386  8.2  0.7  4.3  11.7  2.74
# 13    4   3  287  1.325  9.7  1.1  2.2   7.5  3.44
# 2     0   1  114  1.011  7.3  0.6  1.8   7.9  4.33
# 6     7   3  360  1.096  7.0  1.7  2.9   7.2  2.46
# 13    4   3  287  1.325  9.7  1.1  2.2   7.5  3.44
# 1    10   7  242  1.452  6.7  0.9  6.4  10.1  1.59
#
# [6 rows x 25 columns]

# %%
result = result.drop_duplicates()
result
# Out:
#                   Name   Age   W  L   ERA   G  GS  SHO  SV    IP  ...  SO  \
# 0          Ben Abeldt*  19.0   3  3  3.72  29   1    0   1  48.1  ...  63
# 13  Sam Stoutenborough  22.0   5  0  4.52  20   9    0   0  65.2  ...  55
# 2          Cohen Feser  20.0   1  0  2.73  19   0    0   1  29.2  ...  26
# 6         Kole Klecker  18.0  10  4  3.84  17  15    0   0  86.2  ...  69
# 1            Cam Brown  21.0   3  2  5.50  15  11    1   0  52.1  ...  59
#
#     HBP  WP   BF   WHIP   H9  HR9  BB9   SO9  SO/W
# 0    10   3  217  1.386  8.2  0.7  4.3  11.7  2.74
# 13    4   3  287  1.325  9.7  1.1  2.2   7.5  3.44
# 2     0   1  114  1.011  7.3  0.6  1.8   7.9  4.33
# 6     7   3  360  1.096  7.0  1.7  2.9   7.2  2.46
# 1    10   7  242  1.452  6.7  0.9  6.4  10.1  1.59
#
# [5 rows x 25 columns]

# %%
result = result.drop(columns=['Name', 'Age'])
result
# Out:
#      W  L   ERA   G  GS  SHO  SV    IP   H   R  ...  SO  HBP  WP   BF   WHIP  \
# 0    3  3  3.72  29   1    0   1  48.1  44  32  ...  63   10   3  217  1.386
# 13   5  0  4.52  20   9    0   0  65.2  71  40  ...  55    4   3  287  1.325
# 2    1  0  2.73  19   0    0   1  29.2  24  10  ...  26    0   1  114  1.011
# 6   10  4  3.84  17  15    0   0  86.2  67  39  ...  69    7   3  360  1.096
# 1    3  2  5.50  15  11    1   0  52.1  39  35  ...  59   10   7  242  1.452
#
#      H9  HR9  BB9   SO9  SO/W
# 0   8.2  0.7  4.3  11.7  2.74
# 13  9.7  1.1  2.2   7.5  3.44
# 2   7.3  0.6  1.8   7.9  4.33
# 6   7.0  1.7  2.9   7.2  2.46
# 1   6.7  0.9  6.4  10.1  1.59
#
# [5 rows x 23 columns]

# %%
result.columns
# Out:
# Index(['W', 'L', 'ERA', 'G', 'GS', 'SHO', 'SV', 'IP', 'H', 'R', 'ER', 'HR',
#        'BB', 'SO', 'HBP', 'WP', 'BF', 'WHIP', 'H9', 'HR9', 'BB9', 'SO9',
#        'SO/W'],
#       dtype='object')

# %%
df2 = result[['W', 'L', 'ERA', 'G', 'GS', 'SHO', 'SV', 'IP', 'H', 'R', 'ER', 'HR',
       'BB', 'SO', 'HBP', 'WP', 'BF', 'WHIP', 'H9', 'HR9', 'BB9', 'SO9',
       'SO/W']].mean()

# %%
p = df2.sort_index()
tcupit_mean = p.to_frame().T
tcupit_mean
# Out:
#      BB   BB9     BF    ER    ERA     G   GS     H    H9  HBP  ...    L     R  \
# 0  22.0  3.52  244.0  26.2  4.062  20.0  7.2  49.0  7.78  6.2  ...  1.8  31.2
#
#    SHO    SO   SO/W   SO9   SV    W   WHIP   WP
# 0  0.2  54.4  2.912  8.88  0.4  4.4  1.254  3.4
#
# [1 rows x 23 columns]

# %%
# tcupit_mean.to_csv('tcu-pitch-mean.csv', index=False)
