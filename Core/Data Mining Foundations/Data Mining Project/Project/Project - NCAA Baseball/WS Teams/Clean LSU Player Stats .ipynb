# %%
import pandas as pd
import numpy as np

# %%
lsub = pd.read_csv('../Data/lsu-bat.csv')

# %%
lsup = pd.read_csv('../Data/lsu-pitch.csv')

# %%
lsup.columns
# Out:
# Index(['Rk', 'Name', 'Age', 'W', 'L', 'W-L%', 'ERA', 'G', 'GS', 'GF', 'CG',
#        'SHO', 'SV', 'IP', 'H', 'R', 'ER', 'HR', 'BB', 'IBB', 'SO', 'HBP', 'BK',
#        'WP', 'BF', 'WHIP', 'H9', 'HR9', 'BB9', 'SO9', 'SO/W', 'Notes'],
#       dtype='object')

# %%
lsup
# Out:
#       Rk               Name   Age   W   L   W-L%    ERA   G  GS  GF  ...  BK  \
# 0    1.0  Nate Ackenhausen*    21   2   0  1.000   3.63  15   0 NaN  ...   0
# 1    2.0      Micah Bucknam    19   0   0    NaN  11.57   8   0 NaN  ...   0
# 2    3.0     Javen Coleman*    21   1   2  0.333   6.39   7   3 NaN  ...   0
# 3    4.0      Bryce Collins    23   2   1  0.667   7.47  15   0 NaN  ...   0
# 4    5.0      Riley Cooper*    21   4   3  0.571   5.02  27   3 NaN  ...   1
# 5    6.0      Samuel Dutton    20   0   0    NaN   6.05  18   0 NaN  ...   0
# 6    7.0    Garrett Edwards    21   4   0  1.000   1.93  10   0 NaN  ...   0
# 7    8.0           Ty Floyd    21   7   0  1.000   4.50  17  15 NaN  ...   2
# 8    9.0       Gavin Guidry    19   3   0  1.000   3.42  19   1 NaN  ...   0
# 9   10.0      Will Hellmers    --   0   0    NaN   9.00   7   0 NaN  ...   0
# 10  11.0   Griffin Herring*    20   4   2  0.667   4.55  17   0 NaN  ...   1
# ...

# %%
lsup = lsup.sort_values(by=['BF'], ascending=False)

# %%
lsup
# Out:
#       Rk               Name   Age   W   L   W-L%    ERA   G  GS  GF  ...  BK  \
# 17   NaN         17 Players  20.5  48  15  0.762   4.54  63  63 NaN  ...   4
# 16  17.0        Paul Skenes    21  12   2  0.857   1.77  17  17 NaN  ...   0
# 7    8.0           Ty Floyd    21   7   0  1.000   4.50  17  15 NaN  ...   2
# 11  12.0      Thatcher Hurd    20   6   2  0.750   6.49  20  10 NaN  ...   0
# 4    5.0      Riley Cooper*    21   4   3  0.571   5.02  27   3 NaN  ...   1
# 12  13.0   Christian Little    19   2   2  0.500   7.09  18   8 NaN  ...   0
# 14  15.0        Blake Money    21   1   0  1.000   5.73  18   2 NaN  ...   0
# 10  11.0   Griffin Herring*    20   4   2  0.667   4.55  17   0 NaN  ...   1
# 8    9.0       Gavin Guidry    19   3   0  1.000   3.42  19   1 NaN  ...   0
# 0    1.0  Nate Ackenhausen*    21   2   0  1.000   3.63  15   0 NaN  ...   0
# 5    6.0      Samuel Dutton    20   0   0    NaN   6.05  18   0 NaN  ...   0
# ...

# %%
lsup = lsup[1:]

# %%
lsup = lsup.drop(columns=['Rk', 'Notes'])

# %%
lsup = lsup.drop(columns=['GF', 'CG'])

# %%
lsup.columns
# Out:
# Index(['Name', 'Age', 'W', 'L', 'W-L%', 'ERA', 'G', 'GS', 'SHO', 'SV', 'IP',
#        'H', 'R', 'ER', 'HR', 'BB', 'IBB', 'SO', 'HBP', 'BK', 'WP', 'BF',
#        'WHIP', 'H9', 'HR9', 'BB9', 'SO9', 'SO/W'],
#       dtype='object')

# %%
lsup = lsup.drop(columns=['BK', 'IBB', 'W-L%'])

# %%
lsup.sort_values(by=['GS'], ascending=False)
# Out:
#                  Name Age   W  L    ERA   G  GS  SHO  SV     IP  ...   SO  \
# 16        Paul Skenes  21  12  2   1.77  17  17    0   0  107.0  ...  188
# 7            Ty Floyd  21   7  0   4.50  17  15    0   1   78.0  ...   93
# 11      Thatcher Hurd  20   6  2   6.49  20  10    0   3   51.1  ...   71
# 12   Christian Little  19   2  2   7.09  18   8    0   2   33.0  ...   41
# 15      Chase Shores?  --   0  1   1.96   7   4    0   0   18.1  ...   15
# 4       Riley Cooper*  21   4  3   5.02  27   3    0   0   52.0  ...   54
# 2      Javen Coleman*  21   1  2   6.39   7   3    0   0   12.2  ...   19
# 14        Blake Money  21   1  0   5.73  18   2    0   0   33.0  ...   28
# 8        Gavin Guidry  19   3  0   3.42  19   1    0   3   23.2  ...   36
# 1       Micah Bucknam  19   0  0  11.57   8   0    0   0    7.0  ...   14
# 9       Will Hellmers  --   0  0   9.00   7   0    0   0   11.0  ...   14
# 0   Nate Ackenhausen*  21   2  0   3.63  15   0    0   2   22.1  ...   24
# ...

# %%
lsup.columns
# Out:
# Index(['Name', 'Age', 'W', 'L', 'ERA', 'G', 'GS', 'SHO', 'SV', 'IP', 'H', 'R',
#        'ER', 'HR', 'BB', 'SO', 'HBP', 'WP', 'BF', 'WHIP', 'H9', 'HR9', 'BB9',
#        'SO9', 'SO/W'],
#       dtype='object')

# %%
lsub.head()
# Out:
#     Rk          Name Age   G   PA   AB   R   H  2B  3B  ...    OBP    SLG  \
# 0  1.0  Cade Beloso*  23  50  198  158  39  50   4   1  ...  0.442  0.620
# 1  2.0   Dylan Crews  21  63  304  226  89  98  15   1  ...  0.576  0.735
# 2  3.0   Gavin Dugas  23  60  268  198  70  57  10   2  ...  0.453  0.586
# 3  4.0    Ethan Frey  19  18   22   18   3   5   1   0  ...  0.364  0.333
# 4  5.0  Gavin Guidry  19  31    9    7   4   1   0   0  ...  0.333  0.143
#
#      OPS   TB  GDP  HBP  SH  SF  IBB  Notes
# 0  1.062   98  NaN    9   1   2  NaN    NaN
# 1  1.310  166  NaN   12   0   1  NaN    NaN
# 2  1.039  116  NaN   30   1   5  NaN    NaN
# 3  0.697    6  NaN    0   0   1  NaN    NaN
# 4  0.476    1  NaN    1   0   0  NaN    NaN
#
# [5 rows x 27 columns]

# %%
lsub.columns
# Out:
# Index(['Rk', 'Name', 'Age', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI',
#        'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'TB', 'GDP', 'HBP',
#        'SH', 'SF', 'IBB', 'Notes'],
#       dtype='object')

# %%
lsub = lsub.drop(columns=['IBB', 'Notes', 'Rk', 'SH', 'CS', 'SB'])

# %%
lsub.head()
# Out:
#            Name Age   G   PA   AB   R   H  2B  3B  HR  ...  BB  SO     BA  \
# 0  Cade Beloso*  23  50  198  158  39  50   4   1  14  ...  28  26  0.317
# 1   Dylan Crews  21  63  304  226  89  98  15   1  17  ...  65  40  0.434
# 2   Gavin Dugas  23  60  268  198  70  57  10   2  15  ...  34  58  0.288
# 3    Ethan Frey  19  18   22   18   3   5   1   0   0  ...   3   6  0.278
# 4  Gavin Guidry  19  31    9    7   4   1   0   0   0  ...   1   4  0.143
#
#      OBP    SLG    OPS   TB  GDP  HBP  SF
# 0  0.442  0.620  1.062   98  NaN    9   2
# 1  0.576  0.735  1.310  166  NaN   12   1
# 2  0.453  0.586  1.039  116  NaN   30   5
# 3  0.364  0.333  0.697    6  NaN    0   1
# 4  0.333  0.143  0.476    1  NaN    1   0
#
# [5 rows x 21 columns]

# %%
lsub = lsub.sort_values(by=['PA'], ascending=False)

# %%
lsub
# Out:
#                 Name   Age   G    PA    AB    R    H   2B  3B   HR  ...   BB  \
# 19        19 Players  21.1  63  2676  2126  588  668  113  15  133  ...  367
# 1        Dylan Crews    21  63   304   226   89   98   15   1   17  ...   65
# 10      Tre' Morgan*    20  61   292   237   60   74   12   3    9  ...   33
# 16   Jordan Thompson    21  63   275   220   49   60   12   1   11  ...   32
# 18       Tommy White    20  58   271   236   59   89   22   0   22  ...   21
# 2        Gavin Dugas    23  60   268   198   70   57   10   2   15  ...   34
# 6       Jared Jones?    --  52   199   158   37   48   12   0   14  ...   36
# 0       Cade Beloso*    23  50   198   158   39   50    4   1   14  ...   28
# 5    Brayden Jobert*    22  52   195   162   34   49    8   1   11  ...   20
# 14     Josh Pearson*    20  47   143   111   24   28    4   3    3  ...   25
# 17  Hayden Travinski    --  36   109    89   29   36    5   0   10  ...   15
# ...

# %%
lsub = lsub[1:]

# %%
lsub
# Out:
#                 Name Age   G   PA   AB   R   H  2B  3B  HR  ...  BB  SO  \
# 1        Dylan Crews  21  63  304  226  89  98  15   1  17  ...  65  40
# 10      Tre' Morgan*  20  61  292  237  60  74  12   3   9  ...  33  28
# 16   Jordan Thompson  21  63  275  220  49  60  12   1  11  ...  32  56
# 18       Tommy White  20  58  271  236  59  89  22   0  22  ...  21  32
# 2        Gavin Dugas  23  60  268  198  70  57  10   2  15  ...  34  58
# 6       Jared Jones?  --  52  199  158  37  48  12   0  14  ...  36  69
# 0       Cade Beloso*  23  50  198  158  39  50   4   1  14  ...  28  26
# 5    Brayden Jobert*  22  52  195  162  34  49   8   1  11  ...  20  48
# 14     Josh Pearson*  20  47  143  111  24  28   4   3   3  ...  25  31
# 17  Hayden Travinski  --  36  109   89  29  36   5   0  10  ...  15  19
# 7      Paxton Kling?  --  51  103   87  29  25   5   2   4  ...   9  26
# 9       Alex Milazzo  22  47   99   82  19  24   1   0   0  ...  10  18
# ...

# %%
lsub = lsub.drop(columns=['GDP'])

# %%
lsub = lsub[:10]
lsub
# Out:
#                 Name Age   G   PA   AB   R   H  2B  3B  HR  RBI  BB  SO  \
# 1        Dylan Crews  21  63  304  226  89  98  15   1  17   67  65  40
# 10      Tre' Morgan*  20  61  292  237  60  74  12   3   9   47  33  28
# 16   Jordan Thompson  21  63  275  220  49  60  12   1  11   49  32  56
# 18       Tommy White  20  58  271  236  59  89  22   0  22   97  21  32
# 2        Gavin Dugas  23  60  268  198  70  57  10   2  15   42  34  58
# 6       Jared Jones?  --  52  199  158  37  48  12   0  14   45  36  69
# 0       Cade Beloso*  23  50  198  158  39  50   4   1  14   41  28  26
# 5    Brayden Jobert*  22  52  195  162  34  49   8   1  11   42  20  48
# 14     Josh Pearson*  20  47  143  111  24  28   4   3   3   25  25  31
# 17  Hayden Travinski  --  36  109   89  29  36   5   0  10   29  15  19
#
#        BA    OBP    SLG    OPS   TB  HBP  SF
# 1   0.434  0.576  0.735  1.310  166   12   1
# 10  0.312  0.425  0.502  0.927  119   17   5
# ...

# %%
lsub = lsub.drop(columns=['Name', 'Age'])

# %%
# Iterate through each row in the DataFrame
for index, row in lsub.iterrows():
    # Divide each entry by the corresponding 'G' column entry
    for column in lsub.columns:
        lsub.at[index, column] = row[column] / row['G']
        
lsub.head()
# Out:
#     G        PA        AB         R         H        2B        3B        HR  \
# 1   1  4.825397  3.587302  1.412698  1.555556  0.238095  0.015873  0.269841
# 10  1  4.786885  3.885246  0.983607  1.213115  0.196721  0.049180  0.147541
# 16  1  4.365079  3.492063  0.777778  0.952381  0.190476  0.015873  0.174603
# 18  1  4.672414  4.068966  1.017241  1.534483  0.379310  0.000000  0.379310
# 2   1  4.466667  3.300000  1.166667  0.950000  0.166667  0.033333  0.250000
#
#          RBI        BB        SO        BA       OBP       SLG       OPS  \
# 1   1.063492  1.031746  0.634921  0.006889  0.009143  0.011667  0.020794
# 10  0.770492  0.540984  0.459016  0.005115  0.006967  0.008230  0.015197
# 16  0.777778  0.507937  0.888889  0.004333  0.006365  0.007714  0.014079
# 18  1.672414  0.362069  0.551724  0.006500  0.007569  0.012931  0.020500
# 2   0.700000  0.566667  0.966667  0.004800  0.007550  0.009767  0.017317
#
#           TB       HBP        SF
# 1   2.634921  0.190476  0.015873
# ...

# %%
lsub.columns
# Out:
# Index(['G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'SO', 'BA',
#        'OBP', 'SLG', 'OPS', 'TB', 'HBP', 'SF'],
#       dtype='object')

# %%
df2 = lsub[['G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'SO', 'BA',
       'OBP', 'SLG', 'OPS', 'TB', 'HBP', 'SF']].mean()

# %%
p = df2.sort_index()
lsubat_mean = p.to_frame().T
lsubat_mean
# Out:
#          2B        3B        AB        BA        BB    G         H       HBP  \
# 0  0.185988  0.021732  3.248135  0.006226  0.559491  1.0  1.066666  0.204167
#
#          HR       OBP       OPS       PA         R       RBI        SF  \
# 0  0.232367  0.008529  0.020247  4.07237  0.881957  0.881472  0.052148
#
#         SLG        SO       TB
# 0  0.011722  0.745857  1.99322

# %%
# lsubat_mean.to_csv('lsu-batting.csv', index=False)

# %%
lsups = lsup[:3]

# %%
lsupg = lsup.sort_values(by=['G'], ascending=False)
lsupg = lsupg[:3]
lsupg
# Out:
#              Name Age  W  L   ERA   G  GS  SHO  SV    IP  ...  SO  HBP  WP  \
# 4   Riley Cooper*  21  4  3  5.02  27   3    0   0  52.0  ...  54    4   3
# 11  Thatcher Hurd  20  6  2  6.49  20  10    0   3  51.1  ...  71    2   8
# 8    Gavin Guidry  19  3  0  3.42  19   1    0   3  23.2  ...  36    2  10
#
#      BF   WHIP    H9  HR9  BB9   SO9  SO/W
# 4   239  1.442  10.0  1.0  2.9   9.3  3.18
# 11  240  1.695   9.3  1.4  6.0  12.4  2.09
# 8   103  1.141   6.1  0.4  4.2  13.7  3.27
#
# [3 rows x 25 columns]

# %%
lsups = lsup.sort_values(by=['IP'], ascending=False)
lsups = lsup[:3]
lsups
# Out:
#              Name Age   W  L   ERA   G  GS  SHO  SV     IP  ...   SO  HBP  WP  \
# 16    Paul Skenes  21  12  2  1.77  17  17    0   0  107.0  ...  188    3   7
# 7        Ty Floyd  21   7  0  4.50  17  15    0   1   78.0  ...   93   12   5
# 11  Thatcher Hurd  20   6  2  6.49  20  10    0   3   51.1  ...   71    2   8
#
#      BF   WHIP   H9  HR9  BB9   SO9   SO/W
# 16  406  0.776  5.5  0.6  1.5  15.8  10.44
# 7   336  1.218  7.3  1.7  3.7  10.7   2.91
# 11  240  1.695  9.3  1.4  6.0  12.4   2.09
#
# [3 rows x 25 columns]

# %%
frames = [lsupg, lsups]

result = pd.concat(frames)
result
# Out:
#              Name Age   W  L   ERA   G  GS  SHO  SV     IP  ...   SO  HBP  WP  \
# 4   Riley Cooper*  21   4  3  5.02  27   3    0   0   52.0  ...   54    4   3
# 11  Thatcher Hurd  20   6  2  6.49  20  10    0   3   51.1  ...   71    2   8
# 8    Gavin Guidry  19   3  0  3.42  19   1    0   3   23.2  ...   36    2  10
# 16    Paul Skenes  21  12  2  1.77  17  17    0   0  107.0  ...  188    3   7
# 7        Ty Floyd  21   7  0  4.50  17  15    0   1   78.0  ...   93   12   5
# 11  Thatcher Hurd  20   6  2  6.49  20  10    0   3   51.1  ...   71    2   8
#
#      BF   WHIP    H9  HR9  BB9   SO9   SO/W
# 4   239  1.442  10.0  1.0  2.9   9.3   3.18
# 11  240  1.695   9.3  1.4  6.0  12.4   2.09
# 8   103  1.141   6.1  0.4  4.2  13.7   3.27
# 16  406  0.776   5.5  0.6  1.5  15.8  10.44
# 7   336  1.218   7.3  1.7  3.7  10.7   2.91
# 11  240  1.695   9.3  1.4  6.0  12.4   2.09
#
# [6 rows x 25 columns]

# %%
result = result.drop_duplicates()
result
# Out:
#              Name Age   W  L   ERA   G  GS  SHO  SV     IP  ...   SO  HBP  WP  \
# 4   Riley Cooper*  21   4  3  5.02  27   3    0   0   52.0  ...   54    4   3
# 11  Thatcher Hurd  20   6  2  6.49  20  10    0   3   51.1  ...   71    2   8
# 8    Gavin Guidry  19   3  0  3.42  19   1    0   3   23.2  ...   36    2  10
# 16    Paul Skenes  21  12  2  1.77  17  17    0   0  107.0  ...  188    3   7
# 7        Ty Floyd  21   7  0  4.50  17  15    0   1   78.0  ...   93   12   5
#
#      BF   WHIP    H9  HR9  BB9   SO9   SO/W
# 4   239  1.442  10.0  1.0  2.9   9.3   3.18
# 11  240  1.695   9.3  1.4  6.0  12.4   2.09
# 8   103  1.141   6.1  0.4  4.2  13.7   3.27
# 16  406  0.776   5.5  0.6  1.5  15.8  10.44
# 7   336  1.218   7.3  1.7  3.7  10.7   2.91
#
# [5 rows x 25 columns]

# %%
result = result.drop(columns=['Name', 'Age'])
result
# Out:
#      W  L   ERA   G  GS  SHO  SV     IP   H   R  ...   SO  HBP  WP   BF  \
# 4    4  3  5.02  27   3    0   0   52.0  58  32  ...   54    4   3  239
# 11   6  2  6.49  20  10    0   3   51.1  53  38  ...   71    2   8  240
# 8    3  0  3.42  19   1    0   3   23.2  16  12  ...   36    2  10  103
# 16  12  2  1.77  17  17    0   0  107.0  65  26  ...  188    3   7  406
# 7    7  0  4.50  17  15    0   1   78.0  63  45  ...   93   12   5  336
#
#      WHIP    H9  HR9  BB9   SO9   SO/W
# 4   1.442  10.0  1.0  2.9   9.3   3.18
# 11  1.695   9.3  1.4  6.0  12.4   2.09
# 8   1.141   6.1  0.4  4.2  13.7   3.27
# 16  0.776   5.5  0.6  1.5  15.8  10.44
# 7   1.218   7.3  1.7  3.7  10.7   2.91
#
# [5 rows x 23 columns]

# %%
# Iterate through each row in the DataFrame
for index, row in result.iterrows():
    # Divide each entry by the corresponding 'G' column entry
    for column in result.columns:
        result.at[index, column] = row[column] / row['G']
        
result
# Out:
#            W         L       ERA  G        GS  SHO        SV        IP  \
# 4   0.148148  0.111111  0.185926  1  0.111111    0  0.000000  1.925926
# 11  0.300000  0.100000  0.324500  1  0.500000    0  0.150000  2.555000
# 8   0.157895  0.000000  0.180000  1  0.052632    0  0.157895  1.221053
# 16  0.705882  0.117647  0.104118  1  1.000000    0  0.000000  6.294118
# 7   0.411765  0.000000  0.264706  1  0.882353    0  0.058824  4.588235
#
#            H         R  ...         SO       HBP        WP         BF  \
# 4   2.148148  1.185185  ...   2.000000  0.148148  0.111111   8.851852
# 11  2.650000  1.900000  ...   3.550000  0.100000  0.400000  12.000000
# 8   0.842105  0.631579  ...   1.894737  0.105263  0.526316   5.421053
# 16  3.823529  1.529412  ...  11.058824  0.176471  0.411765  23.882353
# 7   3.705882  2.647059  ...   5.470588  0.705882  0.294118  19.764706
#
#         WHIP        H9       HR9       BB9       SO9      SO/W
# ...

# %%
result.columns
# Out:
# Index(['W', 'L', 'ERA', 'G', 'GS', 'SHO', 'SV', 'IP', 'H', 'R', 'ER', 'HR',
#        'BB', 'SO', 'HBP', 'WP', 'BF', 'WHIP', 'H9', 'HR9', 'BB9', 'SO9',
#        'SO/W'],
#       dtype='object')

# %%
df2 = result[['W', 'L', 'ERA', 'G', 'GS', 'SHO', 'SV', 'IP', 'H', 'R', 'ER', 'HR',
       'BB', 'SO', 'HBP', 'WP', 'BF', 'WHIP', 'H9', 'HR9', 'BB9', 'SO9',
       'SO/W']].mean()

# %%
p = df2.sort_index()
lsupit_mean = p.to_frame().T
lsupit_mean
# Out:
#          BB       BB9         BF        ER      ERA    G        GS         H  \
# 0  1.169951  0.186868  13.983993  1.385434  0.21185  1.0  0.509219  2.633933
#
#          H9       HBP  ...         L         R  SHO       SO      SO/W  \
# 0  0.381873  0.247153  ...  0.065752  1.578647  0.0  4.79483  0.235935
#
#         SO9        SV         W      WHIP        WP
# 0  0.648864  0.073344  0.344738  0.063101  0.348662
#
# [1 rows x 23 columns]

# %%
# lsupit_mean.to_csv('lsupit_mean.csv', index=False)

# %%
# # Iterate through each row in the DataFrame
# for index, row in lsup.iterrows():
#     # Divide each entry by the corresponding 'G' column entry
#     for column in lsup.columns:
#         lsup.at[index, column] = row[column] / row['G']
        
# lsup.head()
# Out:
#            W         L       ERA  G        GS  SHO        SV        IP  \
# 16  0.705882  0.117647  0.104118  1  1.000000    0  0.000000  6.294118
# 7   0.411765  0.000000  0.264706  1  0.882353    0  0.058824  4.588235
# 11  0.300000  0.100000  0.324500  1  0.500000    0  0.150000  2.555000
# 4   0.148148  0.111111  0.185926  1  0.111111    0  0.000000  1.925926
# 12  0.111111  0.111111  0.393889  1  0.444444    0  0.111111  1.833333
#
#            H         R  ...         SO       HBP        WP         BF  \
# 16  3.823529  1.529412  ...  11.058824  0.176471  0.411765  23.882353
# 7   3.705882  2.647059  ...   5.470588  0.705882  0.294118  19.764706
# 11  2.650000  1.900000  ...   3.550000  0.100000  0.400000  12.000000
# 4   2.148148  1.185185  ...   2.000000  0.148148  0.111111   8.851852
# 12  1.555556  1.444444  ...   2.277778  0.111111  0.111111   8.611111
#
#         WHIP        H9       HR9       BB9       SO9      SO/W
# ...

# %%
# lsup = lsup.drop(columns=['Name', 'Age'])
