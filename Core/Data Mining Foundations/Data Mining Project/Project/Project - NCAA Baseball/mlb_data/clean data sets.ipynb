# %%
import pandas as pd
import numpy as np

# %%
pit22 = pd.read_csv('pit22.csv')

# %%
bat22 = pd.read_csv('bat22.csv')

# %%
bat22.head()
# Out:
#                      Tm  #Bat  BatAge   R/G    G    PA    AB    R     H   2B  \
# 0  Arizona Diamondbacks    57    26.5  4.33  162  6027  5351  702  1232  262
# 1        Atlanta Braves    53    27.5  4.87  162  6082  5509  789  1394  298
# 2     Baltimore Orioles    58    27.0  4.16  162  6049  5429  674  1281  275
# 3        Boston Red Sox    54    28.8  4.54  162  6144  5539  735  1427  352
# 4          Chicago Cubs    64    27.9  4.06  162  6072  5425  657  1293  265
#
#    ...    SLG    OPS  OPS+    TB  GDP  HBP  SH  SF  IBB   LOB
# 0  ...  0.385  0.689    95  2061   97   60  31  50   14  1039
# 1  ...  0.443  0.761   108  2443  103   66   1  36   13  1030
# 2  ...  0.390  0.695    98  2119   95   83  12  43   10  1095
# 3  ...  0.409  0.731   100  2268  131   63  12  50   23  1133
# 4  ...  0.387  0.698    95  2097  130   84  19  36   16  1100
#
# [5 rows x 29 columns]

# %%
bat22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 29 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tm      31 non-null     object
#  1   #Bat    32 non-null     int64
#  2   BatAge  32 non-null     float64
#  3   R/G     32 non-null     float64
#  4   G       32 non-null     int64
#  5   PA      32 non-null     int64
#  6   AB      32 non-null     int64
#  7   R       32 non-null     int64
#  8   H       32 non-null     int64
#  9   2B      32 non-null     int64
#  10  3B      32 non-null     int64
#  11  HR      32 non-null     int64
#  12  RBI     32 non-null     int64
#  13  SB      32 non-null     int64
#  14  CS      32 non-null     int64
#  15  BB      32 non-null     int64
#  16  SO      32 non-null     int64
#  17  BA      32 non-null     float64
#  18  OBP     32 non-null     float64
#  19  SLG     32 non-null     float64
#  20  OPS     32 non-null     float64
# ...

# %%
bat22.describe()
# Out:
#               #Bat     BatAge        R/G            G             PA  \
# count    32.000000  32.000000  32.000000    32.000000      32.000000
# mean    100.875000  28.200000   4.283750   308.812500   11567.875000
# std     254.480971   1.114132   0.429056   830.496915   31109.938613
# min      43.000000  25.900000   3.440000   162.000000    5863.000000
# 25%      51.000000  27.400000   4.045000   162.000000    6009.500000
# 50%      55.000000  28.200000   4.305000   162.000000    6079.500000
# 75%      61.000000  29.100000   4.542500   162.000000    6147.500000
# max    1495.000000  30.200000   5.230000  4860.000000  182052.000000
#
#                   AB             R             H           2B          3B  \
# count      32.000000     32.000000     32.000000    32.000000   32.000000
# mean    10386.843750   1322.750000   2521.000000   504.531250   40.843750
# std     27933.663231   3557.974641   6780.281691  1357.156206  110.148905
# ...

# %%
bat22.columns
# Out:
# Index(['Tm', '#Bat', 'BatAge', 'R/G', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B',
#        'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+',
#        'TB', 'GDP', 'HBP', 'SH', 'SF', 'IBB', 'LOB'],
#       dtype='object')

# %%
bat22 = bat22.drop(columns=['SB', 'CS', 'OPS+', 'GDP', 'IBB', 'LOB'])

# %%
bat22 = bat22.drop(columns=['#Bat'])

# %%
bat22 = bat22.drop(columns=['SH'])

# %%
bat22 = bat22.drop(columns=['BatAge'])

# %%
bat22 = bat22[:-2]

# %%
bat22
# Out:
#                        Tm   R/G    G    PA    AB    R     H   2B  3B   HR  \
# 0    Arizona Diamondbacks  4.33  162  6027  5351  702  1232  262  24  173
# 1          Atlanta Braves  4.87  162  6082  5509  789  1394  298  11  243
# 2       Baltimore Orioles  4.16  162  6049  5429  674  1281  275  25  171
# 3          Boston Red Sox  4.54  162  6144  5539  735  1427  352  12  155
# 4            Chicago Cubs  4.06  162  6072  5425  657  1293  265  31  159
# 5       Chicago White Sox  4.23  162  6123  5611  686  1435  272   9  149
# 6         Cincinnati Reds  4.00  162  5978  5380  648  1264  235  18  156
# 7     Cleveland Guardians  4.31  162  6163  5558  698  1410  273  31  127
# 8        Colorado Rockies  4.31  162  6105  5540  698  1408  280  34  149
# 9          Detroit Tigers  3.44  162  5870  5378  557  1240  235  27  110
# 10         Houston Astros  4.55  162  6054  5409  737  1341  284  13  214
# 11     Kansas City Royals  3.95  162  6010  5437  640  1327  247  38  138
# ...

# %%
pit22.head()
# Out:
#                      Tm  #P  PAge  RA/G    W   L   W-L%   ERA    G   GS  ...  \
# 0  Arizona Diamondbacks  33  30.0  4.57   74  88  0.457  4.25  162  162  ...
# 1        Atlanta Braves  32  30.0  3.76  101  61  0.623  3.46  162  162  ...
# 2     Baltimore Orioles  36  27.7  4.25   83  79  0.512  3.97  162  162  ...
# 3        Boston Red Sox  33  30.2  4.86   78  84  0.481  4.53  162  162  ...
# 4          Chicago Cubs  43  29.5  4.51   74  88  0.457  4.00  162  162  ...
#
#      BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W   LOB
# 0  6065    95  4.33  1.293  8.5  1.2  3.2  7.7  2.41  1051
# 1  6031   121  3.46  1.191  7.6  0.9  3.1  9.7  3.11  1101
# 2  6058   100  4.03  1.290  8.8  1.1  2.8  7.6  2.74  1092
# 3  6167    94  4.17  1.354  8.9  1.2  3.3  8.5  2.56  1109
# 4  6162   104  4.33  1.304  8.4  1.3  3.4  8.6  2.56  1130
#
# [5 rows x 36 columns]

# %%
pit22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 36 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tm      31 non-null     object
#  1   #P      32 non-null     int64
#  2   PAge    32 non-null     float64
#  3   RA/G    32 non-null     float64
#  4   W       32 non-null     int64
#  5   L       32 non-null     int64
#  6   W-L%    32 non-null     float64
#  7   ERA     32 non-null     float64
#  8   G       32 non-null     int64
#  9   GS      32 non-null     int64
#  10  GF      32 non-null     int64
#  11  CG      32 non-null     int64
#  12  tSho    32 non-null     int64
#  13  cSho    32 non-null     int64
#  14  SV      32 non-null     int64
#  15  IP      32 non-null     float64
#  16  H       32 non-null     int64
#  17  R       32 non-null     int64
#  18  ER      32 non-null     int64
#  19  HR      32 non-null     int64
#  20  BB      32 non-null     int64
# ...

# %%
pit22 = pit22.drop(columns=['W-L%', 'GF', 'GS', 'BK', 'ERA+', 'LOB', 'tSho', 'CG', 'PAge', '#P', 'SO/W'])

# %%
pit22.head()
# Out:
#                      Tm  RA/G    W   L   ERA    G  cSho  SV      IP     H  \
# 0  Arizona Diamondbacks  4.57   74  88  4.25  162     0  33  1430.0  1345
# 1        Atlanta Braves  3.76  101  61  3.46  162     1  55  1448.0  1224
# 2     Baltimore Orioles  4.25   83  79  3.97  162     1  46  1433.1  1406
# 3        Boston Red Sox  4.86   78  84  4.53  162     2  39  1431.0  1411
# 4          Chicago Cubs  4.51   74  88  4.00  162     0  44  1443.2  1342
#
#    ...    SO  HBP  WP    BF   FIP   WHIP   H9  HR9  BB9  SO9
# 0  ...  1216   59  51  6065  4.33  1.293  8.5  1.2  3.2  7.7
# 1  ...  1554   62  55  6031  3.46  1.191  7.6  0.9  3.1  9.7
# 2  ...  1214   64  47  6058  4.03  1.290  8.8  1.1  2.8  7.6
# 3  ...  1346   72  60  6167  4.17  1.354  8.9  1.2  3.3  8.5
# 4  ...  1383   73  53  6162  4.33  1.304  8.4  1.3  3.4  8.6
#
# [5 rows x 25 columns]

# %%
pit22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 25 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tm      31 non-null     object
#  1   RA/G    32 non-null     float64
#  2   W       32 non-null     int64
#  3   L       32 non-null     int64
#  4   ERA     32 non-null     float64
#  5   G       32 non-null     int64
#  6   cSho    32 non-null     int64
#  7   SV      32 non-null     int64
#  8   IP      32 non-null     float64
#  9   H       32 non-null     int64
#  10  R       32 non-null     int64
#  11  ER      32 non-null     int64
#  12  HR      32 non-null     int64
#  13  BB      32 non-null     int64
#  14  IBB     32 non-null     int64
#  15  SO      32 non-null     int64
#  16  HBP     32 non-null     int64
#  17  WP      32 non-null     int64
#  18  BF      32 non-null     int64
#  19  FIP     32 non-null     float64
#  20  WHIP    32 non-null     float64
# ...

# %%
pit22 = pit22.drop(columns=['cSho', 'SV', 'IBB', 'HBP', 'RA/G'])

# %%
pit22 = pit22[:-2]

# %%
bat22.head()
# Out:
#                      Tm   R/G    G    PA    AB    R     H   2B  3B   HR  RBI  \
# 0  Arizona Diamondbacks  4.33  162  6027  5351  702  1232  262  24  173  658
# 1        Atlanta Braves  4.87  162  6082  5509  789  1394  298  11  243  753
# 2     Baltimore Orioles  4.16  162  6049  5429  674  1281  275  25  171  639
# 3        Boston Red Sox  4.54  162  6144  5539  735  1427  352  12  155  704
# 4          Chicago Cubs  4.06  162  6072  5425  657  1293  265  31  159  620
#
#     BB    SO     BA    OBP    SLG    OPS    TB  HBP  SF
# 0  531  1341  0.230  0.304  0.385  0.689  2061   60  50
# 1  470  1498  0.253  0.317  0.443  0.761  2443   66  36
# 2  476  1390  0.236  0.305  0.390  0.695  2119   83  43
# 3  478  1373  0.258  0.321  0.409  0.731  2268   63  50
# 4  507  1448  0.238  0.311  0.387  0.698  2097   84  36

# %%
pit22.head()
# Out:
#                      Tm    W   L   ERA    G      IP     H    R   ER   HR   BB  \
# 0  Arizona Diamondbacks   74  88  4.25  162  1430.0  1345  740  676  191  504
# 1        Atlanta Braves  101  61  3.46  162  1448.0  1224  609  556  148  500
# 2     Baltimore Orioles   83  79  3.97  162  1433.1  1406  688  632  171  443
# 3        Boston Red Sox   78  84  4.53  162  1431.0  1411  787  721  185  526
# 4          Chicago Cubs   74  88  4.00  162  1443.2  1342  731  642  207  540
#
#      SO  WP    BF   FIP   WHIP   H9  HR9  BB9  SO9
# 0  1216  51  6065  4.33  1.293  8.5  1.2  3.2  7.7
# 1  1554  55  6031  3.46  1.191  7.6  0.9  3.1  9.7
# 2  1214  47  6058  4.03  1.290  8.8  1.1  2.8  7.6
# 3  1346  60  6167  4.17  1.354  8.9  1.2  3.3  8.5
# 4  1383  53  6162  4.33  1.304  8.4  1.3  3.4  8.6

# %%
bat21 = pd.read_csv('bat21.csv')

# %%
pit21 = pd.read_csv('pit21.csv')

# %%
bat21.head()
# Out:
#                      Tm  #Bat  BatAge   R/G    G    PA    AB    R     H   2B  \
# 0  Arizona Diamondbacks    64    28.9  4.19  162  6144  5489  679  1297  308
# 1        Atlanta Braves    56    28.2  4.91  161  6056  5363  790  1307  269
# 2     Baltimore Orioles    62    26.7  4.07  162  5983  5420  659  1296  266
# 3        Boston Red Sox    56    28.0  5.12  162  6122  5495  829  1434  330
# 4          Chicago Cubs    69    29.1  4.35  162  5972  5306  705  1255  225
#
#    ...    SLG    OPS  OPS+    TB  GDP  HBP  SH  SF  IBB   LOB
# 0  ...  0.382  0.692    87  2099   99   54  32  28   24  1152
# 1  ...  0.435  0.754    98  2333   81   67  32  43   36  1072
# 2  ...  0.402  0.705    92  2177  105   65  14  31   12  1046
# 3  ...  0.449  0.777   106  2467  100   61  10  42   22  1093
# 4  ...  0.407  0.719    93  2162  133   92  40  30   17  1019
#
# [5 rows x 29 columns]

# %%
pit21.head()
# Out:
#                      Tm  #P  PAge  RA/G   W    L   W-L%   ERA    G   GS  ...  \
# 0  Arizona Diamondbacks  41  28.5  5.51  52  110  0.321  5.11  162  162  ...
# 1        Atlanta Braves  30  29.5  4.07  88   73  0.547  3.88  161  161  ...
# 2     Baltimore Orioles  42  28.1  5.90  52  110  0.321  5.84  162  162  ...
# 3        Boston Red Sox  37  29.7  4.62  92   70  0.568  4.26  162  162  ...
# 4          Chicago Cubs  40  29.4  5.18  71   91  0.438  4.87  162  162  ...
#
#      BF  ERA+   FIP   WHIP   H9  HR9  BB9  SO9  SO/W   LOB
# 0  6270    83  4.88  1.436  9.4  1.5  3.5  7.9  2.23  1146
# 1  5944   112  4.09  1.243  7.9  1.2  3.3  9.0  2.75  1074
# 2  6252    77  5.15  1.484  9.7  1.7  3.6  7.9  2.19  1103
# 3  6147   110  3.95  1.378  8.9  1.1  3.5  9.7  2.80  1163
# 4  6202    87  4.88  1.403  8.8  1.5  3.8  8.7  2.28  1143
#
# [5 rows x 36 columns]

# %%
bat21 = bat21.drop(columns=['SB', 'CS', 'OPS+', 'GDP', 'IBB', 'LOB', '#Bat', 'SH', 'BatAge'])
bat21.head()
# Out:
#                      Tm   R/G    G    PA    AB    R     H   2B  3B   HR  RBI  \
# 0  Arizona Diamondbacks  4.19  162  6144  5489  679  1297  308  31  144  644
# 1        Atlanta Braves  4.91  161  6056  5363  790  1307  269  20  239  762
# 2     Baltimore Orioles  4.07  162  5983  5420  659  1296  266  15  195  632
# 3        Boston Red Sox  5.12  162  6122  5495  829  1434  330  23  219  783
# 4          Chicago Cubs  4.35  162  5972  5306  705  1255  225  26  210  672
#
#     BB    SO     BA    OBP    SLG    OPS    TB  HBP  SF
# 0  537  1465  0.236  0.309  0.382  0.692  2099   54  28
# 1  549  1453  0.244  0.319  0.435  0.754  2333   67  43
# 2  451  1454  0.239  0.304  0.402  0.705  2177   65  31
# 3  512  1386  0.261  0.328  0.449  0.777  2467   61  42
# 4  502  1596  0.237  0.312  0.407  0.719  2162   92  30

# %%
bat21 = bat21[:-2]

# %%
pit21 = pit21.drop(columns=['W-L%', 'GF', 'GS', 'BK', 'ERA+', 'LOB', 'tSho', 'CG', 'PAge', 
                            '#P', 'SO/W', 'cSho', 'SV', 'IBB', 'HBP', 'RA/G'])

# %%
pit21 = pit21[:-2]

# %%
pit21.head()
# Out:
#                      Tm   W    L   ERA    G      IP     H    R   ER   HR   BB  \
# 0  Arizona Diamondbacks  52  110  5.11  162  1417.1  1480  893  804  232  555
# 1        Atlanta Braves  88   73  3.88  161  1410.2  1237  656  608  183  516
# 2     Baltimore Orioles  52  110  5.84  162  1402.0  1518  956  910  258  563
# 3        Boston Red Sox  92   70  4.26  162  1419.0  1409  749  671  176  546
# 4          Chicago Cubs  71   91  4.87  162  1412.2  1386  839  765  235  596
#
#      SO  WP    BF   FIP   WHIP   H9  HR9  BB9  SO9
# 0  1238  43  6270  4.88  1.436  9.4  1.5  3.5  7.9
# 1  1417  73  5944  4.09  1.243  7.9  1.2  3.3  9.0
# 2  1234  88  6252  5.15  1.484  9.7  1.7  3.6  7.9
# 3  1527  63  6147  3.95  1.378  8.9  1.1  3.5  9.7
# 4  1358  60  6202  4.88  1.403  8.8  1.5  3.8  8.7

# %%
bat21.head()
# Out:
#                      Tm   R/G    G    PA    AB    R     H   2B  3B   HR  RBI  \
# 0  Arizona Diamondbacks  4.19  162  6144  5489  679  1297  308  31  144  644
# 1        Atlanta Braves  4.91  161  6056  5363  790  1307  269  20  239  762
# 2     Baltimore Orioles  4.07  162  5983  5420  659  1296  266  15  195  632
# 3        Boston Red Sox  5.12  162  6122  5495  829  1434  330  23  219  783
# 4          Chicago Cubs  4.35  162  5972  5306  705  1255  225  26  210  672
#
#     BB    SO     BA    OBP    SLG    OPS    TB  HBP  SF
# 0  537  1465  0.236  0.309  0.382  0.692  2099   54  28
# 1  549  1453  0.244  0.319  0.435  0.754  2333   67  43
# 2  451  1454  0.239  0.304  0.402  0.705  2177   65  31
# 3  512  1386  0.261  0.328  0.449  0.777  2467   61  42
# 4  502  1596  0.237  0.312  0.407  0.719  2162   92  30

# %%
pit19 = pd.read_csv('pit19.csv')
bat19 = pd.read_csv('bat19.csv')

# %%
bat19 = bat19.drop(columns=['SB', 'CS', 'OPS+', 'GDP', 'IBB', 'LOB', '#Bat', 'SH', 'BatAge'])
# Out:
#                        Tm   R/G     G      PA      AB      R      H    2B  \
# 0    Arizona Diamondbacks  5.02   162    6315    5633    813   1419   288
# 1          Atlanta Braves  5.28   162    6302    5560    855   1432   277
# 2       Baltimore Orioles  4.50   162    6189    5596    729   1379   252
# 3          Boston Red Sox  5.56   162    6475    5770    901   1554   345
# 4            Chicago Cubs  5.02   162    6195    5461    814   1378   270
# 5       Chicago White Sox  4.40   161    6042    5529    708   1443   260
# 6         Cincinnati Reds  4.33   162    6100    5450    701   1328   235
# 7       Cleveland Indians  4.75   162    6124    5425    769   1354   286
# 8        Colorado Rockies  5.15   162    6288    5660    835   1502   323
# 9          Detroit Tigers  3.61   161    6039    5549    582   1333   292
# 10         Houston Astros  5.68   162    6394    5613    920   1538   323
# 11     Kansas City Royals  4.27   162    6080    5496    691   1356   281
# ...

# %%
bat19 = bat19[:-2]

# %%
pit19 = pit19.drop(columns=['W-L%', 'GF', 'GS', 'BK', 'ERA+', 'LOB', 'tSho', 'CG', 'PAge', 
                            '#P', 'SO/W', 'cSho', 'SV', 'IBB', 'HBP', 'RA/G'])

# %%
pit19 = pit19[:-2]

# %%
pit18 = pd.read_csv('pit18.csv')
bat18 = pd.read_csv('bat18.csv')

# %%
bat18 = bat18.drop(columns=['SB', 'CS', 'OPS+', 'GDP', 'IBB', 'LOB', '#Bat', 'SH', 'BatAge'])

# %%
bat18 = bat18[:-2]

# %%
pit18 = pit18.drop(columns=['W-L%', 'GF', 'GS', 'BK', 'ERA+', 'LOB', 'tSho', 'CG', 'PAge', 
                            '#P', 'SO/W', 'cSho', 'SV', 'IBB', 'HBP', 'RA/G'])

# %%
pit18 = pit18[:-2]

# %%
pit17 = pd.read_csv('pit17.csv')
bat17 = pd.read_csv('bat17.csv')

# %%
bat17 = bat17.drop(columns=['SB', 'CS', 'OPS+', 'GDP', 'IBB', 'LOB', '#Bat', 'SH', 'BatAge'])

# %%
bat17 = bat17[:-2]

# %%
pit17 = pit17.drop(columns=['W-L%', 'GF', 'GS', 'BK', 'ERA+', 'LOB', 'tSho', 'CG', 'PAge', 
                            '#P', 'SO/W', 'cSho', 'SV', 'IBB', 'HBP', 'RA/G'])

# %%
pit17 = pit17[:-2]

# %%
pit17['year'] = 2017

# %%
bat17['year'] = 2017

# %%
pit18['year'] = 2018

# %%
bat18['year'] = 2018

# %%
bat19['year'] = 2019
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_82885/2844491877.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bat19['year'] = 2019

# %%
pit19['year'] = 2019

# %%
bat21['year'] = 2021
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_82885/1116338348.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bat21['year'] = 2021

# %%
pit21['year'] = 2021
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_82885/396092198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pit21['year'] = 2021

# %%
bat22['year'] = 2022

# %%
pit22['year'] = 2022
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_82885/2702576890.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pit22['year'] = 2022

# %%
pit22
# Out:
#                        Tm    W    L   ERA    G      IP     H    R   ER   HR  \
# 0    Arizona Diamondbacks   74   88  4.25  162  1430.0  1345  740  676  191
# 1          Atlanta Braves  101   61  3.46  162  1448.0  1224  609  556  148
# 2       Baltimore Orioles   83   79  3.97  162  1433.1  1406  688  632  171
# 3          Boston Red Sox   78   84  4.53  162  1431.0  1411  787  721  185
# 4            Chicago Cubs   74   88  4.00  162  1443.2  1342  731  642  207
# 5       Chicago White Sox   81   81  3.92  162  1447.2  1330  717  631  166
# 6         Cincinnati Reds   62  100  4.86  162  1423.1  1366  815  768  213
# 7     Cleveland Guardians   92   70  3.46  162  1456.0  1252  634  560  172
# 8        Colorado Rockies   68   94  5.06  162  1425.1  1516  873  802  184
# 9          Detroit Tigers   66   96  4.04  162  1419.2  1336  713  637  167
# 10         Houston Astros  106   56  2.90  162  1445.1  1121  518  465  134
# ...

# %%
pitch = pd.concat([pit17, pit18, pit19, pit21, pit22], axis=0)

# %%
pit17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tm      30 non-null     object
#  1   W       30 non-null     int64
#  2   L       30 non-null     int64
#  3   ERA     30 non-null     float64
#  4   G       30 non-null     int64
#  5   IP      30 non-null     float64
#  6   H       30 non-null     int64
#  7   R       30 non-null     int64
#  8   ER      30 non-null     int64
#  9   HR      30 non-null     int64
#  10  BB      30 non-null     int64
#  11  SO      30 non-null     int64
#  12  WP      30 non-null     int64
#  13  BF      30 non-null     int64
#  14  FIP     30 non-null     float64
#  15  WHIP    30 non-null     float64
#  16  H9      30 non-null     float64
#  17  HR9     30 non-null     float64
#  18  BB9     30 non-null     float64
#  19  SO9     30 non-null     float64
#  20  year    30 non-null     int64
# ...

# %%
pitch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 29
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tm      150 non-null    object
#  1   W       150 non-null    int64
#  2   L       150 non-null    int64
#  3   ERA     150 non-null    float64
#  4   G       150 non-null    int64
#  5   IP      150 non-null    float64
#  6   H       150 non-null    int64
#  7   R       150 non-null    int64
#  8   ER      150 non-null    int64
#  9   HR      150 non-null    int64
#  10  BB      150 non-null    int64
#  11  SO      150 non-null    int64
#  12  WP      150 non-null    int64
#  13  BF      150 non-null    int64
#  14  FIP     150 non-null    float64
#  15  WHIP    150 non-null    float64
#  16  H9      150 non-null    float64
#  17  HR9     150 non-null    float64
#  18  BB9     150 non-null    float64
#  19  SO9     150 non-null    float64
#  20  year    150 non-null    int64
# ...

# %%
bat = pd.concat([bat17, bat18, bat19, bat21, bat22], axis=0)

# %%
bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 29
# Data columns (total 21 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tm      150 non-null    object
#  1   R/G     150 non-null    float64
#  2   G       150 non-null    int64
#  3   PA      150 non-null    int64
#  4   AB      150 non-null    int64
#  5   R       150 non-null    int64
#  6   H       150 non-null    int64
#  7   2B      150 non-null    int64
#  8   3B      150 non-null    int64
#  9   HR      150 non-null    int64
#  10  RBI     150 non-null    int64
#  11  BB      150 non-null    int64
#  12  SO      150 non-null    int64
#  13  BA      150 non-null    float64
#  14  OBP     150 non-null    float64
#  15  SLG     150 non-null    float64
#  16  OPS     150 non-null    float64
#  17  TB      150 non-null    int64
#  18  HBP     150 non-null    int64
#  19  SF      150 non-null    int64
#  20  year    150 non-null    int64
# ...

# %%
# bat.to_csv('batting.csv', index=False)

# %%
# pitch.to_csv('pitch.csv', index=False)
