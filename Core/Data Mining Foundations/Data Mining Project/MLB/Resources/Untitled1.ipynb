# %% [markdown]
# [GLOSSARY](https://baseballsavant.mlb.com/csv-docs)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('savant_data.csv')

# %%
df.head()
# Out:
#   pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0         SL  2023-07-07           86.9          -1.96           6.82
# 1         SL  2023-07-07           85.5          -1.78           6.76
# 2         FF  2023-07-07           94.3          -1.59           6.70
# 3         FF  2023-07-07           93.9          -1.66           6.74
# 4         FF  2023-07-07           94.3          -1.68           6.77
#
#          player_name  batter  pitcher     events    description  ...  \
# 0  Verlander, Justin  572761   434378  field_out  hit_into_play  ...
# 1  Verlander, Justin  596142   434378  field_out  hit_into_play  ...
# 2  Verlander, Justin  596142   434378        NaN           ball  ...
# 3  Verlander, Justin  630105   434378  field_out  hit_into_play  ...
# 4  Verlander, Justin  630105   434378        NaN           ball  ...
#
#    fld_score  post_away_score  post_home_score  post_bat_score  \
# ...

# %%
df.columns
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'player_name', 'batter', 'pitcher', 'events',
#        'description', 'spin_dir', 'spin_rate_deprecated',
#        'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
#        'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
#        'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
#        'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
#        'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
#        'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
# ...

# %%
df = df.drop(columns=['player_name', 'if_fielding_alignment', 'of_fielding_alignment'])

# %%
df
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            SL  2023-07-07           86.9          -1.96           6.82
# 1            SL  2023-07-07           85.5          -1.78           6.76
# 2            FF  2023-07-07           94.3          -1.59           6.70
# 3            FF  2023-07-07           93.9          -1.66           6.74
# 4            FF  2023-07-07           94.3          -1.68           6.77
# ...         ...         ...            ...            ...            ...
# 1151         FF  2023-05-04           94.6          -1.56           7.02
# 1152         FF  2023-05-04           94.8          -1.51           6.96
# 1153         SL  2023-05-04           85.8          -1.52           6.96
# 1154         FF  2023-05-04           94.4          -1.43           6.94
# 1155         FF  2023-05-04           93.4          -1.67           6.97
#
#       batter  pitcher     events    description  spin_dir  ...  away_score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 89 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   pitch_type                       1156 non-null   object
#  1   game_date                        1156 non-null   object
#  2   release_speed                    1155 non-null   float64
#  3   release_pos_x                    1156 non-null   float64
#  4   release_pos_z                    1156 non-null   float64
#  5   batter                           1156 non-null   int64
#  6   pitcher                          1156 non-null   int64
#  7   events                           291 non-null    object
#  8   description                      1156 non-null   object
#  9   spin_dir                         0 non-null      float64
#  10  spin_rate_deprecated             0 non-null      float64
#  11  break_angle_deprecated           0 non-null      float64
# ...

# %%
df = df.drop(columns=['umpire', 'sv_id', 'tfs_zulu_deprecated', 'tfs_deprecated', 
                     'spin_dir', 'spin_rate_deprecated', 'break_angle_deprecated', 
                     'break_length_deprecated'])

# %%
df
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            SL  2023-07-07           86.9          -1.96           6.82
# 1            SL  2023-07-07           85.5          -1.78           6.76
# 2            FF  2023-07-07           94.3          -1.59           6.70
# 3            FF  2023-07-07           93.9          -1.66           6.74
# 4            FF  2023-07-07           94.3          -1.68           6.77
# ...         ...         ...            ...            ...            ...
# 1151         FF  2023-05-04           94.6          -1.56           7.02
# 1152         FF  2023-05-04           94.8          -1.51           6.96
# 1153         SL  2023-05-04           85.8          -1.52           6.96
# 1154         FF  2023-05-04           94.4          -1.43           6.94
# 1155         FF  2023-05-04           93.4          -1.67           6.97
#
#       batter  pitcher     events    description  zone  ... away_score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 81 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   pitch_type                       1156 non-null   object
#  1   game_date                        1156 non-null   object
#  2   release_speed                    1155 non-null   float64
#  3   release_pos_x                    1156 non-null   float64
#  4   release_pos_z                    1156 non-null   float64
#  5   batter                           1156 non-null   int64
#  6   pitcher                          1156 non-null   int64
#  7   events                           291 non-null    object
#  8   description                      1156 non-null   object
#  9   zone                             1156 non-null   int64
#  10  des                              1156 non-null   object
#  11  game_type                        1156 non-null   object
# ...

# %%
df['hit_distance_sc']
# Out:
# 0       249.0
# 1       153.0
# 2         NaN
# 3       276.0
# 4         NaN
#         ...
# 1151      NaN
# 1152    338.0
# 1153      NaN
# 1154      NaN
# 1155      NaN
# Name: hit_distance_sc, Length: 1156, dtype: float64

# %%
df['hc_y']
# Out:
# 0       121.25
# 1       157.57
# 2          NaN
# 3       100.69
# 4          NaN
#          ...
# 1151       NaN
# 1152     66.50
# 1153       NaN
# 1154       NaN
# 1155       NaN
# Name: hc_y, Length: 1156, dtype: float64
