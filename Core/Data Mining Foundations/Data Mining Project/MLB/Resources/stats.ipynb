# %%
import pandas as pd
import numpy as np

# %%
# !pip install pybaseball
# Out:
# ...
# WARNING: Error parsing requirements for markupsafe: [Errno 2] No such file or directory: '/Users/ryantalbot/opt/anaconda3/lib/python3.9/site-packages/MarkupSafe-2.0.1.dist-info/METADATA'

# %%
# import sys
# sys.path

# %%
# /Users/yufeng/anaconda3/envs/py33/bin/python -m pip install plotly

# %%
from pybaseball import statcast

# %%
data = statcast(start_dt='2017-06-24', end_dt='2017-06-27')
# Out:
# This is a large query, it may take a moment to complete
# 100%|█████████████████████████████████████████████| 4/4 [00:14<00:00,  3.67s/it]

# %%
data.head(2)
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3338         CU 2017-06-27           79.7          -1.34           5.41
# 3429         FF 2017-06-27           98.1          -1.35           5.42
#
#      player_name  batter  pitcher     events    description  ...  fld_score  \
# 3338  Bush, Matt  608070   456713  field_out  hit_into_play  ...          2
# 3429  Bush, Matt  429665   456713  field_out  hit_into_play  ...          2
#
#       post_away_score  post_home_score  post_bat_score  post_fld_score  \
# 3338                2                1               1               2
# 3429                2                1               1               2
#
#      if_fielding_alignment of_fielding_alignment spin_axis delta_home_win_exp  \
# 3338              Standard             Strategic        51             -0.096
# 3429              Standard             Strategic       204              -0.11
#
#      delta_run_exp
# 3338        -0.228
# 3429        -0.292
#
# ...

# %%
from pybaseball import schedule_and_record
# data = schedule_and_record(1927, 'NYY')

# %%
data
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3338         CU 2017-06-27           79.7          -1.34           5.41
# 3429         FF 2017-06-27           98.1          -1.35           5.42
# 3517         FF 2017-06-27           98.3          -1.29           5.45
# 3680         FC 2017-06-27           90.9          -1.46           5.25
# 3843         SI 2017-06-27           99.1          -1.37           5.34
# ...         ...        ...            ...            ...            ...
# 3799         FF 2017-06-24           91.8          -1.73           6.55
# 3924         FS 2017-06-24           82.6          -1.73           6.38
# 4028         SL 2017-06-24           85.9          -1.63           6.37
# 4122         FF 2017-06-24           91.9          -1.47           6.59
# 4256         FF 2017-06-24           92.4          -1.57           6.57
#
#       player_name  batter  pitcher     events      description  ...  \
# ...

# %%
from pybaseball import standings
# standings = standings(2016)[4]

# %%
standings
# Out:
# <function pybaseball.standings.standings(season: Optional[int] = None) -> pandas.core.frame.DataFrame>

# %%
stand = standings(2023)

# %%
stand
# Out:
# [                  Tm   W   L  W-L%    GB  E#
#  1  Baltimore Orioles  74  47  .612    --  --
#  2     Tampa Bay Rays  73  50  .593   2.0  39
#  3  Toronto Blue Jays  67  55  .549   7.5  34
#  4     Boston Red Sox  63  57  .525  10.5  32
#  5   New York Yankees  60  61  .496  14.0  28,
#                      Tm   W   L  W-L%    GB  E#
#  1      Minnesota Twins  63  59  .516    --  --
#  2  Cleveland Guardians  58  63  .479   4.5  37
#  3       Detroit Tigers  54  66  .450   8.0  34
#  4    Chicago White Sox  48  73  .397  14.5  27
#  5   Kansas City Royals  39  83  .320  24.0  17,
#                     Tm   W   L  W-L%    GB  E#
#  1       Texas Rangers  72  49  .595    --  --
#  2      Houston Astros  70  52  .574   2.5  39
#  3    Seattle Mariners  65  55  .542   6.5  36
#  4  Los Angeles Angels  60  62  .492  12.5  29
#  5   Oakland Athletics  34  87  .281  38.0   4,
#                        Tm   W   L  W-L%    GB  E#
#  1         Atlanta Braves  78  42  .650    --  --
# ...

# %%
from pybaseball import statcast

# # get all statcast data for July 4th, 2017
# data = statcast('2017-07-04')

# %%
data
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3193         FC 2017-07-04           91.1          -0.79           6.04
# 3247         FC 2017-07-04           92.3          -1.04           5.86
# 3382         FC 2017-07-04           91.0          -1.32           5.83
# 3443         FF 2017-07-04           95.6          -1.14           5.98
# 3575         FC 2017-07-04           91.2          -1.24           5.94
# ...         ...        ...            ...            ...            ...
# 3908         FF 2017-07-04           93.3           1.18           6.38
# 4048         SL 2017-07-04           88.6           1.19           6.49
# 4206         SL 2017-07-04           89.7           1.11           6.48
# 4267         CU 2017-07-04           73.4           0.81           6.66
# 4364         FF 2017-07-04           92.7           1.08           6.43
#
#            player_name  batter  pitcher     events      description  ...  \
# ...

# %%
#get data for the first seven days of August in 2016
seven = statcast('2016-08-01', '2016-08-07')

#get all data for the Texas Rangers in the 2016 season
rangers = statcast('2016-04-01', '2016-10-30', team='TEX')

# get data for yesterday
yest = statcast()
# Out:
# This is a large query, it may take a moment to complete
# 100%|█████████████████████████████████████████████| 7/7 [00:16<00:00,  2.32s/it]
# This is a large query, it may take a moment to complete
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# Skipping offseason dates
# ...

# %%
seven
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 2598         CH 2016-08-07           82.8          -0.46           6.77
# 2691         FF 2016-08-07           90.1          -0.25            6.8
# 2726         FF 2016-08-07           87.7          -0.42            6.7
# 2824         FF 2016-08-07           89.0          -0.45           6.69
# 2869         SL 2016-08-07           83.2           -0.4           6.79
# ...         ...        ...            ...            ...            ...
# 2276         KC 2016-08-01           83.3           2.07           6.58
# 2342         FF 2016-08-01           98.0            2.1           6.67
# 2438         FF 2016-08-01           97.4           2.09           6.69
# 2491         FF 2016-08-01           97.1           2.01           6.74
# 2577         FF 2016-08-01           97.1           2.28           6.67
#
#         player_name  batter  pitcher     events      description  ...  \
# ...

# %%
rangers
# Out:
#     pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 0           FF 2016-10-09           99.1          -1.47           5.48
# 2           FF 2016-10-09           99.7          -1.51            5.4
# 4           FF 2016-10-09           98.5          -1.49           5.55
# 7           FF 2016-10-09           98.8          -1.58           5.51
# 8           FF 2016-10-09           98.5          -1.39           5.43
# ..         ...        ...            ...            ...            ...
# 120         FF 2016-04-04           92.2           2.03           6.56
# 122         FF 2016-04-04           92.5           1.98           6.55
# 124         FF 2016-04-04           92.5           2.25           6.43
# 129         FC 2016-04-04           88.2           2.19           6.35
# 130         FF 2016-04-04           91.8            1.8           6.66
#
#       player_name  batter  pitcher     events    description  ...  fld_score  \
# ...

# %%
yest
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3799         FC 2023-08-15           93.2           -2.9           6.18
# 3890         FC 2023-08-15           93.5          -2.75           6.16
# 4040         FC 2023-08-15           94.5          -2.81            6.2
# 4137         FC 2023-08-15           93.0          -2.88           6.26
# 4243         FC 2023-08-15           92.9          -2.95           6.18
# ...         ...        ...            ...            ...            ...
# 3845         SI 2023-08-15           88.4           3.04           5.75
# 3920         SI 2023-08-15           88.8           3.28           5.75
# 4036         SI 2023-08-15           89.4           2.96           5.76
# 4219         SI 2023-08-15           89.3           2.91           5.81
# 4270         SI 2023-08-15           88.7           3.06           5.69
#
#          player_name  batter  pitcher     events      description  ...  \
# ...

# %%
from pybaseball import team_game_logs

# %%
# Braves batting logs for 2019
batting_logs = team_game_logs(2019, "ATL")

# Orioles pitching logs from 2018
pitching_logs = team_game_logs(2019, "ATL", "pitching")

# %%
batting_logs
# Out:
#      Game    Date   Home  Opp    Rslt  PA  AB   R   H  2B  ...  SB  CS     BA  \
# 0       1  Mar 28   True  PHI  L,4-10  36  30   4   7   1  ...   1   1  0.233
# 1       2  Mar 30   True  PHI   L,6-8  40  36   6  10   2  ...   1   0  0.258
# 2       3  Mar 31   True  PHI   L,1-5  36  29   1   4   0  ...   1   2  0.221
# 3       4   Apr 1  False  CHC   W,8-0  43  36   8  12   3  ...   0   0  0.252
# 4       5   Apr 3  False  CHC   W,6-4  39  30   6   8   1  ...   1   0  0.255
# ..    ...     ...    ...  ...     ...  ..  ..  ..  ..  ..  ...  ..  ..    ...
# 157   158  Sep 24   True  KCR   L,6-9  41  37   6  11   3  ...   0   0  0.258
# 158   159  Sep 25   True  KCR  W,10-2  48  40  10  14   4  ...   0   0  0.258
# 159   160  Sep 27   True  NYM   L,2-4  39  35   2   9   0  ...   2   0  0.258
# 160   161  Sep 28   True  NYM   L,0-3  37  31   0   4   0  ...   0   0  0.258
# 161   162  Sep 29   True  NYM   L,6-7  45  42   6  11   1  ...   1   1  0.258
#
# ...

# %%
batting_logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Game        162 non-null    int64
#  1   Date        162 non-null    object
#  2   Home        162 non-null    bool
#  3   Opp         162 non-null    object
#  4   Rslt        162 non-null    object
#  5   PA          162 non-null    int64
#  6   AB          162 non-null    int64
#  7   R           162 non-null    int64
#  8   H           162 non-null    int64
#  9   2B          162 non-null    int64
#  10  3B          162 non-null    int64
#  11  HR          162 non-null    int64
#  12  RBI         162 non-null    int64
#  13  BB          162 non-null    int64
#  14  IBB         162 non-null    int64
#  15  SO          162 non-null    int64
#  16  HBP         162 non-null    int64
#  17  SH          162 non-null    int64
#  18  SF          162 non-null    int64
# ...

# %%
batting_logs.describe()
# Out:
#              Game          PA          AB           R           H          2B  \
# count  162.000000  162.000000  162.000000  162.000000  162.000000  162.000000
# mean    81.500000   38.901235   34.320988    5.277778    8.839506    1.709877
# std     46.909487    4.896709    4.068748    3.203744    3.285416    1.359037
# min      1.000000   28.000000   24.000000    0.000000    3.000000    0.000000
# 25%     41.250000   35.000000   32.000000    3.000000    7.000000    1.000000
# 50%     81.500000   38.000000   34.000000    5.000000    8.000000    1.000000
# 75%    121.750000   42.000000   36.000000    7.000000   11.000000    2.750000
# max    162.000000   56.000000   49.000000   15.000000   19.000000    6.000000
#
#                3B          HR         RBI          BB  ...         ROE  \
# count  162.000000  162.000000  162.000000  162.000000  ...  162.000000
# mean     0.179012    1.537037    5.086420    3.820988  ...    0.308642
# ...

# %%
pitching_logs.head()
# Out:
#    Game    Date   Home  Opp    Rslt   IP   H   R  ER  UER  ...  2B  3B  IBB  \
# 0     1  Mar 28   True  PHI  L,4-10  8.0   7  10  10    0  ...   0   0    2
# 1     2  Mar 30   True  PHI   L,6-8  8.0   9   8   8    0  ...   2   1    1
# 2     3  Mar 31   True  PHI   L,1-5  8.0   5   5   5    0  ...   1   0    0
# 3     4   Apr 1  False  CHC   W,8-0  9.0   9   0   0    0  ...   3   0    0
# 4     5   Apr 3  False  CHC   W,6-4  9.0  12   4   4    0  ...   0   0    0
#
#    SH  SF  ROE  GDP  NumPlayers           Umpire  \
# 0   0   0    0    0           5     Mike Winters
# 1   0   0    0    0           6      Tim Timmons
# 2   0   1    0    1           4        Rob Drake
# 3   0   0    1    3           5  Gary Cederstrom
# 4   0   0    0    1           6    Marvin Hudson
#
#                                         PitchersUsed
# 0  J.Teheran (99-52-L), S.Carle (99), W.Parsons (...
# 1  B.Wilson (99-33), W.Parsons (1-L), J.Venters (...
# ...

# %%
pitching_logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Game          162 non-null    int64
#  1   Date          162 non-null    object
#  2   Home          162 non-null    bool
#  3   Opp           162 non-null    object
#  4   Rslt          162 non-null    object
#  5   IP            162 non-null    float64
#  6   H             162 non-null    int64
#  7   R             162 non-null    int64
#  8   ER            162 non-null    int64
#  9   UER           162 non-null    int64
#  10  BB            162 non-null    int64
#  11  SO            162 non-null    int64
#  12  HR            162 non-null    int64
#  13  HBP           162 non-null    int64
#  14  ERA           162 non-null    float64
#  15  BF            162 non-null    int64
#  16  Pit           162 non-null    int64
#  17  Str           162 non-null    int64
# ...

# %%
pitching_logs.describe()
# Out:
#              Game         IP           H           R          ER         UER  \
# count  162.000000  162.00000  162.000000  162.000000  162.000000  162.000000
# mean    81.500000    8.94321    8.771605    4.586420    4.166667    0.419753
# std     46.909487    0.80764    3.346036    3.022987    2.961974    0.937344
# min      1.000000    6.00000    2.000000    0.000000    0.000000    0.000000
# 25%     41.250000    9.00000    6.000000    2.000000    2.000000    0.000000
# 50%     81.500000    9.00000    9.000000    4.000000    4.000000    0.000000
# 75%    121.750000    9.00000   11.000000    7.000000    6.000000    0.000000
# max    162.000000   14.00000   23.000000   14.000000   14.000000    5.000000
#
#                BB          SO          HR         HBP  ...          CS  \
# count  162.000000  162.000000  162.000000  162.000000  ...  162.000000
# mean     3.382716    8.598765    1.253086    0.425926  ...    0.123457
# ...

# %%
batting_logs = team_game_logs(2023, "ATL")

# %%
batting_logs
# Out:
#      Game        Date   Home  Opp    Rslt  PA  AB   R   H  2B  ...  SB  CS  \
# 0       1      Mar 30   True  WSN   W,7-2  46  40   7  12   2  ...   2   0
# 1       2       Apr 1   True  WSN   W,7-1  37  35   7  11   0  ...   0   0
# 2       3       Apr 2   True  WSN   L,1-4  33  28   1   4   1  ...   0   0
# 3       4       Apr 3   True  STL   W,8-4  40  35   8  10   3  ...   0   1
# 4       5       Apr 4   True  STL   W,4-1  38  37   4  12   1  ...   1   0
# ..    ...         ...    ...  ...     ...  ..  ..  ..  ..  ..  ...  ..  ..
# 115   116  Aug 12 (2)   True  NYM   W,6-0  40  34   6   7   2  ...   2   0
# 116   117      Aug 13   True  NYM   L,6-7  37  34   6   7   2  ...   1   0
# 117   118      Aug 14  False  NYY  W,11-3  44  36  11  15   2  ...   1   0
# 118   119      Aug 15  False  NYY   W,5-0  38  31   5   6   0  ...   0   0
# 119   120      Aug 16  False  NYY   W,2-0  29  25   2   3   1  ...   0   1
#
# ...

# %%
pitching_logs = team_game_logs(2023, "ATL", "pitching")

# %%
pitching_logs
# Out:
#      Game       Date   Home  Opp    Rslt   IP   H  R  ER  UER  ...  2B  3B  \
# 0       1     Mar 30   True  WSN   W,7-2  9.0   8  2   2    0  ...   1   0
# 1       2      Apr 1   True  WSN   W,7-1  9.0   5  1   1    0  ...   1   0
# 2       3      Apr 2   True  WSN   L,1-4  8.0   6  4   4    0  ...   1   0
# 3       4      Apr 3   True  STL   W,8-4  9.0  12  4   4    0  ...   0   0
# 4       5      Apr 4   True  STL   W,4-1  9.0  10  1   1    0  ...   1   0
# ..    ...        ...    ...  ...     ...  ...  .. ..  ..  ...  ...  ..  ..
# 115   116  Aug 12(2)   True  NYM   W,6-0  9.0   5  0   0    0  ...   2   0
# 116   117     Aug 13   True  NYM   L,6-7  8.0  10  7   6    1  ...   1   0
# 117   118     Aug 14  False  NYY  W,11-3  9.0  11  3   3    0  ...   1   1
# 118   119     Aug 15  False  NYY   W,5-0  9.0   1  0   0    0  ...   0   0
# 119   120     Aug 16  False  NYY   W,2-0  9.0   4  0   0    0  ...   0   0
#
#      IBB  SH  SF  ROE  GDP  NumPlayers            Umpire  \
# ...

# %%
batting_logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Game        120 non-null    int64
#  1   Date        120 non-null    object
#  2   Home        120 non-null    bool
#  3   Opp         120 non-null    object
#  4   Rslt        120 non-null    object
#  5   PA          120 non-null    int64
#  6   AB          120 non-null    int64
#  7   R           120 non-null    int64
#  8   H           120 non-null    int64
#  9   2B          120 non-null    int64
#  10  3B          120 non-null    int64
#  11  HR          120 non-null    int64
#  12  RBI         120 non-null    int64
#  13  BB          120 non-null    int64
#  14  IBB         120 non-null    int64
#  15  SO          120 non-null    int64
#  16  HBP         120 non-null    int64
#  17  SH          120 non-null    int64
#  18  SF          120 non-null    int64
# ...

# %%
pitching_logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Game          120 non-null    int64
#  1   Date          120 non-null    object
#  2   Home          120 non-null    bool
#  3   Opp           120 non-null    object
#  4   Rslt          120 non-null    object
#  5   IP            120 non-null    float64
#  6   H             120 non-null    int64
#  7   R             120 non-null    int64
#  8   ER            120 non-null    int64
#  9   UER           120 non-null    int64
#  10  BB            120 non-null    int64
#  11  SO            120 non-null    int64
#  12  HR            120 non-null    int64
#  13  HBP           120 non-null    int64
#  14  ERA           120 non-null    float64
#  15  BF            120 non-null    int64
#  16  Pit           120 non-null    int64
#  17  Str           120 non-null    int64
# ...

# %%
pitching_logs.PitchersUsed
# Out:
# 0      M.Fried (99-50), L.Luetge (99-W), J.Chavez (99...
# 1      S.Strider (99-72-W), N.Anderson (99), J.Jiméne...
# 2       J.Shuster (99-32-L), M.Tonkin (99), J.Chavez (2)
# 3      C.Morton (99-37-W), N.Anderson (1-H), C.McHugh...
# 4      D.Dodd (99-54-W), J.Chavez (1-H), J.Jiménez (2...
#                              ...
# 115     S.Strider (4-73-W), A.Minter (0), R.Iglesias (2)
# 116       Y.Chirinos (4-29-L), C.McHugh (3), K.Yates (1)
# 117       M.Fried (4-49-W), P.Johnson (2), J.Jiménez (3)
# 118          B.Elder (4-75-W), A.Minter (2), K.Yates (1)
# 119    C.Morton (4-73-W), P.Johnson (1-H), K.Yates (0...
# Name: PitchersUsed, Length: 120, dtype: object

# %%
atl = statcast('2023-01-01', '2023-08-15', team='ATL')
# Out:
# This is a large query, it may take a moment to complete
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pybaseball/statcast.py:50: UserWarning:
# That's a nice request you got there. It'd be a shame if something were to happen to it.
# We strongly recommend that you enable caching before running this. It's as simple as `pybaseball.cache.enable()`.
# Since the Statcast requests can take a *really* long time to run, if something were to happen, like: a disconnect;
# gremlins; computer repair by associates of Rudy Giuliani; electromagnetic interference from metal trash cans; etc.;
# you could lose a lot of progress. Enabling caching will allow you to immediately recover all the successful
# subqueries if that happens.
#   warnings.warn(_OVERSIZE_WARNING)
# Skipping offseason dates
# 100%|█████████████████████████████████████████| 154/154 [00:22<00:00,  6.78it/s]

# %%
atl
# Out:
#    pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 83         FS 2023-08-15           86.8          -2.46            5.4
# 86         FS 2023-08-15           87.2           -2.6           5.29
# 90         FF 2023-08-15           93.7          -2.48           5.31
# 93         FF 2023-08-15           93.5           -2.6           5.29
# 97         FS 2023-08-15           86.8          -2.65           5.23
# ..        ...        ...            ...            ...            ...
# 63        NaN 2023-03-15           <NA>           <NA>           <NA>
# 65        NaN 2023-03-15           <NA>           <NA>           <NA>
# 75        NaN 2023-03-15           <NA>           <NA>           <NA>
# 80        NaN 2023-03-15           <NA>           <NA>           <NA>
# 86        NaN 2023-03-15           <NA>           <NA>           <NA>
#
#          player_name  batter  pitcher                     events  \
# ...

# %%
data = schedule_and_record(2023, 'ATL')
# Out:
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pybaseball/team_results.py:70: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('',1) #not a useful column
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pybaseball/team_results.py:83: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('Streak2',1)

# %%
data
# Out:
#                   Date   Tm Home_Away  Opp   W/L    R   RA  Inn   W-L  Rank  \
# 1     Thursday, Mar 30  ATL         @  WSN     W  7.0  2.0  9.0   1-0   1.0
# 2      Saturday, Apr 1  ATL         @  WSN     W  7.0  1.0  9.0   2-0   1.0
# 3        Sunday, Apr 2  ATL         @  WSN     L  1.0  4.0  9.0   2-1   2.0
# 4        Monday, Apr 3  ATL         @  STL     W  8.0  4.0  9.0   3-1   1.0
# 5       Tuesday, Apr 4  ATL         @  STL     W  4.0  1.0  9.0   4-1   1.0
# ..                 ...  ...       ...  ...   ...  ...  ...  ...   ...   ...
# 158  Wednesday, Sep 27  ATL      Home  CHC  None  NaN  NaN  NaN  None   NaN
# 159   Thursday, Sep 28  ATL      Home  CHC  None  NaN  NaN  NaN  None   NaN
# 160     Friday, Sep 29  ATL      Home  WSN  None  NaN  NaN  NaN  None   NaN
# 161   Saturday, Sep 30  ATL      Home  WSN  None  NaN  NaN  NaN  None   NaN
# 162      Sunday, Oct 1  ATL      Home  WSN  None  NaN  NaN  NaN  None   NaN
#
# ...

# %% [markdown]
# combine pitching log, batting log and data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 1 to 162
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             162 non-null    object
#  1   Tm               162 non-null    object
#  2   Home_Away        162 non-null    object
#  3   Opp              162 non-null    object
#  4   W/L              120 non-null    object
#  5   R                120 non-null    float64
#  6   RA               120 non-null    float64
#  7   Inn              120 non-null    float64
#  8   W-L              120 non-null    object
#  9   Rank             120 non-null    float64
#  10  GB               120 non-null    object
#  11  Win              120 non-null    object
#  12  Loss             120 non-null    object
#  13  Save             120 non-null    object
#  14  Time             120 non-null    object
#  15  D/N              120 non-null    object
# ...

# %%
pitching_logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 33 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Game          120 non-null    int64
#  1   Date          120 non-null    object
#  2   Home          120 non-null    bool
#  3   Opp           120 non-null    object
#  4   Rslt          120 non-null    object
#  5   IP            120 non-null    float64
#  6   H             120 non-null    int64
#  7   R             120 non-null    int64
#  8   ER            120 non-null    int64
#  9   UER           120 non-null    int64
#  10  BB            120 non-null    int64
#  11  SO            120 non-null    int64
#  12  HR            120 non-null    int64
#  13  HBP           120 non-null    int64
#  14  ERA           120 non-null    float64
#  15  BF            120 non-null    int64
#  16  Pit           120 non-null    int64
#  17  Str           120 non-null    int64
# ...

# %%
batting_logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Game        120 non-null    int64
#  1   Date        120 non-null    object
#  2   Home        120 non-null    bool
#  3   Opp         120 non-null    object
#  4   Rslt        120 non-null    object
#  5   PA          120 non-null    int64
#  6   AB          120 non-null    int64
#  7   R           120 non-null    int64
#  8   H           120 non-null    int64
#  9   2B          120 non-null    int64
#  10  3B          120 non-null    int64
#  11  HR          120 non-null    int64
#  12  RBI         120 non-null    int64
#  13  BB          120 non-null    int64
#  14  IBB         120 non-null    int64
#  15  SO          120 non-null    int64
#  16  HBP         120 non-null    int64
#  17  SH          120 non-null    int64
#  18  SF          120 non-null    int64
# ...

# %% [markdown]
# 31 columsn + 33 columns = 64 columns

# %%
df3 = pd.concat([batting_logs, pitching_logs, data], axis=1)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163 entries, 0 to 162
# Data columns (total 84 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Game             120 non-null    float64
#  1   Date             120 non-null    object
#  2   Home             120 non-null    object
#  3   Opp              120 non-null    object
#  4   Rslt             120 non-null    object
#  5   PA               120 non-null    float64
#  6   AB               120 non-null    float64
#  7   R                120 non-null    float64
#  8   H                120 non-null    float64
#  9   2B               120 non-null    float64
#  10  3B               120 non-null    float64
#  11  HR               120 non-null    float64
#  12  RBI              120 non-null    float64
#  13  BB               120 non-null    float64
#  14  IBB              120 non-null    float64
#  15  SO               120 non-null    float64
# ...

# %%
df= pitching_logs.append(batting_logs)
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_67226/3457327914.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df= pitching_logs.append(batting_logs)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 0 to 119
# Data columns (total 42 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Game          240 non-null    int64
#  1   Date          240 non-null    object
#  2   Home          240 non-null    bool
#  3   Opp           240 non-null    object
#  4   Rslt          240 non-null    object
#  5   IP            120 non-null    float64
#  6   H             240 non-null    int64
#  7   R             240 non-null    int64
#  8   ER            120 non-null    float64
#  9   UER           120 non-null    float64
#  10  BB            240 non-null    int64
#  11  SO            240 non-null    int64
#  12  HR            240 non-null    int64
#  13  HBP           240 non-null    int64
#  14  ERA           120 non-null    float64
#  15  BF            120 non-null    float64
#  16  Pit           120 non-null    float64
#  17  Str           120 non-null    float64
# ...

# %%
df
# Out:
#      Game        Date   Home  Opp    Rslt   IP   H   R   ER  UER  ...  \
# 0       1      Mar 30   True  WSN   W,7-2  9.0   8   2  2.0  0.0  ...
# 1       2       Apr 1   True  WSN   W,7-1  9.0   5   1  1.0  0.0  ...
# 2       3       Apr 2   True  WSN   L,1-4  8.0   6   4  4.0  0.0  ...
# 3       4       Apr 3   True  STL   W,8-4  9.0  12   4  4.0  0.0  ...
# 4       5       Apr 4   True  STL   W,4-1  9.0  10   1  1.0  0.0  ...
# ..    ...         ...    ...  ...     ...  ...  ..  ..  ...  ...  ...
# 115   116  Aug 12 (2)   True  NYM   W,6-0  NaN   7   6  NaN  NaN  ...
# 116   117      Aug 13   True  NYM   L,6-7  NaN   7   6  NaN  NaN  ...
# 117   118      Aug 14  False  NYY  W,11-3  NaN  15  11  NaN  NaN  ...
# 118   119      Aug 15  False  NYY   W,5-0  NaN   6   5  NaN  NaN  ...
# 119   120      Aug 16  False  NYY   W,2-0  NaN   3   2  NaN  NaN  ...
#
#                                           PitchersUsed    PA   RBI     BA  \
# ...

# %%
df_merged.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_67226/2786106695.py in <cell line: 1>()
# ----> 1 df_merged.info()
#
# NameError: name 'df_merged' is not defined

# %%
df_merged

# %%
df = df_col_merged
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_67226/2104473355.py in <cell line: 1>()
# ----> 1 df = df_col_merged
#
# NameError: name 'df_col_merged' is not defined

# %%
df.info()

# %%
# df2 = df.drop_duplicates()

# %%
df['Game']
# Out:
#      Game  Game
# 0       1     1
# 1       2     2
# 2       3     3
# 3       4     4
# 4       5     5
# ..    ...   ...
# 115   116   116
# 116   117   117
# 117   118   118
# 118   119   119
# 119   120   120
#
# [120 rows x 2 columns]

# %%
# df2 = df.loc[:,~df.columns.duplicated()].copy()

# %%
df
# Out:
#      Game        Date   Home  Opp    Rslt  PA  AB   R   H  2B  ...  2B  3B  \
# 0       1      Mar 30   True  WSN   W,7-2  46  40   7  12   2  ...   1   0
# 1       2       Apr 1   True  WSN   W,7-1  37  35   7  11   0  ...   1   0
# 2       3       Apr 2   True  WSN   L,1-4  33  28   1   4   1  ...   1   0
# 3       4       Apr 3   True  STL   W,8-4  40  35   8  10   3  ...   0   0
# 4       5       Apr 4   True  STL   W,4-1  38  37   4  12   1  ...   1   0
# ..    ...         ...    ...  ...     ...  ..  ..  ..  ..  ..  ...  ..  ..
# 115   116  Aug 12 (2)   True  NYM   W,6-0  40  34   6   7   2  ...   2   0
# 116   117      Aug 13   True  NYM   L,6-7  37  34   6   7   2  ...   1   0
# 117   118      Aug 14  False  NYY  W,11-3  44  36  11  15   2  ...   1   1
# 118   119      Aug 15  False  NYY   W,5-0  38  31   5   6   0  ...   0   0
# 119   120      Aug 16  False  NYY   W,2-0  29  25   2   3   1  ...   0   0
#
#      IBB  SH  SF  ROE  GDP  NumPlayers            Umpire  \
# ...

# %%
df3
# Out:
#      Game    Date  Home  Opp   Rslt    PA    AB    R     H   2B  ...      GB  \
# 0     1.0  Mar 30  True  WSN  W,7-2  46.0  40.0  7.0  12.0  2.0  ...     NaN
# 1     2.0   Apr 1  True  WSN  W,7-1  37.0  35.0  7.0  11.0  0.0  ...    Tied
# 2     3.0   Apr 2  True  WSN  L,1-4  33.0  28.0  1.0   4.0  1.0  ...  up 0.5
# 3     4.0   Apr 3  True  STL  W,8-4  40.0  35.0  8.0  10.0  3.0  ...     0.5
# 4     5.0   Apr 4  True  STL  W,4-1  38.0  37.0  4.0  12.0  1.0  ...  up 0.5
# ..    ...     ...   ...  ...    ...   ...   ...  ...   ...  ...  ...     ...
# 158   NaN     NaN   NaN  NaN    NaN   NaN   NaN  NaN   NaN  NaN  ...    None
# 159   NaN     NaN   NaN  NaN    NaN   NaN   NaN  NaN   NaN  NaN  ...    None
# 160   NaN     NaN   NaN  NaN    NaN   NaN   NaN  NaN   NaN  NaN  ...    None
# 161   NaN     NaN   NaN  NaN    NaN   NaN   NaN  NaN   NaN  NaN  ...    None
# 162   NaN     NaN   NaN  NaN    NaN   NaN   NaN  NaN   NaN  NaN  ...    None
#
# ...

# %%
df
# Out:
#      Game        Date   Home  Opp    Rslt  PA  AB   R   H  2B  ...  2B  3B  \
# 0       1      Mar 30   True  WSN   W,7-2  46  40   7  12   2  ...   1   0
# 1       2       Apr 1   True  WSN   W,7-1  37  35   7  11   0  ...   1   0
# 2       3       Apr 2   True  WSN   L,1-4  33  28   1   4   1  ...   1   0
# 3       4       Apr 3   True  STL   W,8-4  40  35   8  10   3  ...   0   0
# 4       5       Apr 4   True  STL   W,4-1  38  37   4  12   1  ...   1   0
# ..    ...         ...    ...  ...     ...  ..  ..  ..  ..  ..  ...  ..  ..
# 115   116  Aug 12 (2)   True  NYM   W,6-0  40  34   6   7   2  ...   2   0
# 116   117      Aug 13   True  NYM   L,6-7  37  34   6   7   2  ...   1   0
# 117   118      Aug 14  False  NYY  W,11-3  44  36  11  15   2  ...   1   1
# 118   119      Aug 15  False  NYY   W,5-0  38  31   5   6   0  ...   0   0
# 119   120      Aug 16  False  NYY   W,2-0  29  25   2   3   1  ...   0   0
#
#      IBB  SH  SF  ROE  GDP  NumPlayers            Umpire  \
# ...

# %%
# !pip install -U dataprep
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/Users/ryantalbot/opt/anaconda3/lib/python3.9/site-packages/MarkupSafe-2.0.1.dist-info/METADATA'

# %%
from dataprep.datasets import load_dataset
from dataprep.eda import create_report
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_67226/181513238.py in <cell line: 1>()
# ----> 1 from dataprep.datasets import load_dataset
#       2 from dataprep.eda import create_report
#
# ModuleNotFoundError: No module named 'dataprep'

# %%
import sys
sys.path
# Out:
# ['/Users/ryantalbot/Desktop/MSDS/Core/Data Mining Foundations/Data Mining Project/MLB/Resources',
#  '/Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python39.zip',
#  '/Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9',
#  '/Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/lib-dynload',
#  '',
#  '/Users/ryantalbot/.local/lib/python3.9/site-packages',
#  '/Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages',
#  '/Users/ryantalbot/.local/lib/python3.9/site-packages/IPython/extensions',
#  '/Users/ryantalbot/.ipython']

# %%
# Users/ryantalbot/opt/anaconda3/envs/tf2/bin/python3 -m pip install -U dataprep

# %%
# !pip install dataprep
# Out:
# ...
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/Users/ryantalbot/opt/anaconda3/lib/python3.9/site-packages/MarkupSafe-2.0.1.dist-info/METADATA'
