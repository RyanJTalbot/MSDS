# %%
import pandas as pd
import numpy as np

# %%
# !pip install pybaseball
# Out:
# ...
# WARNING: Error parsing requirements for markupsafe: [Errno 2] No such file or directory: '/Users/ryantalbot/opt/anaconda3/lib/python3.9/site-packages/MarkupSafe-2.0.1.dist-info/METADATA'

# %%
# !pip install dataprep
# Out:
# ...
#   Using cached dask-2021.12.0-py3-none-any.whl (1.0 MB)
# ...
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/Users/ryantalbot/opt/anaconda3/lib/python3.9/site-packages/MarkupSafe-2.0.1.dist-info/METADATA'

# %%
from pybaseball import statcast

# %%
# from dataprep.datasets import load_dataset
# from dataprep.eda import create_report

# %%
from pybaseball import schedule_and_record

# %%
from pybaseball import standings

# %%
stand = standings(2023)
stand
# Out:
# [                  Tm   W   L  W-L%    GB  E#
#  1  Baltimore Orioles  76  47  .618    --  --
#  2     Tampa Bay Rays  75  51  .595   2.5  36
#  3  Toronto Blue Jays  68  56  .548   8.5  31
#  4     Boston Red Sox  65  58  .528  11.0  29
#  5   New York Yankees  60  63  .488  16.0  24,
#                      Tm   W   L  W-L%    GB  E#
#  1      Minnesota Twins  64  60  .516    --  --
#  2  Cleveland Guardians  59  65  .476   5.0  34
#  3       Detroit Tigers  56  67  .455   7.5  32
#  4    Chicago White Sox  48  75  .390  15.5  24
#  5   Kansas City Royals  40  85  .320  24.5  14,
#                     Tm   W   L  W-L%    GB  E#
#  1       Texas Rangers  72  51  .585    --  --
#  2      Houston Astros  70  54  .565   2.5  37
#  3    Seattle Mariners  68  55  .553   4.0  36
#  4  Los Angeles Angels  61  64  .488  12.0  27
#  5   Oakland Athletics  34  89  .276  38.0   2,
#                        Tm   W   L  W-L%    GB  E#
#  1         Atlanta Braves  80  42  .656    --  --
# ...

# %%
from pybaseball import team_game_logs

# %%
batting_logs = team_game_logs(2023, "ATL")

# %%
pitching_logs = team_game_logs(2023, "ATL", "pitching")
pitching_logs
# Out:
#      Game    Date   Home  Opp    Rslt   IP   H  R  ER  UER  ...  2B  3B  IBB  \
# 0       1  Mar 30   True  WSN   W,7-2  9.0   8  2   2    0  ...   1   0    0
# 1       2   Apr 1   True  WSN   W,7-1  9.0   5  1   1    0  ...   1   0    0
# 2       3   Apr 2   True  WSN   L,1-4  8.0   6  4   4    0  ...   1   0    0
# 3       4   Apr 3   True  STL   W,8-4  9.0  12  4   4    0  ...   0   0    0
# 4       5   Apr 4   True  STL   W,4-1  9.0  10  1   1    0  ...   1   0    0
# ..    ...     ...    ...  ...     ...  ...  .. ..  ..  ...  ...  ..  ..  ...
# 117   118  Aug 14  False  NYY  W,11-3  9.0  11  3   3    0  ...   1   1    0
# 118   119  Aug 15  False  NYY   W,5-0  9.0   1  0   0    0  ...   0   0    0
# 119   120  Aug 16  False  NYY   W,2-0  9.0   4  0   0    0  ...   0   0    0
# 120   121  Aug 18  False  SFG   W,4-0  9.0   2  0   0    0  ...   0   0    0
# 121   122  Aug 19  False  SFG   W,6-5  9.0  11  5   5    0  ...   1   0    0
#
# ...

# %%
# atl = statcast('2023-01-01', '2023-08-15', team='ATL')
# atl

# %%
data = schedule_and_record(2023, 'ATL')
# Out:
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pybaseball/team_results.py:70: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('',1) #not a useful column
# /Users/ryantalbot/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pybaseball/team_results.py:83: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   data = data.drop('Streak2',1)

# %%
data
# Out:
#                   Date   Tm Home_Away  Opp   W/L    R   RA  Inn   W-L  Rank  \
# 1     Thursday, Mar 30  ATL         @  WSN     W  7.0  2.0  9.0   1-0   1.0
# 2      Saturday, Apr 1  ATL         @  WSN     W  7.0  1.0  9.0   2-0   1.0
# 3        Sunday, Apr 2  ATL         @  WSN     L  1.0  4.0  9.0   2-1   2.0
# 4        Monday, Apr 3  ATL         @  STL     W  8.0  4.0  9.0   3-1   1.0
# 5       Tuesday, Apr 4  ATL         @  STL     W  4.0  1.0  9.0   4-1   1.0
# ..                 ...  ...       ...  ...   ...  ...  ...  ...   ...   ...
# 158  Wednesday, Sep 27  ATL      Home  CHC  None  NaN  NaN  NaN  None   NaN
# 159   Thursday, Sep 28  ATL      Home  CHC  None  NaN  NaN  NaN  None   NaN
# 160     Friday, Sep 29  ATL      Home  WSN  None  NaN  NaN  NaN  None   NaN
# 161   Saturday, Sep 30  ATL      Home  WSN  None  NaN  NaN  NaN  None   NaN
# 162      Sunday, Oct 1  ATL      Home  WSN  None  NaN  NaN  NaN  None   NaN
#
# ...

# %%
# create_report(df3).show_browser()

# %%
# from dataprep.eda import create_report

# %%
# report = create_report(df3)
# report

# %%
pitching_logs = pitching_logs.drop(columns=["Game", "Date", "Opp"])

# %%
pitching_logs
# Out:
#       Home    Rslt   IP   H  R  ER  UER  BB  SO  HR  ...  2B  3B  IBB  SH  SF  \
# 0     True   W,7-2  9.0   8  2   2    0   4   5   0  ...   1   0    0   0   1
# 1     True   W,7-1  9.0   5  1   1    0   3  11   1  ...   1   0    0   0   0
# 2     True   L,1-4  8.0   6  4   4    0   5   4   0  ...   1   0    0   0   1
# 3     True   W,8-4  9.0  12  4   4    0   3   6   1  ...   0   0    0   0   0
# 4     True   W,4-1  9.0  10  1   1    0   1   6   0  ...   1   0    0   0   0
# ..     ...     ...  ...  .. ..  ..  ...  ..  ..  ..  ...  ..  ..  ...  ..  ..
# 117  False  W,11-3  9.0  11  3   3    0   2   5   0  ...   1   1    0   0   0
# 118  False   W,5-0  9.0   1  0   0    0   5   4   0  ...   0   0    0   0   0
# 119  False   W,2-0  9.0   4  0   0    0   1  13   0  ...   0   0    0   0   0
# 120  False   W,4-0  9.0   2  0   0    0   1  13   0  ...   0   0    0   0   0
# 121  False   W,6-5  9.0  11  5   5    0   2  11   1  ...   1   0    0   0   1
#
# ...

# %%
batting_logs = batting_logs.drop(columns=[ "Date","Rslt", "Home","Opp"])

# %%
batting_logs
# Out:
#      Game  PA  AB   R   H  2B  3B  HR  RBI  BB  ...  SB  CS     BA    OBP  \
# 0       1  46  40   7  12   2   0   0    5   6  ...   2   0  0.300  0.391
# 1       2  37  35   7  11   0   0   4    6   2  ...   0   0  0.307  0.373
# 2       3  33  28   1   4   1   0   0    1   5  ...   0   0  0.262  0.345
# 3       4  40  35   8  10   3   0   3    8   5  ...   0   1  0.268  0.353
# 4       5  38  37   4  12   1   0   2    4   1  ...   1   0  0.280  0.351
# ..    ...  ..  ..  ..  ..  ..  ..  ..  ...  ..  ...  ..  ..    ...    ...
# 117   118  44  36  11  15   2   0   2   10   8  ...   1   0  0.275  0.345
# 118   119  38  31   5   6   0   0   2    5   5  ...   0   0  0.275  0.345
# 119   120  29  25   2   3   1   0   1    2   4  ...   0   1  0.274  0.345
# 120   121  40  34   4  10   2   1   0    4   5  ...   1   0  0.274  0.345
# 121   122  34  34   6  11   2   0   2    6   0  ...   0   0  0.274  0.345
#
#        SLG    OPS  LOB  NumPlayers  Thr        OppStart
# ...

# %%
batting_logs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Game        122 non-null    int64
#  1   PA          122 non-null    int64
#  2   AB          122 non-null    int64
#  3   R           122 non-null    int64
#  4   H           122 non-null    int64
#  5   2B          122 non-null    int64
#  6   3B          122 non-null    int64
#  7   HR          122 non-null    int64
#  8   RBI         122 non-null    int64
#  9   BB          122 non-null    int64
#  10  IBB         122 non-null    int64
#  11  SO          122 non-null    int64
#  12  HBP         122 non-null    int64
#  13  SH          122 non-null    int64
#  14  SF          122 non-null    int64
#  15  ROE         122 non-null    int64
#  16  GDP         122 non-null    int64
#  17  SB          122 non-null    int64
#  18  CS          122 non-null    int64
# ...

# %%
df3 = pd.concat([batting_logs, pitching_logs, data], axis=1)

# %%
df3
# Out:
#      Game    PA    AB    R     H   2B   3B   HR  RBI   BB  ...      GB  \
# 0     1.0  46.0  40.0  7.0  12.0  2.0  0.0  0.0  5.0  6.0  ...     NaN
# 1     2.0  37.0  35.0  7.0  11.0  0.0  0.0  4.0  6.0  2.0  ...    Tied
# 2     3.0  33.0  28.0  1.0   4.0  1.0  0.0  0.0  1.0  5.0  ...  up 0.5
# 3     4.0  40.0  35.0  8.0  10.0  3.0  0.0  3.0  8.0  5.0  ...     0.5
# 4     5.0  38.0  37.0  4.0  12.0  1.0  0.0  2.0  4.0  1.0  ...  up 0.5
# ..    ...   ...   ...  ...   ...  ...  ...  ...  ...  ...  ...     ...
# 158   NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...    None
# 159   NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...    None
# 160   NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...    None
# 161   NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...    None
# 162   NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...    None
#
#          Win      Loss      Save  Time   D/N  Attendance   cLI  Streak  \
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163 entries, 0 to 162
# Data columns (total 77 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Game             122 non-null    float64
#  1   PA               122 non-null    float64
#  2   AB               122 non-null    float64
#  3   R                122 non-null    float64
#  4   H                122 non-null    float64
#  5   2B               122 non-null    float64
#  6   3B               122 non-null    float64
#  7   HR               122 non-null    float64
#  8   RBI              122 non-null    float64
#  9   BB               122 non-null    float64
#  10  IBB              122 non-null    float64
#  11  SO               122 non-null    float64
#  12  HBP              122 non-null    float64
#  13  SH               122 non-null    float64
#  14  SF               122 non-null    float64
#  15  ROE              122 non-null    float64
# ...

# %%
df3["Date"]
# Out:
# 0                    NaN
# 1       Thursday, Mar 30
# 2        Saturday, Apr 1
# 3          Sunday, Apr 2
# 4          Monday, Apr 3
#              ...
# 158    Wednesday, Sep 27
# 159     Thursday, Sep 28
# 160       Friday, Sep 29
# 161     Saturday, Sep 30
# 162        Sunday, Oct 1
# Name: Date, Length: 163, dtype: object

# %%
duplicateCols = df3.T.drop_duplicates().T

# %%
duplicateCols.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163 entries, 0 to 162
# Data columns (total 77 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Game             122 non-null    object
#  1   PA               122 non-null    object
#  2   AB               122 non-null    object
#  3   R                122 non-null    object
#  4   H                122 non-null    object
#  5   2B               122 non-null    object
#  6   3B               122 non-null    object
#  7   HR               122 non-null    object
#  8   RBI              122 non-null    object
#  9   BB               122 non-null    object
#  10  IBB              122 non-null    object
#  11  SO               122 non-null    object
#  12  HBP              122 non-null    object
#  13  SH               122 non-null    object
#  14  SF               122 non-null    object
#  15  ROE              122 non-null    object
# ...

# %%
df = df3

# %%
df
# Out:
#      Game    PA    AB    R     H   2B   3B   HR  RBI   BB  ...      GB  \
# 0     1.0  46.0  40.0  7.0  12.0  2.0  0.0  0.0  5.0  6.0  ...     NaN
# 1     2.0  37.0  35.0  7.0  11.0  0.0  0.0  4.0  6.0  2.0  ...    Tied
# 2     3.0  33.0  28.0  1.0   4.0  1.0  0.0  0.0  1.0  5.0  ...  up 0.5
# 3     4.0  40.0  35.0  8.0  10.0  3.0  0.0  3.0  8.0  5.0  ...     0.5
# 4     5.0  38.0  37.0  4.0  12.0  1.0  0.0  2.0  4.0  1.0  ...  up 0.5
# ..    ...   ...   ...  ...   ...  ...  ...  ...  ...  ...  ...     ...
# 158   NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...    None
# 159   NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...    None
# 160   NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...    None
# 161   NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...    None
# 162   NaN   NaN   NaN  NaN   NaN  NaN  NaN  NaN  NaN  NaN  ...    None
#
#          Win      Loss      Save  Time   D/N  Attendance   cLI  Streak  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 163 entries, 0 to 162
# Data columns (total 77 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Game             122 non-null    float64
#  1   PA               122 non-null    float64
#  2   AB               122 non-null    float64
#  3   R                122 non-null    float64
#  4   H                122 non-null    float64
#  5   2B               122 non-null    float64
#  6   3B               122 non-null    float64
#  7   HR               122 non-null    float64
#  8   RBI              122 non-null    float64
#  9   BB               122 non-null    float64
#  10  IBB              122 non-null    float64
#  11  SO               122 non-null    float64
#  12  HBP              122 non-null    float64
#  13  SH               122 non-null    float64
#  14  SF               122 non-null    float64
#  15  ROE              122 non-null    float64
# ...

# %%
df = df.iloc[:120]

# %%
df
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...      GB  \
# 0      1.0  46.0  40.0   7.0  12.0  2.0  0.0  0.0   5.0  6.0  ...     NaN
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...    Tied
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...  up 0.5
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...     0.5
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...  up 0.5
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...     ...
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...  up11.0
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...  up11.0
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...  up11.0
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...  up11.5
# 119  120.0  29.0  25.0   2.0   3.0  1.0  0.0  1.0   2.0  4.0  ...  up12.5
#
#          Win      Loss      Save  Time  D/N  Attendance   cLI  Streak  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 0 to 119
# Data columns (total 77 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Game             120 non-null    float64
#  1   PA               120 non-null    float64
#  2   AB               120 non-null    float64
#  3   R                120 non-null    float64
#  4   H                120 non-null    float64
#  5   2B               120 non-null    float64
#  6   3B               120 non-null    float64
#  7   HR               120 non-null    float64
#  8   RBI              120 non-null    float64
#  9   BB               120 non-null    float64
#  10  IBB              120 non-null    float64
#  11  SO               120 non-null    float64
#  12  HBP              120 non-null    float64
#  13  SH               120 non-null    float64
#  14  SF               120 non-null    float64
#  15  ROE              120 non-null    float64
# ...

# %%
rslt = df["Rslt"]

# %%
rslt
# Out:
# 0       W,7-2
# 1       W,7-1
# 2       L,1-4
# 3       W,8-4
# 4       W,4-1
#         ...
# 115     W,6-0
# 116     L,6-7
# 117    W,11-3
# 118     W,5-0
# 119     W,2-0
# Name: Rslt, Length: 120, dtype: object

# %%
rslt.str.split(',', expand=True)
# Out:
#      0     1
# 0    W   7-2
# 1    W   7-1
# 2    L   1-4
# 3    W   8-4
# 4    W   4-1
# ..  ..   ...
# 115  W   6-0
# 116  L   6-7
# 117  W  11-3
# 118  W   5-0
# 119  W   2-0
#
# [120 rows x 2 columns]

# %%
rslt
# Out:
# 0       W,7-2
# 1       W,7-1
# 2       L,1-4
# 3       W,8-4
# 4       W,4-1
#         ...
# 115     W,6-0
# 116     L,6-7
# 117    W,11-3
# 118     W,5-0
# 119     W,2-0
# Name: Rslt, Length: 120, dtype: object

# %%
df[["Rslt", "Score"]] = df["Rslt"].str.split(",", expand=True)
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_36498/2551797390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Rslt", "Score"]] = df["Rslt"].str.split(",", expand=True)
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_36498/2551797390.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Rslt", "Score"]] = df["Rslt"].str.split(",", expand=True)

# %%
df
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...      Win  \
# 0      1.0  46.0  40.0   7.0  12.0  2.0  0.0  0.0   5.0  6.0  ...      NaN
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...   Luetge
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...  Strider
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...     Gore
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...   Morton
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...      ...
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...   Winans
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...  Strider
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...    Senga
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...    Fried
# 119  120.0  29.0  25.0   2.0   3.0  1.0  0.0  1.0   2.0  4.0  ...    Elder
#
# ...

# %%
# %reload_ext autoreload
# %autoreload 2
# from dataprep.datasets import load_dataset
# from dataprep.eda import plot, plot_correlation, plot_missing

# %%
df["Attendance"].isnull().sum()
# Out:
# 3

# %%
df["Umpire"].isnull().sum()
# Out:
# 6

# %%
df.columns
# Out:
# Index(['Game', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB',
#        'SO', 'HBP', 'SH', 'SF', 'ROE', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG',
#        'OPS', 'LOB', 'NumPlayers', 'Thr', 'OppStart', 'Home', 'Rslt', 'IP',
#        'H', 'R', 'ER', 'UER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit',
#        'Str', 'IR', 'IS', 'SB', 'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF',
#        'ROE', 'GDP', 'NumPlayers', 'Umpire', 'PitchersUsed', 'Date', 'Tm',
#        'Home_Away', 'Opp', 'W/L', 'R', 'RA', 'Inn', 'W-L', 'Rank', 'GB', 'Win',
#        'Loss', 'Save', 'Time', 'D/N', 'Attendance', 'cLI', 'Streak',
#        'Orig. Scheduled', 'Score'],
#       dtype='object')

# %%
df = df.drop(columns=["Orig. Scheduled"])

# %%
df
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...      GB  \
# 0      1.0  46.0  40.0   7.0  12.0  2.0  0.0  0.0   5.0  6.0  ...     NaN
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...    Tied
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...  up 0.5
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...     0.5
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...  up 0.5
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...     ...
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...  up11.0
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...  up11.0
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...  up11.0
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...  up11.5
# 119  120.0  29.0  25.0   2.0   3.0  1.0  0.0  1.0   2.0  4.0  ...  up12.5
#
#          Win      Loss      Save  Time  D/N  Attendance   cLI  Streak  Score
# ...

# %%
score = df["Score"]

# %%
df[["atlScore", "oppScore"]] = df["Score"].str.split("-", expand=True)

# %%
df
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...      Loss  \
# 0      1.0  46.0  40.0   7.0  12.0  2.0  0.0  0.0   5.0  6.0  ...       NaN
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...    Corbin
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...      Gray
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...   Shuster
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...  Woodford
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...       ...
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...     Reyes
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...  Quintana
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...  Chirinos
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...   Schmidt
# 119  120.0  29.0  25.0   2.0   3.0  1.0  0.0  1.0   2.0  4.0  ...  Severino
#
# ...

# %%
df = df.drop(columns=["Score"])

# %%
df
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...      Win  \
# 0      1.0  46.0  40.0   7.0  12.0  2.0  0.0  0.0   5.0  6.0  ...      NaN
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...   Luetge
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...  Strider
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...     Gore
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...   Morton
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...      ...
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...   Winans
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...  Strider
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...    Senga
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...    Fried
# 119  120.0  29.0  25.0   2.0   3.0  1.0  0.0  1.0   2.0  4.0  ...    Elder
#
# ...

# %%
# plot(df)

# %%
df["Date"]
# Out:
# 0                       NaN
# 1          Thursday, Mar 30
# 2           Saturday, Apr 1
# 3             Sunday, Apr 2
# 4             Monday, Apr 3
#                ...
# 115    Saturday, Aug 12 (1)
# 116    Saturday, Aug 12 (2)
# 117          Sunday, Aug 13
# 118          Monday, Aug 14
# 119         Tuesday, Aug 15
# Name: Date, Length: 120, dtype: object

# %%
df[["Day", "Date"]] = df["Date"].str.split(",", expand=True)

# %%
df["Date"]
# Out:
# 0              NaN
# 1           Mar 30
# 2            Apr 1
# 3            Apr 2
# 4            Apr 3
#           ...
# 115     Aug 12 (1)
# 116     Aug 12 (2)
# 117         Aug 13
# 118         Aug 14
# 119         Aug 15
# Name: Date, Length: 120, dtype: object

# %%
dat = df

# %%
# from dataprep.clean import clean_date
# clean_date(dat, 'Date')

# %%
df
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...      Loss  \
# 0      1.0  46.0  40.0   7.0  12.0  2.0  0.0  0.0   5.0  6.0  ...       NaN
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...    Corbin
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...      Gray
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...   Shuster
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...  Woodford
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...       ...
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...     Reyes
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...  Quintana
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...  Chirinos
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...   Schmidt
# 119  120.0  29.0  25.0   2.0   3.0  1.0  0.0  1.0   2.0  4.0  ...  Severino
#
# ...

# %%
df["Date"]
# Out:
# 0              NaN
# 1           Mar 30
# 2            Apr 1
# 3            Apr 2
# 4            Apr 3
#           ...
# 115     Aug 12 (1)
# 116     Aug 12 (2)
# 117         Aug 13
# 118         Aug 14
# 119         Aug 15
# Name: Date, Length: 120, dtype: object

# %%
# Function to clean the time
def clean_time(time_str):
    if pd.isna(time_str):
        return None
    # Only keep the time part
    time_parts = time_str.split(' ')
    cleaned_time = time_parts[0]
    return cleaned_time

# Apply the function to the 'Time' column
df["pract"] = df['Time'].apply(clean_time)

df
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...      Save  \
# 0      1.0  46.0  40.0   7.0  12.0  2.0  0.0  0.0   5.0  6.0  ...       NaN
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...      None
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...      None
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...  Finnegan
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...      None
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...       ...
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...      None
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...      None
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...  Ottavino
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...      None
# 119  120.0  29.0  25.0   2.0   3.0  1.0  0.0  1.0   2.0  4.0  ...      None
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 0 to 119
# Data columns (total 80 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Game          120 non-null    float64
#  1   PA            120 non-null    float64
#  2   AB            120 non-null    float64
#  3   R             120 non-null    float64
#  4   H             120 non-null    float64
#  5   2B            120 non-null    float64
#  6   3B            120 non-null    float64
#  7   HR            120 non-null    float64
#  8   RBI           120 non-null    float64
#  9   BB            120 non-null    float64
#  10  IBB           120 non-null    float64
#  11  SO            120 non-null    float64
#  12  HBP           120 non-null    float64
#  13  SH            120 non-null    float64
#  14  SF            120 non-null    float64
#  15  ROE           120 non-null    float64
#  16  GDP           120 non-null    float64
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 0 to 119
# Data columns (total 79 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Game          120 non-null    float64
#  1   PA            120 non-null    float64
#  2   AB            120 non-null    float64
#  3   R             120 non-null    float64
#  4   H             120 non-null    float64
#  5   2B            120 non-null    float64
#  6   3B            120 non-null    float64
#  7   HR            120 non-null    float64
#  8   RBI           120 non-null    float64
#  9   BB            120 non-null    float64
#  10  IBB           120 non-null    float64
#  11  SO            120 non-null    float64
#  12  HBP           120 non-null    float64
#  13  SH            120 non-null    float64
#  14  SF            120 non-null    float64
#  15  ROE           120 non-null    float64
#  16  GDP           120 non-null    float64
# ...

# %%
df.head()
# Out:
#    Game    PA    AB    R     H   2B   3B   HR  RBI   BB  ...      Loss  \
# 0   1.0  46.0  40.0  7.0  12.0  2.0  0.0  0.0  5.0  6.0  ...       NaN
# 1   2.0  37.0  35.0  7.0  11.0  0.0  0.0  4.0  6.0  2.0  ...    Corbin
# 2   3.0  33.0  28.0  1.0   4.0  1.0  0.0  0.0  1.0  5.0  ...      Gray
# 3   4.0  40.0  35.0  8.0  10.0  3.0  0.0  3.0  8.0  5.0  ...   Shuster
# 4   5.0  38.0  37.0  4.0  12.0  1.0  0.0  2.0  4.0  1.0  ...  Woodford
#
#        Save  Time  D/N  Attendance   cLI  Streak  atlScore  oppScore       Day
# 0       NaN   NaN  NaN         NaN   NaN     NaN         7         2       NaN
# 1      None  3:07    D     35756.0   .99     1.0         7         1  Thursday
# 2      None  2:21    D     27529.0  1.08     2.0         1         4  Saturday
# 3  Finnegan  2:17    D     21440.0  1.09    -1.0         8         4    Sunday
# 4      None  2:46    N     37689.0  1.00     1.0         4         1    Monday
#
# [5 rows x 79 columns]

# %%
g = df.columns.to_series().groupby(df.dtypes).groups
g
# Out:
# {float64: ['Game', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'ROE', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'LOB', 'NumPlayers', 'IP', 'H', 'R', 'ER', 'UER', 'BB', 'SO', 'HR', 'HBP', 'ERA', 'BF', 'Pit', 'Str', 'IR', 'IS', 'SB', 'CS', 'AB', '2B', '3B', 'IBB', 'SH', 'SF', 'ROE', 'GDP', 'NumPlayers', 'R', 'RA', 'Inn', 'Rank', 'Attendance', 'Streak'], object: ['Thr', 'OppStart', 'Home', 'Rslt', 'Umpire', 'PitchersUsed', 'Date', 'Tm', 'Home_Away', 'Opp', 'W/L', 'W-L', 'GB', 'Win', 'Loss', 'Save', 'Time', 'D/N', 'cLI', 'atlScore', 'oppScore', 'Day']}

# %%
ds = df.select_dtypes(include='object')
ds
# Out:
#     Thr        OppStart   Home Rslt            Umpire  \
# 0     L    P.Corbin(33)   True    W       Dan Bellino
# 1     R      J.Gray(35)   True    W        Phil Cuzzi
# 2     L      M.Gore(60)   True    L    Mark Ripperger
# 3     R  J.Woodford(25)   True    W     Tony Randazzo
# 4     L      S.Matz(38)   True    W  Junior Valentine
# ..   ..             ...    ...  ...               ...
# 115   L  J.Quintana(61)   True    W    Brennan Miller
# 116   R     K.Senga(57)   True    L      Tripp Gibson
# 117   R    C.Schmidt(8)  False    W       Chris Segal
# 118   R  L.Severino(39)  False    W        CB Bucknor
# 119   R   R.Vásquez(48)  False    W           Ben May
#
#                                           PitchersUsed         Date   Tm  \
# 0    M.Fried (99-50), L.Luetge (99-W), J.Chavez (99...          NaN  NaN
# 1    S.Strider (99-72-W), N.Anderson (99), J.Jiméne...       Mar 30  ATL
# 2     J.Shuster (99-32-L), M.Tonkin (99), J.Chavez (2)        Apr 1  ATL
# ...

# %%
df['atlScore'] = df['atlScore'].astype('int')

# %%
df['oppScore'] = df['oppScore'].astype('int')

# %%
df['cLI'] = df['cLI'].astype('float')

# %%
ds = df.select_dtypes(include='object')
ds
# Out:
#     Thr        OppStart   Home Rslt            Umpire  \
# 0     L    P.Corbin(33)   True    W       Dan Bellino
# 1     R      J.Gray(35)   True    W        Phil Cuzzi
# 2     L      M.Gore(60)   True    L    Mark Ripperger
# 3     R  J.Woodford(25)   True    W     Tony Randazzo
# 4     L      S.Matz(38)   True    W  Junior Valentine
# ..   ..             ...    ...  ...               ...
# 115   L  J.Quintana(61)   True    W    Brennan Miller
# 116   R     K.Senga(57)   True    L      Tripp Gibson
# 117   R    C.Schmidt(8)  False    W       Chris Segal
# 118   R  L.Severino(39)  False    W        CB Bucknor
# 119   R   R.Vásquez(48)  False    W           Ben May
#
#                                           PitchersUsed         Date   Tm  \
# 0    M.Fried (99-50), L.Luetge (99-W), J.Chavez (99...          NaN  NaN
# 1    S.Strider (99-72-W), N.Anderson (99), J.Jiméne...       Mar 30  ATL
# 2     J.Shuster (99-32-L), M.Tonkin (99), J.Chavez (2)        Apr 1  ATL
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score

# %%
df["Opp"]
# Out:
# 0      NaN
# 1      WSN
# 2      WSN
# 3      WSN
# 4      STL
#       ...
# 115    NYM
# 116    NYM
# 117    NYM
# 118    NYY
# 119    NYY
# Name: Opp, Length: 120, dtype: object

# %%
df1 = df

# %%
df1["Opp_code"] = df1["Opp"].astype("category").cat.codes

# %%
df1["Opp_code"]
# Out:
# 0      -1
# 1      27
# 2      27
# 3      27
# 4      23
#        ..
# 115    16
# 116    16
# 117    16
# 118    17
# 119    17
# Name: Opp_code, Length: 120, dtype: int8

# %%
df["Umpire"].nunique()
# Out:
# 69

# %%
df1["Umpire_code"] = df1["Umpire"].astype("category").cat.codes

# %%
df1["Tm"].nunique()
# Out:
# 1

# %%
df1["Win"].nunique()
# Out:
# 61

# %%
df1["Loss"].nunique()
# Out:
# 87

# %%
df1["Save"].nunique()
# Out:
# 28

# %%
df1["Win_code"] = df1["Win"].astype("category").cat.codes

# %%
df1["Loss_code"] = df1["Loss"].astype("category").cat.codes

# %%
df1["Save_code"] = df1["Save"].astype("category").cat.codes

# %%
df1=df1.drop(columns=["Win", "Loss", "Save", "Umpire", "Opp"])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 0 to 119
# Data columns (total 79 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Game          120 non-null    float64
#  1   PA            120 non-null    float64
#  2   AB            120 non-null    float64
#  3   R             120 non-null    float64
#  4   H             120 non-null    float64
#  5   2B            120 non-null    float64
#  6   3B            120 non-null    float64
#  7   HR            120 non-null    float64
#  8   RBI           120 non-null    float64
#  9   BB            120 non-null    float64
#  10  IBB           120 non-null    float64
#  11  SO            120 non-null    float64
#  12  HBP           120 non-null    float64
#  13  SH            120 non-null    float64
#  14  SF            120 non-null    float64
#  15  ROE           120 non-null    float64
#  16  GDP           120 non-null    float64
# ...

# %%
ds = df1.select_dtypes(include='object')
ds.head()
# Out:
#   Thr        OppStart  Home Rslt  \
# 0   L    P.Corbin(33)  True    W
# 1   R      J.Gray(35)  True    W
# 2   L      M.Gore(60)  True    L
# 3   R  J.Woodford(25)  True    W
# 4   L      S.Matz(38)  True    W
#
#                                         PitchersUsed     Date   Tm Home_Away  \
# 0  M.Fried (99-50), L.Luetge (99-W), J.Chavez (99...      NaN  NaN       NaN
# 1  S.Strider (99-72-W), N.Anderson (99), J.Jiméne...   Mar 30  ATL         @
# 2   J.Shuster (99-32-L), M.Tonkin (99), J.Chavez (2)    Apr 1  ATL         @
# 3  C.Morton (99-37-W), N.Anderson (1-H), C.McHugh...    Apr 2  ATL         @
# 4  D.Dodd (99-54-W), J.Chavez (1-H), J.Jiménez (2...    Apr 3  ATL         @
#
#    W/L  W-L      GB  Time  D/N       Day
# 0  NaN  NaN     NaN   NaN  NaN       NaN
# 1    W  1-0    Tied  3:07    D  Thursday
# 2    W  2-0  up 0.5  2:21    D  Saturday
# 3    L  2-1     0.5  2:17    D    Sunday
# 4    W  3-1  up 0.5  2:46    N    Monday

# %%
df1["Thr"].nunique()
# Out:
# 2

# %%
df1["Rslt"].nunique()
# Out:
# 2

# %%
df1["Home"].nunique()
# Out:
# 2

# %%
df1 = df1.drop(columns=["Tm", "Home_Away"])

# %%
df1["Thr_code"] = df1["Thr"].astype("category").cat.codes

# %%
df1["Rslt_code"] = df1["Rslt"].astype("category").cat.codes

# %%
df1["Home_code"] = df1["Home"].astype("category").cat.codes

# %%
df1 = df1.drop(columns=["Home", "Rslt", "Thr"])

# %%
ds = df1.select_dtypes(include='object')
ds.head()
# Out:
#          OppStart                                       PitchersUsed     Date  \
# 0    P.Corbin(33)  M.Fried (99-50), L.Luetge (99-W), J.Chavez (99...      NaN
# 1      J.Gray(35)  S.Strider (99-72-W), N.Anderson (99), J.Jiméne...   Mar 30
# 2      M.Gore(60)   J.Shuster (99-32-L), M.Tonkin (99), J.Chavez (2)    Apr 1
# 3  J.Woodford(25)  C.Morton (99-37-W), N.Anderson (1-H), C.McHugh...    Apr 2
# 4      S.Matz(38)  D.Dodd (99-54-W), J.Chavez (1-H), J.Jiménez (2...    Apr 3
#
#    W/L  W-L      GB  Time  D/N       Day
# 0  NaN  NaN     NaN   NaN  NaN       NaN
# 1    W  1-0    Tied  3:07    D  Thursday
# 2    W  2-0  up 0.5  2:21    D  Saturday
# 3    L  2-1     0.5  2:17    D    Sunday
# 4    W  3-1  up 0.5  2:46    N    Monday

# %%
df1["OppStart"].nunique()
# Out:
# 119

# %%
df1["W/L"].unique()
# Out:
# array([nan, 'W', 'L', 'W-wo', 'L-wo'], dtype=object)

# %%
df1["W/L_code"] = df1["W/L"].astype("category").cat.codes

# %%
ds = df1.select_dtypes(include='object')
ds.head()
# Out:
#          OppStart                                       PitchersUsed     Date  \
# 0    P.Corbin(33)  M.Fried (99-50), L.Luetge (99-W), J.Chavez (99...      NaN
# 1      J.Gray(35)  S.Strider (99-72-W), N.Anderson (99), J.Jiméne...   Mar 30
# 2      M.Gore(60)   J.Shuster (99-32-L), M.Tonkin (99), J.Chavez (2)    Apr 1
# 3  J.Woodford(25)  C.Morton (99-37-W), N.Anderson (1-H), C.McHugh...    Apr 2
# 4      S.Matz(38)  D.Dodd (99-54-W), J.Chavez (1-H), J.Jiménez (2...    Apr 3
#
#    W/L  W-L      GB  Time  D/N       Day
# 0  NaN  NaN     NaN   NaN  NaN       NaN
# 1    W  1-0    Tied  3:07    D  Thursday
# 2    W  2-0  up 0.5  2:21    D  Saturday
# 3    L  2-1     0.5  2:17    D    Sunday
# 4    W  3-1  up 0.5  2:46    N    Monday

# %%
df1["W/L_code"]
# Out:
# 0     -1
# 1      2
# 2      2
# 3      0
# 4      2
#       ..
# 115    2
# 116    2
# 117    0
# 118    2
# 119    2
# Name: W/L_code, Length: 120, dtype: int8

# %% [markdown]
# ## Wins are categorized as 2 and losses are 0. -1 is for NaN

# %%
df1["Day"].nunique()
# Out:
# 7

# %%
df1["Day_code"] = df1["Day"].astype("category").cat.codes

# %%
df1["D/N_code"] = df1["D/N"].astype("category").cat.codes

# %%
df1 = df1.drop(columns=["OppStart", "W/L", "Day", "D/N"])

# %%
ds = df1.select_dtypes(include='object')
ds.head()
# Out:
#                                         PitchersUsed     Date  W-L      GB  \
# 0  M.Fried (99-50), L.Luetge (99-W), J.Chavez (99...      NaN  NaN     NaN
# 1  S.Strider (99-72-W), N.Anderson (99), J.Jiméne...   Mar 30  1-0    Tied
# 2   J.Shuster (99-32-L), M.Tonkin (99), J.Chavez (2)    Apr 1  2-0  up 0.5
# 3  C.Morton (99-37-W), N.Anderson (1-H), C.McHugh...    Apr 2  2-1     0.5
# 4  D.Dodd (99-54-W), J.Chavez (1-H), J.Jiménez (2...    Apr 3  3-1  up 0.5
#
#    Time
# 0   NaN
# 1  3:07
# 2  2:21
# 3  2:17
# 4  2:46

# %%
df1[["Wins", "Losses"]] = df["W-L"].str.split("-", expand=True)

# %%
df1.head()
# Out:
#    Game    PA    AB    R     H   2B   3B   HR  RBI   BB  ...  Loss_code  \
# 0   1.0  46.0  40.0  7.0  12.0  2.0  0.0  0.0  5.0  6.0  ...         -1
# 1   2.0  37.0  35.0  7.0  11.0  0.0  0.0  4.0  6.0  2.0  ...         15
# 2   3.0  33.0  28.0  1.0   4.0  1.0  0.0  0.0  1.0  5.0  ...         30
# 3   4.0  40.0  35.0  8.0  10.0  3.0  0.0  3.0  8.0  5.0  ...         73
# 4   5.0  38.0  37.0  4.0  12.0  1.0  0.0  2.0  4.0  1.0  ...         84
#
#    Save_code  Thr_code  Rslt_code  Home_code  W/L_code  Day_code  D/N_code  \
# 0         -1         0          1          1        -1        -1        -1
# 1         19         1          1          1         2         4         0
# 2         19         0          0          1         2         2         0
# 3          7         1          1          1         0         3         0
# 4         19         0          1          1         2         1         1
#
#    Wins  Losses
# 0   NaN     NaN
# 1     1       0
# 2     2       0
# ...

# %%
df1["W-L"]
# Out:
# 0        NaN
# 1        1-0
# 2        2-0
# 3        2-1
# 4        3-1
#        ...
# 115    74-41
# 116    75-41
# 117    75-42
# 118    76-42
# 119    77-42
# Name: W-L, Length: 120, dtype: object

# %%
df1 = df1.drop(columns=["W-L"])

# %%
ds = df1.select_dtypes(include='object')
ds.head()
# Out:
#                                         PitchersUsed     Date      GB  Time  \
# 0  M.Fried (99-50), L.Luetge (99-W), J.Chavez (99...      NaN     NaN   NaN
# 1  S.Strider (99-72-W), N.Anderson (99), J.Jiméne...   Mar 30    Tied  3:07
# 2   J.Shuster (99-32-L), M.Tonkin (99), J.Chavez (2)    Apr 1  up 0.5  2:21
# 3  C.Morton (99-37-W), N.Anderson (1-H), C.McHugh...    Apr 2     0.5  2:17
# 4  D.Dodd (99-54-W), J.Chavez (1-H), J.Jiménez (2...    Apr 3  up 0.5  2:46
#
#   Wins Losses
# 0  NaN    NaN
# 1    1      0
# 2    2      0
# 3    2      1
# 4    3      1

# %%
df1[0:1]["Losses"] = 0
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_36498/3969788503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1[0:1]["Losses"] = 0

# %%
df1
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...  Loss_code  \
# 0      1.0  46.0  40.0   7.0  12.0  2.0  0.0  0.0   5.0  6.0  ...         -1
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...         15
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...         30
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...         73
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...         84
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...        ...
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...         67
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...         65
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...         14
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...         70
# 119  120.0  29.0  25.0   2.0   3.0  1.0  0.0  1.0   2.0  4.0  ...         72
#
# ...

# %%
df1.loc[0, "Losses"] = 0

# %%
df1
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...  Loss_code  \
# 0      1.0  46.0  40.0   7.0  12.0  2.0  0.0  0.0   5.0  6.0  ...         -1
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...         15
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...         30
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...         73
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...         84
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...        ...
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...         67
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...         65
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...         14
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...         70
# 119  120.0  29.0  25.0   2.0   3.0  1.0  0.0  1.0   2.0  4.0  ...         72
#
# ...

# %%
df1.loc[0, "Wins"] = 0

# %%
df1
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...  Loss_code  \
# 0      1.0  46.0  40.0   7.0  12.0  2.0  0.0  0.0   5.0  6.0  ...         -1
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...         15
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...         30
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...         73
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...         84
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...        ...
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...         67
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...         65
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...         14
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...         70
# 119  120.0  29.0  25.0   2.0   3.0  1.0  0.0  1.0   2.0  4.0  ...         72
#
# ...

# %%
df1['Wins'] = df1['Wins'].astype('int')

# %%
df1['Losses'] = df1['Losses'].astype('int')

# %%
ds = df1.select_dtypes(include='object')
ds.head()
# Out:
#                                         PitchersUsed     Date      GB  Time
# 0  M.Fried (99-50), L.Luetge (99-W), J.Chavez (99...      NaN     NaN   NaN
# 1  S.Strider (99-72-W), N.Anderson (99), J.Jiméne...   Mar 30    Tied  3:07
# 2   J.Shuster (99-32-L), M.Tonkin (99), J.Chavez (2)    Apr 1  up 0.5  2:21
# 3  C.Morton (99-37-W), N.Anderson (1-H), C.McHugh...    Apr 2     0.5  2:17
# 4  D.Dodd (99-54-W), J.Chavez (1-H), J.Jiménez (2...    Apr 3  up 0.5  2:46

# %%
df2 = df1.drop(columns=["PitchersUsed", "Date", "GB", "Time"])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120 entries, 0 to 119
# Data columns (total 73 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Game         120 non-null    float64
#  1   PA           120 non-null    float64
#  2   AB           120 non-null    float64
#  3   R            120 non-null    float64
#  4   H            120 non-null    float64
#  5   2B           120 non-null    float64
#  6   3B           120 non-null    float64
#  7   HR           120 non-null    float64
#  8   RBI          120 non-null    float64
#  9   BB           120 non-null    float64
#  10  IBB          120 non-null    float64
#  11  SO           120 non-null    float64
#  12  HBP          120 non-null    float64
#  13  SH           120 non-null    float64
#  14  SF           120 non-null    float64
#  15  ROE          120 non-null    float64
#  16  GDP          120 non-null    float64
#  17  SB           120 non-null    float64
# ...

# %%
# plot(df2)

# %%
df2.corr()
# Out:
#               Game        PA        AB         R         H        2B  \
# Game      1.000000  0.065203  0.044116  0.176164  0.115711  0.001605
# PA        0.065203  1.000000  0.883344  0.669726  0.763629  0.393422
# AB        0.044116  0.883344  1.000000  0.620062  0.817235  0.340426
# R         0.176164  0.669726  0.620062  1.000000  0.796784  0.482709
# H         0.115711  0.763629  0.817235  0.796784  1.000000  0.417548
# ...            ...       ...       ...       ...       ...       ...
# W/L_code  0.006514  0.070098  0.089193  0.109916  0.111274 -0.024398
# Day_code  0.010444 -0.083479 -0.037720  0.031403  0.008532  0.051415
# D/N_code  0.037613 -0.151371 -0.062469 -0.107230 -0.084617 -0.181115
# Wins      0.997788  0.061572  0.037762  0.168996  0.103036 -0.003108
# Losses    0.992801  0.071018  0.055072  0.187110  0.137256  0.010079
#
#                 3B        HR       RBI        BB  ...  Loss_code  Save_code  \
# ...

# %%
sns.heatmap(df2.corr());

# %%
import tensorflow as tf
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
# Out:
# 2023-08-20 10:04:21.705931: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_36498/4256878215.py in <cell line: 1>()
# ----> 1 import tensorflow as tf
#       2 from datetime import datetime
#       3 import warnings
#       4 warnings.filterwarnings('ignore')
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/tensorflow/__init__.py in <module>
#      35 import typing as _typing
#      36
# ---> 37 from tensorflow.python.tools import module_util as _module_util
# ...

# %% [markdown]
# https://medium.com/@geotourloukis/univariate-time-series-forecasting-ml-project-time-series-generator-sales-dataset-336faa12e11c

# %%
from pylab import rcParams

# %%
rcParams['figure.figsize'] = 10, 6

# %%
plt.figure(figsize= (10,6))
plt.plot(df2)
plt.xlabel('Years')
plt.ylabel('No of Air Passengers')
plt.title('Trend of the Time Series')

# %%
# df_temp['Year'] = pd.DatetimeIndex(df_temp.index).year
# df_temp['Month'] = pd.DatetimeIndex(df_temp.index).month

# %%
df1[""]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._get_loc_duplicates()
#
# ~/opt/anaconda3/envs/tf2/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine._maybe_get_bool_indexer()
#
# ...

# %%
df1["Date"][0] = "Mar 29"

# %%
df1["Date"]
# Out:
# 0              NaN
# 1           Mar 30
# 2            Apr 1
# 3            Apr 2
# 4            Apr 3
#           ...
# 115     Aug 12 (1)
# 116     Aug 12 (2)
# 117         Aug 13
# 118         Aug 14
# 119         Aug 15
# Name: Date, Length: 120, dtype: object

# %%
# Split "Date" column into "Month", "day", and "number" columns
df1["Month"] = df1["Date"].str.extract(r'(\w{3})')
df1["day"] = df1["Date"].str.extract(r'(\d{1,2})')
df1["number"] = df1["Date"].str.extract(r'\((\d+)\)')

# %%
df1
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...  Rslt_code  \
# 0      1.0  46.0  40.0   7.0  12.0  2.0  0.0  0.0   5.0  6.0  ...          1
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...          1
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...          0
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...          1
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...          1
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...        ...
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...          1
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...          0
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...          1
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...          1
# 119  120.0  29.0  25.0   2.0   3.0  1.0  0.0  1.0   2.0  4.0  ...          1
#
# ...

# %%
df1["number"].fillna(0, inplace=True)
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_36498/4104255193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["number"].fillna(0, inplace=True)

# %%
df1
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...  Rslt_code  \
# 0      1.0  46.0  40.0   7.0  12.0  2.0  0.0  0.0   5.0  6.0  ...          1
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...          1
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...          0
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...          1
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...          1
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...        ...
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...          1
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...          0
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...          1
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...          1
# 119  120.0  29.0  25.0   2.0   3.0  1.0  0.0  1.0   2.0  4.0  ...          1
#
# ...

# %%
df1["Month_code"] = df1["Month"].astype("category").cat.codes

# %%
df1["Month_code"].nunique()
# Out:
# 7

# %%
df1 = df1[1:-1]

# %%
df1['day'] = df1['day'].astype('int')
# Out:
# /var/folders/j_/555m2zps099832fjh_m8jjnc0000gn/T/ipykernel_36498/1119101340.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['day'] = df1['day'].astype('int')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 1 to 118
# Data columns (total 81 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Game          118 non-null    float64
#  1   PA            118 non-null    float64
#  2   AB            118 non-null    float64
#  3   R             118 non-null    float64
#  4   H             118 non-null    float64
#  5   2B            118 non-null    float64
#  6   3B            118 non-null    float64
#  7   HR            118 non-null    float64
#  8   RBI           118 non-null    float64
#  9   BB            118 non-null    float64
#  10  IBB           118 non-null    float64
#  11  SO            118 non-null    float64
#  12  HBP           118 non-null    float64
#  13  SH            118 non-null    float64
#  14  SF            118 non-null    float64
#  15  ROE           118 non-null    float64
#  16  GDP           118 non-null    float64
# ...

# %%
df1 = df1.drop(columns=["number", "Month"])

# %%
ds = df1.select_dtypes(include='object')
ds.head()
# Out:
#                                         PitchersUsed     Date      GB  Time
# 1  S.Strider (99-72-W), N.Anderson (99), J.Jiméne...   Mar 30    Tied  3:07
# 2   J.Shuster (99-32-L), M.Tonkin (99), J.Chavez (2)    Apr 1  up 0.5  2:21
# 3  C.Morton (99-37-W), N.Anderson (1-H), C.McHugh...    Apr 2     0.5  2:17
# 4  D.Dodd (99-54-W), J.Chavez (1-H), J.Jiménez (2...    Apr 3  up 0.5  2:46
# 5  B.Elder (99-71-W), M.Tonkin (2), D.Lee (0), C....    Apr 4  up 1.5  2:20

# %%
df5 = df1.drop(columns=["PitchersUsed", "Date", "GB", "Time"])

# %%
df5
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...  Thr_code  \
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...         1
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...         0
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...         1
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...         0
# 5      6.0  38.0  36.0   5.0  10.0  3.0  0.0  1.0   5.0  1.0  ...         1
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...       ...
# 114  115.0  55.0  48.0  21.0  22.0  5.0  0.0  6.0  21.0  6.0  ...         1
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...         0
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...         1
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...         1
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...         1
#
# ...

# %%
plt.figure(figsize= (10,6))
plt.plot(df5)
plt.xlabel('Day_code')
plt.ylabel('Rslt_code')
plt.title('Trend of the Time Series')
# Out:
# Text(0.5, 1.0, 'Trend of the Time Series')

# %%
.80*120
# Out:
# 96.0

# %%
df5_cleaned = df5.dropna()

# %%
sumz = df5.isna().sum()

# %%
sumz.sum()
# Out:
# 4

# %%
dff = df5.drop(columns[""])
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...  Thr_code  \
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...         1
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...         0
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...         1
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...         0
# 5      6.0  38.0  36.0   5.0  10.0  3.0  0.0  1.0   5.0  1.0  ...         1
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...       ...
# 114  115.0  55.0  48.0  21.0  22.0  5.0  0.0  6.0  21.0  6.0  ...         1
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...         0
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...         1
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...         1
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...         1
#
# ...

# %%
train = df5_cleaned[0:96]

# %%
test = df5_cleaned[96:]

# %%
y_train = train["Rslt_code"]

# %%
x_train = train.drop(columns=["Rslt_code"])

# %%
sns.heatmap(train.corr());

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
                                 max_depth=1, random_state=0).fit(x_train, y_train)

# %%
y_test = test["Rslt_code"]

# %%
x_test = test.drop(columns=["Rslt_code"])

# %%
clf.score(x_test, y_test)
# Out:
# 1.0

# %% [markdown]
# need to drop the score if its still there

# %% [markdown]
# https://www.datacamp.com/tutorial/tutorial-time-series-forecasting

# %% [markdown]
# https://www.kaggle.com/code/satishgunjal/tutorial-time-series-analysis-and-forecasting

# %%
df5
# Out:
#       Game    PA    AB     R     H   2B   3B   HR   RBI   BB  ...  Thr_code  \
# 1      2.0  37.0  35.0   7.0  11.0  0.0  0.0  4.0   6.0  2.0  ...         1
# 2      3.0  33.0  28.0   1.0   4.0  1.0  0.0  0.0   1.0  5.0  ...         0
# 3      4.0  40.0  35.0   8.0  10.0  3.0  0.0  3.0   8.0  5.0  ...         1
# 4      5.0  38.0  37.0   4.0  12.0  1.0  0.0  2.0   4.0  1.0  ...         0
# 5      6.0  38.0  36.0   5.0  10.0  3.0  0.0  1.0   5.0  1.0  ...         1
# ..     ...   ...   ...   ...   ...  ...  ...  ...   ...  ...  ...       ...
# 114  115.0  55.0  48.0  21.0  22.0  5.0  0.0  6.0  21.0  6.0  ...         1
# 115  116.0  40.0  34.0   6.0   7.0  2.0  0.0  1.0   5.0  5.0  ...         0
# 116  117.0  37.0  34.0   6.0   7.0  2.0  0.0  2.0   6.0  3.0  ...         1
# 117  118.0  44.0  36.0  11.0  15.0  2.0  0.0  2.0  10.0  8.0  ...         1
# 118  119.0  38.0  31.0   5.0   6.0  0.0  0.0  2.0   5.0  5.0  ...         1
#
# ...
