# %%
import pandas as pd
import numpy as np
from pandas import Index
from pybaseball import statcast

# %%
statcast(start_dt="2019-06-24", end_dt="2019-06-25").columns
df = Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
       'release_pos_z', 'player_name', 'batter', 'pitcher', 'events',
       'description', 'spin_dir', 'spin_rate_deprecated',
       'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
       'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
       'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
       'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
       'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
       'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
       'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
       'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
       'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
       'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
       'fielder_7', 'fielder_8', 'fielder_9', 'release_pos_y',
       'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle',
       'woba_value', 'woba_denom', 'babip_value', 'iso_value',
       'launch_speed_angle', 'at_bat_number', 'pitch_number', 'pitch_name',
       'home_score', 'away_score', 'bat_score', 'fld_score', 'post_away_score',
       'post_home_score', 'post_bat_score', 'post_fld_score',
       'if_fielding_alignment', 'of_fielding_alignment', 'spin_axis',
       'delta_home_win_exp', 'delta_run_exp'],
      dtype='object')
# Out:
# This is a large query, it may take a moment to complete
# 100%|█████████████████████████████████████████████| 2/2 [00:04<00:00,  2.03s/it]

# %%
from pybaseball import statcast

# get all statcast data for July 4th, 2017
data = statcast('2017-07-04')

# #get data for the first seven days of August in 2016
# data = statcast('2016-08-01', '2016-08-07')

# #get all data for the Texas Rangers in the 2016 season
# data = statcast('2016-04-01', '2016-10-30', team='TEX')

# # get data for yesterday
# data = statcast()
# Out:
# This is a large query, it may take a moment to complete
# 100%|█████████████████████████████████████████████| 1/1 [00:03<00:00,  3.84s/it]

# %%
data
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3135         FC 2017-07-04           91.1          -0.79           6.04
# 3271         FC 2017-07-04           92.3          -1.04           5.86
# 3408         FC 2017-07-04           91.0          -1.32           5.83
# 3445         FF 2017-07-04           95.6          -1.14           5.98
# 3528         FC 2017-07-04           91.2          -1.24           5.94
# ...         ...        ...            ...            ...            ...
# 3871         FF 2017-07-04           93.3           1.18           6.38
# 4032         SL 2017-07-04           88.6           1.19           6.49
# 4164         SL 2017-07-04           89.7           1.11           6.48
# 4238         CU 2017-07-04           73.4           0.81           6.66
# 4410         FF 2017-07-04           92.7           1.08           6.43
#
#            player_name  batter  pitcher     events      description  ...  \
# 3135    Osuna, Roberto  642180   532077  field_out    hit_into_play  ...
# 3271    Osuna, Roberto  642180   532077        NaN             foul  ...
# 3408    Osuna, Roberto  453056   532077  strikeout  swinging_strike  ...
# 3445    Osuna, Roberto  453056   532077        NaN             ball  ...
# 3528    Osuna, Roberto  453056   532077        NaN    called_strike  ...
# ...                ...     ...      ...        ...              ...  ...
# 3871  Kershaw, Clayton  572041   477132        NaN             foul  ...
# 4032  Kershaw, Clayton  572041   477132        NaN             foul  ...
# 4164  Kershaw, Clayton  572041   477132        NaN             ball  ...
# 4238  Kershaw, Clayton  572041   477132        NaN             ball  ...
# 4410  Kershaw, Clayton  572041   477132        NaN    called_strike  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 3135          4                4                1               1
# 3271          4                4                1               1
# 3408          4                4                1               1
# 3445          4                4                1               1
# 3528          4                4                1               1
# ...         ...              ...              ...             ...
# 3871          0                0                0               0
# 4032          0                0                0               0
# 4164          0                0                0               0
# 4238          0                0                0               0
# 4410          0                0                0               0
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 3135               4              Standard              Standard       165
# 3271               4              Standard              Standard       174
# 3408               4              Standard              Standard       203
# 3445               4              Standard              Standard       199
# 3528               4              Standard              Standard       178
# ...              ...                   ...                   ...       ...
# 3871               0              Standard              Standard       177
# 4032               0              Standard              Standard       192
# 4164               0              Standard              Standard       195
# 4238               0              Standard              Standard       346
# 4410               0              Standard              Standard       176
#
#      delta_home_win_exp delta_run_exp
# 3135             -0.005        -0.088
# 3271                0.0        -0.018
# 3408             -0.012        -0.152
# 3445                0.0         0.031
# 3528                0.0        -0.045
# ...                 ...           ...
# 3871                0.0           0.0
# 4032                0.0        -0.069
# 4164                0.0          0.05
# 4238                0.0         0.027
# 4410                0.0        -0.037
#
# [4450 rows x 92 columns]

# %%
# from pybaseball import statcast_batter
# from pybaseball import playerid_lookup

# # find David Ortiz's player id (mlbam_key)
# playerid_lookup('ortiz','david')

# # get all available data
# data = statcast_batter('2008-04-01', '2017-07-15', player_id = 120074)

# # get data for August 16th, 2014
# data = statcast_batter('2014-08-16', player_id = 120074)

# %%
data = statcast()
# Out:
# start_dt 2023-08-14
# end_dt 2023-08-15
# Warning: no date range supplied, assuming yesterday's date.
# This is a large query, it may take a moment to complete
# 100%|█████████████████████████████████████████████| 2/2 [00:09<00:00,  4.51s/it]

# %%
data
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 1986         ST 2023-08-14           79.7           -2.9           5.09
# 2050         FF 2023-08-14           93.3           -2.7           5.35
# 2103         SI 2023-08-14           92.4          -2.75           5.28
# 2150         SI 2023-08-14           92.2          -2.56           5.17
# 2208         ST 2023-08-14           77.0          -2.73           5.49
# ...         ...        ...            ...            ...            ...
# 2362         SI 2023-08-14           93.5          -1.39           5.32
# 2395         SL 2023-08-14           82.6          -1.54           5.43
# 2464         SI 2023-08-14           93.7          -1.41           5.26
# 2537         SI 2023-08-14           92.2           -1.2           5.27
# 2631         SI 2023-08-14           92.2           -1.4           5.34
#
#          player_name  batter  pitcher     events      description  ...  \
# 1986  Ottavino, Adam  663647   493603  field_out    hit_into_play  ...
# 2050  Ottavino, Adam  663647   493603        NaN  swinging_strike  ...
# 2103  Ottavino, Adam  663647   493603        NaN    called_strike  ...
# 2150  Ottavino, Adam  668804   493603  strikeout    called_strike  ...
# 2208  Ottavino, Adam  668804   493603        NaN             foul  ...
# ...              ...     ...      ...        ...              ...  ...
# 2362   Singer, Brady  553993   663903        NaN             ball  ...
# 2395   Singer, Brady  677594   663903  field_out    hit_into_play  ...
# 2464   Singer, Brady  677594   663903        NaN             ball  ...
# 2537   Singer, Brady  677594   663903        NaN             ball  ...
# 2631   Singer, Brady  677594   663903        NaN    called_strike  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 1986          7                2                7               2
# 2050          7                2                7               2
# 2103          7                2                7               2
# 2150          7                2                7               2
# 2208          7                2                7               2
# ...         ...              ...              ...             ...
# 2362          0                0                0               0
# 2395          0                0                0               0
# 2464          0                0                0               0
# 2537          0                0                0               0
# 2631          0                0                0               0
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 1986               7              Standard              Standard        72
# 2050               7              Standard              Standard       235
# 2103               7              Standard              Standard       232
# 2150               7             Strategic              Standard       233
# 2208               7             Strategic              Standard        59
# ...              ...                   ...                   ...       ...
# 2362               0              Standard              Standard       216
# 2395               0              Standard              Standard        74
# 2464               0              Standard              Standard       212
# 2537               0              Standard              Standard       201
# 2631               0              Standard              Standard       204
#
#      delta_home_win_exp delta_run_exp
# 1986                0.0        -0.064
# 2050                0.0        -0.024
# 2103                0.0        -0.018
# 2150              0.002        -0.107
# 2208                0.0           0.0
# ...                 ...           ...
# 2362                0.0         0.027
# 2395              0.022        -0.275
# 2464                0.0         0.049
# 2537                0.0         0.027
# 2631                0.0        -0.038
#
# [2658 rows x 92 columns]

# %%
df = data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2658 entries, 1986 to 2631
# Data columns (total 92 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   pitch_type                       2658 non-null   object
#  1   game_date                        2658 non-null   datetime64[ns]
#  2   release_speed                    2658 non-null   Float64
#  3   release_pos_x                    2658 non-null   Float64
#  4   release_pos_z                    2658 non-null   Float64
#  5   player_name                      2658 non-null   object
#  6   batter                           2658 non-null   Int64
#  7   pitcher                          2658 non-null   Int64
#  8   events                           681 non-null    object
#  9   description                      2658 non-null   object
#  10  spin_dir                         0 non-null      Int64
#  11  spin_rate_deprecated             0 non-null      Int64
#  12  break_angle_deprecated           0 non-null      Int64
#  13  break_length_deprecated          0 non-null      Int64
#  14  zone                             2658 non-null   Int64
#  15  des                              2658 non-null   object
#  16  game_type                        2658 non-null   object
#  17  stand                            2658 non-null   object
#  18  p_throws                         2658 non-null   object
#  19  home_team                        2658 non-null   object
#  20  away_team                        2658 non-null   object
#  21  type                             2658 non-null   object
#  22  hit_location                     586 non-null    Int64
#  23  bb_type                          453 non-null    object
#  24  balls                            2658 non-null   Int64
#  25  strikes                          2658 non-null   Int64
#  26  game_year                        2658 non-null   Int64
#  27  pfx_x                            2658 non-null   Float64
#  28  pfx_z                            2658 non-null   Float64
#  29  plate_x                          2658 non-null   Float64
#  30  plate_z                          2658 non-null   Float64
#  31  on_3b                            281 non-null    Int64
#  32  on_2b                            549 non-null    Int64
#  33  on_1b                            909 non-null    Int64
#  34  outs_when_up                     2658 non-null   Int64
#  35  inning                           2658 non-null   Int64
#  36  inning_topbot                    2658 non-null   object
#  37  hc_x                             453 non-null    Float64
#  38  hc_y                             453 non-null    Float64
#  39  tfs_deprecated                   0 non-null      Int64
#  40  tfs_zulu_deprecated              0 non-null      Int64
#  41  fielder_2                        2658 non-null   Int64
#  42  umpire                           0 non-null      Int64
#  43  sv_id                            0 non-null      Int64
#  44  vx0                              2658 non-null   Float64
#  45  vy0                              2658 non-null   Float64
#  46  vz0                              2658 non-null   Float64
#  47  ax                               2658 non-null   Float64
#  48  ay                               2658 non-null   Float64
#  49  az                               2658 non-null   Float64
#  50  sz_top                           2658 non-null   Float64
#  51  sz_bot                           2658 non-null   Float64
#  52  hit_distance_sc                  874 non-null    Int64
#  53  launch_speed                     870 non-null    Float64
#  54  launch_angle                     872 non-null    Int64
#  55  effective_speed                  2658 non-null   Float64
#  56  release_spin_rate                2657 non-null   Int64
#  57  release_extension                2658 non-null   Float64
#  58  game_pk                          2658 non-null   Int64
#  59  pitcher.1                        2658 non-null   Int64
#  60  fielder_2.1                      2658 non-null   Int64
#  61  fielder_3                        2658 non-null   Int64
#  62  fielder_4                        2658 non-null   Int64
#  63  fielder_5                        2658 non-null   Int64
#  64  fielder_6                        2658 non-null   Int64
#  65  fielder_7                        2658 non-null   Int64
#  66  fielder_8                        2658 non-null   Int64
#  67  fielder_9                        2658 non-null   Int64
#  68  release_pos_y                    2658 non-null   Float64
#  69  estimated_ba_using_speedangle    453 non-null    Float64
#  70  estimated_woba_using_speedangle  453 non-null    Float64
#  71  woba_value                       681 non-null    Float64
#  72  woba_denom                       681 non-null    Int64
#  73  babip_value                      681 non-null    Int64
#  74  iso_value                        681 non-null    Int64
#  75  launch_speed_angle               453 non-null    Int64
#  76  at_bat_number                    2658 non-null   Int64
#  77  pitch_number                     2658 non-null   Int64
#  78  pitch_name                       2658 non-null   object
#  79  home_score                       2658 non-null   Int64
#  80  away_score                       2658 non-null   Int64
#  81  bat_score                        2658 non-null   Int64
#  82  fld_score                        2658 non-null   Int64
#  83  post_away_score                  2658 non-null   Int64
#  84  post_home_score                  2658 non-null   Int64
#  85  post_bat_score                   2658 non-null   Int64
#  86  post_fld_score                   2658 non-null   Int64
#  87  if_fielding_alignment            2658 non-null   object
#  88  of_fielding_alignment            2658 non-null   object
#  89  spin_axis                        2657 non-null   Int64
#  90  delta_home_win_exp               2658 non-null   Float64
#  91  delta_run_exp                    2658 non-null   Float64
# dtypes: Float64(26), Int64(49), datetime64[ns](1), object(16)
# memory usage: 2.1+ MB

# %%
df.describe()
# Out:
#        release_speed  release_pos_x  release_pos_z         batter  \
# count    2658.000000    2658.000000    2658.000000    2658.000000
# mean       88.911964      -0.913668       5.771704  634791.583145
# std         6.368631       1.834266       0.514656   52460.011110
# min        37.700000      -3.920000       4.150000  453568.000000
# 25%        84.500000      -2.250000       5.440000  606466.000000
# 50%        90.100000      -1.520000       5.810000  663624.000000
# 75%        93.600000       0.667500       6.110000  670541.000000
# max       101.600000       3.840000       7.020000  691023.000000
#
#              pitcher spin_dir spin_rate_deprecated break_angle_deprecated  \
# count    2658.000000        0                    0                      0
# mean   620341.285553     <NA>                 <NA>                   <NA>
# std     67697.265691     <NA>                 <NA>                   <NA>
# min    453286.000000     <NA>                 <NA>                   <NA>
# 25%    592426.000000     <NA>                 <NA>                   <NA>
# 50%    656322.000000     <NA>                 <NA>                   <NA>
# 75%    668338.000000     <NA>                 <NA>                   <NA>
# max    682990.000000     <NA>                 <NA>                   <NA>
#
#       break_length_deprecated         zone  ...   away_score    bat_score  \
# count                       0  2658.000000  ...  2658.000000  2658.000000
# mean                     <NA>     9.149360  ...     1.761475     2.322799
# std                      <NA>     4.244579  ...     1.997625     2.554711
# min                      <NA>     1.000000  ...     0.000000     0.000000
# 25%                      <NA>     5.000000  ...     0.000000     0.000000
# 50%                      <NA>    11.000000  ...     1.000000     2.000000
# 75%                      <NA>    13.000000  ...     2.000000     4.000000
# max                      <NA>    14.000000  ...    10.000000    12.000000
#
#          fld_score  post_away_score  post_home_score  post_bat_score  \
# count  2658.000000      2658.000000      2658.000000     2658.000000
# mean      2.258465         1.774643         2.841610        2.357788
# std       2.542335         2.005451         2.915077        2.573039
# min       0.000000         0.000000         0.000000        0.000000
# 25%       0.000000         0.000000         0.000000        0.000000
# 50%       2.000000         1.000000         2.000000        2.000000
# 75%       4.000000         2.000000         5.000000        4.000000
# max      12.000000        10.000000        12.000000       12.000000
#
#        post_fld_score    spin_axis  delta_home_win_exp  delta_run_exp
# count     2658.000000  2657.000000         2658.000000    2658.000000
# mean         2.258465   174.607076            0.000919       0.005358
# std          2.542335    74.769102            0.029773       0.255093
# min          0.000000     1.000000           -0.361000      -0.814000
# 25%          0.000000   122.000000            0.000000      -0.064000
# 50%          2.000000   200.000000            0.000000      -0.018000
# 75%          4.000000   222.000000            0.000000       0.037000
# max         12.000000   360.000000            0.487000       2.515000
#
# [8 rows x 75 columns]

# %%
# df=df.dropna()

# %%
# df

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# %%
data = df

# %%
# Handle missing values
data.fillna(method='ffill', inplace=True)

# %%
df.columns
# Out:
# Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
#        'release_pos_z', 'player_name', 'batter', 'pitcher', 'events',
#        'description', 'spin_dir', 'spin_rate_deprecated',
#        'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
#        'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
#        'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
#        'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
#        'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
#        'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
#        'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
#        'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
#        'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
#        'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
#        'fielder_7', 'fielder_8', 'fielder_9', 'release_pos_y',
#        'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle',
#        'woba_value', 'woba_denom', 'babip_value', 'iso_value',
#        'launch_speed_angle', 'at_bat_number', 'pitch_number', 'pitch_name',
#        'home_score', 'away_score', 'bat_score', 'fld_score', 'post_away_score',
#        'post_home_score', 'post_bat_score', 'post_fld_score',
#        'if_fielding_alignment', 'of_fielding_alignment', 'spin_axis',
#        'delta_home_win_exp', 'delta_run_exp'],
#       dtype='object')

# %%
le = LabelEncoder()
data['home_team'] = le.fit_transform(data['home_team'])
data['away_team'] = le.fit_transform(data['away_team'])

# %%
# Scale numerical features
scaler = MinMaxScaler()
data[['home_score', 'away_score']] = scaler.fit_transform(
    data[['home_score', 'away_score']])

# %%
# Save preprocessed data
data.to_csv('preprocessed_data.csv', index=False)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report

# Load preprocessed data
data = pd.read_csv('preprocessed_data.csv')

# %%
data
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            ST  2023-08-14           79.7          -2.90           5.09
# 1            FF  2023-08-14           93.3          -2.70           5.35
# 2            SI  2023-08-14           92.4          -2.75           5.28
# 3            SI  2023-08-14           92.2          -2.56           5.17
# 4            ST  2023-08-14           77.0          -2.73           5.49
# ...         ...         ...            ...            ...            ...
# 2653         SI  2023-08-14           93.5          -1.39           5.32
# 2654         SL  2023-08-14           82.6          -1.54           5.43
# 2655         SI  2023-08-14           93.7          -1.41           5.26
# 2656         SI  2023-08-14           92.2          -1.20           5.27
# 2657         SI  2023-08-14           92.2          -1.40           5.34
#
#          player_name  batter  pitcher     events      description  ...  \
# 0     Ottavino, Adam  663647   493603  field_out    hit_into_play  ...
# 1     Ottavino, Adam  663647   493603  field_out  swinging_strike  ...
# 2     Ottavino, Adam  663647   493603  field_out    called_strike  ...
# 3     Ottavino, Adam  668804   493603  strikeout    called_strike  ...
# 4     Ottavino, Adam  668804   493603  strikeout             foul  ...
# ...              ...     ...      ...        ...              ...  ...
# 2653   Singer, Brady  553993   663903  field_out             ball  ...
# 2654   Singer, Brady  677594   663903  field_out    hit_into_play  ...
# 2655   Singer, Brady  677594   663903  field_out             ball  ...
# 2656   Singer, Brady  677594   663903  field_out             ball  ...
# 2657   Singer, Brady  677594   663903  field_out    called_strike  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 0             7                2                7               2
# 1             7                2                7               2
# 2             7                2                7               2
# 3             7                2                7               2
# 4             7                2                7               2
# ...         ...              ...              ...             ...
# 2653          0                0                0               0
# 2654          0                0                0               0
# 2655          0                0                0               0
# 2656          0                0                0               0
# 2657          0                0                0               0
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 0                  7              Standard              Standard        72
# 1                  7              Standard              Standard       235
# 2                  7              Standard              Standard       232
# 3                  7             Strategic              Standard       233
# 4                  7             Strategic              Standard        59
# ...              ...                   ...                   ...       ...
# 2653               0              Standard              Standard       216
# 2654               0              Standard              Standard        74
# 2655               0              Standard              Standard       212
# 2656               0              Standard              Standard       201
# 2657               0              Standard              Standard       204
#
#      delta_home_win_exp  delta_run_exp
# 0                 0.000         -0.064
# 1                 0.000         -0.024
# 2                 0.000         -0.018
# 3                 0.002         -0.107
# 4                 0.000          0.000
# ...                 ...            ...
# 2653              0.000          0.027
# 2654              0.022         -0.275
# 2655              0.000          0.049
# 2656              0.000          0.027
# 2657              0.000         -0.038
#
# [2658 rows x 92 columns]
