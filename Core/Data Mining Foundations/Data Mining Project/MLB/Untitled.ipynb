# %%
import pandas as pd
import numpy as np
from pandas import Index
from pybaseball import statcast

# %%
statcast(start_dt="2019-06-24", end_dt="2019-06-25").columns
df = Index(['pitch_type', 'game_date', 'release_speed', 'release_pos_x',
       'release_pos_z', 'player_name', 'batter', 'pitcher', 'events',
       'description', 'spin_dir', 'spin_rate_deprecated',
       'break_angle_deprecated', 'break_length_deprecated', 'zone', 'des',
       'game_type', 'stand', 'p_throws', 'home_team', 'away_team', 'type',
       'hit_location', 'bb_type', 'balls', 'strikes', 'game_year', 'pfx_x',
       'pfx_z', 'plate_x', 'plate_z', 'on_3b', 'on_2b', 'on_1b',
       'outs_when_up', 'inning', 'inning_topbot', 'hc_x', 'hc_y',
       'tfs_deprecated', 'tfs_zulu_deprecated', 'fielder_2', 'umpire', 'sv_id',
       'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'sz_top', 'sz_bot',
       'hit_distance_sc', 'launch_speed', 'launch_angle', 'effective_speed',
       'release_spin_rate', 'release_extension', 'game_pk', 'pitcher.1',
       'fielder_2.1', 'fielder_3', 'fielder_4', 'fielder_5', 'fielder_6',
       'fielder_7', 'fielder_8', 'fielder_9', 'release_pos_y',
       'estimated_ba_using_speedangle', 'estimated_woba_using_speedangle',
       'woba_value', 'woba_denom', 'babip_value', 'iso_value',
       'launch_speed_angle', 'at_bat_number', 'pitch_number', 'pitch_name',
       'home_score', 'away_score', 'bat_score', 'fld_score', 'post_away_score',
       'post_home_score', 'post_bat_score', 'post_fld_score',
       'if_fielding_alignment', 'of_fielding_alignment', 'spin_axis',
       'delta_home_win_exp', 'delta_run_exp'],
      dtype='object')
# Out:
# This is a large query, it may take a moment to complete
# 100%|█████████████████████████████████████████████| 2/2 [00:03<00:00,  1.76s/it]

# %%
from pybaseball import statcast

# get all statcast data for July 4th, 2017
data = statcast('2017-07-04')

# #get data for the first seven days of August in 2016
# data = statcast('2016-08-01', '2016-08-07')

# #get all data for the Texas Rangers in the 2016 season
# data = statcast('2016-04-01', '2016-10-30', team='TEX')

# # get data for yesterday
# data = statcast()
# Out:
# This is a large query, it may take a moment to complete
# 100%|█████████████████████████████████████████████| 1/1 [00:03<00:00,  3.90s/it]

# %%
data
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 3149         FC 2017-07-04           91.1          -0.79           6.04
# 3248         FC 2017-07-04           92.3          -1.04           5.86
# 3362         FC 2017-07-04           91.0          -1.32           5.83
# 3475         FF 2017-07-04           95.6          -1.14           5.98
# 3607         FC 2017-07-04           91.2          -1.24           5.94
# ...         ...        ...            ...            ...            ...
# 3946         FF 2017-07-04           93.3           1.18           6.38
# 4026         SL 2017-07-04           88.6           1.19           6.49
# 4140         SL 2017-07-04           89.7           1.11           6.48
# 4304         CU 2017-07-04           73.4           0.81           6.66
# 4347         FF 2017-07-04           92.7           1.08           6.43
#
#            player_name  batter  pitcher     events      description  ...  \
# 3149    Osuna, Roberto  642180   532077  field_out    hit_into_play  ...
# 3248    Osuna, Roberto  642180   532077        NaN             foul  ...
# 3362    Osuna, Roberto  453056   532077  strikeout  swinging_strike  ...
# 3475    Osuna, Roberto  453056   532077        NaN             ball  ...
# 3607    Osuna, Roberto  453056   532077        NaN    called_strike  ...
# ...                ...     ...      ...        ...              ...  ...
# 3946  Kershaw, Clayton  572041   477132        NaN             foul  ...
# 4026  Kershaw, Clayton  572041   477132        NaN             foul  ...
# 4140  Kershaw, Clayton  572041   477132        NaN             ball  ...
# 4304  Kershaw, Clayton  572041   477132        NaN             ball  ...
# 4347  Kershaw, Clayton  572041   477132        NaN    called_strike  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 3149          4                4                1               1
# 3248          4                4                1               1
# 3362          4                4                1               1
# 3475          4                4                1               1
# 3607          4                4                1               1
# ...         ...              ...              ...             ...
# 3946          0                0                0               0
# 4026          0                0                0               0
# 4140          0                0                0               0
# 4304          0                0                0               0
# 4347          0                0                0               0
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 3149               4              Standard              Standard       165
# 3248               4              Standard              Standard       174
# 3362               4              Standard              Standard       203
# 3475               4              Standard              Standard       199
# 3607               4              Standard              Standard       178
# ...              ...                   ...                   ...       ...
# 3946               0              Standard              Standard       177
# 4026               0              Standard              Standard       192
# 4140               0              Standard              Standard       195
# 4304               0              Standard              Standard       346
# 4347               0              Standard              Standard       176
#
#      delta_home_win_exp delta_run_exp
# 3149             -0.005        -0.088
# 3248                0.0        -0.018
# 3362             -0.012        -0.152
# 3475                0.0         0.031
# 3607                0.0        -0.045
# ...                 ...           ...
# 3946                0.0           0.0
# 4026                0.0        -0.069
# 4140                0.0          0.05
# 4304                0.0         0.027
# 4347                0.0        -0.037
#
# [4450 rows x 92 columns]

# %%
# from pybaseball import statcast_batter
# from pybaseball import playerid_lookup

# # find David Ortiz's player id (mlbam_key)
# playerid_lookup('ortiz','david')

# # get all available data
# data = statcast_batter('2008-04-01', '2017-07-15', player_id = 120074)

# # get data for August 16th, 2014
# data = statcast_batter('2014-08-16', player_id = 120074)

# %%
data = statcast()
# Out:
# start_dt 2023-07-16
# end_dt 2023-07-17
# Warning: no date range supplied, assuming yesterday's date.
# This is a large query, it may take a moment to complete
# 100%|█████████████████████████████████████████████| 2/2 [00:13<00:00,  6.58s/it]

# %%
data
# Out:
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 2759         FF 2023-07-16           94.0          -0.82           6.22
# 2826         FF 2023-07-16           93.2          -0.76           6.21
# 2901         CU 2023-07-16           76.2          -0.64           6.16
# 2994         CU 2023-07-16           75.1          -0.72           6.21
# 3207         SL 2023-07-16           87.6          -0.84           6.22
# ...         ...        ...            ...            ...            ...
# 3935         FF 2023-07-16           95.6           -0.8           5.78
# 4104         SL 2023-07-16           85.9          -1.06           5.66
# 4212         FF 2023-07-16           95.4          -0.62            5.8
# 4431         ST 2023-07-16           82.4          -1.22           5.42
# 4555         FF 2023-07-16           95.4          -0.88           5.78
#
#            player_name  batter  pitcher     events      description  ...  \
# 2759  Scholtens, Jesse  607680   669947  field_out    hit_into_play  ...
# 2826  Scholtens, Jesse  606115   669947  field_out    hit_into_play  ...
# 2901  Scholtens, Jesse  606115   669947        NaN     blocked_ball  ...
# 2994  Scholtens, Jesse  606115   669947        NaN             foul  ...
# 3207  Scholtens, Jesse  606115   669947        NaN             foul  ...
# ...                ...     ...      ...        ...              ...  ...
# 3935     Miller, Bryce  682985   682243        NaN             ball  ...
# 4104     Miller, Bryce  682985   682243        NaN  swinging_strike  ...
# 4212     Miller, Bryce  656716   682243  field_out    hit_into_play  ...
# 4431     Miller, Bryce  656716   682243        NaN             ball  ...
# 4555     Miller, Bryce  656716   682243        NaN             foul  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 2759          8                8                1               1
# 2826          8                8                1               1
# 2901          8                8                1               1
# 2994          8                8                1               1
# 3207          8                8                1               1
# ...         ...              ...              ...             ...
# 3935          0                0                0               0
# 4104          0                0                0               0
# 4212          0                0                0               0
# 4431          0                0                0               0
# 4555          0                0                0               0
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 2759               8              Standard              Standard       187
# 2826               8              Standard              Standard       192
# 2901               8              Standard              Standard        32
# 2994               8             Strategic              Standard        33
# 3207               8              Standard              Standard       147
# ...              ...                   ...                   ...       ...
# 3935               0             Strategic              Standard       189
# 4104               0             Strategic              Standard        77
# 4212               0              Standard              Standard       188
# 4431               0              Standard              Standard        32
# 4555               0              Standard              Standard       198
#
#      delta_home_win_exp delta_run_exp
# 2759                0.0        -0.239
# 2826             -0.001        -0.272
# 2901                0.0         0.047
# 2994                0.0           0.0
# 3207                0.0        -0.061
# ...                 ...           ...
# 3935                0.0          0.02
# 4104                0.0        -0.026
# 4212              0.022        -0.225
# 4431                0.0         0.027
# 4555                0.0        -0.039
#
# [4580 rows x 92 columns]

# %%
df = data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4580 entries, 2759 to 4555
# Data columns (total 92 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   pitch_type                       4580 non-null   object
#  1   game_date                        4580 non-null   datetime64[ns]
#  2   release_speed                    4580 non-null   Float64
#  3   release_pos_x                    4580 non-null   Float64
#  4   release_pos_z                    4580 non-null   Float64
#  5   player_name                      4580 non-null   object
#  6   batter                           4580 non-null   Int64
#  7   pitcher                          4580 non-null   Int64
#  8   events                           1172 non-null   object
#  9   description                      4580 non-null   object
#  10  spin_dir                         0 non-null      Int64
#  11  spin_rate_deprecated             0 non-null      Int64
#  12  break_angle_deprecated           0 non-null      Int64
#  13  break_length_deprecated          0 non-null      Int64
#  14  zone                             4580 non-null   Int64
#  15  des                              4580 non-null   object
#  16  game_type                        4580 non-null   object
#  17  stand                            4580 non-null   object
#  18  p_throws                         4580 non-null   object
#  19  home_team                        4580 non-null   object
#  20  away_team                        4580 non-null   object
#  21  type                             4580 non-null   object
#  22  hit_location                     1010 non-null   Int64
#  23  bb_type                          799 non-null    object
#  24  balls                            4580 non-null   Int64
#  25  strikes                          4580 non-null   Int64
#  26  game_year                        4580 non-null   Int64
#  27  pfx_x                            4580 non-null   Float64
#  28  pfx_z                            4580 non-null   Float64
#  29  plate_x                          4580 non-null   Float64
#  30  plate_z                          4580 non-null   Float64
#  31  on_3b                            508 non-null    Int64
#  32  on_2b                            926 non-null    Int64
#  33  on_1b                            1438 non-null   Int64
#  34  outs_when_up                     4580 non-null   Int64
#  35  inning                           4580 non-null   Int64
#  36  inning_topbot                    4580 non-null   object
#  37  hc_x                             798 non-null    Float64
#  38  hc_y                             798 non-null    Float64
#  39  tfs_deprecated                   0 non-null      Int64
#  40  tfs_zulu_deprecated              0 non-null      Int64
#  41  fielder_2                        4580 non-null   Int64
#  42  umpire                           0 non-null      Int64
#  43  sv_id                            0 non-null      Int64
#  44  vx0                              4580 non-null   Float64
#  45  vy0                              4580 non-null   Float64
#  46  vz0                              4580 non-null   Float64
#  47  ax                               4580 non-null   Float64
#  48  ay                               4580 non-null   Float64
#  49  az                               4580 non-null   Float64
#  50  sz_top                           4580 non-null   Float64
#  51  sz_bot                           4580 non-null   Float64
#  52  hit_distance_sc                  1503 non-null   Int64
#  53  launch_speed                     1495 non-null   Float64
#  54  launch_angle                     1495 non-null   Int64
#  55  effective_speed                  4579 non-null   Float64
#  56  release_spin_rate                4579 non-null   Int64
#  57  release_extension                4580 non-null   Float64
#  58  game_pk                          4580 non-null   Int64
#  59  pitcher.1                        4580 non-null   Int64
#  60  fielder_2.1                      4580 non-null   Int64
#  61  fielder_3                        4580 non-null   Int64
#  62  fielder_4                        4580 non-null   Int64
#  63  fielder_5                        4580 non-null   Int64
#  64  fielder_6                        4580 non-null   Int64
#  65  fielder_7                        4580 non-null   Int64
#  66  fielder_8                        4580 non-null   Int64
#  67  fielder_9                        4580 non-null   Int64
#  68  release_pos_y                    4580 non-null   Float64
#  69  estimated_ba_using_speedangle    797 non-null    Float64
#  70  estimated_woba_using_speedangle  797 non-null    Float64
#  71  woba_value                       1172 non-null   Float64
#  72  woba_denom                       1170 non-null   Int64
#  73  babip_value                      1172 non-null   Int64
#  74  iso_value                        1172 non-null   Int64
#  75  launch_speed_angle               797 non-null    Int64
#  76  at_bat_number                    4580 non-null   Int64
#  77  pitch_number                     4580 non-null   Int64
#  78  pitch_name                       4580 non-null   object
#  79  home_score                       4580 non-null   Int64
#  80  away_score                       4580 non-null   Int64
#  81  bat_score                        4580 non-null   Int64
#  82  fld_score                        4580 non-null   Int64
#  83  post_away_score                  4580 non-null   Int64
#  84  post_home_score                  4580 non-null   Int64
#  85  post_bat_score                   4580 non-null   Int64
#  86  post_fld_score                   4580 non-null   Int64
#  87  if_fielding_alignment            4576 non-null   object
#  88  of_fielding_alignment            4576 non-null   object
#  89  spin_axis                        4579 non-null   Int64
#  90  delta_home_win_exp               4580 non-null   Float64
#  91  delta_run_exp                    4580 non-null   Float64
# dtypes: Float64(26), Int64(49), datetime64[ns](1), object(16)
# memory usage: 3.6+ MB

# %%
df.describe()
# Out:
#        release_speed  release_pos_x  release_pos_z         batter  \
# count    4580.000000    4580.000000    4580.000000    4580.000000
# mean       88.958559      -1.011299       5.642336  628834.529258
# std         6.227223       1.771785       0.621267   58629.084802
# min        37.200000      -4.150000       0.830000  444482.000000
# 25%        84.500000      -2.240000       5.350000  596847.000000
# 50%        89.900000      -1.570000       5.720000  655316.000000
# 75%        93.800000      -0.757500       6.020000  669257.000000
# max       101.800000       4.530000       7.180000  807799.000000
#
#              pitcher spin_dir spin_rate_deprecated break_angle_deprecated  \
# count    4580.000000        0                    0                      0
# mean   622942.809825     <NA>                 <NA>                   <NA>
# std     60170.035763     <NA>                 <NA>                   <NA>
# min    453268.000000     <NA>                 <NA>                   <NA>
# 25%    594670.000000     <NA>                 <NA>                   <NA>
# 50%    656302.000000     <NA>                 <NA>                   <NA>
# 75%    669947.000000     <NA>                 <NA>                   <NA>
# max    687798.000000     <NA>                 <NA>                   <NA>
#
#       break_length_deprecated         zone  ...   away_score    bat_score  \
# count                       0  4580.000000  ...  4580.000000  4580.000000
# mean                     <NA>     9.017904  ...     2.239520     2.115939
# std                      <NA>     4.273019  ...     2.485171     2.203822
# min                      <NA>     1.000000  ...     0.000000     0.000000
# 25%                      <NA>     5.000000  ...     0.000000     0.000000
# 50%                      <NA>    11.000000  ...     2.000000     1.000000
# 75%                      <NA>    13.000000  ...     3.000000     3.000000
# max                      <NA>    14.000000  ...    11.000000    11.000000
#
#          fld_score  post_away_score  post_home_score  post_bat_score  \
# count  4580.000000      4580.000000      4580.000000     4580.000000
# mean      2.336026         2.256987         2.229476        2.150437
# std       2.482692         2.493693         2.213531        2.222075
# min       0.000000         0.000000         0.000000        0.000000
# 25%       0.000000         0.000000         0.000000        0.000000
# 50%       2.000000         2.000000         1.000000        1.000000
# 75%       3.000000         3.000000         3.000000        3.000000
# max      11.000000        11.000000         8.000000       11.000000
#
#        post_fld_score    spin_axis  delta_home_win_exp  delta_run_exp
# count     4580.000000  4579.000000         4580.000000    4580.000000
# mean         2.336026   173.656694            0.000342       0.001915
# std          2.482692    70.805261            0.034302       0.251461
# min          0.000000     5.000000           -0.702000      -0.826000
# 25%          0.000000   126.000000            0.000000      -0.072250
# 50%          2.000000   197.000000            0.000000      -0.018000
# 75%          3.000000   221.000000            0.000000       0.037000
# max         11.000000   351.000000            0.711000       3.121000
#
# [8 rows x 75 columns]

# %%
df=df.dropna()

# %%
df
# Out:
# Empty DataFrame
# Columns: [pitch_type, game_date, release_speed, release_pos_x, release_pos_z, player_name, batter, pitcher, events, description, spin_dir, spin_rate_deprecated, break_angle_deprecated, break_length_deprecated, zone, des, game_type, stand, p_throws, home_team, away_team, type, hit_location, bb_type, balls, strikes, game_year, pfx_x, pfx_z, plate_x, plate_z, on_3b, on_2b, on_1b, outs_when_up, inning, inning_topbot, hc_x, hc_y, tfs_deprecated, tfs_zulu_deprecated, fielder_2, umpire, sv_id, vx0, vy0, vz0, ax, ay, az, sz_top, sz_bot, hit_distance_sc, launch_speed, launch_angle, effective_speed, release_spin_rate, release_extension, game_pk, pitcher.1, fielder_2.1, fielder_3, fielder_4, fielder_5, fielder_6, fielder_7, fielder_8, fielder_9, release_pos_y, estimated_ba_using_speedangle, estimated_woba_using_speedangle, woba_value, woba_denom, babip_value, iso_value, launch_speed_angle, at_bat_number, pitch_number, pitch_name, home_score, away_score, bat_score, fld_score, post_away_score, post_home_score, post_bat_score, post_fld_score, if_fielding_alignment, of_fielding_alignment, spin_axis, delta_home_win_exp, delta_run_exp]
# Index: []
#
# [0 rows x 92 columns]
