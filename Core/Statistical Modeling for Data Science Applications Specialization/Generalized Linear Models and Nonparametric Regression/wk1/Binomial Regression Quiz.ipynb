# %%
from IPython.display import Image
Image(filename="Images/Binomial1.png")

# %%
Image(filename="Images/Binomial2.png")

# %%
Image(filename="Images/Binomial3.png")

# %%
Image(filename="Images/Binomial4.png")
