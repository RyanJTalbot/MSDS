# %%
from IPython.display import Image
Image(filename="Images/Theory1.png")

# %%
Image(filename="Images/Theory2.png")

# %%
Image(filename="Images/Theory3.png")

# %%
Image(filename="Images/Theory4.png")
