# %%
from IPython.display import Image
Image(filename="Images/Basics1.png")

# %%
Image(filename="Images/Basics2.png")

# %%
Image(filename="Images/Basics3.png")

# %%
Image(filename="Images/Basics4.png")
