# %%
from IPython.display import Image
Image(filename="images/si1.png")

# %%
Image(filename="images/si2.png")

# %%
Image(filename="images/si3.png")

# %%
Image(filename="images/si4.png")

# %%
Image(filename="images/si5.png")
