# %%
from IPython.display import Image
Image(filename="images/di1.png")

# %%
Image(filename="images/di2.png")

# %%
Image(filename="images/di3.png")

# %%
Image(filename="images/di4.png")

# %%
Image(filename="images/di5.png")

# %%
Image(filename="images/di6.png")
