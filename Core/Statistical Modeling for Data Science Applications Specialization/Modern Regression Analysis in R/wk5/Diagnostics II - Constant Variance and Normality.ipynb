# %%
from IPython.display import Image
Image(filename="images/dii1.png")

# %%
Image(filename="images/dii2.png")

# %%
Image(filename="images/dii3.png")

# %%
Image(filename="images/dii4.png")

# %%
Image(filename="images/dii5.png")

# %%
Image(filename="images/dii6.png")

# %%
Image(filename="images/dii7.png")
