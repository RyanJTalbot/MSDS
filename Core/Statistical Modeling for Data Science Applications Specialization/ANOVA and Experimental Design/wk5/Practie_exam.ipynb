# %% [markdown]
# #### Multiple Choice Questions
#
# 1. **Which of the following statements is true about the difference between an experimental and observational study?**
#    - a) Researchers control the treatment in an observational study.
#    - b) A difference across sample means implies a difference across population means.
#    - c) Researchers control the treatment in an experimental study.
#
# 2. **What is the primary purpose of randomization in statistical inference?**
#    - a) To simplify data analysis.
#    - b) To assign treatments systematically to affect outcomes.
#    - c) To minimize systematic errors in treatment assignments.
#
# 3. **In the context of ANOVA, what is a 'factor'?**
#    - a) A continuous variable influencing the outcome.
#    - b) A discrete, categorical variable used to predict or explain the response variable.
#    - c) A constant value across all observations.
#
# 4. **What is a primary use of the ANCOVA model?**
#    - a) To adjust for several continuous variables correlated with the response.
#    - b) To analyze variance in one-way ANOVA.
#    - c) To apply post hoc comparisons across groups.
#
# 5. **In a one-way ANOVA model, if the p-value is very small, what does it indicate?**
#    - a) Small differences across group means.
#    - b) Significant differences in mean values across groups.
#    - c) No difference in variability within groups.
#
# #### True/False Questions
#
# 6. **The mean response in a one-way ANOVA effects model applies only to one level of a factor.**
#    - True / False
#
# 7. **Randomization in experimental design supports nonspuriousness.**
#    - True / False
#
# 8. **The intercept in a one-way ANOVA regression model represents the expected response in the control group.**
#    - True / False
#
# 9. **In a factorial design, a factor is considered nested if each level appears only within one level of another factor.**
#    - True / False
#
# 10. **One-Way ANOVA can be used to analyze results in a randomized complete block design.**
#     - True / False
#
# #### Short Answer Questions
#
# 11. **Explain the difference between a fixed-effects model and a random-effects model in ANOVA.**
#
# 12. **What is the main advantage of using ANCOVA over simple ANOVA in studies with continuous predictors?**
#
# 13. **Describe the function of post hoc comparisons in the context of ANOVA.**
#
# 14. **In the Tukey method, what does a positive test statistic indicate in post hoc comparisons?**
#
# 15. **Why is it essential to adjust the p-value when conducting multiple post hoc comparisons?**
#
# ---

# %% [markdown]
# ### Answer Key
#
# #### Multiple Choice Answers
# 1. **c)** Researchers control the treatment in an experimental study.
# 2. **c)** To minimize systematic errors in treatment assignments.
# 3. **b)** A discrete, categorical variable used to predict or explain the response variable.
# 4. **a)** To adjust for several continuous variables correlated with the response.
# 5. **b)** Significant differences in mean values across groups.
#
# #### True/False Answers
# 6. **True**
# 7. **True**
# 8. **True**
# 9. **True**
# 10. **False**
#
# #### Short Answer Keys
# 11. **Fixed-effects model** assumes levels of a factor are specific and exhaustive; **random-effects model** treats factor levels as a random sample from a larger population.
# 12. ANCOVA adjusts for continuous variables correlated with the response, enhancing the analysis by reducing error variance.
# 13. Post hoc comparisons determine specific group differences after an ANOVA indicates significant overall differences.
# 14. A positive test statistic in the Tukey method suggests a mean difference between groups.
# 15. Adjusting p-values in multiple comparisons controls the familywise error rate, reducing false positives.
#
# ---

# %% [markdown]
# ---
#
# #### Multiple Choice Questions
#
# 1. **Which of the following statements is true about the difference between an experimental and observational study?**
#    - a) Researchers control the treatment in an observational study.
#    - b) A difference across sample means implies a difference across population means.
#    - c) Researchers control the treatment in an experimental study.
#    - d) Observational studies yield more accurate causal inferences than experimental studies.
#
# 2. **What is the primary purpose of randomization in statistical inference?**
#    - a) To simplify data analysis.
#    - b) To assign treatments systematically to affect outcomes.
#    - c) To minimize systematic errors in treatment assignments.
#    - d) To ensure a larger sample size.
#
# 3. **In the context of ANOVA, what is a 'factor'?**
#    - a) A continuous variable influencing the outcome.
#    - b) A discrete, categorical variable used to predict or explain the response variable.
#    - c) A constant value across all observations.
#    - d) An independent variable that cannot change.
#
# 4. **What is a primary use of the ANCOVA model?**
#    - a) To adjust for several continuous variables correlated with the response.
#    - b) To analyze variance in one-way ANOVA.
#    - c) To apply post hoc comparisons across groups.
#    - d) To test for multicollinearity in regression models.
#
# 5. **In a one-way ANOVA model, if the p-value is very small, what does it indicate?**
#    - a) Small differences across group means.
#    - b) Significant differences in mean values across groups.
#    - c) No difference in variability within groups.
#    - d) High variability between group variances.
#
# 6. **Which assumption is crucial for performing a one-way ANOVA test?**
#    - a) Observations are not independent.
#    - b) Data is normally distributed within each group.
#    - c) Equal variances across groups are not necessary.
#    - d) Population sizes must be equal across groups.
#
# 7. **Which post hoc test is commonly used to control for familywise error rate in multiple comparisons after ANOVA?**
#    - a) Tukey’s HSD
#    - b) Welch’s Test
#    - c) Bonferroni Correction
#    - d) Kruskal-Wallis Test
#
# 8. **Which of the following describes the main goal of a randomized block design?**
#    - a) To reduce the variation between blocks.
#    - b) To reduce the variation within each treatment.
#    - c) To reduce the effect of confounding variables.
#    - d) To minimize the number of treatments.
#
# #### True/False Questions
#
# 9. **The mean response in a one-way ANOVA effects model applies only to one level of a factor.**
#    - True / False
#
# 10. **Randomization in experimental design supports nonspuriousness.**
#    - True / False
#
# 11. **The intercept in a one-way ANOVA regression model represents the expected response in the control group.**
#    - True / False
#
# 12. **In a factorial design, a factor is considered nested if each level appears only within one level of another factor.**
#    - True / False
#
# 13. **One-Way ANOVA can be used to analyze results in a randomized complete block design.**
#     - True / False
#
# 14. **A high F-ratio in an ANOVA analysis suggests that there is more variation between groups than within groups.**
#     - True / False
#
# 15. **If the p-value in ANOVA is above 0.05, we reject the null hypothesis of equal group means.**
#     - True / False
#
# #### Short Answer Questions
#
# 16. **Explain the difference between a fixed-effects model and a random-effects model in ANOVA.**
#
# 17. **What is the main advantage of using ANCOVA over simple ANOVA in studies with continuous predictors?**
#
# 18. **Describe the function of post hoc comparisons in the context of ANOVA.**
#
# 19. **In the Tukey method, what does a positive test statistic indicate in post hoc comparisons?**
#
# 20. **Why is it essential to adjust the p-value when conducting multiple post hoc comparisons?**
#
# 21. **What is the purpose of blocking in an experimental design, and how does it improve the validity of results?**
#
# 22. **In the context of ANOVA, explain what “homogeneity of variances” means and why it matters.**
#
# ---

# %% [markdown]
# ### Answer Key
#
# #### Multiple Choice Answers
#
# 1. **c)** Researchers control the treatment in an experimental study.
# 2. **c)** To minimize systematic errors in treatment assignments.
# 3. **b)** A discrete, categorical variable used to predict or explain the response variable.
# 4. **a)** To adjust for several continuous variables correlated with the response.
# 5. **b)** Significant differences in mean values across groups.
# 6. **b)** Data is normally distributed within each group.
# 7. **a)** Tukey’s HSD
# 8. **c)** To reduce the effect of confounding variables.
#
# #### True/False Answers
#
# 9. **True**
# 10. **True**
# 11. **True**
# 12. **True**
# 13. **False**
# 14. **True**
# 15. **False**
#
# #### Short Answer Keys
#
# 16. **Fixed-effects model** assumes levels of a factor are specific and exhaustive; **random-effects model** treats factor levels as a random sample from a larger population.
# 17. ANCOVA adjusts for continuous variables correlated with the response, enhancing the analysis by reducing error variance.
# 18. Post hoc comparisons determine specific group differences after an ANOVA indicates significant overall differences.
# 19. A positive test statistic in the Tukey method suggests a mean difference between groups.
# 20. Adjusting p-values in multiple comparisons controls the familywise error rate, reducing false positives.
# 21. **Blocking** helps control for variability from extraneous factors, thereby enhancing the precision of the main treatment effect estimates.
# 22. **Homogeneity of variances** means that the variance within each group is roughly equal, an assumption needed for ANOVA to yield accurate results.
