# %%
from IPython.display import Image
Image(filename="images/ANCOVAi1.png")

# %%
Image(filename="images/ANCOVAi2.png")

# %%
Image(filename="images/ANCOVAi3.png")

# %%
Image(filename="images/ANCOVAi4.png")
