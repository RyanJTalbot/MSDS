# %%
from IPython.display import Image
Image(filename="Images/Definitions4.png")

# %%
Image(filename="Images/Definitions1.png")

# %%
Image(filename="Images/Definitions2.png")

# %%
from IPython.display import Image
Image(filename="Images/Definitions3.png")
