# %%
from IPython.display import Image
Image(filename="Images/Conceptual1.png")

# %%
Image(filename="Images/Conceptual2.png")

# %%
Image(filename="Images/Conceptual3.png")

# %%
Image(filename="Images/Conceptual4.png")
