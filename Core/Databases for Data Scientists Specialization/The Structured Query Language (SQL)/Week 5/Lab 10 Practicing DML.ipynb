# %%
from IPython.display import Image
Image(filename="./Images/dml1.png")

# %%
Image(filename="./Images/dml2.png")

# %%
Image(filename="./Images/dml3.png")

# %% [markdown]
# ---

# %%
Image(filename="./Images/dmla1.png")

# %%
Image(filename="./Images/dmla2.png")

# %%
Image(filename="./Images/dmla3.png")
