# %%
from IPython.display import Image
Image(filename="./Images/ddl1.png")

# %%
Image(filename="./Images/ddl2.png")

# %%
Image(filename="./Images/ddla1.png")

# %%
Image(filename="./Images/ddla2.png")

# %%
Image(filename="./Images/ddla3.png")
