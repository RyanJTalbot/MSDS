# %%
from IPython.display import Image
Image(filename="./Images/mt1.png")

# %%
Image(filename="./Images/mt2.png")

# %%
Image(filename="./Images/mt3.png")

# %% [markdown]
# ---

# %%
Image(filename="./Images/mta1.png")

# %%
Image(filename="./Images/mta2.png")
