# %%
from IPython.display import Image
Image(filename="./Images/case1.png")

# %%
Image(filename="./Images/case2.png")

# %%
Image(filename="./Images/casea1.png")

# %%
Image(filename="./Images/casea2.png")
