# %%
from IPython.display import Image
Image(filename="./Images/sa1.png")

# %%
Image(filename="./Images/sa2.png")

# %%
Image(filename="./Images/sa3.png")

# %%
Image(filename="./Images/sa4.png")

# %%
Image(filename="./Images/sa5.png")

# %%
Image(filename="./Images/sa6.png")

# %%
Image(filename="./Images/sa7.png")

# %%
Image(filename="./Images/sa8.png")

# %%
Image(filename="./Images/sa9.png")
