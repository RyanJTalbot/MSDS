# %% [markdown]
# May I ask a silly question? Looked all the way up in the channel and still in a doubt... Please help :slightly_smiling_face: What exactly are we supposed to do in the Final project? What does this mean: "compose THREE distinct business/analytical problems conceptually similar to the problems presented in the Comprehensive SQL Lab"? Just THREE statements similar to those 14 query problems from week 6 (so that we need three queries with solution in total)? Sorry, maybe I am overthinking... but want to make sure that I get it right.
#
# yes your understanding is correct. We have to make three query problems
# similar in nature to the week 6 problems by ourselves, and provide the answers for them.
#
# Update: I was ok with pgadmin4/postgres but when needed to import ClassicModels database for the final project, I did not find Postgres dump to import. So I thought it was good reason to test MySQL as well. Everything works nice with MySQL and actually I think it is the way to go for this course because it makes it easier to complete the final locally as well.

# %%
from IPython import display
display.Image("../screen_shot_2022-03-17_at_10.33.57_am.png")

# %% [markdown]
# https://coursera-assessments.s3.amazonaws.com/assessments/1694745345252/03a2a6c9-8a47-4193-831f-b27717c86468/DTSA%205733%20Final%20Project%20Presentation.mp4
