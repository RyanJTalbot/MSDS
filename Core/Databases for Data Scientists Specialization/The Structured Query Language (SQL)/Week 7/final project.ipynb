# %% [markdown]
# At this point you have completed the Final Comprehensive SQL Lab.  This lab offered you the opportunity to demonstrate your understanding of various SQL commands and concepts, and apply these commands and concepts to the solution of  business/analytical problems.
#
# In this final project, you are asked to consider the “Classic Models” database which you utilized for the Final Comprehensive SQL Lab.
# - Then compose THREE distinct business/analytical problems conceptually similar to the problems presented in the Comprehensive SQL Lab.
# - State each problem as an analysis challenge which students must complete using SQL code against the Classic Models database.
# - After stating each of the three analytical problems, you are required to compose the SQL code necessary to solve the problem.
# - For each, you should capture BOTH the SQL code necessary to solve the problem, AND the SQL Answer Set containing the solution.
#
# - Finally, you must reflect on what you’ve learned during this SQL course.
#     - Based on this reflection please compose a paragraph describing how SQL provides a powerful tool for Data Analysts/Data Scientists to conduct data analytics.

# %% [markdown]
# 1. Top-Selling Products
# IIdentify the top 5 best-selling products across all product lines. Determine these by the total quantity ordered. Provide the product name and the total quantity sold for each.

# %%
from IPython.display import Image
Image(filename="Q1.png")

# %% [markdown]
# 2. Sales by Employee
# Challenge: Calculate the total sales for each sales representative within the company. Total sales should be represented by the sum of payments received from customers assigned to each representative. List the employee number, last name, and their total sales.

# %%
Image(filename="Q2.png")

# %% [markdown]
# 3. Orders and Their Status
# Challenge: List all orders with a status of 'Shipped', including the order number, order date, required date, and the number of different products ordered in each. Sort the results by order date.

# %%
Image(filename="Q3.png")

# %% [markdown]
# ---

# %% [markdown]
# compose a paragraph describing how SQL provides a powerful tool for Data Analysts/Data Scientists to conduct data analytics.

# %% [markdown]
# ---

# %% [markdown]
# Before taking this SQL course, I had no experience with SQL. But now, I've learned a lot about how SQL can help with data analysis. From basic stuff like selecting data to more advanced things like combining data from different tables, SQL has shown me how to manage and analyze data in powerful ways. It's given me the skills to handle complex datasets, do calculations, and find important patterns and trends. Overall, learning SQL has really expanded my ability to work with data. Throughout the course, I've also learned about various techniques like using dates, dealing with empty values, and grouping data to gain insights efficiently. SQL has become a valuable tool for data analysts and scientists, enabling them to extract meaningful information from diverse datasets and make informed decisions.
#
#
# SQL is a powerful tool for data analysts and scientists, making data analytics straightforward. It allows analysts to easily handle and query databases to extract valuable insights from complex datasets. SQL covers everything from basic tasks like filtering data to more advanced techniques like grouping and joining data from different sources. It can manage dates, handle empty values, and create summaries of data effortlessly. SQL's flexibility enables dynamic data manipulation and aggregation, helping analysts uncover actionable insights from diverse datasets. Overall, SQL simplifies the process of exploring, transforming, and deriving insights from data, making it an essential tool for informed decision-making.
