# %%
from IPython.display import Image
Image(filename="./Images/gf1.png")

# %%
Image(filename="./Images/gf2.png")

# %%
Image(filename="./Images/gf3.png")

# %%
Image(filename="./Images/gf4.png")

# %%
Image(filename="./Images/gf5.png")
