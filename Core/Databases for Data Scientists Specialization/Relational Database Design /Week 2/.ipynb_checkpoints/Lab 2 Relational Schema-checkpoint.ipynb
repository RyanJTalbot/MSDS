# %%
from IPython.display import Image

# %% [markdown]
# ### Relation 1
#
# Given the relation below, answer the questions:

# %%
Image(filename="./Screenshot 2023-03-04 at 20-18-38 Lab 2 Relational Schema Coursera.png")

# %% [markdown]
# ---

# %% [markdown]
# ### Relation 2
#
# For the following relation, answer the questions.

# %%
Image(filename="./Screenshot 2023-03-04 at 20-18-51 Lab 2 Relational Schema Coursera.png")
