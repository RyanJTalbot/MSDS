# %%
from IPython.display import Image

# %% [markdown]
# ## Relation 1
#
# Given the relation below, answer the questions:

# %%
Image(filename="./Screenshot 2023-03-04 at 20-10-47 Lab 1 Relations Coursera.png")

# %% [markdown]
# What is the name of the relation:
#
# What are the attributes of the relation:
#
# What are the tuples of the relation (pick one):
#
# What is the degree of the relation:
#
# What is the cardinality of the relation:
#
# What is the possible domain of attribute ID:
#
# What is the possible domain of attribute Name:
#
# What is the possible domain of attribute Major:
#
# What is the possible domain of attribute Quiz1 - 4:

# %% [markdown]
# Choose some super keys for this relation:
#
# If there is no duplicate name of people:
#
# What might be candidate keys?
#
# What might be the primary key?
#
# What might be the alternate key?

# %% [markdown]
# If there is no duplicate name of people in the same major, what might be candidate keys?
#
# What might be candidate keys?
#
# What might be the primary key?
#
# What might be the alternate key?

# %% [markdown]
# If there are duplicate names of people in the system, what might be candidate keys?
#
# What might be candidate keys?
#
# What might be the primary key?
#
# What might be the alternate key?

# %% [markdown]
# ----

# %% [markdown]
# ### Relation 2
#
# For the following relation, answer the questions.

# %%
Image(filename="./Screenshot 2023-03-04 at 20-11-05 Lab 1 Relations Coursera.png")

# %% [markdown]
# What is the name of the relation:
#
# What are the attributes of the relation:
#
# What are the tuples of the relation (pick one):
#
# What is the degree of the relation:
#
# What is the cardinality of the relation:
#
# What is the possible domain of attribute SKU:
#
# What is the possible domain of attribute Name:
#
# What is the possible domain of attribute VendorID:
#
# What is the possible domain of attribute Price:
#
# What is the possible domain of attribute Date:
#
# What is the possible domain of attribute Quantity:
#
# What is the possible domain of attribute Location:
#
# What is the possible domain of attribute Description:

# %% [markdown]
# Choose some super keys for this relation:
#
# What might be candidate keys?
#
# What might be the primary key?
#
# What might be the alternate key?
