# %%
from IPython.display import Image
Image(filename="./Images/np1.png")

# %%
Image(filename="./Images/np2.png")

# %%
Image(filename="./Images/np3.png")

# %%
Image(filename="./Images/npa1.png")

# %%
Image(filename="./Images/npa2.png")

# %%
Image(filename="./Images/npa3.png")

# %%
Image(filename="./Images/npa4.png")

# %%
Image(filename="./Images/npa5.png")

# %%
Image(filename="./Images/npa6.png")

# %%
Image(filename="./Images/npa7.png")

# %%
Image(filename="./Images/npa8.png")

# %%
Image(filename="./Images/npa9.png")
