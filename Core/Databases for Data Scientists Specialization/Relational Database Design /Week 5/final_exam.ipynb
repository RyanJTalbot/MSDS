# %% [markdown]
# There is just a final project to submit, which is just like one of the assignments. You are asked to
# - build a relational model from start to finish for some hypothetical business or company.
# - Entity Relationships -> ERD -> Final database design (in 3NF), that's all.
#
# - There is a little bit of extra work, in that you have to submit a 5-min presentation video explaining how you completed your project, and you are encouraged to show slides in the presentation, though this is not a hard rule. The expected time for completion of the final project is between 3 and 4 hours, but it is not a timed assignment.

# %%
from IPython import display
display.Image("images/f1.png")

# %%
display.Image("images/f2.png")

# %%
display.Image("images/f3.png")

# %%
display.Image("images/f4.png")

# %% [markdown]
# # Final
# ### Written Report
#
# 1. thnk carefully about the business, describe a clear background story of the business
# 2.  Make sufficient assumptions and create the ER model
# 3.  From teh ER model, create teh ERD
# 4.  Convert the ERD to a relational model
#
# ### Presentation
# - present project ot audience, as if you are going to lfook for investment
#
#
# review rubric
# - is the background story of the project clear to you
# - is the ER model clear to you
# - Is the ER model correctly represented
# - Is the relatonal model succesfully normalized to 3NF
# - final model - complete?
#
# - video presentatoin clearly explained the relational database
# - is video presentation interesting. mult. forms of information: text, images, videos, movement
# -

# %%
display.Image("images/fs1.png")

# %%
display.Image("images/fs2.png")

# %%
display.Image("images/fs3.png")
